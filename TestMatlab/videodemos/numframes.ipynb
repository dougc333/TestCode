# %%
import cv
import cv2

#find num frames in video2.avi
#somethign wrong with avi writes, macbook convert to .mov first
vc = cv2.VideoCapture('/Users/dc/TestCode/TestMatlab/videodemos/video2.mov')
(ret,frame) = vc.read()
numFrames = 0

while frame!=None:
    (ret,frame) = vc.read()
    print "numFrames: " , numFrames
    numFrames +=1
    
print 'done'
#total = 528+1 since we read one before starting while loop. We lost 1 frame in creating file
#bc we read one frame before starting read in videofile.avi
#
# Out:
# /Users/dc/venv/lib/python2.7/site-packages/ipykernel/__main__.py:10: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# numFrames:  0
# numFrames:  1
# numFrames:  2
# numFrames:  3
# numFrames:  4
# numFrames:  5
# numFrames:  6
# numFrames:  7
# numFrames:  8
# numFrames:  9
# numFrames:  10
# numFrames:  11
# numFrames:  12
# numFrames:  13
# numFrames:  14
# numFrames:  15
# numFrames:  16
# numFrames:  17
# numFrames:  18
# numFrames:  19
# numFrames:  20
# numFrames:  21
# numFrames:  22
# numFrames:  23
# numFrames:  24
# numFrames:  25
# numFrames:  26
# numFrames:  27
# numFrames:  28
# numFrames:  29
# numFrames:  30
# numFrames:  31
# numFrames:  32
# numFrames:  33
# numFrames:  34
# numFrames:  35
# numFrames:  36
# numFrames:  37
# numFrames:  38
# numFrames:  39
# numFrames:  40
# numFrames:  41
# numFrames:  42
# numFrames:  43
# numFrames:  44
# numFrames:  45
# numFrames:  46
# numFrames:  47
# numFrames:  48
# numFrames:  49
# numFrames:  50
# numFrames:  51
# numFrames:  52
# numFrames:  53
# numFrames:  54
# numFrames:  55
# numFrames:  56
# numFrames:  57
# numFrames:  58
# numFrames:  59
# numFrames:  60
# numFrames:  61
# numFrames:  62
# numFrames:  63
# numFrames:  64
# numFrames:  65
# numFrames:  66
# numFrames:  67
# numFrames:  68
# numFrames:  69
# numFrames:  70
# numFrames:  71
# numFrames:  72
# numFrames:  73
# numFrames:  74
# numFrames:  75
# numFrames:  76
# numFrames:  77
# numFrames:  78
# numFrames:  79
# numFrames:  80
# numFrames:  81
# numFrames:  82
# numFrames:  83
# numFrames:  84
# numFrames:  85
# numFrames:  86
# numFrames:  87
# numFrames:  88
# numFrames:  89
# numFrames:  90
# numFrames:  91
# numFrames:  92
# numFrames:  93
# numFrames:  94
# numFrames:  95
# numFrames:  96
# numFrames:  97
# numFrames:  98
# numFrames:  99
# numFrames:  100
# numFrames:  101
# numFrames:  102
# numFrames:  103
# numFrames:  104
# numFrames:  105
# numFrames:  106
# numFrames:  107
# numFrames:  108
# numFrames:  109
# numFrames:  110
# numFrames:  111
# numFrames:  112
# numFrames:  113
# numFrames:  114
# numFrames:  115
# numFrames:  116
# numFrames:  117
# numFrames:  118
# numFrames:  119
# numFrames:  120
# numFrames:  121
# numFrames:  122
# numFrames:  123
# numFrames:  124
# numFrames:  125
# numFrames:  126
# numFrames:  127
# numFrames:  128
# numFrames:  129
# numFrames:  130
# numFrames:  131
# numFrames:  132
# numFrames:  133
# numFrames:  134
# numFrames:  135
# numFrames:  136
# numFrames:  137
# numFrames:  138
# numFrames:  139
# numFrames:  140
# numFrames:  141
# numFrames:  142
# numFrames:  143
# numFrames:  144
# numFrames:  145
# numFrames:  146
# numFrames:  147
# numFrames:  148
# numFrames:  149
# numFrames:  150
# numFrames:  151
# numFrames:  152
# numFrames:  153
# numFrames:  154
# numFrames:  155
# numFrames:  156
# numFrames:  157
# numFrames:  158
# numFrames:  159
# numFrames:  160
# numFrames:  161
# numFrames:  162
# numFrames:  163
# numFrames:  164
# numFrames:  165
# numFrames:  166
# numFrames:  167
# numFrames:  168
# numFrames:  169
# numFrames:  170
# numFrames:  171
# numFrames:  172
# numFrames:  173
# numFrames:  174
# numFrames:  175
# numFrames:  176
# numFrames:  177
# numFrames:  178
# numFrames:  179
# numFrames:  180
# numFrames:  181
# numFrames:  182
# numFrames:  183
# numFrames:  184
# numFrames:  185
# numFrames:  186
# numFrames:  187
# numFrames:  188
# numFrames:  189
# numFrames:  190
# numFrames:  191
# numFrames:  192
# numFrames:  193
# numFrames:  194
# numFrames:  195
# numFrames:  196
# numFrames:  197
# numFrames:  198
# numFrames:  199
# numFrames:  200
# numFrames:  201
# numFrames:  202
# numFrames:  203
# numFrames:  204
# numFrames:  205
# numFrames:  206
# numFrames:  207
# numFrames:  208
# numFrames:  209
# numFrames:  210
# numFrames:  211
# numFrames:  212
# numFrames:  213
# numFrames:  214
# numFrames:  215
# numFrames:  216
# numFrames:  217
# numFrames:  218
# numFrames:  219
# numFrames:  220
# numFrames:  221
# numFrames:  222
# numFrames:  223
# numFrames:  224
# numFrames:  225
# numFrames:  226
# numFrames:  227
# numFrames:  228
# numFrames:  229
# numFrames:  230
# numFrames:  231
# numFrames:  232
# numFrames:  233
# numFrames:  234
# numFrames:  235
# numFrames:  236
# numFrames:  237
# numFrames:  238
# numFrames:  239
# numFrames:  240
# numFrames:  241
# numFrames:  242
# numFrames:  243
# numFrames:  244
# numFrames:  245
# numFrames:  246
# numFrames:  247
# numFrames:  248
# numFrames:  249
# numFrames:  250
# numFrames:  251
# numFrames:  252
# numFrames:  253
# numFrames:  254
# numFrames:  255
# numFrames:  256
# numFrames:  257
# numFrames:  258
# numFrames:  259
# numFrames:  260
# numFrames:  261
# numFrames:  262
# numFrames:  263
# numFrames:  264
# numFrames:  265
# numFrames:  266
# numFrames:  267
# numFrames:  268
# numFrames:  269
# numFrames:  270
# numFrames:  271
# numFrames:  272
# numFrames:  273
# numFrames:  274
# numFrames:  275
# numFrames:  276
# numFrames:  277
# numFrames:  278
# numFrames:  279
# numFrames:  280
# numFrames:  281
# numFrames:  282
# numFrames:  283
# numFrames:  284
# numFrames:  285
# numFrames:  286
# numFrames:  287
# numFrames:  288
# numFrames:  289
# numFrames:  290
# numFrames:  291
# numFrames:  292
# numFrames:  293
# numFrames:  294
# numFrames:  295
# numFrames:  296
# numFrames:  297
# numFrames:  298
# numFrames:  299
# numFrames:  300
# numFrames:  301
# numFrames:  302
# numFrames:  303
# numFrames:  304
# numFrames:  305
# numFrames:  306
# numFrames:  307
# numFrames:  308
# numFrames:  309
# numFrames:  310
# numFrames:  311
# numFrames:  312
# numFrames:  313
# numFrames:  314
# numFrames:  315
# numFrames:  316
# numFrames:  317
# numFrames:  318
# numFrames:  319
# numFrames:  320
# numFrames:  321
# numFrames:  322
# numFrames:  323
# numFrames:  324
# numFrames:  325
# numFrames:  326
# numFrames:  327
# numFrames:  328
# numFrames:  329
# numFrames:  330
# numFrames:  331
# numFrames:  332
# numFrames:  333
# numFrames:  334
# numFrames:  335
# numFrames:  336
# numFrames:  337
# numFrames:  338
# numFrames:  339
# numFrames:  340
# numFrames:  341
# numFrames:  342
# numFrames:  343
# numFrames:  344
# numFrames:  345
# numFrames:  346
# numFrames:  347
# numFrames:  348
# numFrames:  349
# numFrames:  350
# numFrames:  351
# numFrames:  352
# numFrames:  353
# numFrames:  354
# numFrames:  355
# numFrames:  356
# numFrames:  357
# numFrames:  358
# numFrames:  359
# numFrames:  360
# numFrames:  361
# numFrames:  362
# numFrames:  363
# numFrames:  364
# numFrames:  365
# numFrames:  366
# numFrames:  367
# numFrames:  368
# numFrames:  369
# numFrames:  370
# numFrames:  371
# numFrames:  372
# numFrames:  373
# numFrames:  374
# numFrames:  375
# numFrames:  376
# numFrames:  377
# numFrames:  378
# numFrames:  379
# numFrames:  380
# numFrames:  381
# numFrames:  382
# numFrames:  383
# numFrames:  384
# numFrames:  385
# numFrames:  386
# numFrames:  387
# numFrames:  388
# numFrames:  389
# numFrames:  390
# numFrames:  391
# numFrames:  392
# numFrames:  393
# numFrames:  394
# numFrames:  395
# numFrames:  396
# numFrames:  397
# numFrames:  398
# numFrames:  399
# numFrames:  400
# numFrames:  401
# numFrames:  402
# numFrames:  403
# numFrames:  404
# numFrames:  405
# numFrames:  406
# numFrames:  407
# numFrames:  408
# numFrames:  409
# numFrames:  410
# numFrames:  411
# numFrames:  412
# numFrames:  413
# numFrames:  414
# numFrames:  415
# numFrames:  416
# numFrames:  417
# numFrames:  418
# numFrames:  419
# numFrames:  420
# numFrames:  421
# numFrames:  422
# numFrames:  423
# numFrames:  424
# numFrames:  425
# numFrames:  426
# numFrames:  427
# numFrames:  428
# numFrames:  429
# numFrames:  430
# numFrames:  431
# numFrames:  432
# numFrames:  433
# numFrames:  434
# numFrames:  435
# numFrames:  436
# numFrames:  437
# numFrames:  438
# numFrames:  439
# numFrames:  440
# numFrames:  441
# numFrames:  442
# numFrames:  443
# numFrames:  444
# numFrames:  445
# numFrames:  446
# numFrames:  447
# numFrames:  448
# numFrames:  449
# numFrames:  450
# numFrames:  451
# numFrames:  452
# numFrames:  453
# numFrames:  454
# numFrames:  455
# numFrames:  456
# numFrames:  457
# numFrames:  458
# numFrames:  459
# numFrames:  460
# numFrames:  461
# numFrames:  462
# numFrames:  463
# numFrames:  464
# numFrames:  465
# numFrames:  466
# numFrames:  467
# numFrames:  468
# numFrames:  469
# numFrames:  470
# numFrames:  471
# numFrames:  472
# numFrames:  473
# numFrames:  474
# numFrames:  475
# numFrames:  476
# numFrames:  477
# numFrames:  478
# numFrames:  479
# numFrames:  480
# numFrames:  481
# numFrames:  482
# numFrames:  483
# numFrames:  484
# numFrames:  485
# numFrames:  486
# numFrames:  487
# numFrames:  488
# numFrames:  489
# numFrames:  490
# numFrames:  491
# numFrames:  492
# numFrames:  493
# numFrames:  494
# numFrames:  495
# numFrames:  496
# numFrames:  497
# numFrames:  498
# numFrames:  499
# numFrames:  500
# numFrames:  501
# numFrames:  502
# numFrames:  503
# numFrames:  504
# numFrames:  505
# numFrames:  506
# numFrames:  507
# numFrames:  508
# numFrames:  509
# numFrames:  510
# numFrames:  511
# numFrames:  512
# numFrames:  513
# numFrames:  514
# numFrames:  515
# numFrames:  516
# numFrames:  517
# numFrames:  518
# numFrames:  519
# numFrames:  520
# numFrames:  521
# numFrames:  522
# numFrames:  523
# numFrames:  524
# numFrames:  525
# numFrames:  526
# numFrames:  527
# numFrames:  528
# done
