# %% [markdown]
# <img src="images/pa1_quiz_1.png" >
# <img src="images/pa1_quiz_2.png" >
# local
# <img src="images/pa1_quiz_3.png" >
# we want common substring between the 2 sequences; much smaller sequence part of reference.
# <img src="images/pa1_quiz_4.png" >
# definition:
# 0 0 0 0       ;gap open penalty for A, gap extension for A, open for B, extend B
# from durbin d is gap open penalty and e is gp extension penalty
# x is the first sequence, y is the second sequence from durbin.pdf
# 0.7=open gap penalty for A or x is dx
# 0.1 = extension penalty for sequnece A is ex
# 1.5 = open gap penalty for B or y is dy
# 0.5 = extension penalty for sequence B or y. is ey
# durbin d is the open gap penalty, e is the gap extension penalty.
# highest 1.5 dy
# 0.7 dx
# 0.5 ey
# 0.1 ex
# or dy, dx, ey, ex
# <img src="images/pa1_quiz_5.png" >
# opening a gap is always higher than extension so dx>ex and ex>ey. The second sequence is DNA. The open gap penalty for DNA higher bc harder to get gap bc double helix structure of DNA compared
# to RNA. Second sequence is DNA.  RNA is first sequence. (verified)
# <img src="images/pa1_quiz_6.png" >
# 3
# <img src="images/pa1_quiz_7.png" >
# no
# <img src="images/pa1_quiz_8.png" >
# not compared to the energy difference of a gap. Mismatch penalty is relative to task. IF there is a higher probability
# of a gap after a UT match then we can add a penalty. No mismatch penalty means gaps are equally probable for all matches.
# <img src="images/pa1_quiz_9.png" >
# 2136
# <img src="images/pa1_quiz_10.png" >
# <img src="images/pa1_quiz_11.png" >

# %% [markdown]
# <h6>Q2</h6>
# homologs -
# orthologs -
# paralogs -
# <img src="images/pa1_quiz_12.png" >
# global
# <img src="images/pa1_quiz_13.png" >
# compare structural or functional annotations. Homology metrics require a score identity and similarity for helping to determine homology.
# <img src="images/pa1_quiz_14.png" >
# Average number of mismatches per alignment: 82.50
# Average number of gaps per alignment: 20.67
# Average length of gaps (this is the average of all averages): 1.50
# ('avg_mis:', 82.5, 'avg_num_gaps:', 20.666666666666668, ' avg_gap_len:', 1.504387814229314)
# <img src="images/pa1_quiz_15.png" >
# human-chimp:2016.0
# human-turtle:1787.0
# human-mouse:1953.0
# <img src="images/pa1_quiz_16.png" >
# 2016.0
# <img src="images/pa1_quiz_17.png" >
# turtle
# <img src="images/pa1_quiz_18.png" >
# 1787.0
# <img src="images/pa1_quiz_19.png" >
# <img src="images/pa1_quiz_20.png" >
# <img src="images/pa1_quiz_21.png" >

# %% [markdown]
# <h6>Q3</h6>
#
#
# <img src="images/pa1_quiz_22.png" >
# local, this https://prosite.expasy.org/cgi-bin/prosite/nicedoc.pl?PDOC50020 says you find a conserved core;
#     how many do you need for a conserved core? align each one globally to find the conserved core. Does align_length find the conserved
#     core number? protein domains can be annotated for structural and functional similarity across species.
#
# <img src="images/pa1_quiz_23.png" >
# assuming domain is a subsequence of protein, find particular domain in protein. protein domains are conserved core:v
#     so this is global.
# <img src="images/pa1_quiz_24.png" >
# wrong, this is done w local: albumin:582.0, ets:345.0, sh2:367.0, trypsin:367.0, ubx:306.0, albumin
# global: trypsin
# <img src="images/pa1_quiz_25.png" >
# 194 global trypsin:1227.0
# trypsin is enzyme to cleace proteins
# <img src="images/pa1_quiz_26.png" >
# <img src="images/pa1_quiz_27.png" >

# %% [markdown]
# <h6><Q4/h6>
# <img src="images/pa1_quiz_28.png" >
# 1578.0
# <img src="images/pa1_quiz_29.png" >
# less, ancestor was much higher up between bacteria and people. What are the other differences between
# gaps or ...?
# <img src="images/pa1_quiz_30.png" >
# <img src="images/pa1_quiz_31.png" >
# <img src="images/pa1_quiz_32.png" >
# <img src="images/pa1_quiz_33.png" >
# Average number of gaps per alignment: 16.75
# Average length of gaps (this is the average of all averages): 1.47
# Average number of mismatches per alignment: 65.25
# open gap 5:
# Average number of gaps per alignment: 5.00
# Average length of gaps (this is the average of all averages): 2.20
# Average number of mismatches per alignment: 75.00
# open gap 0.5:
# Average number of gaps per alignment: 19.00
# Average length of gaps (this is the average of all averages): 1.35
# Average number of mismatches per alignment: 64.67
#     <h6>fewer gaps and more mismatches</h6>
# <img src="images/pa1_quiz_34.png" >
# same mismatches, little less but more gaps
# <img src="images/pa1_quiz_36.png" >
# <img src="images/pa1_quiz_37.png" >
# PAM is based on gold standard manually aligned which perservs physical accuracy but does not mean it is optimal
# for alignment accuracy. Would expect PAM40 to be worse than PAM250 since there are less values and using teh default
# of match=1 and mismatch=-1 is clearly not accurate as given by the entries in blosum62.
# <img src="images/pa1_quiz_38.png" >
# <img src="images/pa1_quiz_39.png" >
