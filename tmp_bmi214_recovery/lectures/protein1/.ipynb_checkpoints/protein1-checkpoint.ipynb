# %%
<img src="images/p1.png">
The native structure or natural state is the lowest energy state of the protein. 
<img src="images/p2.png">
There are 2 research problems 1) predict protein structure where given a AA sequence we perdict the 3d shape.  30k genes in human genome, each one codes a different
protein. We can look at other easier to study organisms and get clues on protein structure/gene pairs. 2 the inverse problem
is given a 3d structure how to predict the AA sequence? Sidechains? The difference is we dont start with a structure in nature
we have a design goal for a synthentic protein and we would like to go backwards. 
<img src="images/p3.png">
both of the above problems going from AA to 3d and synthetic 3d to AA sequecnce are difficult. For each AA there are many
rotatable bonds as seen below. Each AA has 3 different rotations. If you have 100 AA then you have 3 rotations for 
first AA then 3 for the second one, etc.. SO the number of possibilities is 3*3*3.... 100 times 3^100. The number of confirmations
is 3^# of residues. The other problem going from structure to number of sequences is hard, each can be 20AA. 20^#res. The third problem
is we have to find the minimum energy. These are surrounded by water atoms. Hard. To search through the possible conformations
for a 3d struct we iterate through the possible conformations. (movie). Teh second problem of finding the number of sequences
we use a Monte Carlo search. 
<img src="images/p4.png">
we do a montecarlo search by randomly adding side chains and we acccept the sequence if the energy is lower. 
<img src="images/p5.png">
they model 5 interactions to determine energy. 
<img src="images/p6.png">
summary again, 1) first problem is the first blue arrow going from AA sequence to 3d structure and the lower
blue arrow is 2) going from desired configuration to AA sequence. 
<p></p>
Different proteins found in nature, 1) globular protein alpha helix and beta sheets come together and
from spherical structure and the hydrophobic AAs are buried in the interior of the sphere. This burial in 
the interior is what stabilises the protein. 2)helical structure to form long chain this is called channel
protein, 3)AA module is repeated over and over again to form a long filament ,4) protein held together w disulfide
bonds shown in yellow. He is going to cover attempts to design these 4 examples of proteins. 
<img src="images/p7.png">
design flow of 2 cases. Examples that follow start w/structure, use rosetta to find AA sequecne, backcode to DNA, 
make and test. 
<img src="images/p8.png">
globular example, wow. they run this using rosetta@home volunteers donating computer time. And the lowest energy state on
left is final solution but there are many local minima. The search space doesnt converge automatically to a convex global. 
new student goes into his lab and can make new proteins! holy shit. 
<img src="images/p9.png">
Can make larger structures
<img src="images/p10.png">
this is one he made of 80AA linear type not globular. Teh design protein can be more stable than naturally occurring
proteins. He sent to grad student to denature by adding guandidne at 7m and got plot on left. Dont see this in nature
this stable of a protein. 
<img src="images/p11.png">
repeat protein. can make things with these because of structural properties. 
<img src="images/p12.png">
disulfide proteins very small and easy to make. Can be class of theraputics. Very small and easy ot make. 
<img src="images/p13.png">
we can design new functions. 
<img src="images/p14.png">
lowest energy state using rosetta. 
<img src="images/p15.png">
protein design is where we keep the backbone fixed and we search the different combinations of AA for the lowest
energy state. 
<img src="images/p16.png">
shows map of influenza virus and hemiglutin binding region. The hemiglutein regions are conserved; these regions
dont change because they are critical to the functioning and survival of the virus. There is a stem site which is 
conserved and a receptor site. The RS is how the virus gets into our bodies. You can design a protein which binds
to the yellow regions and blocks the virus from getting into our cells. They have designed proteins which bind
at teh stem and receptor site but only talks about stem site. 
<img src="images/p17.png">
2 steps. blow up of stem region. First step is to design AA side chain which fits into the groove in stem region. 

<img src="images/p18.png">
the ribbon holds the sidechains against the virus. The red areas are negatively chaged and he is putting a red
sidechain to electrostaticaly bind the 2 together. 
<img src="images/p19.png">
when he does the designs only a fraction actually fold up into structures. here are 2. you still have to test many 
many different designs to get one that works. 
<img src="images/p20.png">
<img src="images/p21.png">
can design denovo to design proteins to stick to cancer cells or to attract medicines to stick to cancer cells
use protein to design small molecules. digoxigen small molecule for heart. if you get too much of it you can die. so
you can design protein to soak up the excess. teh green is hydrodgen binding interactions. 
<img src="images/p22.png">
