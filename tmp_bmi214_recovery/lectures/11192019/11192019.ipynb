# %% [markdown]
# <img src="11192019_01.png">
# Simplest hypothesis was single gene creates single protein. Another step up in complexity is
# to think of phenotypes and how to break down the larger concept of an observable phenotype.
#
# monogenic: one gene causes observable problem like cystic fibrosis, if you have 2 bad copies of CFTR gene.
#
# CFTR receptor lets salts and fluids flow in/out of cell. Most traits are polygenic. Where you have a continuous
# spectrum of observables and some set of genes associated with this. height is polygenic, multiple
# genes for hieght. MOst extreme is omigenic where most of genes lead to some characteristic like height.
# Wow. Thousands of genes will lead to a phenotype of say diabetes.
#
#
#
# <img src="11192019_02.png">

# %% [markdown]
# benefits of networks, more data, and components are connected. interacting a protein to other proteins or components.
# nework representation can then use common tools to problems. Flexible. understand data drawbacks. for example data can
# be wrong in certain assays. have to understnd false positives and false negatives. also incomplete so have to underdsand
# this part.
# <img src="11192019_3.png">

# %% [markdown]
# Different types of networks, undirected=2 nodes connectd w/edge , directed=diretion on edge, cyclic; network w/cyccle,
# DAG: directed networks wo cycle, acyclic no cycle, cyclic has cycle, weighted: edge has quantative value, self-loops: node to iteself like
# in debruijn lecture. complete network: nodes connected w/all edges. homogeneous:1 node and edge types nonhomo: many node types
# and edge types. heteregenous network: bipartite graph, where there are 2 sets of nodes and set of edges conneting all nodes
# to each other, knowledge graph: eneities and directed edges and the edges qualify by some semantic meaning, different
# edge types are binds or relationships and nodes are entity.
# <img src="11192019_04.png">
# <img src="11192019_05.png">
# definition of graph, set of vertices and edges, each edge is a set of vertices. one representation is adjacency matrix another is adj list.
# sparsity is number of 0s; the most sparse is nothing, no edges and no nodes. Usually we mean there are N edges and dense
# approaching n squared edges. not hard definition. Sparse=use edge or edge list. of dense use adj matrix.
# <img src="11192019_06.png">
# Local: subgraph can take out some nodes and edges from complete graph. anything is subgraph of graph.
# clique: is comlete subgraph. The whole neteowrk is s clique. ??? uncelar. waht is maximan clique? network motif:
# see a lot of little house shapes. maybe this means a regulatory mechanism. motif is a subgraph which occurs
# frequently enough it is important for your problem.
# <img src="11192019_07.png">
# quantifying networks:
# conected components, 2 connected components
#     degee how many neighbors does node have?
#     if network is directed, talk about in indegrees and outdegrees.
#     look at degree distribution of network together using histogram. one things you see in bio network
#     is on log log sale, see a staircase linear in log log space. this is called a power law distribution.
#     if you see this then this is a scale free network. why did he make big deal about htis? this is small world.
#     or network is small diameter. For a network you can compute shortest path. YOu can comptue how to get between networks
#     in shortest way. diameter = longest shortest path. small world phenomana means there is root node where you can go
#     and transmit information efficiently. for bio network. small world is diameter is low. ?? not clear.
#
#
# <img src="11192019_08.png">
# 2) stable, if you take out node, nodes are vunlerable to targeteed attacks.
# clustering coefficient: refers to sparsity of node.
# Clustering coefficient between 0-1
# <img src="11192019_09.png">
# bwtweeness: if you have to get to another node you have to go through a certain node. [0,1]
# how do you know if these stats are significant. if you do hypothesis you need a random model and compare vs. this.
#
# <img src="11192019_10.png">
# network databases, molecular biology.
# 1) regulatory nework. transcription factors and how genes are being transcribed for translation. a protein D
# which can inhibit the TF A from binding to DNA. D blocks A from notation. TransFAC has this info.
# 2) metabolic network, representation of metabolites. how metabolies are alterted. metabolites are catalyzed by
# enzymes. a, b, care metabolines in diamond. The circle A and B are enzyme. We can model efect of enzymes on pathway.
# undirected weighted or unweighed graph. KEGG database. a,b,c are small molecules.
#
# <img src="11192019_11.png">
# 3) signalling netowrk. cell membraine with receptor. Have ligand that binds to receptor and hwen it binds teh receptor
# undergoes a conformational change which will activaet a proteein which will activate a TF and maybe activates a gene.
# unweighted. KEGG has this information.
# <img src="11192019_12.png">
# 4) protein protein interaction. historrcally about proteins physically binding together. The edge is proitens
# binding together. STRING database for protein protein. the original intention was physical pbinding. STRING contais
# experimental data, co-expression, text mining. and other smaller knowledge bases.
# 5) funcitonal co-expression networks. model correlation of network. .9 and .8 spearman correlation. and .5
# <img src="11192019_13.png">
# drugbank how to relate to target as birpartite network. ParmGKB database of drugs how it is processed by doby
# and genetic variants.
# <img src="11192019_14.png">
# how to build your own database? 1) join the differenet networks togetner,
# 2) crate network node by node. expression data w 4 genes, across different samples. want a network, use KNN which
# has most similar expression profile? directed network. individual genes and see how htey are related to each htoer
# 3) edge by edge network construction. build Knowledge graph from literature, a PPI network. If I can qualify
# the network for protein protein interaction. If we can browse the papers and extract from papers and build a network
#  from teh papers. will miss a lot of things but will have some information. Use NLP.
# <img src="11192019_15.png">
# pipeline for doing this. NER to get terms or entities like SL2, EGFR, PLCgamma,
# Normalize:map the entities back to ontology
# exract relations: bind
# extract event: event is PLCGamma1 that sees binds and the EGFR is the receiver of hte action. exracted a triples
#     which is 2 nodes and edge. ONce you ahve big set of tribpes you can creat network. BMI 210. is about these ontologies~~
#
# <img src="11192019_16.png">
# task1: community detection, unsupervised clsutering, identify network communities. peripheral blood mononuclear cells,
# have scRNA data. want to knowif there are communities involved in RNAseq data? build network from RNASeq data!!
# really!! using KNN. apply louvain clustring!! modularity: how good is our clustering, quantifies density of links
# inside vs outside community.
# <img src="11192019_17.png">
# algo: hierarchial clustering, initi one node=one community.2) for each i cancluate deltaQ or change in modularity
#     if I move i into cj. j is neignbor. Calculate deltaQ for all possible neighbors. 3) make a community level network
#     4) go to step 2 until convergence.
# <img src="11192019_18.png">
# example of community level network. make super nodes which contain communities there is edge betwen AB but not
# between B and C. So create hierarchial community. Didnt have to specify k. Converges.
# <img src="11192019_19.png">
# task2: node classification, give me functionally related nodes, guilt by association, iterative diffusion process
# input: list of query label genes. Konw a few genes want ot infer using guilt by association idea. output: labels. wamt
#         to infer what rest of genes do.
# <img src="11192019_20.png">
# algorithm:
# 1) init first iteration predictive labels based on labels you have. query genes have label 1 everything is 0.
# 2) update: update with (1-lambda)y + lambdaSum(wijfj)
# weights from edges. calso calle lable propagation. Genemania implements this!!!
#
#
# <img src="11192019_21.png">
# task3: network alignment. 2 networks want to find correspondence between node and network. yeast network and human
#     gene netrowk. if we know the red lines are homologous proteins we are done. to do this munk. apply node embedding
#     try ot find mapping between nodes and some space.
# <img src="11192019_22.png">
# red network is yeast, black is human, they line up in embedding space.representing nodes as vectors or embeddings.
#
# q) how do you build the embeddings?
#
# <img src="11192019_23.png">
# link prediction: didnt talke about. 2 nodes shouhd have links between them.
# <img src="11192019_24.png">
#
# <img src="11192019_25.png">
# <img src="11192019_26.png">
# <img src="11192019_27.png">
# <img src="11192019_28.png">
# <img src="11192019_29.png">
