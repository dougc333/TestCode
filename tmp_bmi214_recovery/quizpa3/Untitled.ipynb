# %% [markdown]
# <img src="quizpa3_1.png">
# <img src="quizpa3_2.png">
# <img src="quizpa3_3.png">
# <img src="quizpa3_4.png">
# foward biased: faster for coarse implemenation. Not optimal search space. Could be that the fragment beyond
#     the topN combined with other fragments would be a better fit in terms of side chains beyond what we are measuring, the
#     phi and psi angles.
# <img src="quizpa3_5.png">

# %% [markdown]
# <img src="quizpa3_6.png">
# <img src="quizpa3_7.png">
# <img src="quizpa3_8.png">
# <img src="quizpa3_9.png">
# <img src="quizpa3_10.png">

# %% [markdown]
# <img src="quizpa3_11.png">
# <img src="quizpa3_12.png">
# <img src="quizpa3_13.png">
# <img src="quizpa3_14.png">
# <img src="quizpa3_15.png">

# %% [markdown]
# <img src="quizpa3_16.png">
# <img src="quizpa3_17.png">
# <img src="quizpa3_18.png">
# <img src="quizpa3_19.png">
# <img src="quizpa3_20.png">

# %% [markdown]
# <img src="quizpa3_20.png">
# <img src="quizpa3_21.png">
# <img src="quizpa3_22.png">
# <img src="quizpa3_23.png">
# <img src="quizpa3_24.png">
# <img src="quizpa3_25.png">

# %%
fw4=[9.597481143792033,9.82467744696882,12.660167199332047,8.244989068583283,11.510576680261561,8.754099006468977,9.991480188318553,
     9.998484836289157,8.520094227886455,11.130919404636751]
import numpy as np
print(np.mean(fw4))
print(min(fw4))
print(np.std(fw4))
# Out:
# 10.023296920253765
# 8.244989068583283
# 1.3284265402997728

# %%
ubq=[13.615903166283708,16.162528371502738,13.951979935351329,12.740384821947654,13.711019627015322,13.443126014032968,
     14.614644512795955,16.454330935154786,14.015771498451628,14.673742996707102]
print(np.mean(ubq))
print(min(ubq))
print(np.std(ubq))
# Out:
# 14.338343187924318
# 12.740384821947654
# 1.1188189936190016

# %%
clean_fh =  open("../pa3/student_files/starter_code/logdir_anneal1/clean_sim1log_temp1.txt","w")
with open("../pa3/student_files/starter_code/logdir_anneal1/sim1log_temp1.txt","r") as fh:
    lines = fh.readlines()
    for l in lines:
        print(l.split())
        if len(l.split())==6:
            new_line = l.split()[0]+"\t" +  l.split()[1] +"\t"+ old
            print("new_line:",new_line)
            clean_fh.write(new_line+"\n")
        else:
            old = l.split()[2]
            print("updating old to:",l.split()[2])
            clean_fh.write(l)
    clean_fh.close()
fh.close()
# Out:
# ['0', '100', '293.7583477479407']
# updating old to: 293.7583477479407
# ['1', '99.9', '282.2874323533586']
# updating old to: 282.2874323533586
# ['2', '99.8001', '283.3453261674381']
# updating old to: 283.3453261674381
# ['3', '99.7002999', '281.1812480115346']
# updating old to: 281.1812480115346
# ['4', '99.60059960010001', '280.1096475707494']
# updating old to: 280.1096475707494
# ['5', '99.50099900049992', '249.94840820139677']
# updating old to: 249.94840820139677
# ['6', '99.40149800149942', '181.93630781135573']
# updating old to: 181.93630781135573
# ['7', '99.30209650349792', '167.18557746719094']
# updating old to: 167.18557746719094
# ['8', '99.20279440699443', '185.19029719686654']
# updating old to: 185.19029719686654
# ['9', '99.10359161258744', '176.6865194634114']
# updating old to: 176.6865194634114
# ['10', '99.00448802097485', '176.56631654310155']
# updating old to: 176.56631654310155
# ['11', '98.90548353295387', '176.31557347173205']
# ...

# %%
clean_fh =  open("../pa3/student_files/starter_code/logdir_anneal1/clean_sim1log_temp2.txt","w")
with open("../pa3/student_files/starter_code/logdir_anneal1/sim1log_temp2.txt","r") as fh:
    lines = fh.readlines()
    for l in lines:
        print(l.split())
        if len(l.split())==6:
            new_line = l.split()[0]+"\t" +  l.split()[1] +"\t"+ old
            print("new_line:",new_line)
            clean_fh.write(new_line+"\n")
        else:
            old = l.split()[2]
            print("updating old to:",l.split()[2])
            clean_fh.write(l)
    clean_fh.close()
fh.close()
# Out:
# ['0', '100', '252.32593580082607']
# updating old to: 252.32593580082607
# ['1', '99.0', '270.9919290676105']
# updating old to: 270.9919290676105
# ['2', '98.01', '239.80453409597703']
# updating old to: 239.80453409597703
# ['3', '97.0299', '237.8069163811973']
# updating old to: 237.8069163811973
# ['4', '96.059601', '242.90488075942747']
# updating old to: 242.90488075942747
# ['5', '95.09900499', '242.63754223013723']
# updating old to: 242.63754223013723
# ['6', '94.1480149401', '246.38793092189007']
# updating old to: 246.38793092189007
# ['7', '93.206534790699', '248.27969839069377']
# updating old to: 248.27969839069377
# ['8', '92.27446944279201', '219.8440657905299']
# updating old to: 219.8440657905299
# ['9', '91.35172474836409', '175.9608294534026']
# updating old to: 175.9608294534026
# ['10', '90.43820750088045', '176.46379336048318']
# updating old to: 176.46379336048318
# ['11', '89.53382542587164', '151.11560738147858']
# updating old to: 151.11560738147858
# ...

# %%
clean_fh =  open("../pa3/student_files/starter_code/logdir_anneal1/clean_sim1log_temp3.txt","w")
with open("../pa3/student_files/starter_code/logdir_anneal1/sim1log_temp3.txt","r") as fh:
    lines = fh.readlines()
    for l in lines:
        print(l.split())
        if len(l.split())==6:
            new_line = l.split()[0]+"\t" +  l.split()[1] +"\t"+ old
            print("new_line:",new_line)
            clean_fh.write(new_line+"\n")
        else:
            old = l.split()[2]
            print("updating old to:",l.split()[2])
            clean_fh.write(l)
    clean_fh.close()
fh.close()
# Out:
# ['0', '100', '290.97895189901396']
# updating old to: 290.97895189901396
# ['1', '90.0', '235.34492400791342']
# updating old to: 235.34492400791342
# ['2', '81.0', '233.12696422518331']
# updating old to: 233.12696422518331
# ['3', '72.9', '229.02176768640493']
# updating old to: 229.02176768640493
# ['4', '65.61000000000001', '222.58717698844305']
# updating old to: 222.58717698844305
# ['5', '59.049000000000014', '224.7568793018599']
# updating old to: 224.7568793018599
# ['6', '53.144100000000016', '226.72600325851184']
# updating old to: 226.72600325851184
# ['7', '47.829690000000014', '227.4699004926135']
# updating old to: 227.4699004926135
# ['8', '43.04672100000001', '217.3515823373468']
# updating old to: 217.3515823373468
# ['9', '38.742048900000015', '216.64146129749673']
# updating old to: 216.64146129749673
# ['10', '34.86784401000001', '165.5088665650271']
# updating old to: 165.5088665650271
# ['11', '31.381059609000012', '163.8933428505075']
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

#os.getcwd()
df1 = pd.read_csv("../pa3/student_files/starter_code/logdir_anneal1/clean_sim1log_temp1.txt","\t",header=None)
df2 = pd.read_csv("../pa3/student_files/starter_code/logdir_anneal1/sim1log_temp2.txt","\t",header=None)
df3 = pd.read_csv("../pa3/student_files/starter_code/logdir_anneal1/sim1log_temp3.txt","\t",header=None)

print(df1.head())
print("--------")
print(df1.to_numpy().shape)
print(df1.to_numpy()[:,:1])
print("--------")
print(df1.to_numpy()[:,1:2])
print("--------")
print(df1.to_numpy()[:,2:3])
print("--------")

#print(df2.head())
#print(df3.head())
print("mean:",np.mean(df1.to_numpy()[:,2:3]))
print("std:",np.std(df1.to_numpy()[:,2:3]))
print("var:",np.var(df1.to_numpy()[:,2:3]))
#df1.loc[:,2] 
#df1.plot(kind="line",x=df1.loc[:,0],y=df1.loc[:,2])
plt.plot(df1.to_numpy()[:,:1],df1.to_numpy()[:,2:3])
plt.show()
# Out:
#    0         1           2
# 0  0  100.0000  293.758348
# 1  1   99.9000  282.287432
# 2  2   99.8001  283.345326
# 3  3   99.7003  281.181248
# 4  4   99.6006  280.109648
# --------
# (10843, 3)
# [[0.000e+00]
#  [1.000e+00]
#  [2.000e+00]
#  ...
#  [6.235e+03]
#  [6.236e+03]
#  [6.237e+03]]
# --------
# [[100.        ]
#  [ 99.9       ]
#  [ 99.8001    ]
#  ...
#  [  0.10014354]
#  [  0.10014354]
#  [  0.10004339]]
# --------
# [[293.75834775]
#  [282.28743235]
#  [283.34532617]
#  ...
#  [ 66.28868271]
#  [ 66.28868271]
#  [ 66.28868271]]
# --------
# mean: 81.87845896665407
# std: 25.730951028150226
# var: 662.0818408130652

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

#os.getcwd()
df2 = pd.read_csv("../pa3/student_files/starter_code/logdir_anneal1/clean_sim1log_temp2.txt","\t",header=None)

print("mean:",np.mean(df2.to_numpy()[:,2:3]))
print("std:",np.std(df2.to_numpy()[:,2:3]))
print("var:",np.var(df2.to_numpy()[:,2:3]))
plt.plot(df2.to_numpy()[:,:1],df2.to_numpy()[:,2:3])
plt.show()
# Out:
# mean: 87.58842777163777
# std: 43.61246289680649
# var: 1902.046919925323

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

#os.getcwd()
df3 = pd.read_csv("../pa3/student_files/starter_code/logdir_anneal1/clean_sim1log_temp3.txt","\t",header=None)

print("mean:",np.mean(df3.to_numpy()[:,2:3]))
print("std:",np.std(df3.to_numpy()[:,2:3]))
print("var:",np.var(df3.to_numpy()[:,2:3]))
plt.plot(df3.to_numpy()[:,:1],df3.to_numpy()[:,2:3])
plt.show()
# Out:
# mean: 155.77388485694124
# std: 33.48048537215307
# var: 1120.9429007549554
