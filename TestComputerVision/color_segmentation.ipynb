# %%
#replicate MATLAB LAB color space first for proof

import numpy as np
import skimage.filters
from skimage.color import rgb2lab
import scipy.ndimage as ndi
import matplotlib.pyplot as plt


img_stain_rgb = ndi.imread('/Users/dc/TestCode/TestMatlab/week11/hestain.png')
img_stain_lab = rgb2lab(img_stain_rgb)

# %%
# %matplotlib inline

import numpy as np
import skimage.filters
from skimage.color import rgb2lab
import scipy.ndimage as ndi
import matplotlib.pyplot as plt

#what is the difference between p, theta and YSV?
#lab color space ignores differences in brightness
img_rgb = ndi.imread('/Users/dc/TestCode/TestMatlab/week11/IMG_1580.JPG')

img_lab = rgb2lab(img_rgb)

fig,(ax1, ax2) = plt.subplots(ncols=2, sharex=True, sharey=True, subplot_kw={'adjustable':'box-forced'})

ax1.imshow(img_rgb)
ax1.set_title("img rgb")
ax1.axis('off')

ax2.imshow(img_lab)
ax2.set_title("img lab")
ax2.axis('off')

plt.show()

print img_rgb.shape
print img_lab.shape
# Out:
# (2448, 3264, 3)
# (2448, 3264, 3)

# %%
#work through the examples with k-means, em which require predetermination of existing clusters


#mean-shift, cuts dont require additional
