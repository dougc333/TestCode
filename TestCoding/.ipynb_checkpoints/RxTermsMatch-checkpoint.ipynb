# %%
import sqlite3
conn = sqlite3.connect('/Users/dc/TestCode/TestCoding/clinical.sqlite')
c=conn.cursor()
c.execute('select count(*) from allergies;')
numRows = c.fetchone()
print numRows

c.execute("select count(medication_name) from medications inner join rxterms where medications.code=rxterms.RXCUI;")
numMatchMeds = c.fetchone()
print numMatchMeds
# Out:
# (5816,)
# (13178,)

# %%
c.execute("select count(distinct(code)) from medications;")
numMeds=c.fetchone()
c.execute("select count(distinct(RXCUI)) from rxterms;")
numTerms=c.fetchone()
print "numMeds:%s" % numMeds, "numTerms:%s" % numTerms
# Out:
# numMeds:9935 numTerms:21457

# %%
#c.execute("select medications.medication_name, medications.code,rxterms.RXCUI, rxterms.GENERIC_RXCUI,rxterms.TTY, rxterms.FULL_NAME from medications inner join rxterms where medications.code=rxterms.RXCUI limit 1000;")
#matchExample = c.fetchall()
#
#for e in matchExample:
 #   print e

# %%
c.execute("select count(medication_name) from medications inner join rxnatomarchive where medications.code=rxnatomarchive.RXAUI;")
numMatch = c.fetchone()
print numMatch
# Out:
# (64,)

# %%
c.execute("select count(medication_name) from medications inner join rxnatomarchive where medications.code=rxnatomarchive.AUI;")
numMatch = c.fetchone()
print numMatch
# Out:
# (0,)

# %%
c.execute("select count(medication_name) from medications inner join rxnconso where medications.code=rxnconso.RXCUI;")
numMatch = c.fetchone()
print numMatch
# Out:
# (724902,)

# %%
c.execute("select count(medication_name) from medications inner join rxncuichanges where medications.code=rxncuichanges.RXAUI;")
numMatch = c.fetchone()
print numMatch
# Out:
# (0,)

# %%
c.execute("select count(medication_name) from medications inner join rxnrel where medications.code=rxnrel.RXCUI1;")
numMatch = c.fetchone()
print numMatch
# Out:
# (248673,)

# %%
c.execute("select count(medication_name) from medications inner join rxnsat where medications.code=rxnsat.RXCUI;")
numMatch = c.fetchone()
print numMatch
# Out:
# (17008464,)

# %%
c.execute("select count(medication_name) from medications inner join rxnsab where medications.code=rxnsab.VCUI;")
numMatch = c.fetchone()
print numMatch
# Out:
# (0,)

# %%
c.execute("select count(medication_name) from medications inner join rxnsab where medications.code=rxnsab.RCUI;")
numMatch = c.fetchone()
print numMatch
# Out:
# (0,)

# %%
The biggest matches are rxnsat, rxnrel, rxnconso. What is the difference? 
Find the ones which are not matched. Is this consistent across the 3 tables? 
Dont know the difference we use rxconso rxconsole...

# %%
c.execute("select count(code) from medications where code_system_name=\"rxnorm\" and code not in(select DISTINCT(RXCUI) from rxnconso);")
numNotMatch=c.fetchone()
print numNotMatch
print ""

#657/9935 not match
c.execute("select medication_name, code from medications where code_system_name=\"rxnorm\" and code not in(select DISTINCT(RXCUI) from rxnconso);")
notMatch=c.fetchall()
for nm in notMatch:
    print nm
# Out:
# (657,)
#
# (u'Ferrous Sulfate (SLOW FE PO)', u'null')
# (u'Cyanocobalamin (VITAMIN B 12 PO)', u'null')
# (u'TURMERIC PO', u'null')
# (u'Multiple Vitamins-Minerals (MULTIVITAMIN & MINERAL PO)', u'null')
# (u'CARBOXYMETHYLCELLULOSE SODIUM OP', u'null')
# (u'INULIN (FIBER GUMMIES ORAL)', u'null')
# (u'Misc. Devices (WHEELCHAIR) Misc', u'null')
# (u'hydrophil petrolatum-mineral oil Ointment', u'null')
# (u'hydroCODone-acetaminophen, M-1005, 5-500 MG PO TABS', u'null')
# (u'ALBUTEROL SULFATE HFA IN', u'null')
# (u'Pamidronate 90 Mg IV Solr', u'904927')
# (u'Prenatal Multivit-Ca-Min-Fe-FA (PRENATAL VITAMIN) tab', u'null')
# (u'Acetaminophen (TYLENOL EXTRA STRENGTH PO)', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL PO)', u'null')
# (u'EPINEPHrine 0.3 MG/0.3ML Injection Device', u'null')
# (u'EXCEDRIN MIGRAINE PO', u'null')
# (u'Vilazodone HCl (VIIBRYD PO)', u'null')
# (u'sodium chloride (bolus) 0.9 % 30 mL', u'null')
# (u'Insulin Syringe-Needle U-100 30G X 1/2" 0.5 ML MISC', u'null')
# (u'glucose blood test strip', u'null')
# (u'Insulin Pen Needle 31 G x 8 mm misc. route', u'null')
# (u'Insulin Syringe-Needle U-100 (INSULIN SYRINGE 1CC/30GX1/2") 30G X 1/2" 1 ML misc. route', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS PO)', u'null')
# (u'Cyanocobalamin (VITAMIN B-12 PO)', u'null')
# (u'multivitamin capsule', u'null')
# (u'lancets 33 gauge Misc', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL VITAMIN PO)', u'null')
# (u'Levonorgestrel (MIRENA IU)', u'null')
# (u'Cholecalciferol (VITAMIN D PO)', u'null')
# (u'Probiotic Product (PROBIOTIC DAILY PO)', u'null')
# (u'COCONUT OIL ORAL', u'null')
# (u'DOCOSAHEXANOIC ACID/EPA (FISH OIL ORAL)', u'null')
# (u'Misc. Devices (BREAST PUMP) MISC', u'null')
# (u'Breast Pump devi', u'null')
# (u'docusate sodium (COLACE) 100 MG capsule', u'null')
# (u'ibuprofen (ADVIL,MOTRIN) 600 MG tablet', u'null')
# (u'underpads (GOODNITES BED MATS) 2.6 X 2.9 feet Pads', u'null')
# (u'GENERIC DME', u'null')
# (u'Diaper,Brief, Adult,Disposable (PREVAIL BLADDER PAD EXTRA PLUS) Misc', u'null')
# (u'Incontinence Pad, Liner, Disp (PREVAIL PANT LINER) Pads', u'null')
# (u'GLUCOSAMINE HCL PO', u'null')
# (u'Ice Bag Misc', u'null')
# (u'Incontinence Pad, Liner, Disp (BLADDER CONTROL PADS FOR WOMEN) Pads', u'null')
# (u'VITAMIN B COMPLEX PO', u'null')
# (u'multivitamin capsule', u'null')
# (u'SODIUM CHLORIDE/SODIUM BICARB (NEILMED SINUS RINSE COMPLETE NA)', u'null')
# (u'BIFIDOBACTERIUM INFANTIS (ALIGN PO)', u'null')
# (u'RABEPRAZOLE SODIUM (ACIPHEX PO)', u'null')
# (u'multiple vitamin tab', u'null')
# (u'Misc. Devices (BREAST PUMP) misc. route', u'null')
# (u'VALACYCLOVIR HCL (VALTREX ORAL)', u'null')
# (u'Multiple Vitamin (MULTI VITAMIN MENS PO)', u'null')
# (u'injection device for insulin (B-D PEN MINI) XX DEVI', u'null')
# (u'UNABLE TO FIND', u'null')
# (u'clonazePAM (KLONOPIN) 0.5 MG tablet', u'null')
# (u'DULoxetine (CYMBALTA) 60 MG capsule', u'null')
# (u'cephALEXin (KEFLEX) 500 MG capsule', u'null')
# (u'methylPREDNIsolone (MEDROL DOSPACK) 4 mg tablet', u'null')
# (u'dextroamphetamine-amphetamine (AMPHETAMINE-DEXTROAMPHETAMINE) 30 mg tablet', u'null')
# (u'sulfamethoxazole-trimethoprim (BACTRIM,SEPTRA) 200-40 MG/5ML PO Suspension', u'null')
# (u'BENZONATATE PO', u'null')
# (u'Blood-Glucose Meter (ACCU-CHEK NANO) Misc Misc', u'null')
# (u'Lancing Device with Lancets (ACCU-CHEK FASTCLIX) Misc Kit', u'null')
# (u'tetanus/diphtheria/acellular pertussis (Tdap) (ADACEL) Vaccine INJ 0.5 mL', u'null')
# (u'ERYTHROMYCIN BASE (ERYTHROMYCIN TOPICAL)', u'null')
# (u'ferrous sulfate (FERROUS SULFATE) 325 (65 FE) MG tablet', u'null')
# (u'Blood-Glucose Meter (TRUETRACK BLOOD GLUCOSE SYSTEM) Misc Kit', u'null')
# (u'Lancets Misc Misc', u'null')
# (u'Blood Sugar Diagnostic (TRUETEST TEST STRIPS) Misc Strip', u'null')
# (u'Acetone, Urine, Test (KETOSTIX) Misc Strip', u'null')
# (u'Lancets Misc Misc', u'null')
# (u'Blood Sugar Diagnostic (BLOOD GLUCOSE TEST) Misc Strip', u'null')
# (u'Ascorbic Acid (VITAMIN C PO)', u'null')
# (u'IRON PO', u'null')
# (u'lancets (FREESTYLE LANCETS) 28 gauge misc', u'null')
# (u'blood sugar diagnostic (FREESTYLE LITE STRIPS) test strip', u'null')
# (u'Prenatal Multivit-Ca-Min-Fe-FA (PRENATAL VITAMIN) tab', u'null')
# (u'OTC PRODUCT', u'null')
# (u'Cetirizine HCl (ZYRTEC PO)', u'null')
# (u'Prenatal MV-Min-Fe Fum-FA-DHA (PRENATAL 1 PO)', u'null')
# (u'PRENATAL VIT W-CA,FE,FA,<1 MG, (PRENATAL #2 ORAL)', u'null')
# (u'miscellaneous medical supply Misc Misc', u'null')
# (u'BIOTIN ORAL', u'null')
# (u'multivitamin (MULTIVITAMIN) Oral per tablet', u'null')
# (u'BECLOMETHASONE DIPROPIONATE (QVAR INHL)', u'null')
# (u'PEDIATRIC MULTIVIT COMB NO.76 (FLINTSTONES COMPLETE ORAL)', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS PO)', u'null')
# (u'Glucose Blood (ACCU-CHEK SMARTVIEW) In Vitro Strip', u'null')
# (u'Cetirizine HCl (ZYRTEC ALLERGY PO)', u'null')
# (u'blood glucose strip (FREESTYLE LITE) Strips', u'null')
# (u'Iron Sucrose (VENOFER) 100 mg iron/5 mL IV Soln', u'284502')
# (u'insulin pen needle 32G X 4 MM', u'null')
# (u'cholecalciferol, vitamin D3, 1,000 unit capsule', u'null')
# (u'prenatal multivit-Ca-min-Fe-FA Tab', u'null')
# (u'albuterol (PROAIR HFA) 90 mcg/actuation inhaler', u'null')
# (u'cetirizine (ZYRTEC) 10 MG tablet', u'null')
# (u'lidocaine epinephrine (LE) injection 1 mL', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL PO)', u'null')
# (u'MethylPREDNISolone (MEDROL, PAK, PO)', u'null')
# (u'Multiple Vitamin (MULTI VITAMIN DAILY PO)', u'null')
# (u'Lancet Device MISC', u'null')
# (u'glucose blood (ONE TOUCH ULTRA TEST) test strip', u'null')
# (u'Insulin Pen Needle (PEN NEEDLES 31GX5/16") 31G X 8 MM', u'null')
# (u'PNV95/FERROUS FUMARATE/FA (PRENATAL ORAL)', u'null')
# (u'HYDROCODONE-ACETAMINOPHEN ORAL', u'null')
# (u'sertraline (ZOLOFT) 25 mg tablet', u'null')
# (u'Escitalopram Oxalate (LEXAPRO PO)', u'null')
# (u'INV <research study number> (MEDICATION A) syringe', u'null')
# (u'multivitamin (TAB A VITE) tab tablet', u'null')
# (u'blood glucose (ONETOUCH ULTRA TEST STRIPS) test strip', u'null')
# (u'NON-SYSTEM, SEE ADMIN INSTR,', u'null')
# (u'NON-SYSTEM, SEE ADMIN INSTR,', u'null')
# (u'rho(D) immune globulin (RHOPHYLAC) INJ 300 mcg', u'null')
# (u'Pyridoxine HCl (VITAMIN B-6 PO)', u'null')
# (u'COMPOUNDED PRESCRIPTION', u'null')
# (u'COMPOUNDED PRESCRIPTION', u'null')
# (u'TRAMADOL HCL (ULTRAM ORAL)', u'null')
# (u'blood sugar diagnostic (ONETOUCH ULTRA TEST) test strip', u'null')
# (u'insulin needles, DISPOSABLE, (BD INSULIN PEN NEEDLE UF) 31 X 5/16 " ndle', u'null')
# (u'COMPOUNDED PRESCRIPTION', u'null')
# (u'COMPOUNDED PRESCRIPTION', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS PO)', u'null')
# (u'Multiple Vitamins-Minerals (MULTIVITAMIN PO)', u'null')
# (u'Multiple Vitamins-Minerals (AIRBORNE PO)', u'null')
# (u'CPAP', u'null')
# (u'Aspirin-Acetaminophen-Caffeine (EXCEDRIN MIGRAINE PO)', u'null')
# (u'glucose blood VI test strips (ONE TOUCH TEST STRIPS) strip', u'null')
# (u'HydrOXYzine Pamoate (VISTARIL PO)', u'null')
# (u'MALIC ACID ORAL', u'null')
# (u'PRENATAL VIT/IRON FUMARATE/FA (PRENATAL ORAL)', u'null')
# (u'CETIRIZINE HCL OR', u'null')
# (u'Ascorbic Acid (VITAMIN C OR)', u'null')
# (u'EVENING PRIMROSE OIL (EVENING PRIMROSE ORAL)', u'null')
# (u'EVENING PRIMROSE OIL (EVENING PRIMROSE ORAL)', u'null')
# (u'multivitamin (MVI) tablet', u'null')
# (u'Bupivacaine Hcl (Pf) 0.5 % Inj Soln', u'1300440')
# (u'LANSOPRAZOLE PO', u'null')
# (u'Prenatal Multivit-Ca-Min-Fe-FA (PRENATAL VITAMIN) Tablet', u'null')
# (u'Blood Pressure Monitor (BLOOD PRESSURE KIT) Kit', u'null')
# (u'CHROM PICO/BRINDAL BERRY (GARCINIA CAMBOGIA PO)', u'null')
# (u'OXYCODONE HCL/ACETAMINOPHEN (PERCOCET PO)', u'null')
# (u'OMEGA-3 FATTY ACIDS (FISH OIL ORAL)', u'null')
# (u'FOLIC ACID ORAL', u'null')
# (u'VITAMIN E ORAL', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS PO)', u'null')
# (u'ACETAMINOPHEN (TYLENOL 8 HOUR PO)', u'null')
# (u'VIT C/VIT E/LUTEIN/MIN/OMEGA-3 (OCUVITE ORAL)', u'null')
# (u'iodine Liqd', u'null')
# (u'oxyCODONE-acetaminophen (ROXICET) 5-325 mg per tablet', u'null')
# (u'ibuprofen (ADVIL,MOTRIN) 600 MG tablet', u'null')
# (u'HYDROcodone-acetaminophen (NORCO) 5-325 mg per tablet', u'null')
# (u'docusate sodium (COLACE) 250 MG capsule', u'null')
# (u'Insulin Needles, Disposable, 31 gauge x 3/16"', u'null')
# (u'Blood Sugar Diagnostic', u'null')
# (u'Insulin Needles, Disposable, 31 x 3/16 "', u'null')
# (u'CYANOCOBALAMIN, VITAMIN B-12, (VITAMIN B-12 ORAL)', u'null')
# (u'Insulin Pen Needle 32G X 4 MM Does not apply Misc', u'null')
# (u'glucose blood test strip', u'null')
# (u'blood sugar diagnostic Strp', u'null')
# (u'pen needle, diabetic, safety 29 gauge x 1/2" Ndle', u'null')
# (u'Custom Compounded Medication', u'null')
# (u'Custom Compounded Medication', u'null')
# (u'lancets 30 gauge Misc', u'null')
# (u'DHEA 5 mg Tab', u'null')
# (u'BLOOD-GLUCOSE METER (BLOOD GLUCOSE MONITOR KIT MISC)', u'null')
# (u'Custom Compounded Medication', u'null')
# (u'insulin safety needles, disp, (BD AUTOSHIELD PEN NEEDLE) 29 x 1/2 " Ndle', u'null')
# (u'SUPPLEMENT FOR HOME MED DOCUMENTATION', u'null')
# (u'SUPPLEMENT FOR HOME MED DOCUMENTATION', u'null')
# (u'SUPPLEMENT FOR HOME MED DOCUMENTATION', u'null')
# (u'blood sugar diagnostic Strp', u'null')
# (u'needle, disp, 30 G (BD SPECIALTY USE NEEDLES) 30 x 1/2 " Ndle', u'null')
# (u'CHROMIUM ORAL', u'null')
# (u'CYANOCOBALAMIN, VITAMIN B-12, (VITAMIN B-12 ORAL)', u'null')
# (u'MULTIVITAMIN ORAL', u'null')
# (u'ACETAMINOPHEN (TYLENOL ORAL)', u'null')
# (u'DOCOSAHEXANOIC ACID/EPA (FISH OIL ORAL)', u'null')
# (u'CALCIUM CARBONATE (TUMS ORAL)', u'null')
# (u'PNV CMB#21/IRON/FOLIC ACID (PRENATAL COMPLETE ORAL)', u'null')
# (u'Pregabalin (LYRICA PO)', u'null')
# (u'Probiotic Product (PROBIOTIC DAILY PO)', u'null')
# (u'Acetaminophen (TYLENOL PO)', u'null')
# (u'AMOXICILLIN PO', u'null')
# (u'FOLIC ACID PO', u'null')
# (u'RANITIDINE HCL (ZANTAC ORAL)', u'null')
# (u'PRENATAL VITS W-CA,FE,FA,<1MG, (PRENATAL VITAMIN ORAL)', u'null')
# (u'Paroxetine Hcl 30 Mg Po Tabs', u'312243')
# (u'ASCORBIC ACID (VITAMIN C WITH ROSE HIPS PO)', u'null')
# (u'BIOTIN PO', u'null')
# (u'CYANOCOBALAMIN, VITAMIN B-12, (VITAMIN B-12 PO)', u'null')
# (u'Intrauterine Device, IUD, IU IUD', u'null')
# (u'Cholecalciferol (VITAMIN D OR)', u'null')
# (u'Sennosides-Docusate Sodium (SENNA S OR)', u'null')
# (u'Probiotic Product (PROBIOTIC DAILY OR)', u'null')
# (u'Misc. Devices (BREAST PUMP) MISC', u'null')
# (u'multivitamin tablet', u'null')
# (u'Prenatal Vit w/Fe-Methylfol-FA (PNV PO)', u'null')
# (u'Acetaminophen (TYLENOL PO)', u'null')
# (u'OXYCODONE HCL PO', u'null')
# (u'Multiple Vitamin (MULTIVITAMINS) oral tablet', u'null')
# (u'PRENATAL VIT/IRON FUMARATE/FA (PRENATAL ORAL)', u'null')
# (u'PRENATAL VIT #91/FE FUM/FA/DHA (PRENATAL + DHA ORAL)', u'null')
# (u'MISC NATURAL PRODUCTS PO', u'null')
# (u'GABAPENTIN, ONCE-DAILY, PO', u'null')
# (u'CARBIDOPA PO', u'null')
# (u'LOSARTAN POTASSIUM PO', u'null')
# (u'CALCIUM CARBONATE (TUMS ORAL)', u'null')
# (u'Misc. Devices (BREAST PUMP) MISC', u'null')
# (u'Prenatal Vit-Fe Sulfate-FA (PRENATAL VITAMIN PO)', u'null')
# (u'Prenatal Vitamins (DIS) TABS', u'null')
# (u'PRENATAL VITAMINS PO', u'null')
# (u'Multiple Vitamin (MULTIVITAMIN PO)', u'null')
# (u'multivitamin tablet', u'null')
# (u'ALBUTEROL INHAL', u'null')
# (u'MAGNESIUM ORAL', u'null')
# (u'magic mouthwash', u'null')
# (u'COQ10, LIPOSOMAL UBIQUINOL, ORAL', u'null')
# (u'Lancet Devices (LANCING DEVICE) MISC', u'null')
# (u'Lancets MISC', u'null')
# (u'ONDANSETRON (ZOFRAN ODT PO)', u'null')
# (u'CETIRIZINE HCL (ZYRTEC ORAL)', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL VITAMIN PO)', u'null')
# (u'MedroxyPROGESTERone Acetate (DEPO-PROVERA IM)', u'null')
# (u'LITHIUM OR', u'null')
# (u'Zolpidem Tartrate (AMBIEN OR)', u'null')
# (u'QUEtiapine Fumarate (SEROQUEL OR)', u'null')
# (u'Prenat w/o A-FE-Methfol-FA-DHA (PNV-DHA OR)', u'null')
# (u'DME', u'null')
# (u'DIAZEPAM (VALIUM ORAL)', u'null')
# (u'PNV95/FERROUS FUMARATE/FA (PRENATAL ORAL)', u'null')
# (u'UNABLE TO FIND', u'null')
# (u'UNABLE TO FIND', u'null')
# (u'OTHER', u'null')
# (u'FLUTICASONE FUROATE IN', u'null')
# (u'VITAMIN D3 PO', u'null')
# (u'multivitamin with mineral tab', u'null')
# (u'NAPROXEN SODIUM (ALEVE ORAL)', u'null')
# (u'pen needle, diabetic (BD INSULIN PEN NEEDLE UF SHORT) 31 gauge x 5/16" Ndle', u'null')
# (u'DiphenhydrAMINE HCl (BENADRYL ALLERGY PO)', u'null')
# (u'Polyethylene Glycol 3350 (MIRALAX ORAL)', u'null')
# (u'Sennosides (SENOKOT ORAL)', u'null')
# (u'Riboflavin-Magnesium-Feverfew (MIGRELIEF) 200-180-50 MG TABS', u'null')
# (u'Cyanocobalamin (VITAMIN B-12 ORAL)', u'null')
# (u'prenatal vitamin-folic acid 1 mg (PRENATAL VITAMIN) tablet/capsule', u'null')
# (u'MULTI VITAMIN MENS OR', u'null')
# (u'lancets (ONE TOUCH DELICA) 33 gauge Misc', u'null')
# (u'PRENATAL VITAMINS PO', u'null')
# (u'PRENATAL VIT W-CA,FE,FA,<1 MG, (PRENATAL VITAMIN ORAL)', u'null')
# (u'OTHER MEDICATION, ,', u'null')
# (u'IRON PO', u'null')
# (u'Riboflavin-Magnesium-Feverfew (MIGRELIEF PO)', u'null')
# (u'PRENATAL VIT W-CA,FE,FA,<1 MG, (PRENATAL VITAMIN ORAL)', u'null')
# (u'lidocaine 1 % + nifedipine 0.3 % cream 60 gm', u'null')
# (u'ferrous sulfate 325 mg total salt (65 mg elemental) oral tablet', u'null')
# (u'glucose blood VI test strips (ONE TOUCH ULTRA TEST) strip', u'null')
# (u'insulin syringe-needle U-100 1 mL 31 x 5/16" Syrg', u'null')
# (u'Multiple Vitamins-Minerals (OCUVITE PO)', u'null')
# (u'FEXOFENADINE HCL (ALLEGRA PO)', u'null')
# (u'BUDESONIDE INHL', u'null')
# (u'dexamethasone (DECADRON) (conc: 1 mg/mL) oral drops 10 mg', u'null')
# (u'amoxicillin-clavulanate (AUGMENTIN) 875-125 mg per tablet', u'null')
# (u'oxyCODONE (ROXICODONE) 5 MG immediate release tablet', u'null')
# (u'celecoxib (CELEBREX) 100 MG capsule', u'null')
# (u'digestive enzymes Tab', u'null')
# (u'beta-glucan,1-3, 1-4, bulk, 70 % Powd', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS) 0.8 MG PO Tab', u'null')
# (u'Paroxetine Hcl 30 Mg Po Tabs', u'312243')
# (u'Paroxetine Hcl 30 Mg Po Tabs', u'312243')
# (u'Prenatal Multivit-Min-Fe-FA (PRE-NATAL PO)', u'null')
# (u'Cetirizine HCl (ZYRTEC ALLERGY PO)', u'null')
# (u'propranolol (INDERAL) 10 MG tablet', u'null')
# (u'LORazepam (ATIVAN) 0.5 MG tablet', u'null')
# (u'HYDROcodone-acetaminophen (NORCO) 5-325 mg tablet', u'null')
# (u'predniSONE (DELTASONE) 20 MG tablet', u'null')
# (u'prochlorperazine (COMPAZINE) 10 MG tablet', u'null')
# (u'HYDROcodone-acetaminophen (HYCET) 7.5-325 mg/15 mL solution', u'null')
# (u'amoxicillin-clavulanate (AUGMENTIN ES-600) 600-42.9 mg/5 mL suspension', u'null')
# (u'LORazepam (ATIVAN) 0.5 MG tablet', u'null')
# (u'zonisamide (ZONEGRAN) 100 MG capsule', u'null')
# (u'rizatriptan (MAXALT) 10 MG tablet', u'null')
# (u'nortriptyline (PAMELOR) 25 MG capsule', u'null')
# (u'methylPREDNISolone acetate (DEPO-MEDROL) injection 40 mg', u'null')
# (u'bupivacaine (MARCAINE) 0.5 % (5 mg/mL) injection 5 mg', u'null')
# (u'nortriptyline (PAMELOR) 25 MG capsule', u'null')
# (u'zonisamide (ZONEGRAN) 100 MG capsule', u'null')
# (u'naratriptan (AMERGE) 2.5 MG tablet', u'null')
# (u'butalbital-acetaminophen-caffeine (ESGIC) 50-325-40 mg per tablet', u'null')
# (u'coenzyme Q10 10 mg capsule', u'null')
# (u'RIBOFLAVIN ORAL', u'null')
# (u'MAGNESIUM ORAL', u'null')
# (u'sertraline (ZOLOFT) 100 MG tablet', u'null')
# (u'albuterol (PROAIR HFA;PROVENTIL HFA;VENTOLIN HFA) 90 mcg/actuation inhaler', u'null')
# (u'nitrofurantoin (MACRODANTIN) 100 MG capsule', u'null')
# (u'beclomethasone (QVAR) 80 mcg/actuation inhaler', u'null')
# (u'cetirizine (ZYRTEC) 10 MG tablet', u'null')
# (u'fluticasone (FLONASE) 50 mcg/actuation nasal spray', u'null')
# (u'prenatal vitamin-folic acid 1 mg (PRENATAL VITAMIN) tablet/capsule', u'null')
# (u'multivitamin tablet', u'null')
# (u'Montelukast Sodium (SINGULAIR PO)', u'null')
# (u'Thyroid (Armour) 1gr  (60mg)  Tabs', u'80697')
# (u'Thyroid (Armour) 1gr  (60mg)  Tabs', u'80697')
# (u'Thyroid (Armour) 1gr  (60mg)  Tabs', u'80697')
# (u'Thyroid (Armour) 1gr  (60mg)  Tabs', u'80697')
# (u'PNV CMB#21/IRON/FOLIC ACID (PRENATAL COMPLETE ORAL)', u'null')
# (u'blood glucose test strips (ONETOUCH VERIO) Strips', u'null')
# (u'Fexofenadine HCl (ALLEGRA PO)', u'null')
# (u'RANITIDINE HCL (ZANTAC ORAL)', u'null')
# (u'PNV CMB#21/IRON/FOLIC ACID (PRENATAL COMPLETE ORAL)', u'null')
# (u'pen needle, diabetic (BD ULTRA-FINE NANO PEN NEEDLES) 32 gauge x 5/32" Ndle', u'null')
# (u'PRENATAL VIT/IRON FUMARATE/FA (PRENATAL ORAL)', u'null')
# (u'PRENATAL VIT/IRON FUMARATE/FA (PRENATAL ORAL)', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL VITAMIN PO)', u'null')
# (u'MISC MEDICATION, SEE SIG DETAILS,', u'null')
# (u'OXYcodone-acetaminophen (PERCOCET) 5-325 MG Oral Tab', u'null')
# (u'Ascorbic Acid (VITAMELTS VITAMIN C PO)', u'null')
# (u'Inulin (FIBER CHOICE PO)', u'null')
# (u'Probiotic Product (ALIGN PO)', u'null')
# (u'Multiple Vitamins-Minerals (MULTIVITAMIN PO)', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL VITAMIN) 27-0.8 MG Tab', u'null')
# (u'blood sugar diagnostic Strp', u'null')
# (u'multivitamin (THERAGRAN) tablet', u'null')
# (u'Paroxetine 10 Mg Tablet', u'312241')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS) 0.8 MG Tab', u'null')
# (u'glucose blood (FREESTYLE LITE) strip', u'null')
# (u'blood sugar diagnostic (ONETOUCH ULTRA TEST) test strip', u'null')
# (u'CHROM PICO/BRINDAL BERRY (GARCINIA CAMBOGIA PO)', u'null')
# (u'Prenatal Multivit-Ca-Min-Fe-FA (PRENATAL VITAMIN) Tab', u'null')
# (u'Insulin Needles, Disposable, (NANO PEN NEEDLE) 32 gauge x 5/32" Ndle', u'null')
# (u'Paroxetine Hcl 30 Mg Oral Tab', u'312243')
# (u'Paroxetine Hcl 30 Mg Oral Tab', u'312243')
# (u'Omega-3 Fatty Acids (FISH OIL PO)', u'null')
# (u'blood sugar diagnostic (ONETOUCH ULTRA TEST) test strip', u'null')
# (u'Docosahexaenoic Acid (DHA OR)', u'null')
# (u'BREAST PUMP', u'null')
# (u'CALCIUM CARBONATE ORAL', u'null')
# (u'CHOLECALCIFEROL (VITAMIN D3) (VITAMIN D3 ORAL)', u'null')
# (u'OTHER MEDICATION, ,', u'null')
# (u'OTHER MEDICATION, ,', u'null')
# (u'OTHER MEDICATION, ,', u'null')
# (u'OTHER MEDICATION, ,', u'null')
# (u'OTHER MEDICATION, ,', u'null')
# (u'Misc. Devices (BREAST PUMP) MISC', u'null')
# (u'PSEUDOEPHEDRINE HCL (SUDAFED ORAL)', u'null')
# (u'Acetone, Urine, Test (KETOSTIX) Misc Strip', u'null')
# (u'Lancets Misc Misc', u'null')
# (u'Blood Sugar Diagnostic (BLOOD GLUCOSE TEST) Misc Strip', u'null')
# (u'Albuterol Sulfate (ALBUTEROL, PROVENTIL, INHALER **STARTER PACK) 90 mcg/act AERS', u'null')
# (u'RESVERATROL PO', u'null')
# (u'Zinc Sulfate (ZINC 15 PO)', u'null')
# (u'fluticasone (FLONASE) 50 mcg/Actuation nasal', u'null')
# (u'gabapentin (NEURONTIN) 100 MG capsule', u'null')
# (u'pramipexole (MIRAPEX) 0.25 MG tablet', u'null')
# (u'Paroxetine Hcl 20 Mg Oral Tab', u'314199')
# (u'Prenatal Multivit-Ca-Min-Fe-FA (PRENATAL VITAMIN) Oral Tablet', u'null')
# (u'Misc. Devices (BREAST PUMP) XX MISC', u'null')
# (u'Multiple Vitamins-Minerals (MULTIVITAMIN PO)', u'null')
# (u'PREDNISONE', u'null')
# (u'glucose blood (ONETOUCH VERIO) strip', u'null')
# (u'Prenatal Vit-DSS-Fe Cbn-FA (PRENATAL VITAMIN) Tab', u'null')
# (u'Multivitamin Therapeutic Oral Tab', u'null')
# (u'BuPROPion HCl (WELLBUTRIN PO)', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL VITAMINS) 28-0.8 MG Tab', u'null')
# (u'DME DIABETIC SUPPLY ORDER', u'null')
# (u'DME DIABETIC SUPPLY ORDER', u'null')
# (u'FOLIC ACID ORAL', u'null')
# (u'sertraline 25 MG tablet', u'null')
# (u'Probiotic Product (PRO-BIOTIC BLEND PO)', u'null')
# (u'Calcium-Vitamin D 600-200 MG-UNIT Oral Tab', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRE-NATAL FORMULA PO)', u'null')
# (u'Respiratory Therapy Supplies (NEBULIZER) XX DEVI', u'null')
# (u'LACTOBAC CMB #3/FOS/PANTETHINE (PROBIOTIC & ACIDOPHILUS PO)', u'null')
# (u'NORETH A-ET ESTRA/FE FUMARATE (LO LOESTRIN FE PO)', u'null')
# (u'MULTIVITAMINS WITH FLUORIDE (MULTI-VITAMIN PO)', u'null')
# (u'CALCIUM CARBONATE/VITAMIN D3 (CALCIUM + D PO)', u'null')
# (u'PSEUDOEPHEDRINE HCL (SUDAFED ORAL)', u'null')
# (u'ACETAMINOPHEN (TYLENOL ORAL)', u'null')
# (u'CALCIUM CARBONATE (TUMS ORAL)', u'null')
# (u'Prenatal Multivit-Ca-Min-Fe-FA tablet', u'null')
# (u'other (unlisted)', u'null')
# (u'Multiple Vitamins-Minerals (MULTIVITAMIN & MINERAL PO)', u'null')
# (u'PNV NO.115/IRON FUMARATE/FA (PRENATAL #115-IRON-FOLIC ACID ORAL)', u'null')
# (u'IRON PO', u'null')
# (u'GLUCOSAMINE/CHONDROITIN SULF A (GLUCOSAMINE-CHONDROITIN ORAL)', u'null')
# (u'PNV CMB#21/IRON/FOLIC ACID (PRENATAL COMPLETE ORAL)', u'null')
# (u'PNV CMB#21/IRON/FOLIC ACID (PRENATAL COMPLETE ORAL)', u'null')
# (u'Free Text Medication Entry (OTHER)', u'null')
# (u'PNV62/FA/OM3/DHA/EPA/FISH OIL (PRENATAL GUMMY ORAL)', u'null')
# (u'Lidocaine Hcl 1 % Injection Soln', u'1247659')
# (u'Insulin Needles, Disposable, (NANO PEN NEEDLE) 32 gauge x 5/32" ndle', u'null')
# (u'RANITIDINE HCL (ZANTAC ORAL)', u'null')
# (u'Nitrofurantoin Monohyd Macro (MACROBID PO)', u'null')
# (u'Cetirizine HCl (ZYRTEC PO)', u'null')
# (u'MV/FA/D3/K/LYCOP/LUT/HERB#220 (ESTROBLEND ORAL)', u'null')
# (u'prenatal vitamin-folic acid 1 mg (PRENATAL VITAMIN) tablet/capsule', u'null')
# (u'multivitamin (MULTIVITAMIN) tablet', u'null')
# (u'compounded RX: mupirocin-betamethasone valerate-miconazole-ibuprofen (FORMULA #3) 1-0.05-2-2 % ointment', u'null')
# (u'Misc. Devices (BREAST PUMP) device', u'null')
# (u'Insulin Pen Needle (BD PEN NEEDLE NANO U/F) 32G X 4 MM MISC', u'null')
# (u'MISCELLANEOUS MEDICAL SUPPLY (GRADUATED COMPRESSION STOCKINGS)', u'null')
# (u'blood-glucose meter', u'null')
# (u'lancets (ACCU-CHEK FASTCLIX)', u'null')
# (u'blood sugar diagnostic (ACCU-CHEK SMARTVIEW TEST STRIP) strip', u'null')
# (u'PRENATAL VIT COMB.10-IRON-FA ORAL', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL VITAMIN PO)', u'null')
# (u'methylPREDNIsolone (MEDROL DOSPACK) 4 mg tablet', u'null')
# (u'cefUROXime (CEFTIN) 500 MG tablet', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS PO)', u'null')
# (u'PNV WITH CA#74/IRON/FOLIC ACID (PRENATAL VITAMIN 1+1 ORAL)', u'null')
# (u'PNV95/FERROUS FUMARATE/FA (PRENATAL ORAL)', u'null')
# (u'OMEPRAZOLE (PRILOSEC ORAL)', u'null')
# (u'PNV95/FERROUS FUMARATE/FA (PRENATAL ORAL)', u'null')
# (u'OMEPRAZOLE (PRILOSEC ORAL)', u'null')
# (u'OMEPRAZOLE MAGNESIUM (PRILOSEC OTC ORAL)', u'null')
# (u'PNV95/FERROUS FUMARATE/FA (PRENATAL ORAL)', u'null')
# (u'BABY ASPIRIN ORAL', u'null')
# (u'Multiple Vitamins-Minerals (DAILY MULTI PO)', u'null')
# (u'lidocaine 1% injection solution', u'null')
# (u'PRENATAL VIT #91/FE FUM/FA/DHA (PRENATAL + DHA PO)', u'null')
# (u'non-formulary', u'null')
# (u'PNV #38/IRON FUM/FOLATE/DHA (PNV #38-IRON-FA #6-DHA ORAL)', u'null')
# (u'FOLIC ACID PO', u'null')
# (u'CALCIUM CARBONATE/VITAMIN D3 (VITAMIN D-3 PO)', u'null')
# (u'FERROUS FUMARATE (IRON ORAL)', u'null')
# (u'Blood Sugar Diagnostic (ONETOUCH ULTRA TEST) Strips', u'null')
# (u'Compounded Medication', u'null')
# (u'cyclobenzaprine (FLEXERIL) 5 MG tablet', u'null')
# (u'busPIRone (BUSPAR) 5 MG tablet', u'null')
# (u'predniSONE (DELTASONE) 20 MG tablet', u'null')
# (u'methocarbamol (ROBAXIN) 500 MG tablet', u'null')
# (u'naproxen (NAPROSYN) 500 MG tablet', u'null')
# (u'erythromycin (ROMYCIN) ophthalmic ointment', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL VITAMIN PO)', u'null')
# (u'CETIRIZINE HCL (ZYRTEC ORAL)', u'null')
# (u'CETIRIZINE HCL (ZYRTEC ORAL)', u'null')
# (u'Insulin Needles, Disposable, (NANO PEN NEEDLE) 32 gauge x 5/32"', u'null')
# (u'Needle, Disp, (BD DISP NEEDLES) 30G X 1/2" XX MISC', u'null')
# (u'Syringe 22G X 1-1/2" 3 ML XX MISC', u'null')
# (u'Needle, Disp, 18G X 1-1/2" XX MISC', u'null')
# (u'Cetirizine HCl (ZYRTEC PO)', u'null')
# (u'Budesonide (RHINOCORT AQUA NA)', u'null')
# (u'PRENATAL VITAMINS PO', u'null')
# (u'ALBUTEROL IN', u'null')
# (u'Prenat w/o A-FeCbGl-DSS-FA-DHA (PNV OB+DHA OR)', u'null')
# (u'NORGESTREL-ETHINYL ESTRADIOL (LOW-OGESTREL, 28, PO)', u'null')
# (u'OM-3/E/LINOL/ALA/OLEIC/GLA/LIP (OMEGA 3-6-9 ORAL)', u'null')
# (u'CYANOCOBALAMIN, VITAMIN B-12, (VITAMIN B-12 ORAL)', u'null')
# (u'ASCORBIC ACID (VITAMIN C ORAL)', u'null')
# (u'Follitropin Alfa 300 Unit/0.5ml Sc Soln', u'1594431')
# (u'B Complex Vitamins (VITAMIN-B COMPLEX) tablet', u'null')
# (u'ferrous sulfate (FERROUS SULFATE) 325 (65 FE) MG tablet', u'null')
# (u'glucose blood (BAYER CONTOUR NEXT TEST) test strip', u'null')
# (u'VIT C/E/ZN/COPPR/LUTEIN/ZEAXAN (PRESERVISION AREDS 2 ORAL)', u'null')
# (u'Terbinafine-Miconazole Tinc 750 mg-2% 30 ml Top Soln', u'null')
# (u'FREE-TEXT MEDICATION', u'null')
# (u'Misc. Devices (BREAST PUMP) MISC', u'null')
# (u'Ferrous Fumarate (FERRETTS PO)', u'null')
# (u'blood-glucose meter kit', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL OR)', u'null')
# (u'METFORMIN HCL OR', u'null')
# (u'Breast Pump devi', u'null')
# (u'lancets Misc', u'null')
# (u'BLOOD SUGAR DIAGNOSTIC (GLUCOSE BLOOD TEST STRIPS) strip', u'null')
# (u'Miscellaneous (OTHER)', u'null')
# (u'Ferrous Sulfate 324 mg total salt (65 mg elemental) oral tablet,delayed release (DR/EC)', u'null')
# (u'med unable to find', u'null')
# (u'Prenatal MV-Min-Fe Fum-FA-DHA (PRENATAL 1 PO)', u'null')
# (u'HYDROXYPROGESTERONE CAPROATE 250 MG/ML IM INJ', u'null')
# (u'blood glucose (ONE TOUCH ULTRA) test strip', u'null')
# (u'Calcium Carbonate Antacid (TUMS PO)', u'null')
# (u'Blood Glucose Monitoring Suppl (BLOOD GLUCOSE MONITOR SYSTEM) W/DEVICE Kit', u'null')
# (u'Glucose Blood (BAYER CONTOUR NEXT TEST) Strip', u'null')
# (u'Lancets (ONETOUCH ULTRASOFT LANCETS) lancets', u'null')
# (u'blood sugar diagnostic (BLOOD GLUCOSE TEST) test strip', u'null')
# (u'ESOMEPRAZOLE MAGNESIUM (NEXIUM 24HR ORAL)', u'null')
# (u'MULTIVITAMIN (DAILY VITAMIN ORAL)', u'null')
# (u'DOXYLAMINE SUCCINATE (UNISOM, DOXYLAMINE, ORAL)', u'null')
# (u'prenatal multivit-Ca-min-Fe-FA (PRENATAL VITAMIN) tablet', u'null')
# (u'prenatal multivit-Ca-min-Fe-FA Tab', u'null')
# (u'Multiple Vitamins-Minerals (MULTIVITAMIN GUMMIES ADULT PO)', u'null')
# (u'KETOTIFEN FUMARATE OPHTH', u'null')
# (u'ACETAMINOPHEN (TYLENOL ORAL)', u'null')
# (u'L. RHAMNOSUS GG/INULIN (CULTURELLE PROBIOTICS ORAL)', u'null')
# (u'MAGNESIUM ORAL', u'null')
# (u'VITAMIN B COMPLEX ORAL', u'null')
# (u'ERGOCALCIFEROL, VITAMIN D2, (VITAMIN D ORAL)', u'null')
# (u'Cholecalciferol (VITAMIN D PO)', u'null')
# (u'pen needle, diabetic, safety 29 gauge x 1/2" Ndle', u'null')
# (u'multivitamin capsule', u'null')
# (u'ASCORBATE CALCIUM (VITAMIN C ORAL)', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS PO)', u'null')
# (u'glucose blood VI test strips (ONETOUCH VERIO) strip', u'null')
# (u'Fexofenadine HCl (ALLEGRA ALLERGY PO)', u'null')
# (u"MV-MN/IRON FUM/FA/OMEGA3,6,9#3 (WOMEN'S MULTI ORAL)", u'null')
# (u'VIT C-HESPERIDIN-BIOFLAVONOIDS ORAL', u'null')
# (u'Loratadine-Pseudoephedrine (CLARITIN-D 24 HOUR PO)', u'null')
# (u'Glucose Blood (ONE TOUCH ULTRA TEST) Strip', u'null')
# (u'insulin needles, disposable, 31 x 3/16 " needle', u'null')
# (u'ARIPIPRAZOLE (ABILIFY ORAL)', u'null')
# (u'Paroxetine 30 Mg Tablet', u'312243')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS OR)', u'null')
# (u'auto-titrating CPAP (AUTOSET) machine', u'null')
# (u'Lancets', u'null')
# (u'blood-glucose meter', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL VITAMIN PO)', u'null')
# (u'ALBUTEROL INHAL', u'null')
# (u'IRON PO', u'null')
# (u'PNV76/IRON,CARB&GLU/FA/DSS/DHA (CITRANATAL DHA, ALGAL OIL, PO)', u'null')
# (u'Paroxetine 20 Mg Tablet', u'314199')
# (u'PROMETHAZINE HCL (PROMETHAZINE ORAL)', u'null')
# (u"MULTIVIT/IRON/FA/K/HERB NO.244 (ALIVE WOMEN'S ENERGY ORAL)", u'null')
# (u'multivitamin (MVI) tablet', u'null')
# (u'Insulin Pen Needle (B-D UF III MINI PEN NEEDLES) 31G X 5 MM MISC', u'null')
# (u'glucose blood (ONE TOUCH ULTRA TEST) test strip', u'null')
# (u'glucose blood (ONE TOUCH ULTRA TEST) test strip', u'null')
# (u'Insulin Pen Needle (B-D UF III MINI PEN NEEDLES) 31G X 5 MM MISC', u'null')
# (u'Insulin Pen Needle (B-D UF III MINI PEN NEEDLES) 31G X 5 MM MISC', u'null')
# (u'glucose blood (ONE TOUCH ULTRA TEST) test strip', u'null')
# (u'FLAXSEED OIL (OMEGA 3 ORAL)', u'null')
# (u'Cholecalciferol (VITAMIN D3 PO)', u'null')
# (u'LEVOTHYROXINE SODIUM PO', u'null')
# (u'LAMOTRIGINE PO', u'null')
# (u'CLONAZEPAM PO', u'null')
# (u'GABAPENTIN PO', u'null')
# (u'SUMAtriptan Succinate (IMITREX PO)', u'null')
# (u'Prenatal Multivit-Ca-Min-Fe-FA (PRENATAL VITAMIN) Tablet', u'null')
# (u'IRON PO', u'null')
# (u'Cholecalciferol (VITAMIN D ORAL)', u'null')
# (u'QUEtiapine Fumarate (SEROQUEL ORAL)', u'null')
# (u'MULTIVITAMIN ORAL', u'null')
# (u'pen needle, diabetic 29 gauge x 1/2" Ndle', u'null')
# (u'blood sugar diagnostic strip', u'null')
# (u'insulin syringes, disposable, 1 mL Syrg', u'null')
# (u'blood-glucose meter (GLUCOSE MONITORING KIT) kit', u'null')
# (u'levothyroxine (LEVOTHROID) 25 MCG tablet', u'null')
# (u'losartan (COZAAR) 50 MG tablet', u'null')
# (u'losartan-hydrochlorothiazide (HYZAAR) 50-12.5 mg per tablet', u'null')
# (u'cholecalciferol, VITAMIN D3, (VITAMIN D3) 2,000 unit Tab', u'null')
# (u'omega-3 fatty acids-fish oil (FISH OIL) 300-1,000 mg Cap', u'null')
# (u'ibuprofen (ADVIL,MOTRIN) 400 MG tablet', u'null')
# (u'miscellaneous medical supply Misc', u'null')
# (u'OXYGEN-AIR DELIVERY SYSTEMS MISC', u'null')
# (u'FLUTICASONE PROPIONATE (FLOVENT HFA INHL)', u'null')
# (u'Viscous lido 2% 100 mL/Maalox 100 mL/diphenhydramine 100 mL (MIRACLE MOUTHWASH) oral suspension', u'null')
# (u'Probiotic Product (PROBIOTIC DAILY PO)', u'null')
# (u'FIBER PO', u'null')
# (u'Loratadine (CLARITIN PO)', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL ONE DAILY PO)', u'null')
# (u'LOSARTAN POTASSIUM PO', u'null')
# (u'Multiple Vitamins-Minerals (MULTIVITAL PO)', u'null')
# (u'lanolin breastfeeding (LANSINOH) ointment', u'null')
# (u'Multiple Vitamins-Minerals (MULTIVITAMIN OR)', u'null')
# (u'OnabotulinumtoxinA (BOTOX IJ)', u'null')
# (u'Calcium Carbonate-Vitamin D (CALTRATE 600+D OR)', u'null')
# (u'MULTIVITAMIN TABS   OR', u'null')
# (u'Aspirin-Acetaminophen-Caffeine (PAMPRIN MAX PO)', u'null')
# (u'Probiotic Product (PROBIOTIC DAILY PO)', u'null')
# (u'diphenhydramine-magnesium aluminum hydroxide-lidocaine (BMX)', u'null')
# (u'glucose blood VI test strips (ONE TOUCH TEST STRIPS) strip', u'null')
# (u'GLUCOSE MONITOR LANCETS PRESCRIPTION', u'null')
# (u'GLUCOSE TEST STRIPS PRESCRIPTION', u'null')
# (u'L-METHYLFOLATE-B6-B12 PO', u'null')
# (u'Blood Sugar Diagnostic, Drum (ACCU-CHEK COMPACT TEST) Misc Strip', u'null')
# (u'Lancets (ACCU-CHEK SOFTCLIX LANCETS) Misc Misc', u'null')
# (u'NON-DATABASE MEDICATION', u'null')
# (u'COMPOUNDED MEDICATION', u'null')
# (u"PNV#75/IRON FUM/FA/OM3/DHA/EPA (ONE A DAY WOMEN'S PRENATAL DHA ORAL)", u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL VITAMIN PO)', u'null')
# (u'multivitamin (THERAGRAN) per tablet', u'null')
# (u'UNCODED DME', u'null')
# (u'Oxycodone-Acetaminophen (PERCOCET PO)', u'null')
# (u'Oxygen Concentrator', u'null')
# (u'OXYGEN', u'null')
# (u'OMEGA-3S/DHA/EPA/FISH OIL (OMEGA 3 ORAL)', u'null')
# (u'BIFIDOBACTERIUM INFANTIS (ALIGN ORAL)', u'null')
# (u'multivitamin with minerals tablet', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRE-NATAL PO)', u'null')
# (u'Blood Glucose Monitoring Suppl (BLOOD GLUCOSE METER)', u'null')
# (u'Misc. Devices (WHEELCHAIR) Misc', u'null')
# (u'DISABILITY PLACARD', u'null')
# (u'Misc. Devices (CANE) Misc', u'null')
# (u'Coenzyme Q10 (CO Q 10 PO)', u'null')
# (u'DIGESTIVE ENZYMES PO', u'null')
# (u'Calcium-Magnesium-Vitamin D (CALCIUM 500 PO)', u'null')
# (u'Multiple Vitamins-Minerals (MULTIVITAMIN PO)', u'null')
# (u'MECLIZINE HCL', u'null')
# (u'DM HB/PE/ACETAMINOPHEN/CHLORPH (ROBITUSSIN COLD, COUGH, & FLU ORAL)', u'null')
# (u'Calcium Carbonate Antacid (TUMS PO)', u'null')
# (u'Ca Carbonate-Mag Hydroxide (ROLAIDS PO)', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL 19 PO)', u'null')
# (u'B Complex-C-Folic Acid (NEPHRO-VITE PO)', u'null')
# (u'Nutritional Supplements (NEPRO PO)', u'null')
# (u'Paroxetine Hcl 30 Mg Po Tabs', u'312243')
# (u'Nebulizers (ALTERA NEBULIZER) Misc Misc', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS OR)', u'null')
# (u'LACTOBACILLUS ACIDOPHILUS (PROBIOTIC ORAL)', u'null')
# (u'VITAMIN E ACID SUCCINATE (VIT E ACID SUCCINATE, BULK, MISC)', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS PO)', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS PO)', u'null')
# (u'Multiple Vitamins-Minerals (MULTIVITAMIN & MINERAL PO)', u'null')
# (u'Peak Flow Meter DEVI', u'null')
# (u'IRON PO', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (M-VIT PO)', u'null')
# (u'Cholecalciferol (VITAMIN D PO)', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS+FOLATE)', u'null')
# (u'multivitamin (AKA ONE-A-DAY) Oral Tab', u'null')
# (u'lancets (ACCU-CHEK FASTCLIX)', u'null')
# (u'blood sugar diagnostic (ACCU-CHEK AVIVA PLUS TEST STRP) strip', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL VITAMIN PO)', u'null')
# (u'METRONIDAZOLE-SKIN CLEANSER TOP', u'null')
# (u'PRENATAL VIT #91/FE FUM/FA/DHA (PRENATAL + DHA ORAL)', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS OR)', u'null')
# (u'Calcium Carbonate-Vitamin D (CALCIUM 500 + D PO)', u'null')
# (u'KRILL OIL PO', u'null')
# (u'Omega-3 Fatty Acids (SALMON OIL PO)', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS) 0.8 MG Tab', u'null')
# (u'multivitamin with minerals tablet', u'null')
# (u'DIABETIC TESTING STRIPS', u'null')
# (u'DIABETIC TESTING METER', u'null')
# (u'DIABETIC TESTING LANCETS', u'null')
# (u'prenatal multivitamin tablet', u'null')
# (u'DOCOSAHEXANOIC ACID (PRENATAL DHA ORAL)', u'null')
# (u'PRENATAL VITS CMB W-O CA NO.2 (PRENATAL VITAMIN NO.2 PO)', u'null')
# (u'Vacuum Erection Device System kit', u'null')
# (u'ibuprofen (ADVIL,MOTRIN) 200 MG TABS', u'null')
# (u'GENERIC AMB PRESCRIPTION RX', u'null')
# (u'NON FORMULARY', u'null')
# (u'IRON PO', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS PO)', u'null')
# (u'blood sugar (FREESTYLE LITE STRIPS) test strip', u'null')
# (u'insulin syringe-needle (TRUEPLUS INSULIN) 1/2 mL 30 gauge x 5/16', u'null')
# (u'Elastic Bandages & Supports (MEDICAL COMPRESSION STOCKINGS) MISC', u'null')
# (u'Nebulizer Accessories Kit', u'null')
# (u'syringe/needle, disp, 20G X 1" 1 ML', u'null')
# (u'salt moisturizing solution no1 (OCEAN ULTRA SALINE MIST) Mist', u'null')
# (u'losartan (COZAAR) 25 MG tablet', u'null')
# (u'hydrOXYzine (VISTARIL) 50 MG capsule', u'null')
# (u'oxyCODONE (ROXICODONE) 5 MG immediate release tablet', u'null')
# (u'losartan (COZAAR) 25 MG tablet', u'null')
# (u'omeprazole (PRILOSEC) 40 MG capsule', u'null')
# (u'gabapentin (NEURONTIN) 100 MG capsule', u'null')
# (u'leflunomide (ARAVA) 20 MG tablet', u'null')
# (u'losartan (COZAAR) 25 MG tablet', u'null')
# (u'leflunomide (ARAVA) 20 MG tablet', u'null')
# (u'omeprazole (PRILOSEC) 40 MG capsule', u'null')
# (u'Multiple Vitamins-Minerals (MULTIVITAMIN MEN PO)', u'null')
# (u'LORATADINE (CLARITIN ORAL)', u'null')
# (u'Lidocaine Hcl (Pf) 1 % Ij Soln', u'1100193')
# (u'DULoxetine HCl (CYMBALTA PO)', u'null')
# (u'multivitamin tablet', u'null')
# (u'Prenatal MV-Min-Fe Fum-FA-DHA (PRENATAL MULTIVITAMIN + DHA PO)', u'null')
# (u'ERGOCALCIFEROL, VITAMIN D2, (VITAMIN D PO)', u'null')
# (u'ALPRAZOLAM (XANAX ORAL)', u'null')
# (u'Naproxen Sodium (ALEVE PO)', u'null')
# (u'Acetaminophen (TYLENOL PO)', u'null')
# (u'DOCOSAHEXANOIC ACID/EPA (FISH OIL ORAL)', u'null')
# (u'prenatal vitamin-folic acid 1 mg (PRENATAL RX) tablet/capsule', u'null')
# (u'lancets (ONE TOUCH DELICA) 33 gauge misc', u'null')

# %%
import sqlite3
conn = sqlite3.connect('/Users/dc/TestCode/TestCoding/clinical.sqlite')
c=conn.cursor()

#4057 with one entry, will need more data
c.execute("select count(distinct(code)) from medications group by code having count(code)=1;")
num=c.fetchall()
print "num entries w/1 code:%s" % len(num)

#there are 5878 entries with more than 1 code.
c.execute("select code from medications group by code having count(code)>1;")
num=c.fetchall()
print "num entries > 1entry/code:%s" % len(num)

numProcessed=0;
numFound=0
numNotFound=0
writeMe= open("/Users/dc/TestCode/TestCoding/csvfile.csv","w")
for n in num:
    print "n:%s" % n
    c.execute("select distinct(code_name) from medications where code='%s'" % (n[0]))
    res = c.fetchall()
    print "res len:",len(res)
    terms=[]
    if len(res) > 1:
        print "code:%s" % n[0]
        c.execute("select * from rxnconso where RXCUI='%s'" % (n[0]))
        resRXN=c.fetchall()
        print "resRXN len:%s" % len(resRXN)
        if len(resRXN) > 0:
            numFound+=1
            print "resRXN > 0"
            print "find in rxnconso:%s" % resRXN
            for r in resRXN:
                print "processing term:%s" % r[0]
                terms.append(r[0])
            writeMe.write(n[0])
            writeMe.write(",")
            for t in terms:
                writeMe.write(t)
                writeMe.write(",")
            writeMe.write("\n")
#        writeMe.write("----------------")
            writeMe.write("\n")
        else:
            numNotFound+=1
    numProcessed+=1
    if(numProcessed % 100==0):
        print "numProcessed:%s" %numProcessed
writeMe.close()
print "numProcessed:%s" % numProcessed
print "numFound", numFound
print "found:", found
# Out:
# num entries w/1 code:4057
# num entries > 1entry/code:5878
# n:0002-3235-60
# res len: 2
# code:0002-3235-60
# resRXN len:0
# n:0002-3240-30
# res len: 2
# code:0002-3240-30
# resRXN len:0
# n:0002-4462-30
# res len: 2
# code:0002-4462-30
# resRXN len:0
# n:0002-8215-01
# res len: 1
# n:0002-8315-01
# res len: 1
# n:0002-8799-59
# res len: 3
# code:0002-8799-59
# resRXN len:0
# n:0003-0894-21
# res len: 2
# code:0003-0894-21
# resRXN len:0
# n:0004-0068-01
# res len: 1
# n:0004-0259-01
# res len: 1
# n:0004-0800-85
# res len: 4
# code:0004-0800-85
# resRXN len:0
# n:0004-6314-01
# res len: 1
# n:00054-0259-13
# res len: 1
# n:00054327099
# res len: 1
# n:0006-0033-30
# res len: 2
# code:0006-0033-30
# resRXN len:0
# n:0006-0072-31
# res len: 2
# code:0006-0072-31
# resRXN len:0
# n:0006-0277-28
# res len: 2
# code:0006-0277-28
# resRXN len:0
# n:0006-0325-30
# res len: 1
# n:0006-0931-28
# res len: 2
# code:0006-0931-28
# resRXN len:0
# n:0006-0952-31
# res len: 2
# code:0006-0952-31
# resRXN len:0
# n:0008-0606-01
# res len: 2
# code:0008-0606-01
# resRXN len:0
# n:0008-0607-01
# res len: 3
# code:0008-0607-01
# resRXN len:0
# n:0008-0841-81
# res len: 2
# code:0008-0841-81
# resRXN len:0
# n:0008-0843-81
# res len: 1
# n:0008-1222-01
# res len: 1
# n:0009-0029-01
# res len: 1
# n:0009-0050-02
# res len: 2
# code:0009-0050-02
# resRXN len:0
# n:0009-0055-01
# res len: 1
# n:0009-0056-04
# res len: 2
# code:0009-0056-04
# resRXN len:0
# n:0009-0280-02
# res len: 2
# code:0009-0280-02
# resRXN len:0
# n:0009-0306-12
# res len: 1
# n:0009-0395-14
# res len: 1
# n:0009-0417-01
# res len: 1
# n:0009-0746-30
# res len: 1
# n:0009-3116-01
# res len: 1
# n:00093-7146-18
# res len: 1
# n:00093001298
# res len: 1
# n:00093005805
# res len: 1
# n:00093083201
# res len: 1
# n:00093202631
# res len: 1
# n:00093738498
# res len: 1
# n:00143-1473-01
# res len: 1
# n:00143973910
# res len: 1
# n:00168-0004-15
# res len: 1
# n:00172541211
# res len: 1
# n:00173068220
# res len: 1
# n:00185-0415-01
# res len: 1
# n:00228-2029-10
# res len: 1
# n:0023-0316-04
# res len: 1
# n:0023-3240-15
# res len: 1
# n:0023-9163-30
# res len: 2
# code:0023-9163-30
# resRXN len:0
# n:0024-5401-31
# res len: 2
# code:0024-5401-31
# resRXN len:0
# n:0025-1031-31
# res len: 1
# n:0025-1525-31
# res len: 2
# code:0025-1525-31
# resRXN len:0
# n:0025-1821-31
# res len: 5
# code:0025-1821-31
# resRXN len:0
# n:0029-1525-44
# res len: 2
# code:0029-1525-44
# resRXN len:0
# n:0032-1224-01
# res len: 1
# n:0032-1708-01
# res len: 1
# n:0037-0241-10
# res len: 1
# n:00378075110
# res len: 1
# n:00378181301
# res len: 1
# n:00378341201
# res len: 1
# n:00378363701
# res len: 1
# n:0045-0449-05
# res len: 2
# code:0045-0449-05
# resRXN len:0
# n:0046-0872-21
# res len: 1
# n:00487-9501-01
# res len: 1
# n:0049-2340-45
# res len: 3
# code:0049-2340-45
# resRXN len:0
# n:0049-3500-79
# res len: 3
# code:0049-3500-79
# resRXN len:0
# n:0049-4900-41
# res len: 2
# code:0049-4900-41
# resRXN len:0
# n:0049-4910-30
# res len: 1
# n:0049-4910-41
# res len: 3
# code:0049-4910-41
# resRXN len:0
# n:0051-0021-21
# res len: 1
# n:0051-8462-33
# res len: 2
# code:0051-8462-33
# resRXN len:0
# n:0052-0105-30
# res len: 2
# code:0052-0105-30
# resRXN len:0
# n:0052-0273-01
# res len: 4
# code:0052-0273-01
# resRXN len:0
# n:0052-0274-01
# res len: 2
# code:0052-0274-01
# resRXN len:0
# n:0052-0301-51
# res len: 2
# code:0052-0301-51
# resRXN len:0
# n:0054-0010-21
# res len: 1
# n:0054-0018-20
# res len: 2
# code:0054-0018-20
# resRXN len:0
# n:0054-0021-25
# res len: 1
# n:0054-0037-21
# res len: 2
# code:0054-0037-21
# resRXN len:0
# n:0054-0046-41
# res len: 3
# code:0054-0046-41
# resRXN len:0
# n:0054-0085-25
# res len: 2
# code:0054-0085-25
# resRXN len:0
# n:0054-0086-25
# res len: 2
# code:0054-0086-25
# resRXN len:0
# n:0054-0086-29
# res len: 2
# code:0054-0086-29
# resRXN len:0
# n:0054-0087-25
# res len: 4
# code:0054-0087-25
# resRXN len:0
# n:0054-0098-20
# res len: 1
# n:0054-0117-25
# res len: 1
# n:0054-0163-25
# res len: 2
# code:0054-0163-25
# resRXN len:0
# n:0054-0166-25
# res len: 3
# code:0054-0166-25
# resRXN len:0
# n:0054-0177-13
# res len: 1
# n:0054-0220-25
# res len: 4
# code:0054-0220-25
# resRXN len:0
# n:0054-0222-25
# res len: 2
# code:0054-0222-25
# resRXN len:0
# n:0054-0229-25
# res len: 1
# n:0054-0244-24
# res len: 1
# n:0054-0259-13
# res len: 4
# code:0054-0259-13
# resRXN len:0
# n:0054-0269-13
# res len: 2
# code:0054-0269-13
# resRXN len:0
# n:0054-0279-03
# res len: 2
# code:0054-0279-03
# resRXN len:0
# n:0054-2527-25
# res len: 2
# code:0054-2527-25
# resRXN len:0
# n:0054-3270-99
# res len: 5
# code:0054-3270-99
# resRXN len:0
# n:0054-4084-25
# res len: 2
# code:0054-4084-25
# resRXN len:0
# numProcessed:100
# n:0054-4120-25
# res len: 1
# n:0054-4184-25
# res len: 4
# code:0054-4184-25
# resRXN len:0
# n:0054-4297-25
# res len: 4
# code:0054-4297-25
# resRXN len:0
# n:0054-4299-25
# res len: 3
# code:0054-4299-25
# resRXN len:0
# n:0054-4527-25
# res len: 2
# code:0054-4527-25
# resRXN len:0
# n:0054-4570-25
# res len: 2
# code:0054-4570-25
# resRXN len:0
# n:0054-4581-11
# res len: 2
# code:0054-4581-11
# resRXN len:0
# n:0054-4728-25
# res len: 3
# code:0054-4728-25
# resRXN len:0
# n:00555-9016-58
# res len: 1
# n:00555030202
# res len: 1
# n:00555097302
# res len: 1
# n:0056-0169-70
# res len: 1
# n:00603107558
# res len: 1
# n:00603499821
# res len: 1
# n:0065-0271-05
# res len: 1
# n:0065-0272-25
# res len: 2
# code:0065-0272-25
# resRXN len:0
# n:0066-0494-25
# res len: 1
# n:0067-4345-04
# res len: 1
# n:0068-0226-30
# res len: 1
# n:0069-3060-30
# res len: 2
# code:0069-3060-30
# resRXN len:0
# n:0069-3060-75
# res len: 3
# code:0069-3060-75
# resRXN len:0
# n:0069-5410-66
# res len: 4
# code:0069-5410-66
# resRXN len:0
# n:0071-0156-23
# res len: 3
# code:0071-0156-23
# resRXN len:0
# n:0071-0157-23
# res len: 1
# n:0071-0418-13
# res len: 4
# code:0071-0418-13
# resRXN len:0
# n:0071-0805-24
# res len: 1
# n:0071-1015-68
# res len: 2
# code:0071-1015-68
# resRXN len:0
# n:0074-3333-30
# res len: 1
# n:0074-3799-02
# res len: 2
# code:0074-3799-02
# resRXN len:0
# n:0074-4339-02
# res len: 1
# n:0074-4552-11
# res len: 3
# code:0074-4552-11
# resRXN len:0
# n:0074-6594-19
# res len: 1
# n:0074-6624-11
# res len: 2
# code:0074-6624-11
# resRXN len:0
# n:0074-7069-11
# res len: 2
# code:0074-7069-11
# resRXN len:0
# n:0074-7070-19
# res len: 2
# code:0074-7070-19
# resRXN len:0
# n:0074-7804-19
# res len: 1
# n:0074-9296-19
# res len: 1
# n:0078-0084-05
# res len: 2
# code:0078-0084-05
# resRXN len:0
# n:00781261305
# res len: 1
# n:0085-0924-01
# res len: 1
# n:0085-1132-01
# res len: 2
# code:0085-1132-01
# resRXN len:0
# n:0085-1341-07
# res len: 1
# n:0085-4610-01
# res len: 2
# code:0085-4610-01
# resRXN len:0
# n:0085-7206-01
# res len: 2
# code:0085-7206-01
# resRXN len:0
# n:0087-6063-13
# res len: 2
# code:0087-6063-13
# resRXN len:0
# n:0088-2219-05
# res len: 4
# code:0088-2219-05
# resRXN len:0
# n:0088-2220-33
# res len: 2
# code:0088-2220-33
# resRXN len:0
# n:0093-0011-98
# res len: 5
# code:0093-0011-98
# resRXN len:0
# n:0093-0012-98
# res len: 5
# code:0093-0012-98
# resRXN len:0
# n:0093-0027-01
# res len: 1
# n:0093-0029-01
# res len: 1
# n:0093-0039-01
# res len: 5
# code:0093-0039-01
# resRXN len:0
# n:0093-0041-03
# res len: 3
# code:0093-0041-03
# resRXN len:0
# n:0093-0051-01
# res len: 1
# n:0093-0053-01
# res len: 3
# code:0093-0053-01
# resRXN len:0
# n:0093-0054-01
# res len: 3
# code:0093-0054-01
# resRXN len:0
# n:0093-0058-01
# res len: 4
# code:0093-0058-01
# resRXN len:0
# n:0093-0135-01
# res len: 1
# n:0093-0147-01
# res len: 2
# code:0093-0147-01
# resRXN len:0
# n:0093-0148-01
# res len: 1
# n:0093-0149-01
# res len: 6
# code:0093-0149-01
# resRXN len:0
# n:0093-0150-01
# res len: 3
# code:0093-0150-01
# resRXN len:0
# n:0093-0155-06
# res len: 3
# code:0093-0155-06
# resRXN len:0
# n:0093-0264-15
# res len: 2
# code:0093-0264-15
# resRXN len:0
# n:0093-0293-01
# res len: 2
# code:0093-0293-01
# resRXN len:0
# n:0093-0311-01
# res len: 2
# code:0093-0311-01
# resRXN len:0
# n:0093-0314-01
# res len: 3
# code:0093-0314-01
# resRXN len:0
# n:0093-0350-01
# res len: 1
# n:0093-0463-01
# res len: 3
# code:0093-0463-01
# resRXN len:0
# n:0093-0537-01
# res len: 2
# code:0093-0537-01
# resRXN len:0
# n:0093-0576-06
# res len: 2
# code:0093-0576-06
# resRXN len:0
# n:0093-0657-01
# res len: 2
# code:0093-0657-01
# resRXN len:0
# n:0093-0670-05
# res len: 2
# code:0093-0670-05
# resRXN len:0
# n:0093-0733-01
# res len: 2
# code:0093-0733-01
# resRXN len:0
# n:0093-0734-01
# res len: 2
# code:0093-0734-01
# resRXN len:0
# n:0093-0752-01
# res len: 3
# code:0093-0752-01
# resRXN len:0
# n:0093-0753-01
# res len: 2
# code:0093-0753-01
# resRXN len:0
# n:0093-0771-98
# res len: 2
# code:0093-0771-98
# resRXN len:0
# n:0093-0810-01
# res len: 2
# code:0093-0810-01
# resRXN len:0
# n:0093-0810-05
# res len: 1
# n:0093-0811-01
# res len: 3
# code:0093-0811-01
# resRXN len:0
# n:0093-0832-01
# res len: 6
# code:0093-0832-01
# resRXN len:0
# n:0093-0833-01
# res len: 2
# code:0093-0833-01
# resRXN len:0
# n:0093-0834-01
# res len: 1
# n:0093-0840-15
# res len: 3
# code:0093-0840-15
# resRXN len:0
# n:0093-0900-01
# res len: 2
# code:0093-0900-01
# resRXN len:0
# n:0093-1003-01
# res len: 2
# code:0093-1003-01
# resRXN len:0
# n:0093-1010-42
# res len: 3
# code:0093-1010-42
# resRXN len:0
# n:0093-1015-01
# res len: 2
# code:0093-1015-01
# resRXN len:0
# n:0093-1048-01
# res len: 5
# code:0093-1048-01
# resRXN len:0
# n:0093-1049-01
# res len: 2
# code:0093-1049-01
# resRXN len:0
# n:0093-1174-01
# res len: 2
# code:0093-1174-01
# resRXN len:0
# n:0093-2060-98
# res len: 2
# code:0093-2060-98
# resRXN len:0
# n:0093-2085-17
# res len: 4
# code:0093-2085-17
# resRXN len:0
# n:0093-2203-01
# res len: 3
# code:0093-2203-01
# resRXN len:0
# n:0093-2204-01
# res len: 3
# code:0093-2204-01
# resRXN len:0
# n:0093-2210-01
# res len: 2
# code:0093-2210-01
# resRXN len:0
# n:0093-2263-01
# res len: 2
# code:0093-2263-01
# resRXN len:0
# n:0093-2264-01
# res len: 3
# code:0093-2264-01
# resRXN len:0
# n:0093-2275-34
# res len: 7
# code:0093-2275-34
# resRXN len:0
# numProcessed:200
# n:0093-3109-05
# res len: 4
# code:0093-3109-05
# resRXN len:0
# n:0093-3109-53
# res len: 1
# n:0093-3125-01
# res len: 1
# n:0093-3147-01
# res len: 3
# code:0093-3147-01
# resRXN len:0
# n:0093-3160-06
# res len: 2
# code:0093-3160-06
# resRXN len:0
# n:0093-3167-53
# res len: 2
# code:0093-3167-53
# resRXN len:0
# n:0093-4177-73
# res len: 2
# code:0093-4177-73
# resRXN len:0
# n:0093-5171-44
# res len: 3
# code:0093-5171-44
# resRXN len:0
# n:0093-5353-01
# res len: 1
# n:0093-5354-01
# res len: 4
# code:0093-5354-01
# resRXN len:0
# n:0093-5852-01
# res len: 1
# n:0093-6450-56
# res len: 2
# code:0093-6450-56
# resRXN len:0
# n:0093-6451-56
# res len: 3
# code:0093-6451-56
# resRXN len:0
# n:0093-6815-73
# res len: 2
# code:0093-6815-73
# resRXN len:0
# n:0093-6816-73
# res len: 2
# code:0093-6816-73
# resRXN len:0
# n:0093-7146-09
# res len: 5
# code:0093-7146-09
# resRXN len:0
# n:0093-7146-18
# res len: 2
# code:0093-7146-18
# resRXN len:0
# n:0093-7153-10
# res len: 2
# code:0093-7153-10
# resRXN len:0
# n:0093-7154-10
# res len: 3
# code:0093-7154-10
# resRXN len:0
# n:0093-7155-10
# res len: 4
# code:0093-7155-10
# resRXN len:0
# n:0093-7166-01
# res len: 1
# n:0093-7169-56
# res len: 3
# code:0093-7169-56
# resRXN len:0
# n:0093-7188-10
# res len: 1
# n:0093-7198-56
# res len: 3
# code:0093-7198-56
# resRXN len:0
# n:0093-7201-10
# res len: 1
# n:0093-7202-10
# res len: 2
# code:0093-7202-10
# resRXN len:0
# n:0093-7206-56
# res len: 2
# code:0093-7206-56
# resRXN len:0
# n:0093-7212-01
# res len: 3
# code:0093-7212-01
# resRXN len:0
# n:0093-7214-01
# res len: 3
# code:0093-7214-01
# resRXN len:0
# n:0093-7219-06
# res len: 1
# n:0093-7234-01
# res len: 2
# code:0093-7234-01
# resRXN len:0
# n:0093-7247-06
# res len: 2
# code:0093-7247-06
# resRXN len:0
# n:0093-7248-06
# res len: 3
# code:0093-7248-06
# resRXN len:0
# n:0093-7255-01
# res len: 1
# n:0093-7256-01
# res len: 3
# code:0093-7256-01
# resRXN len:0
# n:0093-7292-53
# res len: 2
# code:0093-7292-53
# resRXN len:0
# n:0093-7293-53
# res len: 2
# code:0093-7293-53
# resRXN len:0
# n:0093-7295-01
# res len: 2
# code:0093-7295-01
# resRXN len:0
# n:0093-7296-01
# res len: 2
# code:0093-7296-01
# resRXN len:0
# n:0093-7350-56
# res len: 4
# code:0093-7350-56
# resRXN len:0
# n:0093-7351-56
# res len: 3
# code:0093-7351-56
# resRXN len:0
# n:0093-7355-56
# res len: 3
# code:0093-7355-56
# resRXN len:0
# n:0093-7364-10
# res len: 4
# code:0093-7364-10
# resRXN len:0
# n:0093-7365-10
# res len: 4
# code:0093-7365-10
# resRXN len:0
# n:0093-7366-10
# res len: 4
# code:0093-7366-10
# resRXN len:0
# n:0093-7367-10
# res len: 2
# code:0093-7367-10
# resRXN len:0
# n:0093-7371-01
# res len: 1
# n:0093-7382-01
# res len: 3
# code:0093-7382-01
# resRXN len:0
# n:0093-7384-56
# res len: 2
# code:0093-7384-56
# resRXN len:0
# n:0093-7385-56
# res len: 5
# code:0093-7385-56
# resRXN len:0
# n:0093-7386-56
# res len: 7
# code:0093-7386-56
# resRXN len:0
# n:0093-7426-98
# res len: 3
# code:0093-7426-98
# resRXN len:0
# n:0093-7465-05
# res len: 2
# code:0093-7465-05
# resRXN len:0
# n:0093-7474-89
# res len: 2
# code:0093-7474-89
# resRXN len:0
# n:0093-7540-06
# res len: 3
# code:0093-7540-06
# resRXN len:0
# n:0093-7542-06
# res len: 2
# code:0093-7542-06
# resRXN len:0
# n:0093-7543-56
# res len: 2
# code:0093-7543-56
# resRXN len:0
# n:0093-7544-56
# res len: 2
# code:0093-7544-56
# resRXN len:0
# n:0093-7569-56
# res len: 2
# code:0093-7569-56
# resRXN len:0
# n:0093-7580-56
# res len: 1
# n:0093-7613-56
# res len: 1
# n:0093-8342-01
# res len: 1
# n:0093-8343-01
# res len: 4
# code:0093-8343-01
# resRXN len:0
# n:0093-8344-01
# res len: 2
# code:0093-8344-01
# resRXN len:0
# n:0093-8940-01
# res len: 2
# code:0093-8940-01
# resRXN len:0
# n:0093-8943-01
# res len: 4
# code:0093-8943-01
# resRXN len:0
# n:0093-8947-01
# res len: 3
# code:0093-8947-01
# resRXN len:0
# n:0093-9133-06
# res len: 2
# code:0093-9133-06
# resRXN len:0
# n:0093-9652-01
# res len: 4
# code:0093-9652-01
# resRXN len:0
# n:0096-0707-35
# res len: 2
# code:0096-0707-35
# resRXN len:0
# n:01100040100315
# res len: 1
# n:0113-0274-68
# res len: 4
# code:0113-0274-68
# resRXN len:0
# n:0113-0416-78
# res len: 1
# n:0113-0604-62
# res len: 5
# code:0113-0604-62
# resRXN len:0
# n:0115-1331-01
# res len: 1
# n:0115-6811-08
# res len: 1
# n:0115-8211-01
# res len: 6
# code:0115-8211-01
# resRXN len:0
# n:0116-2001-16
# res len: 1
# n:01200010100110
# res len: 2
# code:01200010100110
# resRXN len:0
# n:01200010100315
# res len: 1
# n:0121-0638-05
# res len: 3
# code:0121-0638-05
# resRXN len:0
# n:0121-0747-10
# res len: 2
# code:0121-0747-10
# resRXN len:0
# n:0121-1744-05
# res len: 2
# code:0121-1744-05
# resRXN len:0
# n:0121-4811-05
# res len: 1
# n:01300020100115
# res len: 1
# n:0132-0201-40
# res len: 1
# n:0135-0070-03
# res len: 2
# code:0135-0070-03
# resRXN len:0
# n:0140-0004-01
# res len: 1
# n:0140-0005-01
# res len: 2
# code:0140-0005-01
# resRXN len:0
# n:0143-1263-01
# res len: 3
# code:0143-1263-01
# resRXN len:0
# n:0143-1264-01
# res len: 4
# code:0143-1264-01
# resRXN len:0
# n:0143-1265-01
# res len: 2
# code:0143-1265-01
# resRXN len:0
# n:0143-1267-01
# res len: 3
# code:0143-1267-01
# resRXN len:0
# n:0143-1270-01
# res len: 3
# code:0143-1270-01
# resRXN len:0
# n:0143-1290-01
# res len: 4
# code:0143-1290-01
# resRXN len:0
# n:0143-1292-01
# res len: 2
# code:0143-1292-01
# resRXN len:0
# n:0143-1473-01
# res len: 4
# code:0143-1473-01
# resRXN len:0
# n:0143-1787-01
# res len: 2
# code:0143-1787-01
# resRXN len:0
# n:0143-2112-05
# res len: 3
# code:0143-2112-05
# resRXN len:0
# n:0143-3142-05
# res len: 2
# code:0143-3142-05
# resRXN len:0
# numProcessed:300
# n:0143-9924-90
# res len: 1
# n:0143-9928-01
# res len: 1
# n:0168-0003-15
# res len: 2
# code:0168-0003-15
# resRXN len:0
# n:0168-0004-15
# res len: 2
# code:0168-0004-15
# resRXN len:0
# n:0168-0006-15
# res len: 2
# code:0168-0006-15
# resRXN len:0
# n:0168-0059-60
# res len: 2
# code:0168-0059-60
# resRXN len:0
# n:0168-0080-16
# res len: 3
# code:0168-0080-16
# resRXN len:0
# n:0168-0089-15
# res len: 1
# n:0168-0134-60
# res len: 2
# code:0168-0134-60
# resRXN len:0
# n:0168-0146-30
# res len: 1
# n:0168-0162-15
# res len: 2
# code:0168-0162-15
# resRXN len:0
# n:0168-0162-30
# res len: 1
# n:0168-0163-15
# res len: 4
# code:0168-0163-15
# resRXN len:0
# n:0168-0201-60
# res len: 3
# code:0168-0201-60
# resRXN len:0
# n:0168-0202-30
# res len: 2
# code:0168-0202-30
# resRXN len:0
# n:0168-0202-60
# res len: 1
# n:0168-0203-60
# res len: 4
# code:0168-0203-60
# resRXN len:0
# n:0168-0204-37
# res len: 2
# code:0168-0204-37
# resRXN len:0
# n:0168-0258-15
# res len: 2
# code:0168-0258-15
# resRXN len:0
# n:0168-0275-45
# res len: 2
# code:0168-0275-45
# resRXN len:0
# n:0168-0312-15
# res len: 1
# n:0168-0323-46
# res len: 3
# code:0168-0323-46
# resRXN len:0
# n:0168-0357-30
# res len: 1
# n:0169-4060-12
# res len: 1
# n:0169-4060-13
# res len: 2
# code:0169-4060-13
# resRXN len:0
# n:0169-5176-03
# res len: 2
# code:0169-5176-03
# resRXN len:0
# n:0169-6339-10
# res len: 5
# code:0169-6339-10
# resRXN len:0
# n:0169-6438-10
# res len: 2
# code:0169-6438-10
# resRXN len:0
# n:0169-7501-11
# res len: 3
# code:0169-7501-11
# resRXN len:0
# n:0172-2083-60
# res len: 3
# code:0172-2083-60
# resRXN len:0
# n:0172-3757-60
# res len: 1
# n:0172-3758-60
# res len: 3
# code:0172-3758-60
# resRXN len:0
# n:0172-3758-70
# res len: 1
# n:0172-3759-60
# res len: 1
# n:0172-3760-60
# res len: 4
# code:0172-3760-60
# resRXN len:0
# n:0172-3925-60
# res len: 2
# code:0172-3925-60
# resRXN len:0
# n:0172-3926-60
# res len: 2
# code:0172-3926-60
# resRXN len:0
# n:0172-3927-60
# res len: 2
# code:0172-3927-60
# resRXN len:0
# n:0172-4096-60
# res len: 3
# code:0172-4096-60
# resRXN len:0
# n:0172-4357-49
# res len: 3
# code:0172-4357-49
# resRXN len:0
# n:0172-4363-70
# res len: 1
# n:0172-4364-60
# res len: 2
# code:0172-4364-60
# resRXN len:0
# n:0172-4365-60
# res len: 5
# code:0172-4365-60
# resRXN len:0
# n:0172-4366-60
# res len: 2
# code:0172-4366-60
# resRXN len:0
# n:0172-5032-60
# res len: 2
# code:0172-5032-60
# resRXN len:0
# n:0172-5411-46
# res len: 2
# code:0172-5411-46
# resRXN len:0
# n:0172-5412-11
# res len: 3
# code:0172-5412-11
# resRXN len:0
# n:0172-5413-46
# res len: 2
# code:0172-5413-46
# resRXN len:0
# n:0172-5728-60
# res len: 5
# code:0172-5728-60
# resRXN len:0
# n:0172-5728-80
# res len: 1
# n:0173-0135-55
# res len: 2
# code:0173-0135-55
# resRXN len:0
# n:0173-0178-55
# res len: 2
# code:0173-0178-55
# resRXN len:0
# n:0173-0344-14
# res len: 2
# code:0173-0344-14
# resRXN len:0
# n:0173-0446-00
# res len: 4
# code:0173-0446-00
# resRXN len:0
# n:0173-0447-00
# res len: 2
# code:0173-0447-00
# resRXN len:0
# n:0173-0453-01
# res len: 1
# n:0173-0569-00
# res len: 5
# code:0173-0569-00
# resRXN len:0
# n:0173-0570-00
# res len: 2
# code:0173-0570-00
# resRXN len:0
# n:0173-0642-55
# res len: 1
# n:0173-0644-60
# res len: 1
# n:0173-0682-20
# res len: 5
# code:0173-0682-20
# resRXN len:0
# n:0173-0696-00
# res len: 1
# n:0173-0697-00
# res len: 4
# code:0173-0697-00
# resRXN len:0
# n:0173-0717-20
# res len: 2
# code:0173-0717-20
# resRXN len:0
# n:0173-0736-01
# res len: 1
# n:0178-0089-90
# res len: 1
# n:0178-0891-30
# res len: 2
# code:0178-0891-30
# resRXN len:0
# n:0182-4028-01
# res len: 1
# n:0182-4039-01
# res len: 1
# n:0182-8453-89
# res len: 1
# n:0185-0010-05
# res len: 1
# n:0185-0034-10
# res len: 1
# n:0185-0063-01
# res len: 1
# n:0185-0111-01
# res len: 3
# code:0185-0111-01
# resRXN len:0
# n:0185-0117-05
# res len: 1
# n:0185-0205-01
# res len: 2
# code:0185-0205-01
# resRXN len:0
# n:0185-0210-01
# res len: 2
# code:0185-0210-01
# resRXN len:0
# n:0185-0281-01
# res len: 4
# code:0185-0281-01
# resRXN len:0
# n:0185-0371-01
# res len: 2
# code:0185-0371-01
# resRXN len:0
# n:0185-0372-01
# res len: 4
# code:0185-0372-01
# resRXN len:0
# n:0185-0373-01
# res len: 5
# code:0185-0373-01
# resRXN len:0
# n:0185-0401-01
# res len: 4
# code:0185-0401-01
# resRXN len:0
# n:0185-0404-01
# res len: 3
# code:0185-0404-01
# resRXN len:0
# n:0185-0410-05
# res len: 1
# n:0185-0415-01
# res len: 3
# code:0185-0415-01
# resRXN len:0
# n:0185-0648-01
# res len: 2
# code:0185-0648-01
# resRXN len:0
# n:0185-0771-01
# res len: 1
# n:0185-0932-30
# res len: 2
# code:0185-0932-30
# resRXN len:0
# n:0185-4400-10
# res len: 4
# code:0185-4400-10
# resRXN len:0
# n:0185-7322-30
# res len: 1
# n:0186-0370-20
# res len: 2
# code:0186-0370-20
# resRXN len:0
# n:0186-0372-20
# res len: 1
# n:0186-0742-31
# res len: 3
# code:0186-0742-31
# resRXN len:0
# n:0186-0916-12
# res len: 2
# code:0186-0916-12
# resRXN len:0
# n:0186-5020-31
# res len: 2
# code:0186-5020-31
# resRXN len:0
# n:0186-5040-31
# res len: 2
# code:0186-5040-31
# resRXN len:0
# n:0193-2880-21
# res len: 1
# n:0193-2880-50
# res len: 1
# n:0193-7310-25
# res len: 1
# n:01990002200340
# res len: 5
# code:01990002200340
# resRXN len:0
# numProcessed:400
# n:02100020000110
# res len: 3
# code:02100020000110
# resRXN len:0
# n:02200065050310
# res len: 2
# code:02200065050310
# resRXN len:0
# n:02200065050315
# res len: 2
# code:02200065050315
# resRXN len:0
# n:0228-2027-10
# res len: 4
# code:0228-2027-10
# resRXN len:0
# n:0228-2029-10
# res len: 3
# code:0228-2029-10
# resRXN len:0
# n:0228-2031-10
# res len: 4
# code:0228-2031-10
# resRXN len:0
# n:0228-2039-10
# res len: 1
# n:0228-2057-10
# res len: 4
# code:0228-2057-10
# resRXN len:0
# n:0228-2059-10
# res len: 2
# code:0228-2059-10
# resRXN len:0
# n:0228-2127-10
# res len: 3
# code:0228-2127-10
# resRXN len:0
# n:0228-2348-10
# res len: 2
# code:0228-2348-10
# resRXN len:0
# n:0228-2551-06
# res len: 2
# code:0228-2551-06
# resRXN len:0
# n:0228-2636-11
# res len: 4
# code:0228-2636-11
# resRXN len:0
# n:0228-2637-11
# res len: 1
# n:0228-2666-11
# res len: 1
# n:0228-2672-11
# res len: 3
# code:0228-2672-11
# resRXN len:0
# n:0228-2673-11
# res len: 1
# n:0228-2820-11
# res len: 2
# code:0228-2820-11
# resRXN len:0
# n:0228-3004-11
# res len: 1
# n:0228-3262-11
# res len: 1
# n:0228-3481-11
# res len: 2
# code:0228-3481-11
# resRXN len:0
# n:02300040000120
# res len: 1
# n:0245-0108-01
# res len: 2
# code:0245-0108-01
# resRXN len:0
# n:0247-1053-20
# res len: 2
# code:0247-1053-20
# resRXN len:0
# n:0247-1253-16
# res len: 2
# code:0247-1253-16
# resRXN len:0
# n:0256-0152-02
# res len: 1
# n:0264-1800-36
# res len: 1
# n:0299-5908-45
# res len: 2
# code:0299-5908-45
# resRXN len:0
# n:0299-5918-25
# res len: 1
# n:0299-5918-45
# res len: 1
# n:0310-0275-10
# res len: 2
# code:0310-0275-10
# resRXN len:0
# n:0310-0751-39
# res len: 2
# code:0310-0751-39
# resRXN len:0
# n:0310-6100-30
# res len: 1
# n:0310-6520-04
# res len: 2
# code:0310-6520-04
# resRXN len:0
# n:03400010000320
# res len: 6
# code:03400010000320
# resRXN len:0
# n:03400010000334
# res len: 3
# code:03400010000334
# resRXN len:0
# n:03500010000320
# res len: 2
# code:03500010000320
# resRXN len:0
# n:0378-0018-01
# res len: 4
# code:0378-0018-01
# resRXN len:0
# n:0378-0137-01
# res len: 1
# n:0378-0147-01
# res len: 2
# code:0378-0147-01
# resRXN len:0
# n:0378-0182-01
# res len: 4
# code:0378-0182-01
# resRXN len:0
# n:0378-0183-01
# res len: 2
# code:0378-0183-01
# resRXN len:0
# n:0378-0184-01
# res len: 4
# code:0378-0184-01
# resRXN len:0
# n:0378-0208-01
# res len: 1
# n:0378-0214-01
# res len: 1
# n:0378-0218-01
# res len: 2
# code:0378-0218-01
# resRXN len:0
# n:0378-0222-01
# res len: 2
# code:0378-0222-01
# resRXN len:0
# n:0378-0373-01
# res len: 4
# code:0378-0373-01
# resRXN len:0
# n:0378-0421-01
# res len: 1
# n:0378-0433-01
# res len: 3
# code:0378-0433-01
# resRXN len:0
# n:0378-0435-01
# res len: 2
# code:0378-0435-01
# resRXN len:0
# n:0378-0472-01
# res len: 2
# code:0378-0472-01
# resRXN len:0
# n:0378-0751-01
# res len: 5
# code:0378-0751-01
# resRXN len:0
# n:0378-0771-01
# res len: 3
# code:0378-0771-01
# resRXN len:0
# n:0378-0810-01
# res len: 1
# n:0378-0871-99
# res len: 2
# code:0378-0871-99
# resRXN len:0
# n:0378-1066-01
# res len: 1
# n:0378-1089-01
# res len: 2
# code:0378-1089-01
# resRXN len:0
# n:0378-1105-01
# res len: 2
# code:0378-1105-01
# resRXN len:0
# n:0378-1110-01
# res len: 2
# code:0378-1110-01
# resRXN len:0
# n:0378-1110-05
# res len: 1
# n:0378-1404-96
# res len: 2
# code:0378-1404-96
# resRXN len:0
# n:0378-1458-01
# res len: 2
# code:0378-1458-01
# resRXN len:0
# n:0378-1610-01
# res len: 2
# code:0378-1610-01
# resRXN len:0
# n:0378-1620-01
# res len: 2
# code:0378-1620-01
# resRXN len:0
# n:0378-1705-05
# res len: 2
# code:0378-1705-05
# resRXN len:0
# n:0378-1707-05
# res len: 2
# code:0378-1707-05
# resRXN len:0
# n:0378-1800-01
# res len: 6
# code:0378-1800-01
# resRXN len:0
# n:0378-1803-01
# res len: 5
# code:0378-1803-01
# resRXN len:0
# n:0378-1805-01
# res len: 4
# code:0378-1805-01
# resRXN len:0
# n:0378-1807-01
# res len: 3
# code:0378-1807-01
# resRXN len:0
# n:0378-1809-01
# res len: 3
# code:0378-1809-01
# resRXN len:0
# n:0378-1811-01
# res len: 3
# code:0378-1811-01
# resRXN len:0
# n:0378-1813-01
# res len: 3
# code:0378-1813-01
# resRXN len:0
# n:0378-1815-01
# res len: 3
# code:0378-1815-01
# resRXN len:0
# n:0378-1817-01
# res len: 3
# code:0378-1817-01
# resRXN len:0
# n:0378-1819-01
# res len: 2
# code:0378-1819-01
# resRXN len:0
# n:0378-2042-01
# res len: 2
# code:0378-2042-01
# resRXN len:0
# n:0378-2071-05
# res len: 2
# code:0378-2071-05
# resRXN len:0
# n:0378-2076-01
# res len: 1
# n:0378-2146-01
# res len: 3
# code:0378-2146-01
# resRXN len:0
# n:0378-2302-01
# res len: 2
# code:0378-2302-01
# resRXN len:0
# n:0378-2537-01
# res len: 1
# n:0378-2610-01
# res len: 4
# code:0378-2610-01
# resRXN len:0
# n:0378-2625-01
# res len: 3
# code:0378-2625-01
# resRXN len:0
# n:0378-2650-01
# res len: 1
# n:0378-3040-01
# res len: 1
# n:0378-3050-01
# res len: 1
# n:0378-3125-01
# res len: 1
# n:0378-3422-01
# res len: 7
# code:0378-3422-01
# resRXN len:0
# n:0378-3611-01
# res len: 2
# code:0378-3611-01
# resRXN len:0
# n:0378-3635-01
# res len: 2
# code:0378-3635-01
# resRXN len:0
# n:0378-3637-01
# res len: 5
# code:0378-3637-01
# resRXN len:0
# n:0378-3702-59
# res len: 2
# code:0378-3702-59
# resRXN len:0
# n:0378-3855-77
# res len: 2
# code:0378-3855-77
# resRXN len:0
# n:0378-3856-10
# res len: 4
# code:0378-3856-10
# resRXN len:0
# n:0378-3857-10
# res len: 2
# code:0378-3857-10
# resRXN len:0
# n:0378-4188-01
# res len: 1
# n:0378-4543-01
# res len: 2
# code:0378-4543-01
# resRXN len:0
# n:0378-4546-01
# res len: 2
# code:0378-4546-01
# resRXN len:0
# numProcessed:500
# n:0378-4547-01
# res len: 2
# code:0378-4547-01
# resRXN len:0
# n:0378-5050-01
# res len: 1
# n:0378-5208-05
# res len: 3
# code:0378-5208-05
# resRXN len:0
# n:0378-5209-77
# res len: 3
# code:0378-5209-77
# resRXN len:0
# n:0378-5210-05
# res len: 1
# n:0378-5210-77
# res len: 5
# code:0378-5210-77
# resRXN len:0
# n:0378-5211-93
# res len: 1
# n:0378-5340-01
# res len: 2
# code:0378-5340-01
# resRXN len:0
# n:0378-5615-05
# res len: 2
# code:0378-5615-05
# resRXN len:0
# n:0378-5617-05
# res len: 2
# code:0378-5617-05
# resRXN len:0
# n:0378-5630-59
# res len: 1
# n:0378-6150-93
# res len: 4
# code:0378-6150-93
# resRXN len:0
# n:0378-6160-01
# res len: 1
# n:0378-6323-05
# res len: 2
# code:0378-6323-05
# resRXN len:0
# n:0378-6605-01
# res len: 1
# n:0378-6610-01
# res len: 2
# code:0378-6610-01
# resRXN len:0
# n:0378-6727-01
# res len: 2
# code:0378-6727-01
# resRXN len:0
# n:0378-7280-53
# res len: 3
# code:0378-7280-53
# resRXN len:0
# n:0378-7283-53
# res len: 2
# code:0378-7283-53
# resRXN len:0
# n:0378-7296-53
# res len: 2
# code:0378-7296-53
# resRXN len:0
# n:0378-7732-93
# res len: 10
# code:0378-7732-93
# resRXN len:0
# n:0378-7734-93
# res len: 1
# n:0378-8688-54
# res len: 3
# code:0378-8688-54
# resRXN len:0
# n:0378-9121-98
# res len: 3
# code:0378-9121-98
# resRXN len:0
# n:0378-9122-98
# res len: 2
# code:0378-9122-98
# resRXN len:0
# n:0378-9123-98
# res len: 2
# code:0378-9123-98
# resRXN len:0
# n:04000020000110
# res len: 2
# code:04000020000110
# resRXN len:0
# n:04000020100110
# res len: 1
# n:04000020100310
# res len: 2
# code:04000020100310
# resRXN len:0
# n:0406-0365-01
# res len: 2
# code:0406-0365-01
# resRXN len:0
# n:0406-0367-01
# res len: 1
# n:0406-0484-62
# res len: 1
# n:0406-0512-01
# res len: 9
# code:0406-0512-01
# resRXN len:0
# n:0406-0552-01
# res len: 8
# code:0406-0552-01
# resRXN len:0
# n:0406-0594-01
# res len: 1
# n:0406-3243-01
# res len: 4
# code:0406-3243-01
# resRXN len:0
# n:0406-3244-01
# res len: 4
# code:0406-3244-01
# resRXN len:0
# n:0406-8315-01
# res len: 3
# code:0406-8315-01
# resRXN len:0
# n:0406-8330-01
# res len: 2
# code:0406-8330-01
# resRXN len:0
# n:0406-8380-01
# res len: 2
# code:0406-8380-01
# resRXN len:0
# n:0406-8515-01
# res len: 1
# n:0407-1412-10
# res len: 1
# n:0409-3795-49
# res len: 1
# n:0409-9094-31
# res len: 1
# n:0430-0420-14
# res len: 4
# code:0430-0420-14
# resRXN len:0
# n:04351-79710
# res len: 1
# n:0440-7010-01
# res len: 4
# code:0440-7010-01
# resRXN len:0
# n:0440-7011-01
# res len: 3
# code:0440-7011-01
# resRXN len:0
# n:0440-7125-30
# res len: 1
# n:0440-7126-30
# res len: 1
# n:0440-7127-30
# res len: 2
# code:0440-7127-30
# resRXN len:0
# n:0440-7128-30
# res len: 1
# n:0440-7185-09
# res len: 2
# code:0440-7185-09
# resRXN len:0
# n:0440-7521-30
# res len: 2
# code:0440-7521-30
# resRXN len:0
# n:0440-7545-30
# res len: 1
# n:0440-7605-10
# res len: 1
# n:0440-7617-12
# res len: 2
# code:0440-7617-12
# resRXN len:0
# n:0440-7627-10
# res len: 2
# code:0440-7627-10
# resRXN len:0
# n:0440-7627-30
# res len: 3
# code:0440-7627-30
# resRXN len:0
# n:0440-7628-08
# res len: 1
# n:0440-7628-20
# res len: 2
# code:0440-7628-20
# resRXN len:0
# n:0440-7720-30
# res len: 4
# code:0440-7720-30
# resRXN len:0
# n:0440-7721-30
# res len: 3
# code:0440-7721-30
# resRXN len:0
# n:0440-7796-04
# res len: 3
# code:0440-7796-04
# resRXN len:0
# n:0440-7796-14
# res len: 4
# code:0440-7796-14
# resRXN len:0
# n:0440-7830-30
# res len: 3
# code:0440-7830-30
# resRXN len:0
# n:0440-8000-30
# res len: 2
# code:0440-8000-30
# resRXN len:0
# n:0440-8070-06
# res len: 1
# n:0440-8167-30
# res len: 2
# code:0440-8167-30
# resRXN len:0
# n:0440-8406-30
# res len: 2
# code:0440-8406-30
# resRXN len:0
# n:0440-8406-40
# res len: 1
# n:0440-8531-30
# res len: 1
# n:0440-8653-30
# res len: 2
# code:0440-8653-30
# resRXN len:0
# n:0456-1405-30
# res len: 2
# code:0456-1405-30
# resRXN len:0
# n:0456-2020-01
# res len: 3
# code:0456-2020-01
# resRXN len:0
# n:0456-4010-01
# res len: 1
# n:0469-0617-11
# res len: 1
# n:0472-0117-20
# res len: 2
# code:0472-0117-20
# resRXN len:0
# n:0472-0337-30
# res len: 1
# n:0472-0339-56
# res len: 1
# n:0487-9501-01
# res len: 5
# code:0487-9501-01
# resRXN len:0
# n:0487-9801-01
# res len: 2
# code:0487-9801-01
# resRXN len:0
# n:05000020100310
# res len: 3
# code:05000020100310
# resRXN len:0
# n:05000020100315
# res len: 7
# code:05000020100315
# resRXN len:0
# n:05000020100320
# res len: 2
# code:05000020100320
# resRXN len:0
# n:05000034000330
# res len: 2
# code:05000034000330
# resRXN len:0
# n:05000034000340
# res len: 2
# code:05000034000340
# resRXN len:0
# n:0517-0031-25
# res len: 3
# code:0517-0031-25
# resRXN len:0
# n:0517-0032-25
# res len: 1
# n:0517-0720-01
# res len: 1
# n:0525-0450-90
# res len: 2
# code:0525-0450-90
# resRXN len:0
# n:0536-1938-07
# res len: 2
# code:0536-1938-07
# resRXN len:0
# n:0536-3086-10
# res len: 2
# code:0536-3086-10
# resRXN len:0
# n:0536-3305-01
# res len: 2
# code:0536-3305-01
# resRXN len:0
# n:0536-3556-01
# res len: 4
# code:0536-3556-01
# resRXN len:0
# n:0536-3756-01
# res len: 3
# code:0536-3756-01
# resRXN len:0
# n:0536-3790-01
# res len: 6
# code:0536-3790-01
# resRXN len:0
# n:0536-3844-01
# res len: 2
# code:0536-3844-01
# resRXN len:0
# n:0536-4046-10
# res len: 5
# code:0536-4046-10
# resRXN len:0
# n:0536-4085-01
# res len: 3
# code:0536-4085-01
# resRXN len:0
# numProcessed:600
# n:0536-6889-08
# res len: 2
# code:0536-6889-08
# resRXN len:0
# n:0536-7415-51
# res len: 1
# n:0548-5602-00
# res len: 2
# code:0548-5602-00
# resRXN len:0
# n:0548-5605-00
# res len: 2
# code:0548-5605-00
# resRXN len:0
# n:0555-0211-10
# res len: 2
# code:0555-0211-10
# resRXN len:0
# n:0555-0323-02
# res len: 4
# code:0555-0323-02
# resRXN len:0
# n:0555-0777-02
# res len: 1
# n:0555-0779-02
# res len: 6
# code:0555-0779-02
# resRXN len:0
# n:0555-0788-02
# res len: 3
# code:0555-0788-02
# resRXN len:0
# n:0555-0789-02
# res len: 3
# code:0555-0789-02
# resRXN len:0
# n:0555-0791-02
# res len: 4
# code:0555-0791-02
# resRXN len:0
# n:0555-0831-02
# res len: 1
# n:0555-0833-02
# res len: 2
# code:0555-0833-02
# resRXN len:0
# n:0555-0869-02
# res len: 3
# code:0555-0869-02
# resRXN len:0
# n:0555-0873-02
# res len: 2
# code:0555-0873-02
# resRXN len:0
# n:0555-0886-04
# res len: 1
# n:0555-9014-67
# res len: 1
# n:0555-9016-58
# res len: 4
# code:0555-9016-58
# resRXN len:0
# n:0555-9018-58
# res len: 1
# n:0555-9026-58
# res len: 2
# code:0555-9026-58
# resRXN len:0
# n:0555-9027-42
# res len: 1
# n:0555-9043-58
# res len: 3
# code:0555-9043-58
# resRXN len:0
# n:0555-9045-58
# res len: 2
# code:0555-9045-58
# resRXN len:0
# n:0555-9049-58
# res len: 2
# code:0555-9049-58
# resRXN len:0
# n:0555-9064-58
# res len: 2
# code:0555-9064-58
# resRXN len:0
# n:0562-7805-01
# res len: 1
# n:0573-0169-30
# res len: 2
# code:0573-0169-30
# resRXN len:0
# n:0574-0220-01
# res len: 2
# code:0574-0220-01
# resRXN len:0
# n:0574-0250-01
# res len: 3
# code:0574-0250-01
# resRXN len:0
# n:0574-0412-07
# res len: 3
# code:0574-0412-07
# resRXN len:0
# n:0574-0608-01
# res len: 3
# code:0574-0608-01
# resRXN len:0
# n:0574-7090-12
# res len: 2
# code:0574-7090-12
# resRXN len:0
# n:0591-0795-10
# res len: 1
# n:0591-0844-01
# res len: 3
# code:0591-0844-01
# resRXN len:0
# n:0591-0932-01
# res len: 3
# code:0591-0932-01
# resRXN len:0
# n:0591-0933-01
# res len: 2
# code:0591-0933-01
# resRXN len:0
# n:0591-2715-01
# res len: 1
# n:0591-2717-01
# res len: 5
# code:0591-2717-01
# resRXN len:0
# n:0591-3159-01
# res len: 2
# code:0591-3159-01
# resRXN len:0
# n:0591-3196-89
# res len: 1
# n:0591-3202-01
# res len: 8
# code:0591-3202-01
# resRXN len:0
# n:0591-3369-01
# res len: 1
# n:0591-3525-11
# res len: 3
# code:0591-3525-11
# resRXN len:0
# n:0591-3591-60
# res len: 2
# code:0591-3591-60
# resRXN len:0
# n:0591-5216-01
# res len: 2
# code:0591-5216-01
# resRXN len:0
# n:0591-5307-01
# res len: 6
# code:0591-5307-01
# resRXN len:0
# n:0591-5443-01
# res len: 2
# code:0591-5443-01
# resRXN len:0
# n:0591-5443-05
# res len: 1
# n:0591-5882-01
# res len: 2
# code:0591-5882-01
# resRXN len:0
# n:0591-5883-01
# res len: 3
# code:0591-5883-01
# resRXN len:0
# n:05928-00100
# res len: 1
# n:0597-0075-41
# res len: 2
# code:0597-0075-41
# resRXN len:0
# n:0597-0100-61
# res len: 3
# code:0597-0100-61
# resRXN len:0
# n:0597-0135-54
# res len: 2
# code:0597-0135-54
# resRXN len:0
# n:0597-0140-30
# res len: 2
# code:0597-0140-30
# resRXN len:0
# n:0603-0179-29
# res len: 4
# code:0603-0179-29
# resRXN len:0
# n:0603-0209-22
# res len: 2
# code:0603-0209-22
# resRXN len:0
# n:0603-0823-54
# res len: 1
# n:0603-1075-58
# res len: 1
# n:0603-2544-28
# res len: 2
# code:0603-2544-28
# resRXN len:0
# n:0603-3887-21
# res len: 4
# code:0603-3887-21
# resRXN len:0
# n:0603-3891-21
# res len: 1
# n:0603-4486-21
# res len: 1
# n:0603-4593-15
# res len: 7
# code:0603-4593-15
# resRXN len:0
# n:0603-5192-21
# res len: 4
# code:0603-5192-21
# resRXN len:0
# n:0603-6053-21
# res len: 2
# code:0603-6053-21
# resRXN len:0
# n:0603-6330-20
# res len: 1
# n:0603-7608-17
# res len: 2
# code:0603-7608-17
# resRXN len:0
# n:0615-0585-43
# res len: 3
# code:0615-0585-43
# resRXN len:0
# n:0615-2578-43
# res len: 2
# code:0615-2578-43
# resRXN len:0
# n:0641-0376-25
# res len: 2
# code:0641-0376-25
# resRXN len:0
# n:0642-0075-30
# res len: 2
# code:0642-0075-30
# resRXN len:0
# n:0703-6801-01
# res len: 4
# code:0703-6801-01
# resRXN len:0
# n:0713-0317-88
# res len: 2
# code:0713-0317-88
# resRXN len:0
# n:0713-0526-12
# res len: 1
# n:0761-0379-20
# res len: 2
# code:0761-0379-20
# resRXN len:0
# n:0777-3107-30
# res len: 2
# code:0777-3107-30
# resRXN len:0
# n:0781-1375-01
# res len: 2
# code:0781-1375-01
# resRXN len:0
# n:0781-1599-10
# res len: 1
# n:0781-1762-01
# res len: 1
# n:0781-1764-01
# res len: 1
# n:0781-1785-01
# res len: 2
# code:0781-1785-01
# resRXN len:0
# n:0781-1789-01
# res len: 2
# code:0781-1789-01
# resRXN len:0
# n:0781-1830-10
# res len: 1
# n:0781-1852-20
# res len: 1
# n:0781-1883-10
# res len: 3
# code:0781-1883-10
# resRXN len:0
# n:0781-1884-31
# res len: 2
# code:0781-1884-31
# resRXN len:0
# n:0781-1943-39
# res len: 2
# code:0781-1943-39
# resRXN len:0
# n:0781-2102-01
# res len: 2
# code:0781-2102-01
# resRXN len:0
# n:0781-2103-01
# res len: 2
# code:0781-2103-01
# resRXN len:0
# n:0781-2104-01
# res len: 2
# code:0781-2104-01
# resRXN len:0
# n:0781-2822-01
# res len: 2
# code:0781-2822-01
# resRXN len:0
# n:0781-2823-01
# res len: 4
# code:0781-2823-01
# resRXN len:0
# n:0781-2855-05
# res len: 2
# code:0781-2855-05
# resRXN len:0
# n:0781-3243-75
# res len: 2
# code:0781-3243-75
# resRXN len:0
# n:0781-3245-72
# res len: 2
# code:0781-3245-72
# resRXN len:0
# n:0781-5057-31
# res len: 1
# n:0781-5077-01
# res len: 6
# code:0781-5077-01
# resRXN len:0
# n:0781-5114-60
# res len: 1
# n:0781-5317-01
# res len: 1
# numProcessed:700
# n:0781-5318-01
# res len: 1
# n:0781-7077-87
# res len: 3
# code:0781-7077-87
# resRXN len:0
# n:0832-0301-00
# res len: 1
# n:0832-1024-00
# res len: 1
# n:08396-9007-18
# res len: 2
# code:08396-9007-18
# resRXN len:0
# n:0904-3233-52
# res len: 2
# code:0904-3233-52
# resRXN len:0
# n:0904-3990-61
# res len: 2
# code:0904-3990-61
# resRXN len:0
# n:0904-3991-61
# res len: 1
# n:0904-4040-73
# res len: 1
# n:0904-4043-60
# res len: 3
# code:0904-4043-60
# resRXN len:0
# n:0904-4218-13
# res len: 2
# code:0904-4218-13
# resRXN len:0
# n:0904-5042-60
# res len: 2
# code:0904-5042-60
# resRXN len:0
# n:0904-5068-60
# res len: 1
# n:0904-5125-59
# res len: 1
# n:0904-5165-61
# res len: 2
# code:0904-5165-61
# resRXN len:0
# n:0904-5313-46
# res len: 3
# code:0904-5313-46
# resRXN len:0
# n:0904-5395-61
# res len: 3
# code:0904-5395-61
# resRXN len:0
# n:0904-5604-13
# res len: 2
# code:0904-5604-13
# resRXN len:0
# n:0904-5677-61
# res len: 1
# n:0904-5678-61
# res len: 1
# n:0904-5986-60
# res len: 2
# code:0904-5986-60
# resRXN len:0
# n:0904-6157-60
# res len: 2
# code:0904-6157-60
# resRXN len:0
# n:0904-7927-17
# res len: 1
# n:0955-0250-50
# res len: 2
# code:0955-0250-50
# resRXN len:0
# n:0955-1025-90
# res len: 1
# n:0955-1703-10
# res len: 1
# n:1000048
# res len: 2
# code:1000048
# resRXN len:32
# resRXN > 0
# find in rxnconso:[(u'1000048', u'ENG', u'', u'', u'', u'', u'', u'1100706', u'', u'', u'', u'MMSL', u'CD', u'1105', u'doxepin 10 mg oral capsule', u'', u'N', u''), (u'1000048', u'ENG', u'', u'', u'', u'', u'', u'1100708', u'', u'321811006', u'', u'SNOMEDCT_US', u'PT', u'321811006', u'Doxepin 10mg capsule', u'', u'N', u''), (u'1000048', u'ENG', u'', u'', u'', u'', u'', u'1100709', u'', u'', u'', u'MMSL', u'BD', u'1105', u'Doxepin Hydrochloride, 10 mg oral capsule', u'', u'N', u''), (u'1000048', u'ENG', u'', u'', u'', u'', u'', u'1100735', u'', u'', u'', u'MDDB', u'CD', u'03038', u'Doxepin HCl Cap 10 MG', u'', u'N', u''), (u'1000048', u'ENG', u'', u'', u'', u'', u'', u'1100737', u'', u'', u'', u'VANDF', u'CD', u'4002477', u'DOXEPIN HCL 10MG CAP', u'', u'N', u''), (u'1000048', u'ENG', u'', u'', u'', u'', u'', u'1100740', u'', u'321811006', u'', u'SNOMEDCT_US', u'SY', u'321811006', u'Doxepin hydrochloride 10mg capsule', u'', u'N', u''), (u'1000048', u'ENG', u'', u'', u'', u'', u'', u'1100741', u'', u'321811006', u'', u'SNOMEDCT_US', u'FN', u'321811006', u'Doxepin 10mg capsule (product)', u'', u'N', u''), (u'1000048', u'ENG', u'', u'', u'', u'', u'', u'2527490', u'', u'', u'', u'MMX', u'CD', u'101275', u'Doxepin Hydrochloride 10 MG Oral Capsule', u'', u'N', u''), (u'1000048', u'ENG', u'', u'', u'', u'', u'', u'2643082', u'', u'', u'', u'GS', u'CD', u'3823', u'Doxepin Hydrochloride 10mg Oral capsule', u'', u'N', u''), (u'1000048', u'ENG', u'', u'', u'', u'', u'', u'2753530', u'', u'', u'', u'MTHSPL', u'DP', u'0591-5629', u'Doxepin hydrochloride 10 MILLIGRAM In 1 CAPSULE ORAL CAPSULE', u'', u'N', u'4096'), (u'1000048', u'ENG', u'', u'', u'', u'', u'', u'2840542', u'', u'', u'', u'VANDF', u'AB', u'4002477', u'DOXEPIN HCL 10MG CAP', u'', u'N', u''), (u'1000048', u'ENG', u'', u'', u'', u'', u'', u'3036225', u'', u'', u'', u'MTHSPL', u'DP', u'54868-2317', u'DOXEPIN HYDROCHLORIDE 10 mg ORAL CAPSULE', u'', u'N', u'4096'), (u'1000048', u'ENG', u'', u'', u'', u'', u'', u'3142577', u'', u'N0000150635', u'', u'NDFRT', u'AB', u'N0000150635', u'DOXEPIN HCL 10MG CAP', u'', u'N', u''), (u'1000048', u'ENG', u'', u'', u'', u'', u'', u'3142578', u'', u'N0000150635', u'', u'NDFRT', u'PT', u'N0000150635', u'DOXEPIN HCL 10MG CAP', u'', u'N', u''), (u'1000048', u'ENG', u'', u'', u'', u'', u'', u'3142579', u'', u'N0000150635', u'', u'NDFRT', u'FN', u'N0000150635', u'DOXEPIN HCL 10MG CAP [VA Product]', u'', u'N', u''), (u'1000048', u'ENG', u'', u'', u'', u'', u'', u'3281862', u'3281862', u'1000048', u'', u'RXNORM', u'SCD', u'1000048', u'Doxepin Hydrochloride 10 MG Oral Capsule', u'', u'N', u'4096'), (u'1000048', u'ENG', u'', u'', u'', u'', u'', u'3550159', u'', u'', u'', u'MTHSPL', u'DP', u'21695-441', u'Doxepin Hydrochloride 10 mg ORAL CAPSULE', u'', u'N', u'4096'), (u'1000048', u'ENG', u'', u'', u'', u'', u'', u'3716157', u'', u'', u'', u'MTHSPL', u'DP', u'0378-1049', u'DOXEPIN HYDROCHLORIDE 10 mg ORAL CAPSULE [Doxepin Hydrochloride]', u'', u'N', u'4096'), (u'1000048', u'ENG', u'', u'', u'', u'', u'', u'3804638', u'', u'', u'', u'MTHSPL', u'DP', u'51079-436', u'DOXEPIN HYDROCHLORIDE 10 mg ORAL CAPSULE [Doxepin Hydrochloride]', u'', u'N', u'4096'), (u'1000048', u'ENG', u'', u'', u'', u'', u'', u'3868350', u'', u'', u'', u'MTHSPL', u'DP', u'16590-631', u'DOXEPIN HYDROCHLORIDE 10 mg ORAL CAPSULE', u'', u'N', u'4096'), (u'1000048', u'ENG', u'', u'', u'', u'', u'', u'4250768', u'', u'', u'', u'MTHSPL', u'DP', u'49349-865', u'DOXEPIN HYDROCHLORIDE 10 mg ORAL CAPSULE', u'', u'N', u'4096'), (u'1000048', u'ENG', u'', u'', u'', u'', u'', u'4261333', u'', u'', u'', u'MTHSPL', u'DP', u'35356-650', u'DOXEPIN HYDROCHLORIDE 10 mg ORAL CAPSULE [Doxepin Hydrochloride]', u'', u'N', u'4096'), (u'1000048', u'ENG', u'', u'', u'', u'', u'', u'5050563', u'', u'', u'', u'MTHSPL', u'DP', u'63629-3221', u'DOXEPIN HYDROCHLORIDE 10 mg ORAL CAPSULE [Doxepin Hydrochloride]', u'', u'N', u'4096'), (u'1000048', u'ENG', u'', u'', u'', u'', u'', u'5917501', u'', u'', u'', u'NDDF', u'CDA', ...
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# processing term:1000048
# n:1000070
# res len: 1
# n:1000114
# res len: 6
# code:1000114
# resRXN len:36
# resRXN > 0
# find in rxnconso:[(u'1000114', u'ENG', u'', u'', u'', u'', u'', u'1224935', u'', u'', u'', u'MMSL', u'CD', u'1847', u'medroxyPROGESTERone 10 mg oral tablet', u'', u'N', u''), (u'1000114', u'ENG', u'', u'', u'', u'', u'', u'1224937', u'', u'325601006', u'', u'SNOMEDCT_US', u'PT', u'325601006', u'Medroxyprogesterone acetate 10mg tablet', u'', u'N', u''), (u'1000114', u'ENG', u'', u'', u'', u'', u'', u'1224982', u'', u'', u'', u'MDDB', u'CD', u'00873', u'Medroxyprogesterone Acetate Tab 10 MG', u'', u'N', u''), (u'1000114', u'ENG', u'', u'', u'', u'', u'', u'1224984', u'', u'', u'', u'VANDF', u'CD', u'4002352', u'MEDROXYPROGESTERONE ACETATE 10MG TAB', u'', u'N', u''), (u'1000114', u'ENG', u'', u'', u'', u'', u'', u'1224992', u'', u'325601006', u'', u'SNOMEDCT_US', u'FN', u'325601006', u'Medroxyprogesterone acetate 10mg tablet (product)', u'', u'N', u''), (u'1000114', u'ENG', u'', u'', u'', u'', u'', u'2369705', u'', u'', u'', u'MMSL', u'BD', u'1847', u'MedroxyPROGESTERone Acetate, 10 mg oral tablet', u'', u'N', u''), (u'1000114', u'ENG', u'', u'', u'', u'', u'', u'2646111', u'', u'', u'', u'GS', u'CD', u'3557', u'Medroxyprogesterone Acetate 10mg Oral tablet', u'', u'N', u''), (u'1000114', u'ENG', u'', u'', u'', u'', u'', u'2844353', u'', u'', u'', u'VANDF', u'AB', u'4002352', u'MEDROXYPROGESTERONE ACETATE 10MG TAB', u'', u'N', u''), (u'1000114', u'ENG', u'', u'', u'', u'', u'', u'3192016', u'', u'N0000150521', u'', u'NDFRT', u'AB', u'N0000150521', u'MEDROXYPROGESTERONE ACETATE 10MG TAB', u'', u'N', u''), (u'1000114', u'ENG', u'', u'', u'', u'', u'', u'3192017', u'', u'N0000150521', u'', u'NDFRT', u'PT', u'N0000150521', u'MEDROXYPROGESTERONE ACETATE 10MG TAB', u'', u'N', u''), (u'1000114', u'ENG', u'', u'', u'', u'', u'', u'3192018', u'', u'N0000150521', u'', u'NDFRT', u'FN', u'N0000150521', u'MEDROXYPROGESTERONE ACETATE 10MG TAB [VA Product]', u'', u'N', u''), (u'1000114', u'ENG', u'', u'', u'', u'', u'', u'3281931', u'3281931', u'1000114', u'', u'RXNORM', u'SCD', u'1000114', u'medroxyprogesterone acetate 10 MG Oral Tablet', u'', u'N', u'4096'), (u'1000114', u'ENG', u'', u'', u'', u'', u'', u'3520145', u'', u'', u'', u'MTHSPL', u'DP', u'21695-896', u'MEDROXYPROGESTERONE ACETATE 10 mg ORAL TABLET', u'', u'N', u'4096'), (u'1000114', u'ENG', u'', u'', u'', u'', u'', u'3609758', u'', u'', u'', u'MTHSPL', u'DP', u'0555-0779', u'MEDROXYPROGESTERONE ACETATE 10 mg ORAL TABLET', u'', u'N', u'4096'), (u'1000114', u'ENG', u'', u'', u'', u'', u'', u'3629026', u'', u'', u'', u'MTHSPL', u'DP', u'54868-0109', u'MEDROXYPROGESTERONE ACETATE 10 mg ORAL TABLET [MEDROXYPROGESTERONE ACETATE]', u'', u'N', u'4096'), (u'1000114', u'ENG', u'', u'', u'', u'', u'', u'3718237', u'', u'', u'', u'MTHSPL', u'DP', u'49349-287', u'MEDROXYPROGESTERONE ACETATE 10 mg ORAL TABLET', u'', u'N', u'4096'), (u'1000114', u'ENG', u'', u'', u'', u'', u'', u'3721887', u'', u'', u'', u'MTHSPL', u'DP', u'55154-0533', u'medroxyprogesterone acetate 10 mg ORAL TABLET', u'', u'N', u'4096'), (u'1000114', u'ENG', u'', u'', u'', u'', u'', u'3734553', u'3734553', u'1000114', u'', u'RXNORM', u'TMSY', u'1000114', u'medroxyPROGESTERone acetate 10 MG Oral Tablet', u'', u'N', u'4096'), (u'1000114', u'ENG', u'', u'', u'', u'', u'', u'3786026', u'', u'', u'', u'MMX', u'CD', u'102321', u'Medroxyprogesterone Acetate 10 MG Oral Tablet', u'', u'N', u''), (u'1000114', u'ENG', u'', u'', u'', u'', u'', u'3870997', u'', u'', u'', u'MTHSPL', u'DP', u'55289-160', u'MEDROXYPROGESTERONE ACETATE 10 mg ORAL TABLET', u'', u'N', u'4096'), (u'1000114', u'ENG', u'', u'', u'', u'', u'', u'4249286', u'', u'', u'', u'MTHSPL', u'DP', u'68788-9899', u'MEDROXYPROGESTERONE ACETATE 10 mg ORAL TABLET', u'', u'N', u'4096'), (u'1000114', u'ENG', u'', u'', u'', u'', u'', u'4637382', u'', u'', u'', u'NDDF', u'CDA', u'003271', u'MEDROXYPROGESTERONE ACETATE 10 mg ORAL TABLET', u'', u'N', u''), (u'1000114', u'ENG', u'', u'', u'', u'', u'', u'4637383', u'', u'', u'', u'NDDF', u'CDC', u'003271', u'MEDROXYPROGESTERONE ACETATE 10 ...
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# processing term:1000114
# n:1000124
# res len: 2
# code:1000124
# resRXN len:9
# resRXN > 0
# find in rxnconso:[(u'1000124', u'ENG', u'', u'', u'', u'', u'', u'1910097', u'1910097', u'1000124', u'', u'RXNORM', u'SY', u'1000124', u'Provera 10 MG Oral Tablet', u'', u'N', u'4096'), (u'1000124', u'ENG', u'', u'', u'', u'', u'', u'1910098', u'', u'', u'', u'MMSL', u'BD', u'1847', u'Provera, 10 mg oral tablet', u'', u'N', u''), (u'1000124', u'ENG', u'', u'', u'', u'', u'', u'2648546', u'', u'', u'', u'GS', u'BD', u'22277', u'Provera 10mg Tablet', u'', u'N', u''), (u'1000124', u'ENG', u'', u'', u'', u'', u'', u'2996277', u'', u'', u'', u'GS', u'BD', u'35363', u'Provera 10mg Tablet', u'', u'N', u''), (u'1000124', u'ENG', u'', u'', u'', u'', u'', u'3281941', u'3281941', u'1000124', u'', u'RXNORM', u'SBD', u'1000124', u'medroxyprogesterone acetate 10 MG Oral Tablet [Provera]', u'', u'N', u'4096'), (u'1000124', u'ENG', u'', u'', u'', u'', u'', u'3735595', u'3735595', u'1000124', u'', u'RXNORM', u'TMSY', u'1000124', u'medroxyPROGESTERone acetate 10 MG Oral Tablet [Provera]', u'', u'N', u'4096'), (u'1000124', u'ENG', u'', u'', u'', u'', u'', u'3786030', u'', u'', u'', u'MMX', u'BD', u'NOCODE', u'Medroxyprogesterone Acetate 10 MG Oral Tablet [PROVERA]', u'', u'N', u''), (u'1000124', u'ENG', u'', u'', u'', u'', u'', u'5495362', u'', u'', u'', u'MTHSPL', u'DP', u'0009-0050', u'MEDROXYPROGESTERONE ACETATE 10 mg ORAL TABLET [Provera]', u'', u'N', u'4096'), (u'1000124', u'ENG', u'', u'', u'', u'', u'', u'6365038', u'6365038', u'1000124', u'', u'RXNORM', u'PSN', u'1000124', u'Provera 10 MG Oral Tablet', u'', u'N', u'4096')]
# processing term:1000124
# processing term:1000124
# processing term:1000124
# processing term:1000124
# processing term:1000124
# processing term:1000124
# processing term:1000124
# processing term:1000124
# processing term:1000124
# n:1000126
# res len: 2
# code:1000126
# resRXN len:31
# resRXN > 0
# ...
# processing term:847230
# processing term:847230
# processing term:847230
# processing term:847230
# processing term:847230
# processing term:847230
# processing term:847230
# processing term:847230
# processing term:847230
# processing term:847230
# processing term:847230
# n:847232
# res len: 5
# code:847232
# resRXN len:13
# resRXN > 0
# find in rxnconso:[(u'847232', u'ENG', u'', u'', u'', u'', u'', u'2715187', u'', u'', u'', u'MMSL', u'BD', u'7235', u'Lantus Solostar Pen, 100 units/mL subcutaneous solution', u'', u'N', u''), (u'847232', u'ENG', u'', u'', u'', u'', u'', u'3066101', u'3066101', u'847232', u'', u'RXNORM', u'SY', u'847232', u'Lantus 300 UNT per 3 ML OptiClik Pen', u'', u'N', u'4096'), (u'847232', u'ENG', u'', u'', u'', u'', u'', u'3621351', u'', u'', u'', u'MTHSPL', u'DP', u'54868-5765', u'INSULIN GLARGINE 100 [iU] in 1 mL SUBCUTANEOUS INJECTION, SOLUTION [Lantus]', u'', u'N', u'4096'), (u'847232', u'ENG', u'', u'', u'', u'', u'', u'3621352', u'', u'', u'', u'MTHSPL', u'DP', u'54868-6231', u'INSULIN GLARGINE 100 [iU] in 1 mL SUBCUTANEOUS INJECTION, SOLUTION [Lantus]', u'', u'N', u'4096'), (u'847232', u'ENG', u'', u'', u'', u'', u'', u'5045468', u'', u'', u'', u'GS', u'BD', u'28900', u'Lantus SoloStar 100units/ml Pre-Filled Pen Solution for Injection', u'', u'N', u''), (u'847232', u'ENG', u'', u'', u'', u'', u'', u'5533113', u'', u'', u'', u'MTHSPL', u'DP', u'0088-2219', u'insulin glargine 100 [iU] in 1 mL SUBCUTANEOUS INJECTION, SOLUTION [Lantus Solostar]', u'', u'N', u'4096'), (u'847232', u'ENG', u'', u'', u'', u'', u'', u'6833772', u'6833772', u'847232', u'', u'RXNORM', u'SY', u'847232', u'Lantus 300 UNT per 3 ML SoloStar Pen', u'', u'N', u'4096'), (u'847232', u'ENG', u'', u'', u'', u'', u'', u'7244411', u'7244411', u'847232', u'', u'RXNORM', u'SBD', u'847232', u'3 ML Insulin Glargine 100 UNT/ML Pen Injector [Lantus]', u'', u'N', u'4096'), (u'847232', u'ENG', u'', u'', u'', u'', u'', u'7244412', u'7244412', u'847232', u'', u'RXNORM', u'SY', u'847232', u'3 ML Lantus 100 UNT/ML Pen Injector', u'', u'N', u'4096'), (u'847232', u'ENG', u'', u'', u'', u'', u'', u'7244452', u'7244452', u'847232', u'', u'RXNORM', u'SY', u'847232', u'Lantus 300 UNT per 3 ML Pen Injector', u'', u'N', u'4096'), (u'847232', u'ENG', u'', u'', u'', u'', u'', u'7245303', u'7245303', u'847232', u'', u'RXNORM', u'PSN', u'847232', u'Lantus 100 UNT/ML in 3 ML Pen Injector', u'', u'N', u'4096'), (u'847232', u'ENG', u'', u'', u'', u'', u'', u'7275474', u'', u'', u'', u'MMX', u'BD', u'NOCODE', u'Insulin Glargine, Recombinant 100 U/1 ML Subcutaneous Solution [LANTUS SOLOSTAR]', u'', u'N', u''), (u'847232', u'ENG', u'', u'', u'', u'', u'', u'7285680', u'', u'', u'', u'MMX', u'MTH_RXN_BD', u'NOCODE', u'Insulin Glargine, Recombinant 100 U/1 ML Subcutaneous Solution [LANTUS]_#2', u'', u'N', u'')]
# processing term:847232
# processing term:847232
# processing term:847232
# processing term:847232
# processing term:847232
# processing term:847232
# processing term:847232
# processing term:847232
# processing term:847232
# processing term:847232
# processing term:847232
# processing term:847232
# processing term:847232
# n:847239
# res len: 3
# code:847239
# resRXN len:18
# resRXN > 0
# find in rxnconso:[(u'847239', u'ENG', u'', u'', u'', u'', u'', u'2358884', u'', u'416785003', u'', u'SNOMEDCT_US', u'PT', u'416785003', u'insulin detemir 100iu/mL injection solution 3mL prefilled pen', u'', u'N', u''), (u'847239', u'ENG', u'', u'', u'', u'', u'', u'2358885', u'', u'416785003', u'', u'SNOMEDCT_US', u'FN', u'416785003', u'insulin detemir 100iu/mL injection solution 3mL prefilled pen (product)', u'', u'N', u''), (u'847239', u'ENG', u'', u'', u'', u'', u'', u'2358886', u'', u'416785003', u'', u'SNOMEDCT_US', u'SY', u'416785003', u'insulin detemir 100iu/mL prefilled pen 3mL', u'', u'N', u''), (u'847239', u'ENG', u'', u'', u'', u'', u'', u'2602269', u'', u'', u'', u'VANDF', u'CD', u'4025120', u'INSULIN,DETEMIR,HUMAN 100 UNIT/ML INJ,FLEXPEN,3ML', u'', u'O', u''), (u'847239', u'ENG', u'', u'', u'', u'', u'', u'2843298', u'', u'', u'', u'VANDF', u'AB', u'4025120', u'INSULIN,DETEMIR 100UNIT/ML FLEXPEN 3ML', u'', u'O', u''), (u'847239', u'ENG', u'', u'', u'', u'', u'', u'3176364', u'', u'N0000172052', u'', u'NDFRT', u'AB', u'N0000172052', u'INSULIN,DETEMIR 100UNIT/ML FLEXPEN 3ML', u'', u'O', u''), (u'847239', u'ENG', u'', u'', u'', u'', u'', u'3176370', u'', u'N0000172052', u'', u'NDFRT', u'PT', u'N0000172052', u'INSULIN,DETEMIR,HUMAN 100 UNIT/ML INJ,FLEXPEN,3ML', u'', u'O', u''), (u'847239', u'ENG', u'', u'', u'', u'', u'', u'3176371', u'', u'N0000172052', u'', u'NDFRT', u'FN', u'N0000172052', u'INSULIN,DETEMIR,HUMAN 100 UNIT/ML INJ,FLEXPEN,3ML [VA Product]', u'', u'O', u''), (u'847239', u'ENG', u'', u'', u'', u'', u'', u'3810803', u'', u'', u'', u'NDDF', u'CDA', u'057439', u'INSULIN DETEMIR 100 unit/mL (3 mL) SUB-Q INSULIN PEN (ML)', u'', u'N', u''), (u'847239', u'ENG', u'', u'', u'', u'', u'', u'3810804', u'', u'', u'', u'NDDF', u'CDC', u'057439', u'INSULIN DETEMIR 100 unit/mL (3 mL) SUB-Q INSULIN PEN (ML)', u'', u'N', u''), (u'847239', u'ENG', u'', u'', u'', u'', u'', u'3810805', u'', u'', u'', u'NDDF', u'CDD', u'057439', u'INSULIN DETEMIR@100 unit/mL (3 mL)@SUB-Q@INSULIN PEN (ML)', u'', u'N', u''), (u'847239', u'ENG', u'', u'', u'', u'', u'', u'6399484', u'', u'', u'', u'VANDF', u'AB', u'4033530', u'INSULIN,DETEMIR 100UNIT/ML FLEXTOUCH 3ML', u'', u'N', u''), (u'847239', u'ENG', u'', u'', u'', u'', u'', u'6399485', u'', u'', u'', u'VANDF', u'CD', u'4033530', u'INSULIN,DETEMIR,HUMAN 100 UNIT/ML INJ,FLEXTOUCH,3ML', u'', u'N', u''), (u'847239', u'ENG', u'', u'', u'', u'', u'', u'6405339', u'', u'N0000190868', u'', u'NDFRT', u'AB', u'N0000190868', u'INSULIN,DETEMIR 100UNIT/ML FLEXTOUCH 3ML', u'', u'O', u''), (u'847239', u'ENG', u'', u'', u'', u'', u'', u'6405340', u'', u'N0000190868', u'', u'NDFRT', u'PT', u'N0000190868', u'INSULIN,DETEMIR,HUMAN 100 UNIT/ML INJ,FLEXTOUCH,3ML', u'', u'O', u''), (u'847239', u'ENG', u'', u'', u'', u'', u'', u'6405341', u'', u'N0000190868', u'', u'NDFRT', u'FN', u'N0000190868', u'INSULIN,DETEMIR,HUMAN 100 UNIT/ML INJ,FLEXTOUCH,3ML [VA Product]', u'', u'O', u''), (u'847239', u'ENG', u'', u'', u'', u'', u'', u'7245517', u'7245517', u'847239', u'', u'RXNORM', u'SCD', u'847239', u'3 ML insulin detemir 100 UNT/ML Pen Injector', u'', u'N', u'4096'), (u'847239', u'ENG', u'', u'', u'', u'', u'', u'7246156', u'7246156', u'847239', u'', u'RXNORM', u'PSN', u'847239', u'insulin detemir 100 UNT/ML in 3 ML Pen Injector', u'', u'N', u'4096')]
# processing term:847239
# processing term:847239
# processing term:847239
# processing term:847239
# processing term:847239
# processing term:847239
# processing term:847239
# processing term:847239
# processing term:847239
# processing term:847239
# processing term:847239
# processing term:847239
# processing term:847239
# processing term:847239
# processing term:847239
# processing term:847239
# processing term:847239
# processing term:847239
# n:847241
# res len: 3
# code:847241
# resRXN len:18
# resRXN > 0
# find in rxnconso:[(u'847241', u'ENG', u'', u'', u'', u'', u'', u'2455338', u'', u'', u'', u'MMSL', u'BD', u'13364', u'Levemir FlexPen, 100 units/mL subcutaneous solution', u'', u'N', u''), (u'847241', u'ENG', u'', u'', u'', u'', u'', u'2645525', u'', u'', u'', u'GS', u'BD', u'20823', u'Levemir FlexPen 100units/ml Solution for Injection', u'', u'N', u''), (u'847241', u'ENG', u'', u'', u'', u'', u'', u'2645526', u'', u'', u'', u'GS', u'BD', u'20824', u'Levemir InnoLet 100units/ml Solution for Injection', u'', u'O', u''), (u'847241', u'ENG', u'', u'', u'', u'', u'', u'2645527', u'', u'', u'', u'GS', u'BD', u'20825', u'Levemir PenFill 100units/ml Solution for Injection', u'', u'O', u''), (u'847241', u'ENG', u'', u'', u'', u'', u'', u'2975636', u'2975636', u'847241', u'', u'RXNORM', u'SY', u'847241', u'Levemir 100 UNT/ML 3 ML FlexPen', u'', u'N', u'4096'), (u'847241', u'ENG', u'', u'', u'', u'', u'', u'2975637', u'2975637', u'847241', u'', u'RXNORM', u'SY', u'847241', u'Levemir 100 UNT/ML 3 ML PenFill', u'', u'N', u'4096'), (u'847241', u'ENG', u'', u'', u'', u'', u'', u'3319221', u'', u'', u'', u'MTHSPL', u'DP', u'54868-5883', u'INSULIN DETEMIR 14.2 mg in 1 mL SUBCUTANEOUS INJECTION, SOLUTION [Levemir]', u'', u'N', u'4096'), (u'847241', u'ENG', u'', u'', u'', u'', u'', u'6340808', u'', u'', u'', u'GS', u'BD', u'87819', u'Levemir FlexTouch 100units/ml Solution for Injection', u'', u'N', u''), (u'847241', u'ENG', u'', u'', u'', u'', u'', u'6340913', u'6340913', u'847241', u'', u'RXNORM', u'SY', u'847241', u'Levemir 100 UNT/ML 3 ML FlexTouch', u'', u'N', u'4096'), (u'847241', u'ENG', u'', u'', u'', u'', u'', u'6380961', u'', u'', u'', u'MMSL', u'BD', u'13364', u'Levemir FlexTouch, 100 units/mL subcutaneous solution', u'', u'N', u''), (u'847241', u'ENG', u'', u'', u'', u'', u'', u'6826345', u'', u'', u'', u'MTHSPL', u'DP', u'0169-6438', u'INSULIN DETEMIR 100 [iU] in 1 mL SUBCUTANEOUS INJECTION, SOLUTION [Levemir]', u'', u'N', u'4096'), (u'847241', u'ENG', u'', u'', u'', u'', u'', u'6826346', u'', u'', u'', u'MTHSPL', u'DP', u'0169-6439', u'INSULIN DETEMIR 100 [iU] in 1 mL SUBCUTANEOUS INJECTION, SOLUTION [Levemir]', u'', u'N', u'4096'), (u'847241', u'ENG', u'', u'', u'', u'', u'', u'6836956', u'6836956', u'847241', u'', u'RXNORM', u'PSN', u'847241', u'Levemir 100 UNT/ML in 3 ML Pen Injector', u'', u'N', u'4096'), (u'847241', u'ENG', u'', u'', u'', u'', u'', u'7245519', u'7245519', u'847241', u'', u'RXNORM', u'SBD', u'847241', u'3 ML insulin detemir 100 UNT/ML Pen Injector [Levemir]', u'', u'N', u'4096'), (u'847241', u'ENG', u'', u'', u'', u'', u'', u'7245520', u'7245520', u'847241', u'', u'RXNORM', u'SY', u'847241', u'3 ML Levemir 100 UNT/ML Pen Injector', u'', u'N', u'4096'), (u'847241', u'ENG', u'', u'', u'', u'', u'', u'7275470', u'', u'', u'', u'MMX', u'BD', u'NOCODE', u'Insulin Detemir 100 U/1 ML Subcutaneous Solution [LEVEMIR FLEXPEN]', u'', u'N', u''), (u'847241', u'ENG', u'', u'', u'', u'', u'', u'7275471', u'', u'', u'', u'MMX', u'BD', u'NOCODE', u'Insulin Detemir 100 U/1 ML Subcutaneous Solution [LEVEMIR FLEXTOUCH]', u'', u'N', u''), (u'847241', u'ENG', u'', u'', u'', u'', u'', u'7286091', u'', u'', u'', u'MMX', u'MTH_RXN_BD', u'NOCODE', u'Insulin Detemir 100 U/1 ML Subcutaneous Solution [LEVEMIR]_#2', u'', u'N', u'')]
# processing term:847241
# processing term:847241
# processing term:847241
# processing term:847241
# processing term:847241
# processing term:847241
# processing term:847241
# processing term:847241
# processing term:847241
# processing term:847241
# processing term:847241
# processing term:847241
# processing term:847241
# processing term:847241
# processing term:847241
# processing term:847241
# processing term:847241
# processing term:847241
# n:84762
# res len: 2
# code:84762
# resRXN len:0
# n:84764
# res len: 1
# n:847910
# res len: 1
# n:847913
# res len: 1
# n:84815
# res len: 1
# n:84877
# res len: 1
# n:849389
# res len: 2
# code:849389
# resRXN len:48
# resRXN > 0
# find in rxnconso:[(u'849389', u'ENG', u'', u'', u'', u'', u'', u'1907444', u'', u'', u'', u'MMSL', u'CD', u'192', u'amantadine 100 mg oral capsule', u'', u'N', u''), (u'849389', u'ENG', u'', u'', u'', u'', u'', u'1907449', u'', u'323133000', u'', u'SNOMEDCT_US', u'PT', u'323133000', u'Amantadine hydrochloride 100mg capsule', u'', u'N', u''), (u'849389', u'ENG', u'', u'', u'', u'', u'', u'1907450', u'', u'', u'', u'MMSL', u'BD', u'192', u'Amantadine Hydrochloride, 100 mg oral capsule', u'', u'N', u''), (u'849389', u'ENG', u'', u'', u'', u'', u'', u'1907467', u'', u'', u'', u'MDDB', u'CD', u'03892', u'Amantadine HCl Cap 100 MG', u'', u'N', u''), (u'849389', u'ENG', u'', u'', u'', u'', u'', u'1907469', u'', u'', u'', u'VANDF', u'CD', u'4005192', u'AMANTADINE HCL 100MG CAP', u'', u'N', u''), (u'849389', u'ENG', u'', u'', u'', u'', u'', u'1907471', u'', u'', u'', u'VANDF', u'CD', u'4005194', u'AMANTADINE HCL 100MG CAP,UD', u'', u'N', u''), (u'849389', u'ENG', u'', u'', u'', u'', u'', u'1907485', u'', u'323133000', u'', u'SNOMEDCT_US', u'FN', u'323133000', u'Amantadine hydrochloride 100mg capsule (product)', u'', u'N', u''), (u'849389', u'ENG', u'', u'', u'', u'', u'', u'2295645', u'', u'', u'', u'MMX', u'CD', u'100080', u'Amantadine Hydrochloride 100 MG Oral Capsule, Liquid Filled', u'', u'N', u''), (u'849389', u'ENG', u'', u'', u'', u'', u'', u'2639006', u'', u'', u'', u'GS', u'CD', u'4267', u'Amantadine Hydrochloride 100mg Oral capsule', u'', u'N', u''), (u'849389', u'ENG', u'', u'', u'', u'', u'', u'2835569', u'', u'', u'', u'VANDF', u'AB', u'4005192', u'AMANTADINE HCL 100MG CAP', u'', u'N', u''), (u'849389', u'ENG', u'', u'', u'', u'', u'', u'2835570', u'', u'', u'', u'VANDF', u'AB', u'4005194', u'AMANTADINE HCL 100MG CAP UD', u'', u'N', u''), (u'849389', u'ENG', u'', u'', u'', u'', u'', u'2963391', u'', u'', u'', u'MMX', u'CD', u'127316', u'Amantadine Hydrochloride 100 MG Oral Capsule', u'', u'N', u''), (u'849389', u'ENG', u'', u'', u'', u'', u'', u'2969035', u'2969035', u'849389', u'', u'RXNORM', u'SCD', u'849389', u'Amantadine Hydrochloride 100 MG Oral Capsule', u'', u'N', u'4096'), (u'849389', u'ENG', u'', u'', u'', u'', u'', u'2991272', u'', u'', u'', u'MTHSPL', u'DP', u'0781-2048', u'AMANTADINE HYDROCHLORIDE 100 mg ORAL CAPSULE', u'', u'N', u'4096'), (u'849389', u'ENG', u'', u'', u'', u'', u'', u'3099256', u'', u'N0000153223', u'', u'NDFRT', u'AB', u'N0000153223', u'AMANTADINE HCL 100MG CAP', u'', u'N', u''), (u'849389', u'ENG', u'', u'', u'', u'', u'', u'3099257', u'', u'N0000153223', u'', u'NDFRT', u'PT', u'N0000153223', u'AMANTADINE HCL 100MG CAP', u'', u'N', u''), (u'849389', u'ENG', u'', u'', u'', u'', u'', u'3099258', u'', u'N0000153225', u'', u'NDFRT', u'AB', u'N0000153225', u'AMANTADINE HCL 100MG CAP UD', u'', u'N', u''), (u'849389', u'ENG', u'', u'', u'', u'', u'', u'3099259', u'', u'N0000153223', u'', u'NDFRT', u'FN', u'N0000153223', u'AMANTADINE HCL 100MG CAP [VA Product]', u'', u'N', u''), (u'849389', u'ENG', u'', u'', u'', u'', u'', u'3099260', u'', u'N0000153225', u'', u'NDFRT', u'PT', u'N0000153225', u'AMANTADINE HCL 100MG CAP,UD', u'', u'N', u''), (u'849389', u'ENG', u'', u'', u'', u'', u'', u'3099261', u'', u'N0000153225', u'', u'NDFRT', u'FN', u'N0000153225', u'AMANTADINE HCL 100MG CAP,UD [VA Product]', u'', u'N', u''), (u'849389', u'ENG', u'', u'', u'', u'', u'', u'3521916', u'', u'', u'', u'MTHSPL', u'DP', u'54868-0800', u'AMANTADINE HYDROCHLORIDE 100 mg ORAL CAPSULE', u'', u'N', u'4096'), (u'849389', u'ENG', u'', u'', u'', u'', u'', u'3545540', u'', u'', u'', u'MTHSPL', u'DP', u'21695-564', u'AMANTADINE HYDROCHLORIDE 100 mg ORAL CAPSULE [Amantadine HCl]', u'', u'N', u'4096'), (u'849389', u'ENG', u'', u'', u'', u'', u'', u'3549098', u'', u'', u'', u'MTHSPL', u'DP', u'16590-008', u'AMANTADINE HYDROCHLORIDE 100 mg ORAL CAPSULE', u'', u'N', u'4096'), (u'849389', u'ENG', u'', u'', u'', u'', u'', u'3638886', u'', u'', u'', u'MTHSPL', u'DP', u'49349-193', u'AMANTADINE HYDROCHLORIDE 100 mg ORAL CAPSULE', u'', ...
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# processing term:849389
# n:849431
# res len: 2
# code:849431
# resRXN len:62

# %%
#build hash table and look up
readFile = open("/Users/dc/TestCode/TestCoding/csvfile.csv","r")
listKeywords=[]
for line in readFile:
    if len(line.strip())>3:
        print line.strip()
        print line[0:len(line)-2]
        tokens=line[0:len(line)-2].split()
        print "numTokens:%s" % len(tokens)
        print tokens[0]
        listKeywords.append(tokens[0])
        
readFile.close()

# %%
print "numInList:%d" % len(listKeywords)

numMatch=0
for li in listKeywords:
    tokens=li.split(",")
    print "num:%s" % tokens[0] , "name:%s" % tokens[1]
    c.execute("select count(*) from rxnconso where RXCUI='%s'" % (tokens[0]))
    num=c.fetchone()
    print "num:%s" % num
    if num > 0:
        c.execute("select * from rxnconso where RXCUI='%s'" % (tokens[0]))
        numR=c.fetchall()
        print "found result:%s" % numR
        print numR
        numMatch +=1
print "numMatch:%s" % numMatch
# Out:
# numInList:0
# numMatch:0

# %%
#bag of letters test
