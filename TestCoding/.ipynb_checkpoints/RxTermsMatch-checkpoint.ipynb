# %%
import sqlite3
conn = sqlite3.connect('/Users/dc/TestCode/TestCoding/clinical.sqlite')
c=conn.cursor()
c.execute('select count(*) from allergies;')
numRows = c.fetchone()
print numRows

c.execute("select count(medication_name) from medications inner join rxterms where medications.code=rxterms.RXCUI;")
numMatchMeds = c.fetchone()
print numMatchMeds
# Out:
# (5816,)
# (13178,)

# %%
c.execute("select count(distinct(code)) from medications;")
numMeds=c.fetchone()
c.execute("select count(distinct(RXCUI)) from rxterms;")
numTerms=c.fetchone()
print "numMeds:%s" % numMeds, "numTerms:%s" % numTerms
# Out:
# numMeds:9935 numTerms:21457

# %%
#c.execute("select medications.medication_name, medications.code,rxterms.RXCUI, rxterms.GENERIC_RXCUI,rxterms.TTY, rxterms.FULL_NAME from medications inner join rxterms where medications.code=rxterms.RXCUI limit 1000;")
#matchExample = c.fetchall()
#
#for e in matchExample:
 #   print e

# %%
c.execute("select count(medication_name) from medications inner join rxnatomarchive where medications.code=rxnatomarchive.RXAUI;")
numMatch = c.fetchone()
print numMatch
# Out:
# (64,)

# %%
c.execute("select count(medication_name) from medications inner join rxnatomarchive where medications.code=rxnatomarchive.AUI;")
numMatch = c.fetchone()
print numMatch
# Out:
# (0,)

# %%
c.execute("select count(medication_name) from medications inner join rxnconso where medications.code=rxnconso.RXCUI;")
numMatch = c.fetchone()
print numMatch
# Out:
# (724902,)

# %%
c.execute("select count(medication_name) from medications inner join rxncuichanges where medications.code=rxncuichanges.RXAUI;")
numMatch = c.fetchone()
print numMatch
# Out:
# (0,)

# %%
c.execute("select count(medication_name) from medications inner join rxnrel where medications.code=rxnrel.RXCUI1;")
numMatch = c.fetchone()
print numMatch
# Out:
# (248673,)

# %%
c.execute("select count(medication_name) from medications inner join rxnsat where medications.code=rxnsat.RXCUI;")
numMatch = c.fetchone()
print numMatch
# Out:
# (17008464,)

# %%
c.execute("select count(medication_name) from medications inner join rxnsab where medications.code=rxnsab.VCUI;")
numMatch = c.fetchone()
print numMatch
# Out:
# (0,)

# %%
c.execute("select count(medication_name) from medications inner join rxnsab where medications.code=rxnsab.RCUI;")
numMatch = c.fetchone()
print numMatch
# Out:
# (0,)

# %%
The biggest matches are rxnsat, rxnrel, rxnconso. What is the difference? 
Find the ones which are not matched. Is this consistent across the 3 tables?

# %%
c.execute("select count(code) from medications where code_system_name=\"rxnorm\" and code not in(select DISTINCT(RXCUI1) from rxnrel);")
numNotMatch=c.fetchone()
print numNotMatch
print ""

#1014/9935 not match
c.execute("select medication_name, code from medications where code_system_name=\"rxnorm\" and code not in(select DISTINCT(RXCUI1) from rxnrel);")
notMatch=c.fetchall()
for nm in notMatch:
    print nm
# Out:
# (1014,)
#
# (u'Multiple Vitamin (MULTIVITAMIN) tablet', u'89905')
# (u'Container (SHARPS CONTAINER) Misc Misc', u'693114')
# (u'Multiple Vitamin (MULTIVITAMINS) capsule', u'89905')
# (u'Levomefolate Calcium 15 Mg Tablet', u'630802')
# (u'Fish Oil Oil', u'4419')
# (u'Omega-3 Fatty Acids 500 Mg Oral Cpdr', u'4301')
# (u'Misc Natural Products (CHELIDONIUM COMPOUND) Liquid', u'285220')
# (u'L-Methylfolate (DEPLIN) 15 MG Tablet', u'630802')
# (u'Multiple Vitamin (MULTI-VITAMIN) Tab', u'89905')
# (u'Needle, Disp, (BD SPECIALTY USE) 30 x 1/2 " Misc Needle', u'432332')
# (u'Syringe with Needle, Disp, (BD SAFETYGLIDE) 3 mL 22 x 1 1/2" Misc Syringe', u'431392')
# (u'Syringe with Needle, Disp, (BD SAFETYGLIDE) 3 mL 22 x 1 1/2" Misc Syringe', u'431392')
# (u'Needle, Disp, (BD SPECIALTY USE) 30 gauge x 1/2" Misc Needle', u'432332')
# (u'Soap & Cleansers (AMBI ESSENTIALS GENTLE CLEANSR) EX CREA', u'217335')
# (u'Blood Glucose Control, Normal (ONETOUCH ULTRA CONTROL) Misc Soln', u'692590')
# (u'Blood Sugar Test (ONETOUCH ULTRA TEST) Misc Strips', u'692591')
# (u'BD INSULIN SYRINGE ULTRA-FINE 1 mL 31 x 5/16" Misc Syrg', u'5856')
# (u'GELCLAIR ORAL GEL PACKET', u'667470')
# (u'Prenatal Vit #96-Ferrous Fumarate-Folic Acid 27 Mg Iron-800 McG Tablet', u'90176')
# (u'Probiotic Product (SOLUBLE FIBER/PROBIOTICS) CHEW', u'402462')
# (u'ONE TOUCH ULTRA TEST MISC STRIPS', u'692591')
# (u'ONETOUCH ULTRA TEST MISC STRIPS', u'692591')
# (u'Magnesium 100 Mg Capsule', u'6574')
# (u'Prenatal Multivitamin', u'89905')
# (u'Prenatal Multivitamin', u'89905')
# (u'Prenatal Multivitamin', u'89905')
# (u'Prenatal Multivitamin', u'89905')
# (u'Prenatal Multivitamin', u'89905')
# (u'Prenatal Multivitamin', u'89905')
# (u'Prenatal Multivitamin', u'89905')
# (u'Prenatal Multivitamin', u'89905')
# (u'Prenatal Multivitamin', u'89905')
# (u'Prenatal Multivitamin', u'89905')
# (u'Prenatal Multivitamin', u'89905')
# (u'Prenatal Multivitamin', u'89905')
# (u'Prenatal Multivitamin', u'89905')
# (u'Prenatal Multivitamin', u'89905')
# (u'Prenatal Multivitamin', u'89905')
# (u'Prenatal Multivitamin', u'89905')
# (u'Prenatal Multivitamin', u'89905')
# (u'Prenatal Multivitamin', u'89905')
# (u'Ferrous Sulfate (SLOW FE PO)', u'null')
# (u'Cyanocobalamin (VITAMIN B 12 PO)', u'null')
# (u'TURMERIC PO', u'null')
# (u'Multiple Vitamins-Minerals (MULTIVITAMIN & MINERAL PO)', u'null')
# (u'CARBOXYMETHYLCELLULOSE SODIUM OP', u'null')
# (u'Magnesium 250 Mg Po Tabs', u'1426853')
# (u'INULIN (FIBER GUMMIES ORAL)', u'null')
# (u'Prenatal Vit-Iron Fumarate-Fa 27 Mg-1 Mg Tablet', u'90176')
# (u'Multiple Vitamin (ONCE DAILY) Tab', u'89905')
# (u'Misc. Devices (WHEELCHAIR) Misc', u'null')
# (u'hydrophil petrolatum-mineral oil Ointment', u'null')
# (u'Multiple Vitamin (MULTIVITAMIN) Cap', u'89905')
# (u'hydroCODone-acetaminophen, M-1005, 5-500 MG PO TABS', u'null')
# (u'ALBUTEROL SULFATE HFA IN', u'null')
# (u'Pamidronate 90 Mg IV Solr', u'904927')
# (u'Multiple Vitamin (MULTIVITAMIN) capsule', u'89905')
# (u'Prenatal Multivit-Ca-Min-Fe-FA (PRENATAL VITAMIN) tab', u'null')
# (u'AZITHROMYCIN', u'727450')
# (u'Acetaminophen (TYLENOL EXTRA STRENGTH PO)', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL PO)', u'null')
# (u'EPINEPHrine 0.3 MG/0.3ML Injection Device', u'null')
# (u'Intrauterine Device (PARAGARD T 380A) UTRN IUD', u'2837')
# (u'EXCEDRIN MIGRAINE PO', u'null')
# (u'Vilazodone HCl (VIIBRYD PO)', u'null')
# (u'Magnesium 250 Mg Po Tabs', u'1426853')
# (u'sodium chloride (bolus) 0.9 % 30 mL', u'null')
# (u'abatacept (ORENCIA) 750 mg in sodium chloride (IV) 0.9 % 100 mL IVPB', u'9853')
# (u'abatacept (ORENCIA) 750 mg in sodium chloride (IV) 0.9 % 100 mL IVPB', u'153974')
# (u'Insulin Syringe-Needle U-100 30G X 1/2" 0.5 ML MISC', u'null')
# (u'glucose blood test strip', u'null')
# (u'Insulin Pen Needle 31 G x 8 mm misc. route', u'null')
# (u'Blood Glucose Monitoring Suppl (ACCU-CHEK COMPACT CARE KIT) misc. route kit', u'583344')
# (u'Insulin Syringe-Needle U-100 (INSULIN SYRINGE 1CC/30GX1/2") 30G X 1/2" 1 ML misc. route', u'null')
# (u'Prenatal Vit#96-Ferrous Fum-Fa 27 Mg Iron- 800 McG Oral Tab', u'90176')
# (u'multivitamin, prenatal (Prenatal Multivitamins with Vitamin B Complex, Vitamin C, Minerals and L-Methylfolate oral capsule)', u'89905')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS PO)', u'null')
# (u'Cyanocobalamin (VITAMIN B-12 PO)', u'null')
# (u'multivitamin capsule', u'null')
# (u'lancets 33 gauge Misc', u'null')
# (u'Blood Sugar Diagnostic Strips', u'692591')
# (u'Blood Sugar Diagnostic Strips', u'692591')
# (u'Blood-Glucose Meter Kit', u'240786')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL VITAMIN PO)', u'null')
# (u'Levonorgestrel (MIRENA IU)', u'null')
# (u'Cholecalciferol (VITAMIN D PO)', u'null')
# (u'Probiotic Product (PROBIOTIC DAILY PO)', u'null')
# (u'COCONUT OIL ORAL', u'null')
# (u'DOCOSAHEXANOIC ACID/EPA (FISH OIL ORAL)', u'null')
# (u'Misc. Devices (BREAST PUMP) MISC', u'null')
# (u'Breast Pump devi', u'null')
# (u'docusate sodium (COLACE) 100 MG capsule', u'null')
# (u'ibuprofen (ADVIL,MOTRIN) 600 MG tablet', u'null')
# (u'underpads (GOODNITES BED MATS) 2.6 X 2.9 feet Pads', u'null')
# (u'GENERIC DME', u'null')
# (u'Diaper,Brief, Adult,Disposable (PREVAIL BLADDER PAD EXTRA PLUS) Misc', u'null')
# (u'Incontinence Pad, Liner, Disp (PREVAIL PANT LINER) Pads', u'null')
# (u'GLUCOSAMINE HCL PO', u'null')
# (u'Ice Bag Misc', u'null')
# (u'Incontinence Pad, Liner, Disp (BLADDER CONTROL PADS FOR WOMEN) Pads', u'null')
# (u'VITAMIN B COMPLEX PO', u'null')
# (u'multivitamin capsule', u'null')
# (u'Calcium 600 Mg Capsule', u'1895')
# (u'SODIUM CHLORIDE/SODIUM BICARB (NEILMED SINUS RINSE COMPLETE NA)', u'null')
# (u'BIFIDOBACTERIUM INFANTIS (ALIGN PO)', u'null')
# (u'RABEPRAZOLE SODIUM (ACIPHEX PO)', u'null')
# (u'multiple vitamin tab', u'null')
# (u'Misc. Devices (BREAST PUMP) misc. route', u'null')
# (u'VALACYCLOVIR HCL (VALTREX ORAL)', u'null')
# (u'Multiple Vitamin (MULTI VITAMIN MENS PO)', u'null')
# (u'injection device for insulin (B-D PEN MINI) XX DEVI', u'null')
# (u'Levomefolate-B2-B6-B12 6 Mg-5 Mg-50 Mg-1 Mg Tablet', u'404926')
# (u'UNABLE TO FIND', u'null')
# (u'Prenatal Vit-Iron Fumarate-FA (PRENATAL S) 27-0.8 mg Oral Tab', u'90176')
# (u'Prenatal Vit#96-Ferrous Fum-Fa 27 Mg Iron- 800 McG Oral Tab', u'90176')
# (u'Prenatal Vit#96-Ferrous Fum-Fa 27 Mg Iron- 800 McG Oral Tab', u'90176')
# (u'Prenatal Vit-Iron Fumarate-FA (PRENATAL S) 27-0.8 mg Oral Tab', u'90176')
# (u'multivitamin, prenatal (Prenatal Multivitamins oral tablet)', u'89905')
# (u'multivitamin, prenatal (Prenatal Multivitamins oral tablet)', u'89905')
# (u'multivitamin, prenatal (Prenatal Multivitamins oral tablet)', u'89905')
# (u'multivitamin, prenatal (Prenatal Multivitamins oral tablet)', u'89905')
# (u'Prenatal Multivitamins oral tablet', u'89905')
# (u'multivitamin, prenatal (Prenatal Multivitamins oral tablet)', u'89905')
# (u'multivitamin, prenatal (Prenatal Multivitamins oral tablet)', u'89905')
# (u'multivitamin, prenatal (Prenatal Multivitamins oral tablet)', u'89905')
# (u'multivitamin, prenatal (Prenatal Multivitamins oral tablet)', u'89905')
# (u'multivitamin, prenatal (Prenatal Multivitamins oral tablet)', u'89905')
# (u'multivitamin, prenatal (Prenatal Multivitamins oral tablet)', u'89905')
# (u'multivitamin, prenatal (Prenatal Multivitamins oral tablet)', u'89905')
# (u'multivitamin, prenatal (Prenatal Multivitamins oral tablet)', u'89905')
# (u'multivitamin, prenatal (Prenatal Multivitamins oral tablet)', u'89905')
# (u'multivitamin, prenatal (Prenatal Multivitamins oral tablet)', u'89905')
# (u'multivitamin, prenatal (Prenatal Multivitamins oral tablet)', u'89905')
# (u'multivitamin, prenatal (Prenatal Multivitamins oral tablet)', u'89905')
# (u'multivitamin, prenatal (Prenatal Multivitamins oral tablet)', u'89905')
# (u'multivitamin, prenatal (Prenatal Multivitamins oral tablet)', u'89905')
# (u'multivitamin, prenatal (Prenatal Multivitamins oral tablet)', u'89905')
# (u'multivitamin, prenatal (Prenatal Multivitamins oral tablet)', u'89905')
# (u'multivitamin, prenatal (Prenatal Multivitamins oral tablet)', u'89905')
# (u'clonazePAM (KLONOPIN) 0.5 MG tablet', u'null')
# (u'DULoxetine (CYMBALTA) 60 MG capsule', u'null')
# (u'cephALEXin (KEFLEX) 500 MG capsule', u'null')
# (u'methylPREDNIsolone (MEDROL DOSPACK) 4 mg tablet', u'null')
# (u'dextroamphetamine-amphetamine (AMPHETAMINE-DEXTROAMPHETAMINE) 30 mg tablet', u'null')
# (u'sulfamethoxazole-trimethoprim (BACTRIM,SEPTRA) 200-40 MG/5ML PO Suspension', u'null')
# (u'BENZONATATE PO', u'null')
# (u'ACCU-CHEK SMARTVIEW TEST STRIP Misc Strip', u'583344')
# (u'ACCU-CHEK FASTCLIX Misc Misc', u'583344')
# (u'Blood-Glucose Meter (ACCU-CHEK NANO) Misc Misc', u'null')
# (u'Lancing Device with Lancets (ACCU-CHEK FASTCLIX) Misc Kit', u'null')
# (u'tetanus/diphtheria/acellular pertussis (Tdap) (ADACEL) Vaccine INJ 0.5 mL', u'null')
# (u'Prenatal Vit-Calcium-Iron-FA (PRENATAL VITAMIN) Oral Tab', u'237741')
# (u'Magnesium 250 Mg Tablet', u'6574')
# (u'ERYTHROMYCIN BASE (ERYTHROMYCIN TOPICAL)', u'null')
# (u'Fe Carbonyl-Fe Gluconate-FA-Vit B12-Vit C-DSS (FERRALET) 90-1 mg tablet', u'216347')
# (u'ferrous sulfate (FERROUS SULFATE) 325 (65 FE) MG tablet', u'null')
# (u'Blood-Glucose Meter (TRUETRACK BLOOD GLUCOSE SYSTEM) Misc Kit', u'null')
# (u'Lancets Misc Misc', u'null')
# (u'Blood Sugar Diagnostic (TRUETEST TEST STRIPS) Misc Strip', u'null')
# (u'Acetone, Urine, Test (KETOSTIX) Misc Strip', u'null')
# (u'Lancets Misc Misc', u'null')
# (u'Blood Sugar Diagnostic (BLOOD GLUCOSE TEST) Misc Strip', u'null')
# (u'Ascorbic Acid (VITAMIN C PO)', u'null')
# (u'IRON PO', u'null')
# (u'lancets (FREESTYLE LANCETS) 28 gauge misc', u'null')
# (u'blood sugar diagnostic (FREESTYLE LITE STRIPS) test strip', u'null')
# (u'Prenatal Multivit-Ca-Min-Fe-FA (PRENATAL VITAMIN) tab', u'null')
# (u'OTC PRODUCT', u'null')
# (u'Prenatal Vit-Iron Fumarate-FA (PRENATAL S) 27-0.8 mg Oral Tab', u'90176')
# (u'Prenatal Vit-Iron Fumarate-FA (PRENATAL S) 27-0.8 mg Oral Tab', u'90176')
# (u'Cetirizine HCl (ZYRTEC PO)', u'null')
# (u'Prenatal Vit-Calcium-Iron-FA (PRENATAL VITAMIN) Oral Tab', u'237741')
# (u'Prenatal MV-Min-Fe Fum-FA-DHA (PRENATAL 1 PO)', u'null')
# (u'Inhalational Spacer (AEROCHAMBER Z-STAT PLUS-FLW SG) Misc Spcr', u'1086493')
# (u'Magnesium 250 Mg Tablet', u'6574')
# (u'PRENATAL VIT W-CA,FE,FA,<1 MG, (PRENATAL #2 ORAL)', u'null')
# (u'miscellaneous medical supply Misc Misc', u'null')
# (u'BIOTIN ORAL', u'null')
# (u'multivitamin (MULTIVITAMIN) Oral per tablet', u'null')
# (u'ONETOUCH ULTRA TEST MISC STRIPS', u'692591')
# (u'BECLOMETHASONE DIPROPIONATE (QVAR INHL)', u'null')
# (u'PEDIATRIC MULTIVIT COMB NO.76 (FLINTSTONES COMPLETE ORAL)', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS PO)', u'null')
# (u'Glucose Blood (ACCU-CHEK SMARTVIEW) In Vitro Strip', u'null')
# (u'ACCU-CHEK FASTCLIX LANCETS Does not apply Misc', u'583344')
# (u'Cetirizine HCl (ZYRTEC ALLERGY PO)', u'null')
# (u'Inhalational Spacer (AEROCHAMBER PLUS FLOW-VU) Misc Spcr', u'1086493')
# (u'blood glucose strip (FREESTYLE LITE) Strips', u'null')
# (u'Prenatal Vit#96-Ferrous Fum-Fa 27 Mg Iron- 800 McG Oral Tab', u'90176')
# (u'Iron Sucrose (VENOFER) 100 mg iron/5 mL IV Soln', u'284502')
# (u'chewable multivitamin (FLINTSTONE ANIMAL SHAPES) WITH C & FA chewable tablet', u'89905')
# (u'insulin pen needle 32G X 4 MM', u'null')
# (u'Container (SHARPS CONTAINER) Misc Misc', u'693114')
# (u'cholecalciferol, vitamin D3, 1,000 unit capsule', u'null')
# (u'prenatal multivit-Ca-min-Fe-FA Tab', u'null')
# (u'albuterol (PROAIR HFA) 90 mcg/actuation inhaler', u'null')
# (u'cetirizine (ZYRTEC) 10 MG tablet', u'null')
# (u'lidocaine epinephrine (LE) injection 1 mL', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL PO)', u'null')
# (u'MethylPREDNISolone (MEDROL, PAK, PO)', u'null')
# (u'Multiple Vitamin (MULTI VITAMIN DAILY PO)', u'null')
# (u'Lancet Device MISC', u'null')
# (u'glucose blood (ONE TOUCH ULTRA TEST) test strip', u'null')
# (u'Insulin Pen Needle (PEN NEEDLES 31GX5/16") 31G X 8 MM', u'null')
# (u'Prenatal Vit-Iron Fumarate-FA (PRENATAL VITAMIN) 27-0.8 mg Oral Tab', u'90176')
# (u'PNV95/FERROUS FUMARATE/FA (PRENATAL ORAL)', u'null')
# (u'HYDROCODONE-ACETAMINOPHEN ORAL', u'null')
# (u'Copper (PARAGARD T 380A) 380 square mm UTRN IUD', u'2837')
# (u'sertraline (ZOLOFT) 25 mg tablet', u'null')
# (u'Escitalopram Oxalate (LEXAPRO PO)', u'null')
# (u'PARAGARD T 380A UTRN IUD', u'2837')
# (u'CEROVITE ADVANCED FORMULA 18-400 mg-mcg tab', u'90176')
# (u'INV <research study number> (MEDICATION A) syringe', u'null')
# (u'multivitamin (TAB A VITE) tab tablet', u'null')
# (u'Blood Sugar Test (ONETOUCH ULTRA TEST) Misc Strips', u'692591')
# (u'blood glucose (ONETOUCH ULTRA TEST STRIPS) test strip', u'null')
# (u'insulin syringe-needle U-100 (BD INSULIN SYRINGE ULTRA-FINE) 1/2 mL 31 x 15/64" Misc Syringe', u'5856')
# (u'NON-SYSTEM, SEE ADMIN INSTR,', u'null')
# (u'NON-SYSTEM, SEE ADMIN INSTR,', u'null')
# (u'insulin syringe-needle U-100 (BD INSULIN SYRINGE ULTRA-FINE) 1/2 mL 31 x 15/64" Misc Syringe', u'5856')
# (u'rho(D) immune globulin (RHOPHYLAC) INJ 300 mcg', u'null')
# (u'Pyridoxine HCl (VITAMIN B-6 PO)', u'null')
# (u'COMPOUNDED PRESCRIPTION', u'null')
# (u'COMPOUNDED PRESCRIPTION', u'null')
# (u'TRAMADOL HCL (ULTRAM ORAL)', u'null')
# (u'blood sugar diagnostic (ONETOUCH ULTRA TEST) test strip', u'null')
# (u'insulin needles, DISPOSABLE, (BD INSULIN PEN NEEDLE UF) 31 X 5/16 " ndle', u'null')
# (u'COMPOUNDED PRESCRIPTION', u'null')
# (u'COMPOUNDED PRESCRIPTION', u'null')
# (u'Inhalational Spacer (AEROCHAMBER Z-STAT PLUS-FLW SG) Misc Spcr', u'1086493')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS PO)', u'null')
# (u'Multiple Vitamins-Minerals (MULTIVITAMIN PO)', u'null')
# (u'Multiple Vitamins-Minerals (AIRBORNE PO)', u'null')
# (u'CPAP', u'null')
# (u'Syringe (Disposable) 3 Ml Misc Syringe', u'431482')
# (u'Needle, Disp, (BD Specialty Use) 30 gauge x 1/2" Misc Needle', u'432332')
# (u'Needle, Disp, (BD REGULAR BEVEL NEEDLES) 18 gauge x 1 1/2" Misc Needle', u'432227')
# (u'Syringe (Disposable) 3 Ml Misc Syringe', u'431482')
# (u'Needle, Disp, (BD Specialty Use) 30 gauge x 1/2" Misc Needle', u'432332')
# (u'Needle, Disp, (BD REGULAR BEVEL NEEDLES) 18 gauge x 1 1/2" Misc Needle', u'432227')
# (u'Aspirin-Acetaminophen-Caffeine (EXCEDRIN MIGRAINE PO)', u'null')
# (u'Prenatal Vit-Calcium-Iron-FA (PRENATAL VITAMIN) Oral Tab', u'237741')
# (u'Prenatal Vit-Calcium-Iron-FA (PRENATAL VITAMIN) Oral Tab', u'237741')
# (u'Prenatal Vit-Calcium-Iron-FA (PRENATAL VITAMIN) Oral Tab', u'237741')
# (u'Prenatal Vit-Calcium-Iron-FA (PRENATAL VITAMIN) Oral Tab', u'237741')
# (u'glucose blood VI test strips (ONE TOUCH TEST STRIPS) strip', u'null')
# (u'HydrOXYzine Pamoate (VISTARIL PO)', u'null')
# (u'Multiple Vitamins-Minerals (MULTIVITAL) TABS', u'89905')
# (u'MALIC ACID ORAL', u'null')
# (u'PRENATAL VIT/IRON FUMARATE/FA (PRENATAL ORAL)', u'null')
# (u'Barium Sulfate (READI-CAT 2) 2.1 % (w/v), 2.0 % (w/w) Oral Susp', u'607141')
# (u'CETIRIZINE HCL OR', u'null')
# (u'Ascorbic Acid (VITAMIN C OR)', u'null')
# (u'EVENING PRIMROSE OIL (EVENING PRIMROSE ORAL)', u'null')
# (u'EVENING PRIMROSE OIL (EVENING PRIMROSE ORAL)', u'null')
# (u'multivitamin (MVI) tablet', u'null')
# (u'Bupivacaine Hcl (Pf) 0.5 % Inj Soln', u'1300440')
# (u'LANSOPRAZOLE PO', u'null')
# (u'Prenatal Multivit-Ca-Min-Fe-FA (PRENATAL VITAMIN) Tablet', u'null')
# (u'Blood Pressure Monitor (BLOOD PRESSURE KIT) Kit', u'null')
# (u'CHROM PICO/BRINDAL BERRY (GARCINIA CAMBOGIA PO)', u'null')
# (u'OXYCODONE HCL/ACETAMINOPHEN (PERCOCET PO)', u'null')
# (u'OMEGA-3 FATTY ACIDS (FISH OIL ORAL)', u'null')
# (u'FOLIC ACID ORAL', u'null')
# (u'VITAMIN E ORAL', u'null')
# (u'Rx Supply Misc (Lantus and Novolog Pen needles)', u'379750')
# (u'Rx Supply Misc (Lantus and Novolog Pen needles)', u'379750')
# (u'Rx Supply Misc (Lantus and Novolog Pen needles)', u'379750')
# (u'Rx Supply Misc (Lantus and Novolog Pen needles)', u'379750')
# (u'Rx Supply Misc (Lantus and Novolog Pen needles)', u'379750')
# (u'Rx Supply Misc (Lantus and Novolog Pen needles)', u'379750')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS PO)', u'null')
# (u'ACETAMINOPHEN (TYLENOL 8 HOUR PO)', u'null')
# (u'VIT C/VIT E/LUTEIN/MIN/OMEGA-3 (OCUVITE ORAL)', u'null')
# (u'iodine Liqd', u'null')
# (u'oxyCODONE-acetaminophen (ROXICET) 5-325 mg per tablet', u'null')
# (u'ibuprofen (ADVIL,MOTRIN) 600 MG tablet', u'null')
# (u'HYDROcodone-acetaminophen (NORCO) 5-325 mg per tablet', u'null')
# (u'docusate sodium (COLACE) 250 MG capsule', u'null')
# (u'Insulin Needles, Disposable, 31 gauge x 3/16"', u'null')
# (u'Blood Sugar Diagnostic', u'null')
# (u'Insulin Needles, Disposable, 31 x 3/16 "', u'null')
# (u'CYANOCOBALAMIN, VITAMIN B-12, (VITAMIN B-12 ORAL)', u'null')
# (u'lancets (ONETOUCH DELICA LANCETS) 33 gauge Misc Misc', u'239826')
# (u'Insulin Pen Needle 32G X 4 MM Does not apply Misc', u'null')
# (u'Pen Needle, Diabetic 32 Gauge X 5/32"', u'991450')
# (u'Pen Needle, Diabetic 32 Gauge X 5/32"', u'991450')
# (u'glucose blood test strip', u'null')
# (u'blood sugar diagnostic Strp', u'null')
# (u'pen needle, diabetic, safety 29 gauge x 1/2" Ndle', u'null')
# (u'Custom Compounded Medication', u'null')
# (u'Custom Compounded Medication', u'null')
# (u'lancets 30 gauge Misc', u'null')
# (u'DHEA 5 mg Tab', u'null')
# (u'BLOOD-GLUCOSE METER (BLOOD GLUCOSE MONITOR KIT MISC)', u'null')
# (u'Custom Compounded Medication', u'null')
# (u'insulin safety needles, disp, (BD AUTOSHIELD PEN NEEDLE) 29 x 1/2 " Ndle', u'null')
# (u'SUPPLEMENT FOR HOME MED DOCUMENTATION', u'null')
# (u'SUPPLEMENT FOR HOME MED DOCUMENTATION', u'null')
# (u'SUPPLEMENT FOR HOME MED DOCUMENTATION', u'null')
# (u'blood sugar diagnostic Strp', u'null')
# (u'needle, disp, 30 G (BD SPECIALTY USE NEEDLES) 30 x 1/2 " Ndle', u'null')
# (u'CHROMIUM ORAL', u'null')
# (u'CYANOCOBALAMIN, VITAMIN B-12, (VITAMIN B-12 ORAL)', u'null')
# (u'MULTIVITAMIN ORAL', u'null')
# (u'Trivora Tablets  28&#039;s', u'220491')
# (u'Suprep Bowel Prep Soln', u'1006666')
# (u'Trivora Tablets  28&#039;s', u'220491')
# (u'Trivora Tablets  28&#039;s', u'220491')
# (u'Trivora Tablets  28&#039;s', u'220491')
# (u'Trivora Tablets  28&#039;s', u'220491')
# (u'ACETAMINOPHEN (TYLENOL ORAL)', u'null')
# (u'DOCOSAHEXANOIC ACID/EPA (FISH OIL ORAL)', u'null')
# (u'CALCIUM CARBONATE (TUMS ORAL)', u'null')
# (u'PNV CMB#21/IRON/FOLIC ACID (PRENATAL COMPLETE ORAL)', u'null')
# (u'Calcium 500mg W/Vit D Tablets 375&#039;s', u'1895')
# (u'Calcium 600+D (200u) Tablets', u'215827')
# (u'Calcium 600+D (200u) Tablets', u'1895')
# (u'Diclofenac Sodium 75mg DR Tablets', u'9853')
# (u'Proair Inh (200 Puffs)8.5gm Dos Ctr', u'216345')
# (u'Levothyroxine 0.05mg (50mcg) Tab', u'731977')
# (u'Levothyroxine 0.05mg (50mcg) Tab', u'731977')
# (u'Levothyroxine 0.05mg (50mcg) Tab', u'731977')
# (u'Levothyroxine 0.025mg (25mcg) Tab', u'731977')
# (u'Levothyroxine 0.025mg (25mcg) Tab', u'731977')
# (u'Advair Diskus 250/50mcg (Yellow) 60', u'284649')
# (u'Esomeprazole Magnesium 40mg DR Caps', u'6574')
# (u'Proventil HFA Inh (200 Puffs) 6.7gm', u'219483')
# (u'Levothyroxine 0.025mg (25mcg) Tab', u'731977')
# (u'Pregabalin (LYRICA PO)', u'null')
# (u'Probiotic Product (PROBIOTIC DAILY PO)', u'null')
# (u'Acetaminophen (TYLENOL PO)', u'null')
# (u'AMOXICILLIN PO', u'null')
# (u'FOLIC ACID PO', u'null')
# (u'RANITIDINE HCL (ZANTAC ORAL)', u'null')
# (u'PRENATAL VITS W-CA,FE,FA,<1MG, (PRENATAL VITAMIN ORAL)', u'null')
# (u'Paroxetine Hcl 30 Mg Po Tabs', u'312243')
# (u'Multiple Vitamin (MULTIVITAMINS) Oral Cap', u'89905')
# (u'Pnv Cmb#95-Ferrous Fumarate-Fa 28 Mg Iron- 800 McG Oral Tab', u'90176')
# (u'ASCORBIC ACID (VITAMIN C WITH ROSE HIPS PO)', u'null')
# (u'BIOTIN PO', u'null')
# (u'CYANOCOBALAMIN, VITAMIN B-12, (VITAMIN B-12 PO)', u'null')
# (u'Intrauterine Device, IUD, IU IUD', u'null')
# (u'Cholecalciferol (VITAMIN D OR)', u'null')
# (u'Sennosides-Docusate Sodium (SENNA S OR)', u'null')
# (u'Probiotic Product (PROBIOTIC DAILY OR)', u'null')
# (u'Misc. Devices (BREAST PUMP) MISC', u'null')
# (u'multivitamin tablet', u'null')
# (u'Prenatal Vit-Iron Fumarate-FA (PRENATAL FORMULA) 28 mg iron- 800 mcg Oral Tab', u'90176')
# (u'Inhalational Spacer (AEROCHAMBER Z-STAT PLUS-FLW SG) Misc Spcr', u'1086493')
# (u'Prenatal Vit w/Fe-Methylfol-FA (PNV PO)', u'null')
# (u'Acetaminophen (TYLENOL PO)', u'null')
# (u'OXYCODONE HCL PO', u'null')
# (u'Multiple Vitamin (MULTIVITAMINS) oral tablet', u'null')
# (u'PARAGARD INTRAUTERINE COPPER IUD 1 Device', u'1362130')
# (u'pen needle, diabetic (BD ULTRA-FINE NANO PEN NEEDLES) 32 gauge x 5/32" Misc Needle', u'991450')
# (u'PRENATAL VIT/IRON FUMARATE/FA (PRENATAL ORAL)', u'null')
# (u'PRENATAL VIT #91/FE FUM/FA/DHA (PRENATAL + DHA ORAL)', u'null')
# (u'MISC NATURAL PRODUCTS PO', u'null')
# (u'GABAPENTIN, ONCE-DAILY, PO', u'null')
# (u'CARBIDOPA PO', u'null')
# (u'LOSARTAN POTASSIUM PO', u'null')
# (u'PREDNISONE', u'1021645')
# (u'CALCIUM CARBONATE (TUMS ORAL)', u'null')
# (u'Misc. Devices (BREAST PUMP) MISC', u'null')
# (u'Prenatal Vit-Fe Sulfate-FA (PRENATAL VITAMIN PO)', u'null')
# (u'Prenat-FeCbn-FeAsp-Meth-FA-DHA (PRENATE MINI) 18-0.6-0.4-350 MG CAPS', u'1648316')
# (u'Prenatal Vitamins (DIS) TABS', u'null')
# (u'PRENATAL VITAMINS PO', u'null')
# (u'Multiple Vitamin (MULTIVITAMIN PO)', u'null')
# (u'multivitamin tablet', u'null')
# (u'ALBUTEROL INHAL', u'null')
# (u'Adderall XR 30mg Capsules', u'352398')
# (u'Adderall XR 30mg Capsules', u'352398')
# (u'Azelastine 0.1%(137mcg/Sp)200 Doses', u'216345')
# (u'Azelastine 0.1%(137mcg/Sp)200 Doses', u'216345')
# (u'Adderall XR 30mg Capsules', u'352398')
# (u'Adderall XR 30mg Capsules', u'352398')
# (u'Adderall XR 30mg Capsules', u'352398')
# (u'Adderall XR 30mg Capsules', u'352398')
# (u'Adderall XR 30mg Capsules', u'352398')
# (u'Adderall XR 30mg Capsules', u'352398')
# (u'Adderall XR 30mg Capsules', u'352398')
# (u'Adderall XR 30mg Capsules', u'352398')
# (u'Adderall XR 30mg Capsules', u'352398')
# (u'Adderall XR 30mg Capsules', u'352398')
# (u'Levothyroxine 0.075mg (75mcg) Tabs', u'731977')
# (u'Azelastine 0.1%(137mcg/Sp)200 Doses', u'216345')
# (u'Adderall XR 30mg Capsules', u'352398')
# (u'Adderall XR 30mg Capsules', u'352398')
# (u'Adderall XR 30mg Capsules', u'352398')
# (u'Azelastine 0.1%(137mcg/Sp)200 Doses', u'216345')
# (u'Levothyroxine 0.075mg (75mcg) Tabs', u'731977')
# (u'Adderall XR 30mg Capsules', u'352398')
# (u'MAGNESIUM ORAL', u'null')
# (u'magic mouthwash', u'null')
# (u'COQ10, LIPOSOMAL UBIQUINOL, ORAL', u'null')
# (u'Lancet Devices (LANCING DEVICE) MISC', u'null')
# (u'Blood Glucose Monitoring Suppl (ACCU-CHEK AVIVA PLUS) W/DEVICE KIT', u'583344')
# (u'glucose blood test accu-chek (AVIVA PLUS) STRP strip', u'583344')
# (u'Lancets MISC', u'null')
# (u'ONDANSETRON (ZOFRAN ODT PO)', u'null')
# (u'Pediatric Multiple Vit-C-FA (FLINSTONES GUMMIES OMEGA-3 DHA) chewable tablet', u'89905')
# (u'Pediatric Multiple Vit-C-FA (FLINSTONES GUMMIES OMEGA-3 DHA) chewable tablet', u'4301')
# (u'CETIRIZINE HCL (ZYRTEC ORAL)', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL VITAMIN PO)', u'null')
# (u'MedroxyPROGESTERone Acetate (DEPO-PROVERA IM)', u'null')
# (u'LITHIUM OR', u'null')
# (u'Zolpidem Tartrate (AMBIEN OR)', u'null')
# (u'QUEtiapine Fumarate (SEROQUEL OR)', u'null')
# (u'Prenat w/o A-FE-Methfol-FA-DHA (PNV-DHA OR)', u'null')
# (u'DME', u'null')
# (u'DIAZEPAM (VALIUM ORAL)', u'null')
# (u'PNV95/FERROUS FUMARATE/FA (PRENATAL ORAL)', u'null')
# (u'UNABLE TO FIND', u'null')
# (u'UNABLE TO FIND', u'null')
# (u'OTHER', u'null')
# (u'Ferrous Gluconate 325 Mg (37 Mg Iron) Po Tab', u'90176')
# (u'FLUTICASONE FUROATE IN', u'null')
# (u'VITAMIN D3 PO', u'null')
# (u'multivitamin with mineral tab', u'null')
# (u'NAPROXEN SODIUM (ALEVE ORAL)', u'null')
# (u'pen needle, diabetic (BD INSULIN PEN NEEDLE UF SHORT) 31 gauge x 5/16" Ndle', u'null')
# (u'DiphenhydrAMINE HCl (BENADRYL ALLERGY PO)', u'null')
# (u'insulin syringe-needle U-100 (BD INSULIN SYRINGE ULTRA-FINE) 1/2 mL 31 x 15/64" Misc Syringe', u'5856')
# (u'Inhalational Spacer (AEROCHAMBER Z-STAT PLUS-FLW SG) Misc Spcr', u'1086493')
# (u'Polyethylene Glycol 3350 (MIRALAX ORAL)', u'null')
# (u'Sennosides (SENOKOT ORAL)', u'null')
# (u'Riboflavin-Magnesium-Feverfew (MIGRELIEF) 200-180-50 MG TABS', u'null')
# (u'Cyanocobalamin (VITAMIN B-12 ORAL)', u'null')
# (u'therapeutic multivitamin-minerals (THERAGRAN-M) TABS', u'89905')
# (u'prenatal vitamin-folic acid 1 mg (PRENATAL VITAMIN) tablet/capsule', u'null')
# (u'MULTI VITAMIN MENS OR', u'null')
# (u'lancets (ONE TOUCH DELICA) 33 gauge Misc', u'null')
# (u'lancets (ONE TOUCH DELICA) 33 gauge Misc', u'239826')
# (u'Blood Sugar Diagnostic Misc Strp', u'692591')
# (u'Blood Sugar Diagnostic Misc Strp', u'692591')
# (u'Insulin Needles (Disposable) 31 X 3/16 Inch Misc Ndle', u'637361')
# (u'Insulin Needles (Disposable) 31 X 3/16 Inch Misc Ndle', u'637361')
# (u'Blood Sugar Diagnostic Misc Strp', u'692591')
# (u'Prenatal Vit-Iron Fumarate-Fa 27-0.8 Mg Oral Tab', u'90176')
# (u'PRENATAL VITAMINS PO', u'null')
# (u'PRENATAL VIT W-CA,FE,FA,<1 MG, (PRENATAL VITAMIN ORAL)', u'null')
# (u'ACCU-CHEK AVIVA PLUS test strip', u'583344')
# (u'Blood Glucose Monitoring Suppl (TRUERESULT BLOOD GLUCOSE) W/DEVICE KIT', u'807850')
# (u'OTHER MEDICATION, ,', u'null')
# (u'IRON PO', u'null')
# (u'Riboflavin-Magnesium-Feverfew (MIGRELIEF PO)', u'null')
# (u'Ultra Fine Insulin Syringe-Needle U-100 (BD INSULIN ULTRA-FINE) 1 mL 30 gauge x 1/2" Misc Syringe', u'431247')
# (u'PRENATAL VIT W-CA,FE,FA,<1 MG, (PRENATAL VITAMIN ORAL)', u'null')
# (u'lidocaine 1 % + nifedipine 0.3 % cream 60 gm', u'null')
# (u'ferrous sulfate 325 mg total salt (65 mg elemental) oral tablet', u'null')
# (u'Insulin Syringe-Needle U-100 1/2 Ml 31 X 5/16"', u'431264')
# (u'glucose blood VI test strips (ONE TOUCH ULTRA TEST) strip', u'null')
# (u'insulin syringe-needle U-100 1 mL 31 x 5/16" Syrg', u'null')
# (u'Multiple Vitamins-Minerals (OCUVITE PO)', u'null')
# (u'FEXOFENADINE HCL (ALLEGRA PO)', u'null')
# (u'Multivitamin Capsule', u'89905')
# (u'PARAGARD INTRAUTERINE COPPER IUD 1 Each', u'1362130')
# (u'BUDESONIDE INHL', u'null')
# (u'Container (SHARPS CONTAINER) Misc Misc', u'693114')
# (u'dexamethasone (DECADRON) (conc: 1 mg/mL) oral drops 10 mg', u'null')
# (u'Prenat-FeCbn-FeAsp-Meth-FA-DHA (PRENATE MINI) 18-0.6-0.4-350 MG Cap', u'1648316')
# (u'MULTIVITAMINS PO TABS', u'89905')
# (u'amoxicillin-clavulanate (AUGMENTIN) 875-125 mg per tablet', u'null')
# (u'oxyCODONE (ROXICODONE) 5 MG immediate release tablet', u'null')
# (u'celecoxib (CELEBREX) 100 MG capsule', u'null')
# (u'digestive enzymes Tab', u'null')
# (u'beta-glucan,1-3, 1-4, bulk, 70 % Powd', u'null')
# (u'Needle, Disp, (BD Specialty Use) 30 gauge x 1/2" Misc Needle', u'432332')
# (u'Syringe with Needle, Disp, (BD Luer-Lok) 3 mL 21 x 1 1/2" Misc Syringe', u'431388')
# (u'Prenatal Vit-Iron Fumarate-FA (PRENATAL S) 27-0.8 mg Oral Tab', u'90176')
# (u'Container (SHARPS CONTAINER) Misc Misc', u'693114')
# (u'Needle, Disp, (BD Specialty Use) 30 gauge x 1/2" Misc Needle', u'432332')
# (u'Syringe with Needle, Disp, (BD Luer-Lok) 3 mL 21 x 1 1/2" Misc Syringe', u'431388')
# (u'Arm Brace (FUTURO LEFT HAND WRIST BRACE) Misc Misc', u'239917')
# (u'prenatal multivitamin (VINATE ONE) PO tablet', u'89905')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS) 0.8 MG PO Tab', u'null')
# (u'Paroxetine Hcl 30 Mg Po Tabs', u'312243')
# (u'Paroxetine Hcl 30 Mg Po Tabs', u'312243')
# (u'Prenatal Multivit-Min-Fe-FA (PRE-NATAL PO)', u'null')
# (u'Cetirizine HCl (ZYRTEC ALLERGY PO)', u'null')
# (u'propranolol (INDERAL) 10 MG tablet', u'null')
# (u'LORazepam (ATIVAN) 0.5 MG tablet', u'null')
# (u'HYDROcodone-acetaminophen (NORCO) 5-325 mg tablet', u'null')
# (u'predniSONE (DELTASONE) 20 MG tablet', u'null')
# (u'prochlorperazine (COMPAZINE) 10 MG tablet', u'null')
# (u'HYDROcodone-acetaminophen (HYCET) 7.5-325 mg/15 mL solution', u'null')
# (u'amoxicillin-clavulanate (AUGMENTIN ES-600) 600-42.9 mg/5 mL suspension', u'null')
# (u'LORazepam (ATIVAN) 0.5 MG tablet', u'null')
# (u'zonisamide (ZONEGRAN) 100 MG capsule', u'null')
# (u'rizatriptan (MAXALT) 10 MG tablet', u'null')
# (u'nortriptyline (PAMELOR) 25 MG capsule', u'null')
# (u'methylPREDNISolone acetate (DEPO-MEDROL) injection 40 mg', u'null')
# (u'bupivacaine (MARCAINE) 0.5 % (5 mg/mL) injection 5 mg', u'null')
# (u'nortriptyline (PAMELOR) 25 MG capsule', u'null')
# (u'zonisamide (ZONEGRAN) 100 MG capsule', u'null')
# (u'naratriptan (AMERGE) 2.5 MG tablet', u'null')
# (u'butalbital-acetaminophen-caffeine (ESGIC) 50-325-40 mg per tablet', u'null')
# (u'coenzyme Q10 10 mg capsule', u'null')
# (u'RIBOFLAVIN ORAL', u'null')
# (u'MAGNESIUM ORAL', u'null')
# (u'sertraline (ZOLOFT) 100 MG tablet', u'null')
# (u'albuterol (PROAIR HFA;PROVENTIL HFA;VENTOLIN HFA) 90 mcg/actuation inhaler', u'null')
# (u'nitrofurantoin (MACRODANTIN) 100 MG capsule', u'null')
# (u'beclomethasone (QVAR) 80 mcg/actuation inhaler', u'null')
# (u'cetirizine (ZYRTEC) 10 MG tablet', u'null')
# (u'fluticasone (FLONASE) 50 mcg/actuation nasal spray', u'null')
# (u'prenatal vitamin-folic acid 1 mg (PRENATAL VITAMIN) tablet/capsule', u'null')
# (u'multivitamin tablet', u'null')
# (u'Montelukast Sodium (SINGULAIR PO)', u'null')
# (u'Thyroid (Armour) 1gr  (60mg)  Tabs', u'80697')
# (u'Thyroid (Armour) 1gr  (60mg)  Tabs', u'80697')
# (u'Thyroid (Armour) 1gr  (60mg)  Tabs', u'80697')
# (u'Wellbutrin XL 150mg Tablets', u'405400')
# (u'Thyroid (Armour) 1gr  (60mg)  Tabs', u'80697')
# (u'Wellbutrin XL 150mg Tablets', u'405400')
# (u'Wellbutrin XL 150mg Tablets', u'405400')
# (u'PNV CMB#21/IRON/FOLIC ACID (PRENATAL COMPLETE ORAL)', u'null')
# (u'AZITHROMYCIN', u'727450')
# (u'PREDNISONE', u'1270912')
# (u'PREDNISONE', u'1601070')
# (u'blood glucose test strips (ONETOUCH VERIO) Strips', u'null')
# (u'Fexofenadine HCl (ALLEGRA PO)', u'null')
# (u'Prenatal Vit-Iron Fumarate-FA (STUART PRENATAL) 28 mg iron- 800 mcg Oral Tab', u'90176')
# (u'RANITIDINE HCL (ZANTAC ORAL)', u'null')
# (u'PNV CMB#21/IRON/FOLIC ACID (PRENATAL COMPLETE ORAL)', u'null')
# (u'pen needle, diabetic (BD ULTRA-FINE NANO PEN NEEDLES) 32 gauge x 5/32" Ndle', u'null')
# (u'PRENATAL VIT/IRON FUMARATE/FA (PRENATAL ORAL)', u'null')
# (u'PRENATAL VIT/IRON FUMARATE/FA (PRENATAL ORAL)', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL VITAMIN PO)', u'null')
# (u'MISC MEDICATION, SEE SIG DETAILS,', u'null')
# (u'sodium chloride 0.9 % SolP 500 mL with vancomycin 1,000 mg SolR 2.25 g IVPB', u'9853')
# (u'sodium chloride 0.9 % SolP 500 mL with vancomycin 1,000 mg SolR 2.25 g IVPB', u'153974')
# (u'sodium chloride 0.9 % SolP 500 mL with vancomycin 1,000 mg SolR 2 g IVPB', u'9853')
# (u'sodium chloride 0.9 % SolP 500 mL with vancomycin 1,000 mg SolR 2 g IVPB', u'153974')
# (u'OXYcodone-acetaminophen (PERCOCET) 5-325 MG Oral Tab', u'null')
# (u'Ascorbic Acid (VITAMELTS VITAMIN C PO)', u'null')
# (u'Inulin (FIBER CHOICE PO)', u'null')
# (u'Probiotic Product (ALIGN PO)', u'null')
# (u'Multiple Vitamins-Minerals (MULTIVITAMIN PO)', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL VITAMIN) 27-0.8 MG Tab', u'null')
# (u'Barium Sulfate (READI-CAT 2) 2.1 % (w/v), 2.0 % (w/w) Oral Susp', u'607141')
# (u'Barium Sulfate (READI-CAT 2) 2.1 % (w/v), 2.0 % (w/w) Oral Susp', u'607141')
# (u'blood sugar diagnostic Strp', u'null')
# (u'Inhalational Spacer (AEROCHAMBER Z-STAT PLUS-FLW SG) Misc Spcr', u'1086493')
# (u'multivitamin (THERAGRAN) tablet', u'null')
# (u'Paroxetine 10 Mg Tablet', u'312241')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS) 0.8 MG Tab', u'null')
# (u'glucose blood (FREESTYLE LITE) strip', u'null')
# (u'blood sugar diagnostic (ONETOUCH ULTRA TEST) test strip', u'null')
# (u'Prenatal Vit-Iron Fumarate-FA (STUART PRENATAL) 28 mg iron- 800 mcg Oral Tab', u'90176')
# (u'Prenatal Vit-Iron Fumarate-FA (PRENATAL VITAMIN WITH MINERALS) 28 mg iron- 800 mcg Oral Tab', u'90176')
# (u'Prenatal Vit-Iron Fumarate-FA (PRENATAL VITAMIN WITH MINERALS) 28 mg iron- 800 mcg Oral Tab', u'90176')
# (u'CHROM PICO/BRINDAL BERRY (GARCINIA CAMBOGIA PO)', u'null')
# (u'Prenatal Vitamin With Calcium No.72-Iron 27 Mg-Folic Acid 1 Mg Tablet', u'90176')
# (u'Prenatal Multivit-Ca-Min-Fe-FA (PRENATAL VITAMIN) Tab', u'null')
# (u'Insulin Needles, Disposable, (NANO PEN NEEDLE) 32 gauge x 5/32" Ndle', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PNV PRENATAL PLUS MULTIVITAMIN) 27-1 MG TABS', u'1422995')
# (u'Prenat w/o A-FeCbn-Meth-FA-DHA (PRENATE MINI) 29-0.6-0.4-350 MG capsule', u'1439470')
# (u'Prenat w/o A-FeCbn-Meth-FA-DHA (PRENATE MINI) 29-0.6-0.4-350 MG capsule', u'1439470')
# (u'Paroxetine Hcl 30 Mg Oral Tab', u'312243')
# (u'Paroxetine Hcl 30 Mg Oral Tab', u'312243')
# (u'Omega-3 Fatty Acids (FISH OIL PO)', u'null')
# (u'blood sugar diagnostic (ONETOUCH ULTRA TEST) test strip', u'null')
# (u'Docosahexaenoic Acid (DHA OR)', u'null')
# (u'BREAST PUMP', u'null')
# (u'Iron 18 Mg Tablet', u'90176')
# (u'CALCIUM CARBONATE ORAL', u'null')
# (u'CHOLECALCIFEROL (VITAMIN D3) (VITAMIN D3 ORAL)', u'null')
# (u'OTHER MEDICATION, ,', u'null')
# (u'OTHER MEDICATION, ,', u'null')
# (u'OTHER MEDICATION, ,', u'null')
# (u'OTHER MEDICATION, ,', u'null')
# (u'OTHER MEDICATION, ,', u'null')
# (u'sodium chloride 0.9 % 0.9 % Solp 100 mL with meropenem 1 gram SolR 2 g', u'9853')
# (u'sodium chloride 0.9 % 0.9 % Solp 100 mL with meropenem 1 gram SolR 2 g', u'153974')
# (u'Misc. Devices (BREAST PUMP) MISC', u'null')
# (u'Pnv With Calcium No.72-Iron-Fa 27 Mg Iron- 1 Mg Oral Tab', u'90176')
# (u'Pnv With Calcium No.72-Iron-Fa 27 Mg Iron- 1 Mg Oral Tab', u'90176')
# (u'PSEUDOEPHEDRINE HCL (SUDAFED ORAL)', u'null')
# (u'Acetone, Urine, Test (KETOSTIX) Misc Strip', u'null')
# (u'Lancets Misc Misc', u'null')
# (u'Blood Sugar Diagnostic (BLOOD GLUCOSE TEST) Misc Strip', u'null')
# (u'Albuterol Sulfate (ALBUTEROL, PROVENTIL, INHALER **STARTER PACK) 90 mcg/act AERS', u'null')
# (u'Pediatric Multivit-Minerals-C (FLINTSTONES GUMMIES COMPLETE) CHEW', u'89905')
# (u'RESVERATROL PO', u'null')
# (u'Magnesium 100 Mg Po Tabs', u'1426853')
# (u'Zinc Sulfate (ZINC 15 PO)', u'null')
# (u'fluticasone (FLONASE) 50 mcg/Actuation nasal', u'null')
# (u'gabapentin (NEURONTIN) 100 MG capsule', u'null')
# (u'pramipexole (MIRAPEX) 0.25 MG tablet', u'null')
# (u'Paroxetine Hcl 20 Mg Oral Tab', u'314199')
# (u'Container (SHARPS CONTAINER) Misc Misc', u'693114')
# (u'Prenatal Vitamin With Calcium No.72-Iron 27 Mg-Folic Acid 1 Mg Tablet', u'90176')
# (u'Prenatal Multivit-Ca-Min-Fe-FA (PRENATAL VITAMIN) Oral Tablet', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL PLUS IRON VITAMIN) 27-1 MG PO TABS', u'1490949')
# (u'Prenatal Vit-DSS-Fe Cbn-FA (MYNATAL ADVANCE) PO TABS', u'216347')
# (u'Misc. Devices (BREAST PUMP) XX MISC', u'null')
# (u'Multiple Vitamins-Minerals (MULTIVITAMIN PO)', u'null')
# (u'PREDNISONE', u'null')
# (u'glucose blood (ONETOUCH VERIO) strip', u'null')
# (u'Blood Glucose Control, Normal (ONETOUCH ULTRA CONTROL) Misc Soln', u'692590')
# (u'Blood Sugar Test (ONETOUCH ULTRA TEST) Misc Strips', u'692591')
# (u'Blood Glucose Meter with Device (ONETOUCH ULTRA2) Misc Kit', u'240786')
# (u'Prenatal Vit-DSS-Fe Cbn-FA (PRENATAL VITAMIN) Tab', u'null')
# (u'Multivitamin Therapeutic Oral Tab', u'null')
# (u'BuPROPion HCl (WELLBUTRIN PO)', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL VITAMINS) 28-0.8 MG Tab', u'null')
# (u'DME DIABETIC SUPPLY ORDER', u'null')
# (u'DME DIABETIC SUPPLY ORDER', u'null')
# (u'Prenatal Vit-Iron Fumarate-FA (RIGHT STEP PRENATAL VITAMINS) 27-0.8 mg Oral Tab', u'90176')
# (u'FOLIC ACID ORAL', u'null')
# (u'sertraline 25 MG tablet', u'null')
# (u'Probiotic Product (PRO-BIOTIC BLEND PO)', u'null')
# (u'Calcium-Vitamin D 600-200 MG-UNIT Oral Tab', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRE-NATAL FORMULA PO)', u'null')
# (u'Respiratory Therapy Supplies (NEBULIZER) XX DEVI', u'null')
# (u'LACTOBAC CMB #3/FOS/PANTETHINE (PROBIOTIC & ACIDOPHILUS PO)', u'null')
# (u'NORETH A-ET ESTRA/FE FUMARATE (LO LOESTRIN FE PO)', u'null')
# (u'MULTIVITAMINS WITH FLUORIDE (MULTI-VITAMIN PO)', u'null')
# (u'CALCIUM CARBONATE/VITAMIN D3 (CALCIUM + D PO)', u'null')
# (u'PSEUDOEPHEDRINE HCL (SUDAFED ORAL)', u'null')
# (u'ACETAMINOPHEN (TYLENOL ORAL)', u'null')
# (u'CALCIUM CARBONATE (TUMS ORAL)', u'null')
# (u'Prenatal Multivit-Ca-Min-Fe-FA tablet', u'null')
# (u'multivitamin tablet', u'89905')
# (u'other (unlisted)', u'null')
# (u'Multiple Vitamins-Minerals (MULTIVITAMIN & MINERAL PO)', u'null')
# (u'PNV NO.115/IRON FUMARATE/FA (PRENATAL #115-IRON-FOLIC ACID ORAL)', u'null')
# (u'IRON PO', u'null')
# (u'GLUCOSAMINE/CHONDROITIN SULF A (GLUCOSAMINE-CHONDROITIN ORAL)', u'null')
# (u'PNV CMB#21/IRON/FOLIC ACID (PRENATAL COMPLETE ORAL)', u'null')
# (u'PNV CMB#21/IRON/FOLIC ACID (PRENATAL COMPLETE ORAL)', u'null')
# (u'Iohexol (OMNIPAQUE) 240 mg iodine/mL IV Soln', u'218874')
# (u'Iohexol (OMNIPAQUE) 240 mg iodine/mL IV Soln', u'218874')
# (u'Free Text Medication Entry (OTHER)', u'null')
# (u'PNV62/FA/OM3/DHA/EPA/FISH OIL (PRENATAL GUMMY ORAL)', u'null')
# (u'Lidocaine Hcl 1 % Injection Soln', u'1247659')
# (u'Prenatal Vit-Calcium-Iron-FA (PRENATAL VITAMIN) Oral Tab', u'237741')
# (u'Iohexol (OMNIPAQUE) 240 mg iodine/mL IV Soln', u'218874')
# (u'Iohexol (OMNIPAQUE) 240 mg iodine/mL IV Soln', u'218874')
# (u'Prenatal Vit-Calcium-Iron-FA (PRENATAL VITAMIN) Oral Tab', u'237741')
# (u'Inhalational Spacer (AEROCHAMBER Z-STAT PLUS-FLW SG) Misc Spcr', u'1086493')
# (u'Insulin Needles, Disposable, (NANO PEN NEEDLE) 32 gauge x 5/32" ndle', u'null')
# (u'RANITIDINE HCL (ZANTAC ORAL)', u'null')
# (u'Nitrofurantoin Monohyd Macro (MACROBID PO)', u'null')
# (u'Cetirizine HCl (ZYRTEC PO)', u'null')
# (u'Prenatal Vit-Iron Carbonyl-FA (PRENATAL PLUS IRON) 29-1 MG TABS', u'1658418')
# (u'MV/FA/D3/K/LYCOP/LUT/HERB#220 (ESTROBLEND ORAL)', u'null')
# (u'prenatal vitamin-folic acid 1 mg (PRENATAL VITAMIN) tablet/capsule', u'null')
# (u'insulin syringe-needle U-100 (BD INSULIN SYRINGE ULTRA-FINE) 1/2 mL 31 gauge x 15/64" Misc Syringe', u'5856')
# (u'multivitamin (MULTIVITAMIN) tablet', u'null')
# (u'diphenhydrAMINE-aluminum-magnesium hydroxide-simethicone-lidocaine HCl 2%', u'6574')
# (u"Multivitamin-Iron-Folic Acid (ADULTS' DAILY FORMULA) 18-400 mg-mcg Oral Tab", u'90176')
# (u'compounded RX: mupirocin-betamethasone valerate-miconazole-ibuprofen (FORMULA #3) 1-0.05-2-2 % ointment', u'null')
# (u'Misc. Devices (BREAST PUMP) device', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL PLUS VITAMIN WITH FOLIC ACID 1 MG) tablet', u'999019')
# (u'Insulin Pen Needle (BD PEN NEEDLE NANO U/F) 32G X 4 MM MISC', u'null')
# (u'MISCELLANEOUS MEDICAL SUPPLY (GRADUATED COMPRESSION STOCKINGS)', u'null')
# (u'blood-glucose meter', u'null')
# (u'lancets (ACCU-CHEK FASTCLIX)', u'null')
# (u'blood sugar diagnostic (ACCU-CHEK SMARTVIEW TEST STRIP) strip', u'null')
# (u'Blood Sugar Test (ONETOUCH ULTRA TEST) Misc Strips', u'692591')
# (u'Prenat-FeFum-DSS-FA-DHA w/o A (TRIVEEN-PRX RNF) 26-1.2-300 MG CAPS', u'1464446')
# (u'PRENATAL VIT COMB.10-IRON-FA ORAL', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL VITAMIN PO)', u'null')
# (u'methylPREDNIsolone (MEDROL DOSPACK) 4 mg tablet', u'null')
# (u'cefUROXime (CEFTIN) 500 MG tablet', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS PO)', u'null')
# (u'PNV WITH CA#74/IRON/FOLIC ACID (PRENATAL VITAMIN 1+1 ORAL)', u'null')
# (u'Prenatal Vit#96-Ferrous Fum-Fa 27 Mg Iron- 800 McG Oral Tab', u'90176')
# (u'Nasal Exhalation Resistance Dv (PROVENT) Nasl Devi', u'845969')
# (u'PNV95/FERROUS FUMARATE/FA (PRENATAL ORAL)', u'null')
# (u'OMEPRAZOLE (PRILOSEC ORAL)', u'null')
# (u'PNV95/FERROUS FUMARATE/FA (PRENATAL ORAL)', u'null')
# (u'OMEPRAZOLE (PRILOSEC ORAL)', u'null')
# (u'OMEPRAZOLE MAGNESIUM (PRILOSEC OTC ORAL)', u'null')
# (u'Fish Oil-Cholecalciferol (FISH OIL + D3) 1000-1000 MG-UNIT CAPS', u'4419')
# (u'PNV95/FERROUS FUMARATE/FA (PRENATAL ORAL)', u'null')
# (u'BABY ASPIRIN ORAL', u'null')
# (u'Inhalational Spacer (AEROCHAMBER Z-STAT PLUS-FLW SG) Misc Spcr', u'1086493')
# (u'Pnv With Calcium No.72-Iron-Fa 27 Mg Iron- 1 Mg Po Tab', u'90176')
# (u'Multiple Vitamins-Minerals (DAILY MULTI PO)', u'null')
# (u'lidocaine 1% injection solution', u'null')
# (u'Prenatal Vitamin With Calcium No.72-Iron 27 Mg-Folic Acid 1 Mg Tablet', u'90176')
# (u'PRENATAL VIT #91/FE FUM/FA/DHA (PRENATAL + DHA PO)', u'null')
# (u'non-formulary', u'null')
# (u'PNV #38/IRON FUM/FOLATE/DHA (PNV #38-IRON-FA #6-DHA ORAL)', u'null')
# (u'FOLIC ACID PO', u'null')
# (u'CALCIUM CARBONATE/VITAMIN D3 (VITAMIN D-3 PO)', u'null')
# (u'FERROUS FUMARATE (IRON ORAL)', u'null')
# (u'Prenatal Vitamin Cmb No.21-Iron-Folic Acid 14 Mg-400 McG Tablet', u'90176')
# (u'Blood Pressure Monitor Misc Kit', u'239829')
# (u'Prenatal Vit #96-Ferrous Fumarate-Folic Acid 27 Mg Iron-800 McG Tablet', u'90176')
# (u'Blood Sugar Diagnostic (ONETOUCH ULTRA TEST) Strips', u'null')
# (u'Compounded Medication', u'null')
# (u'Inhalational Spacer (AEROCHAMBER Z-STAT PLUS-FLW SG) Misc Spcr', u'1086493')
# (u'cyclobenzaprine (FLEXERIL) 5 MG tablet', u'null')
# (u'busPIRone (BUSPAR) 5 MG tablet', u'null')
# (u'predniSONE (DELTASONE) 20 MG tablet', u'null')
# (u'methocarbamol (ROBAXIN) 500 MG tablet', u'null')
# (u'naproxen (NAPROSYN) 500 MG tablet', u'null')
# (u'erythromycin (ROMYCIN) ophthalmic ointment', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL VITAMIN PO)', u'null')
# (u'CETIRIZINE HCL (ZYRTEC ORAL)', u'null')
# (u'CETIRIZINE HCL (ZYRTEC ORAL)', u'null')
# (u'Insulin Needles, Disposable, (NANO PEN NEEDLE) 32 gauge x 5/32"', u'null')
# (u'Needle, Disp, (BD DISP NEEDLES) 30G X 1/2" XX MISC', u'null')
# (u'Syringe 22G X 1-1/2" 3 ML XX MISC', u'null')
# (u'Needle, Disp, 18G X 1-1/2" XX MISC', u'null')
# (u'Cetirizine HCl (ZYRTEC PO)', u'null')
# (u'Budesonide (RHINOCORT AQUA NA)', u'null')
# (u'PRENATAL VITAMINS PO', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL PLUS) 27-1 MG tablet', u'1490949')
# (u'ALBUTEROL IN', u'null')
# (u'Prenat w/o A-FeCbGl-DSS-FA-DHA (PNV OB+DHA OR)', u'null')
# (u'Prenatal Vit #96-Ferrous Fumarate-Folic Acid 27 Mg Iron-800 McG Tablet', u'90176')
# (u'NORGESTREL-ETHINYL ESTRADIOL (LOW-OGESTREL, 28, PO)', u'null')
# (u'OM-3/E/LINOL/ALA/OLEIC/GLA/LIP (OMEGA 3-6-9 ORAL)', u'null')
# (u'CYANOCOBALAMIN, VITAMIN B-12, (VITAMIN B-12 ORAL)', u'null')
# (u'ASCORBIC ACID (VITAMIN C ORAL)', u'null')
# (u'Prenatal Vit-Iron Fumarate-Fa 28 Mg Iron- 800 McG Oral Tab', u'90176')
# (u'Follitropin Alfa 300 Unit/0.5ml Sc Soln', u'1594431')
# (u'ACCU-CHEK SOFTCLIX LANCETS lancets', u'583344')
# (u'ACCU-CHEK AVIVA PLUS test strip', u'583344')
# (u'Blood Glucose Monitoring Suppl (ACCU-CHEK AVIVA PLUS) W/DEVICE KIT', u'583344')
# (u'B Complex Vitamins (VITAMIN-B COMPLEX) tablet', u'null')
# (u'Multiple Vitamin (MULTIVITAMIN) capsule', u'89905')
# (u'ferrous sulfate (FERROUS SULFATE) 325 (65 FE) MG tablet', u'null')
# (u'glucose blood (BAYER CONTOUR NEXT TEST) test strip', u'null')
# (u'VIT C/E/ZN/COPPR/LUTEIN/ZEAXAN (PRESERVISION AREDS 2 ORAL)', u'null')
# (u'Terbinafine-Miconazole Tinc 750 mg-2% 30 ml Top Soln', u'null')
# (u'FREE-TEXT MEDICATION', u'null')
# (u'Misc. Devices (BREAST PUMP) MISC', u'null')
# (u'Ferrous Fumarate (FERRETTS PO)', u'null')
# (u'blood-glucose meter kit', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL OR)', u'null')
# (u'METFORMIN HCL OR', u'null')
# (u'prenatal multivitamin (MYNATAL) capsule', u'89905')
# (u'Breast Pump devi', u'null')
# (u'Arm Brace (FUTURO RIGHT HAND WRIST BRACE) Misc Misc', u'239917')
# (u'lancets (ONE TOUCH DELICA LANCETS) 33 gauge Misc Misc', u'239826')
# (u'Acetone Urine Test (KETOSTIX) Misc Strips', u'235506')
# (u'Blood Glucose Meter with Device (ONE TOUCH ULTRA 2) Misc Kit', u'240786')
# (u'Blood Sugar Test (ONE TOUCH ULTRA TEST) Misc Strips', u'692591')
# (u'lancets Misc', u'null')
# (u'BLOOD SUGAR DIAGNOSTIC (GLUCOSE BLOOD TEST STRIPS) strip', u'null')
# (u'Miscellaneous (OTHER)', u'null')
# (u'Ferrous Sulfate 324 mg total salt (65 mg elemental) oral tablet,delayed release (DR/EC)', u'null')
# (u'med unable to find', u'null')
# (u'Prenatal Vitamin-Ferrous Fumarate-FA (PRENATAL) 28 mg iron- 800 mcg Oral Tab', u'90176')
# (u'Prenatal MV-Min-Fe Fum-FA-DHA (PRENATAL 1 PO)', u'null')
# (u'HYDROXYPROGESTERONE CAPROATE 250 MG/ML IM INJ', u'null')
# (u'Needle, Disp, (BD SPECIALTY USE) 30 gauge x 1/2" Misc Needle', u'432332')
# (u'Syringe with Needle, Disp, (BD SAFETYGLIDE) 3 mL 22 x 1 1/2" Misc Syringe', u'431392')
# (u'Needle, Disp, (BD SPECIALTY USE) 30 gauge x 1/2" Misc Needle', u'432332')
# (u'Syringe with Needle, Disp, (BD SAFETYGLIDE) 3 mL 22 x 1 1/2" Misc Syringe', u'431392')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL MULTIVITAMIN) 28-0.8 MG TABS TABLET', u'89905')
# (u'blood glucose (ONE TOUCH ULTRA) test strip', u'null')
# (u'ACCU-CHEK SMARTVIEW TEST STRIPS', u'583344')
# (u'Calcium Carbonate Antacid (TUMS PO)', u'null')
# (u'Blood Glucose Monitoring Suppl (BLOOD GLUCOSE MONITOR SYSTEM) W/DEVICE Kit', u'null')
# (u'BAYER MICROLET LANCETS Misc', u'747212')
# (u'Glucose Blood (BAYER CONTOUR NEXT TEST) Strip', u'null')
# (u'Lancets (ONETOUCH ULTRASOFT LANCETS) lancets', u'null')
# (u'blood sugar diagnostic (BLOOD GLUCOSE TEST) test strip', u'null')
# (u'ESOMEPRAZOLE MAGNESIUM (NEXIUM 24HR ORAL)', u'null')
# (u'MULTIVITAMIN (DAILY VITAMIN ORAL)', u'null')
# (u'DOXYLAMINE SUCCINATE (UNISOM, DOXYLAMINE, ORAL)', u'null')
# (u'prenatal multivit-Ca-min-Fe-FA (PRENATAL VITAMIN) tablet', u'null')
# (u'prenatal multivit-Ca-min-Fe-FA Tab', u'null')
# (u'Multiple Vitamins-Minerals (MULTIVITAMIN GUMMIES ADULT PO)', u'null')
# (u'KETOTIFEN FUMARATE OPHTH', u'null')
# (u'ACETAMINOPHEN (TYLENOL ORAL)', u'null')
# (u'L. RHAMNOSUS GG/INULIN (CULTURELLE PROBIOTICS ORAL)', u'null')
# (u'MAGNESIUM ORAL', u'null')
# (u'VITAMIN B COMPLEX ORAL', u'null')
# (u'ERGOCALCIFEROL, VITAMIN D2, (VITAMIN D ORAL)', u'null')
# (u'Prenatal Vit-Calcium-Iron-FA (PRENATAL VITAMIN) Oral Tab', u'237741')
# (u'Multiple Vitamin (MULTIVITAMIN) Cap', u'89905')
# (u'Cholecalciferol (VITAMIN D PO)', u'null')
# (u'Syringe with Needle, Disp, (BD Luer-Lok) 3 mL 21 x 1 1/2" Misc Syringe', u'431388')
# (u'Needle, Disp, (BD Specialty Use) 30 gauge x 1/2" Misc Needle', u'432332')
# (u'Syringe with Needle, Disp, (BD Luer-Lok) 3 mL 21 x 1 1/2" Misc Syringe', u'431388')
# (u'Needle, Disp, (BD Specialty Use) 30 gauge x 1/2" Misc Needle', u'432332')
# (u'pen needle, diabetic, safety 29 gauge x 1/2" Ndle', u'null')
# (u'multivitamin capsule', u'null')
# (u'ASCORBATE CALCIUM (VITAMIN C ORAL)', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS PO)', u'null')
# (u'Prenatal Vit-Iron Fumarate-Fa 27-0.8 Mg Oral Tab', u'90176')
# (u'Prenatal Vit-Iron Fumarate-Fa 27-0.8 Mg Oral Tab', u'90176')
# (u'glucose blood VI test strips (ONETOUCH VERIO) strip', u'null')
# (u'Fexofenadine HCl (ALLEGRA ALLERGY PO)', u'null')
# (u"MV-MN/IRON FUM/FA/OMEGA3,6,9#3 (WOMEN'S MULTI ORAL)", u'null')
# (u'VIT C-HESPERIDIN-BIOFLAVONOIDS ORAL', u'null')
# (u'Multiple Vitamin (MULTIVITAMIN) capsule', u'89905')
# (u'Loratadine-Pseudoephedrine (CLARITIN-D 24 HOUR PO)', u'null')
# (u'Glucose Blood (ONE TOUCH ULTRA TEST) Strip', u'null')
# (u'insulin needles, disposable, 31 x 3/16 " needle', u'null')
# (u'ARIPIPRAZOLE (ABILIFY ORAL)', u'null')
# (u'Prenatal Vit-Iron Fumarate-Fa 27-0.8 Mg Oral Tab', u'90176')
# (u'Prenatal Vit-Iron Fumarate-Fa 27-0.8 Mg Oral Tab', u'90176')
# (u'Paroxetine 30 Mg Tablet', u'312243')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS OR)', u'null')
# (u'auto-titrating CPAP (AUTOSET) machine', u'null')
# (u'Intrauterine Device (PARAGARD T 380A) UTRN IUD', u'2837')
# (u'Lancets', u'null')
# (u'blood-glucose meter', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL VITAMIN PO)', u'null')
# (u'ALBUTEROL INHAL', u'null')
# (u'IRON PO', u'null')
# (u'Calcium 500 Mg Po Tabs', u'1895')
# (u'PNV76/IRON,CARB&GLU/FA/DSS/DHA (CITRANATAL DHA, ALGAL OIL, PO)', u'null')
# (u'Prenatal Multivit-Ca-Min-Fe-Fa Po Tabs', u'237741')
# (u'Prenatal Multivit-Ca-Min-Fe-Fa Po Tabs', u'237741')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL PLUS) 27-1 MG tablet', u'1490949')
# (u'Paroxetine 20 Mg Tablet', u'314199')
# (u'PROMETHAZINE HCL (PROMETHAZINE ORAL)', u'null')
# (u'Blood Sugar Test (ONETOUCH ULTRA TEST) Misc Strips', u'692591')
# (u'pen needle, diabetic (BD INSULIN PEN NEEDLE UF MINI) 31 gauge x 3/16" Misc Needle', u'637361')
# (u"MULTIVIT/IRON/FA/K/HERB NO.244 (ALIVE WOMEN'S ENERGY ORAL)", u'null')
# (u'Prenat-FeFum-DSS-FA-DHA w/o A (TRIVEEN-PRX RNF) 26-1.2-300 MG CAPS', u'1081799')
# (u'Prenat-FeFum-DSS-FA-DHA w/o A (TRIVEEN-PRX RNF) 26-1.2-300 MG CAPS', u'1243705')
# (u'Calcium 500 Mg Tablet', u'1895')
# (u'multivitamin (MVI) tablet', u'null')
# (u'Insulin Pen Needle (B-D UF III MINI PEN NEEDLES) 31G X 5 MM MISC', u'null')
# (u'glucose blood (ONE TOUCH ULTRA TEST) test strip', u'null')
# (u'glucose blood (ONE TOUCH ULTRA TEST) test strip', u'null')
# (u'Insulin Pen Needle (B-D UF III MINI PEN NEEDLES) 31G X 5 MM MISC', u'null')
# (u'Insulin Pen Needle (B-D UF III MINI PEN NEEDLES) 31G X 5 MM MISC', u'null')
# (u'glucose blood (ONE TOUCH ULTRA TEST) test strip', u'null')
# (u'FLAXSEED OIL (OMEGA 3 ORAL)', u'null')
# (u'Prenatal Vit-Calcium-Iron-FA (PRENATAL VITAMIN) Oral Tab', u'237741')
# (u'Calcium 500 Mg Oral Tab', u'1895')
# (u'Prenat w/o A-FeCbGl-DSS-FA-DHA (CITRANATAL ASSURE) 35-1 & 300 MG PO MISC', u'853030')
# (u'Cholecalciferol (VITAMIN D3 PO)', u'null')
# (u'LEVOTHYROXINE SODIUM PO', u'null')
# (u'LAMOTRIGINE PO', u'null')
# (u'CLONAZEPAM PO', u'null')
# (u'GABAPENTIN PO', u'null')
# (u'multivitamin, therapeutic with minerals (THERA-VIT-M) TABS', u'89905')
# (u'SUMAtriptan Succinate (IMITREX PO)', u'null')
# (u'Prenatal Multivit-Ca-Min-Fe-FA (PRENATAL VITAMIN) Tablet', u'null')
# (u'IRON PO', u'null')
# (u'Cholecalciferol (VITAMIN D ORAL)', u'null')
# (u'QUEtiapine Fumarate (SEROQUEL ORAL)', u'null')
# (u'MULTIVITAMIN ORAL', u'null')
# (u'pen needle, diabetic 29 gauge x 1/2" Ndle', u'null')
# (u'blood sugar diagnostic strip', u'null')
# (u'insulin syringes, disposable, 1 mL Syrg', u'null')
# (u'blood-glucose meter (GLUCOSE MONITORING KIT) kit', u'null')
# (u'levothyroxine (LEVOTHROID) 25 MCG tablet', u'null')
# (u'losartan (COZAAR) 50 MG tablet', u'null')
# (u'losartan-hydrochlorothiazide (HYZAAR) 50-12.5 mg per tablet', u'null')
# (u'cholecalciferol, VITAMIN D3, (VITAMIN D3) 2,000 unit Tab', u'null')
# (u'omega-3 fatty acids-fish oil (FISH OIL) 300-1,000 mg Cap', u'null')
# (u'ibuprofen (ADVIL,MOTRIN) 400 MG tablet', u'null')
# (u'miscellaneous medical supply Misc', u'null')
# (u'OXYGEN-AIR DELIVERY SYSTEMS MISC', u'null')
# (u'FLUTICASONE PROPIONATE (FLOVENT HFA INHL)', u'null')
# (u'Viscous lido 2% 100 mL/Maalox 100 mL/diphenhydramine 100 mL (MIRACLE MOUTHWASH) oral suspension', u'null')
# (u'Probiotic Product (PROBIOTIC DAILY PO)', u'null')
# (u'FIBER PO', u'null')
# (u'Loratadine (CLARITIN PO)', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL ONE DAILY PO)', u'null')
# (u'Syringe with Needle, Disp, (BD Luer-Lok) 3 mL 21 x 1 1/2" Misc Syringe', u'431388')
# (u'Needle, Disp, (BD Specialty Use) 30 gauge x 1/2" Misc Needle', u'432332')
# (u'LOSARTAN POTASSIUM PO', u'null')
# (u'Multiple Vitamins-Minerals (MULTIVITAL PO)', u'null')
# (u'lanolin breastfeeding (LANSINOH) ointment', u'null')
# (u'Multiple Vitamins-Minerals (MULTIVITAMIN OR)', u'null')
# (u'Inhalational Spacer (AEROCHAMBER Z-STAT PLUS-FLW SG) Misc Spcr', u'1086493')
# (u'OnabotulinumtoxinA (BOTOX IJ)', u'null')
# (u'Calcium Carbonate-Vitamin D (CALTRATE 600+D OR)', u'null')
# (u'MULTIVITAMIN TABS   OR', u'null')
# (u'BD INSULIN SYRINGE ULTRA-FINE 0.3 ML 31 X 5/16" MISC SYRINGE', u'5856')
# (u'Aspirin-Acetaminophen-Caffeine (PAMPRIN MAX PO)', u'null')
# (u'Probiotic Product (PROBIOTIC DAILY PO)', u'null')
# (u'Probiotic Product (PROBIOTIC COMPLEX ACIDOPHILUS) CAPS', u'214978')
# (u'diphenhydramine-magnesium aluminum hydroxide-lidocaine (BMX)', u'null')
# (u'Multiple Vitamins-Minerals (BARIATRIC FUSION) Chew Tab', u'89905')
# (u'glucose blood VI test strips (ONE TOUCH TEST STRIPS) strip', u'null')
# (u'Needle, Disp, (BD REGULAR BEVEL) 27 x 1/2 " Misc Needle', u'432329')
# (u'Syringe, Disposable, (BD LUER-LOK) 3 mL Misc Syringe', u'431482')
# (u'GLUCOSE MONITOR LANCETS PRESCRIPTION', u'null')
# (u'GLUCOSE TEST STRIPS PRESCRIPTION', u'null')
# (u'L-METHYLFOLATE-B6-B12 PO', u'null')
# (u'Multiple Vitamin (MULTIVITAMIN) PO CAPS', u'89905')
# (u'Multiple Vitamin (MULTIVITAMIN) PO CAPS', u'89905')
# (u'Blood Sugar Diagnostic, Drum (ACCU-CHEK COMPACT TEST) Misc Strip', u'null')
# (u'Lancets (ACCU-CHEK SOFTCLIX LANCETS) Misc Misc', u'null')
# (u'NON-DATABASE MEDICATION', u'null')
# (u'COMPOUNDED MEDICATION', u'null')
# (u'Prenatal Vit-Calcium-Iron-FA (PRENATAL VITAMIN) Oral Tab', u'237741')
# (u'Acetone Urine Test (KETOSTIX) Misc Strips', u'235506')
# (u'lancets (ONETOUCH DELICA LANCETS) 33 gauge Misc Misc', u'239826')
# (u'Ultra Fine II Insulin Syringe-Needle U-100 (BD INSULIN SYRINGE ULTRA-FINE) 1/2 mL 31 x 5/16" Misc Syringe', u'5856')
# (u"PNV#75/IRON FUM/FA/OM3/DHA/EPA (ONE A DAY WOMEN'S PRENATAL DHA ORAL)", u'null')
# (u'Prenatal Vit#96-Ferrous Fum-Fa 27 Mg Iron- 800 McG Oral Tab', u'90176')
# (u'Container (SHARPS CONTAINER) Misc Misc', u'693114')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL VITAMIN PO)', u'null')
# (u'multivitamin (THERAGRAN) per tablet', u'null')
# (u'UNCODED DME', u'null')
# (u'Oxycodone-Acetaminophen (PERCOCET PO)', u'null')
# (u'Oxygen Concentrator', u'null')
# (u'OXYGEN', u'null')
# (u'OMEGA-3S/DHA/EPA/FISH OIL (OMEGA 3 ORAL)', u'null')
# (u'BIFIDOBACTERIUM INFANTIS (ALIGN ORAL)', u'null')
# (u'multivitamin with minerals tablet', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRE-NATAL PO)', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL PLUS) tablet', u'1490949')
# (u'Blood Glucose Monitoring Suppl (BLOOD GLUCOSE METER)', u'null')
# (u'Prenat-FeFum-FePo-FA-Omega 3 (TARON-C DHA) 53.5-38-1 MG oral Cap', u'1427780')
# (u'Misc. Devices (WHEELCHAIR) Misc', u'null')
# (u'DISABILITY PLACARD', u'null')
# (u'Misc. Devices (CANE) Misc', u'null')
# (u'Coenzyme Q10 (CO Q 10 PO)', u'null')
# (u'DIGESTIVE ENZYMES PO', u'null')
# (u'Calcium-Magnesium-Vitamin D (CALCIUM 500 PO)', u'null')
# (u'Multiple Vitamins-Minerals (MULTIVITAMIN PO)', u'null')
# (u'MECLIZINE HCL', u'null')
# (u'Calcium 1200-1000 Mg-Unit Po Chew', u'1895')
# (u'DM HB/PE/ACETAMINOPHEN/CHLORPH (ROBITUSSIN COLD, COUGH, & FLU ORAL)', u'null')
# (u'Calcium Carbonate Antacid (TUMS PO)', u'null')
# (u'Ca Carbonate-Mag Hydroxide (ROLAIDS PO)', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL 19 PO)', u'null')
# (u'B Complex-C-Folic Acid (NEPHRO-VITE PO)', u'null')
# (u'Nutritional Supplements (NEPRO PO)', u'null')
# (u'Paroxetine Hcl 30 Mg Po Tabs', u'312243')
# (u'Nebulizers (ALTERA NEBULIZER) Misc Misc', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS OR)', u'null')
# (u'Copper 380 Square Mm Intrauterine Device', u'2837')
# (u'LACTOBACILLUS ACIDOPHILUS (PROBIOTIC ORAL)', u'null')
# (u'VITAMIN E ACID SUCCINATE (VIT E ACID SUCCINATE, BULK, MISC)', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS PO)', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS PO)', u'null')
# (u'Multiple Vitamins-Minerals (MULTIVITAMIN & MINERAL PO)', u'null')
# (u'Peak Flow Meter DEVI', u'null')
# (u'IRON PO', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (M-VIT PO)', u'null')
# (u'Cholecalciferol (VITAMIN D PO)', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS+FOLATE)', u'null')
# (u'multivitamin (AKA ONE-A-DAY) Oral Tab', u'null')
# (u'lancets (ACCU-CHEK FASTCLIX)', u'null')
# (u'blood sugar diagnostic (ACCU-CHEK AVIVA PLUS TEST STRP) strip', u'null')
# (u'Prenatal Vit-Fe Fumarate-FA (PRENATAL VITAMIN PO)', u'null')
# (u'METRONIDAZOLE-SKIN CLEANSER TOP', u'null')
# (u'PARAGARD INTRAUTERINE COPPER IUD 1 Device', u'1362130')
# (u'PRENATAL VIT #91/FE FUM/FA/DHA (PRENATAL + DHA ORAL)', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS OR)', u'null')
# (u'Calcium Carbonate-Vitamin D (CALCIUM 500 + D PO)', u'null')
# (u'KRILL OIL PO', u'null')
# (u'Omega-3 Fatty Acids (SALMON OIL PO)', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS) 0.8 MG Tab', u'null')
# (u'multivitamin with minerals tablet', u'null')
# (u'Blood Sugar Diagnostic Strips', u'692591')
# (u'Blood Sugar Diagnostic Strips', u'692591')
# (u'DIABETIC TESTING STRIPS', u'null')
# (u'DIABETIC TESTING METER', u'null')
# (u'DIABETIC TESTING LANCETS', u'null')
# (u'prenatal multivitamin tablet', u'null')
# (u'DOCOSAHEXANOIC ACID (PRENATAL DHA ORAL)', u'null')
# (u'PRENATAL VITS CMB W-O CA NO.2 (PRENATAL VITAMIN NO.2 PO)', u'null')
# (u'Vacuum Erection Device System kit', u'null')
# (u'ibuprofen (ADVIL,MOTRIN) 200 MG TABS', u'null')
# (u'GENERIC AMB PRESCRIPTION RX', u'null')
# (u'Multivitamin Oral Tab', u'89905')
# (u'NON FORMULARY', u'null')
# (u'IRON PO', u'null')
# (u'Prenatal Multivit-Min-Fe-FA (PRENATAL VITAMINS PO)', u'null')
# (u'blood sugar (FREESTYLE LITE STRIPS) test strip', u'null')
# (u'insulin syringe-needle (TRUEPLUS INSULIN) 1/2 mL 30 gauge x 5/16', u'null')
# (u'Prenat w/o A-FeCbGl-DSS-FA-DHA (CITRANATAL ASSURE) 35-1 & 300 MG MISC', u'853030')
# (u'Elastic Bandages & Supports (MEDICAL COMPRESSION STOCKINGS) MISC', u'null')
# (u'Nebulizer Accessories Kit', u'null')
# (u'syringe/needle, disp, 20G X 1" 1 ML', u'null')
# (u'Prenatal #19-Iron-Folic Acid 29 Mg Iron- 1 Mg Oral Chew Tab', u'90176')
# (u'salt moisturizing solution no1 (OCEAN ULTRA SALINE MIST) Mist', u'null')
# (u'losartan (COZAAR) 25 MG tablet', u'null')
# (u'hydrOXYzine (VISTARIL) 50 MG capsule', u'null')
# (u'oxyCODONE (ROXICODONE) 5 MG immediate release tablet', u'null')
# (u'losartan (COZAAR) 25 MG tablet', u'null')
# (u'omeprazole (PRILOSEC) 40 MG capsule', u'null')
# (u'gabapentin (NEURONTIN) 100 MG capsule', u'null')
# (u'leflunomide (ARAVA) 20 MG tablet', u'null')
# (u'losartan (COZAAR) 25 MG tablet', u'null')
# (u'leflunomide (ARAVA) 20 MG tablet', u'null')
# (u'omeprazole (PRILOSEC) 40 MG capsule', u'null')
# (u'Multiple Vitamins-Minerals (MULTIVITAMIN MEN PO)', u'null')
# (u'Prenatal Vit#96-Ferrous Fum-Fa 27 Mg Iron- 800 McG Oral Tab', u'90176')
# (u'Prenatal Vit#96-Ferrous Fum-Fa 27 Mg Iron- 800 McG Oral Tab', u'90176')
# (u'LORATADINE (CLARITIN ORAL)', u'null')
# (u'Lidocaine Hcl (Pf) 1 % Ij Soln', u'1100193')
# (u'DULoxetine HCl (CYMBALTA PO)', u'null')
# (u'ACCU-CHEK SMARTVIEW TEST STRIP strip', u'583344')
# (u'BD INSULIN PEN NEEDLE UF MINI 31 gauge x 3/16"', u'5856')
# (u'multivitamin tablet', u'null')
# (u'Arm Brace (FUTURO LEFT HAND WRIST BRACE) Misc Misc', u'239917')
# (u'Arm Brace (FUTURO LEFT HAND WRIST BRACE) Misc Misc', u'239917')
# (u'Arm Brace (FUTURO LEFT HAND WRIST BRACE) Misc Misc', u'239917')
# (u'Prenatal MV-Min-Fe Fum-FA-DHA (PRENATAL MULTIVITAMIN + DHA PO)', u'null')
# (u'ERGOCALCIFEROL, VITAMIN D2, (VITAMIN D PO)', u'null')
# (u'ALPRAZOLAM (XANAX ORAL)', u'null')
# (u'Naproxen Sodium (ALEVE PO)', u'null')
# (u'Acetaminophen (TYLENOL PO)', u'null')
# (u'DOCOSAHEXANOIC ACID/EPA (FISH OIL ORAL)', u'null')
# (u'prenatal vitamin-folic acid 1 mg (PRENATAL RX) tablet/capsule', u'null')
# (u'Blood Sugar Diagnostic Strips', u'692591')
# (u'Blood Sugar Diagnostic Strips', u'692591')
# (u'Blood Sugar Diagnostic Strips', u'692591')
# (u'lancets (ONE TOUCH DELICA) 33 gauge misc', u'null')
# (u'lancets (ONE TOUCH DELICA) 33 gauge misc', u'239826')
# (u'Prenatal Vit#96-Ferrous Fum-Fa 27 Mg Iron- 800 McG Oral Tab', u'90176')

# %%
#5878 with more than 1 entry
c.execute("select count(distinct(code)) from medications group by code having count(code)>1;")
num=c.fetchall()
print len(num)

c.execute("select count(distinct(code)) from medications group by code having count(code)=1;")
num=c.fetchall()
print len(num)

#4057 with one entry, will need more data
c.execute("select code from medications group by code having count(code)>1;")
num=c.fetchall()
print len(num)
#there are 5878 entries with more than 1 code. dictionary/code
#dictTerms={}
numProcessed=0;
with open("csvfile.csv") as writeMe:
    for n in num:
        c.execute("select distinct(code_name) from medications where code='%s'" % (n[0]))
        res = c.fetchall()
        #print "res:",res
        terms=[]
        if len(res) > 1:
            print "code:%s" % n[0]
            for r in res:
                print "processing term:%s" % r[0]
                terms.append(r[0])
     #      dictTerms[n[0]]=terms
        
        numProcessed+=1
        print "numProcessed:%s" %numProcessed
        #if numProcessed==5000:
        #   break
    print "numProcessed:%s" % numProcessed
# Out:
# 5878
# 4057
# 5878
# code:0002-3235-60
# processing term:Cymbalta 20 Mg Po Cpep
# processing term:Cymbalta 20 Mg Or Cpep
# numProcessed:1
# code:0002-3240-30
# processing term:Cymbalta 30 Mg Capsule,Delayed Release
# processing term:Cymbalta 30 Mg Oral Ec Cap
# numProcessed:2
# code:0002-4462-30
# processing term:Cialis 5 Mg Po Tabs
# processing term:Cialis 5 Mg Tablet
# numProcessed:3
# numProcessed:3
# numProcessed:3
# code:0002-8799-59
# processing term:Humalog Kwikpen 100 Unit/Ml Subcutaneous Sopn
# processing term:Humalog Kwikpen 100 Unit/Ml Subq Insulin Pen
# processing term:Humalog Kwikpen 100 Unit/Ml Subcutaneous
# numProcessed:4
# code:0003-0894-21
# processing term:Eliquis 5 Mg Tablet
# processing term:Eliquis 5 Mg Po Tabs
# numProcessed:5
# numProcessed:5
# numProcessed:5
# code:0004-0800-85
# processing term:Tamiflu 75 Mg Po Caps
# processing term:Tamiflu 75 Mg Oral Caps
# processing term:Tamiflu 75 Mg Capsule
# processing term:Tamiflu 75 Mg Or Caps
# numProcessed:6
# numProcessed:6
# numProcessed:6
# numProcessed:6
# code:0006-0033-30
# processing term:Belsomra 10 Mg Po Tabs
# processing term:Belsomra 10 Mg Tablet
# numProcessed:7
# code:0006-0072-31
# processing term:Proscar 5 Mg Or Tabs
# processing term:Proscar 5 Mg Tablet
# numProcessed:8
# code:0006-0277-28
# processing term:Januvia 100 Mg Po Tabs
# processing term:Januvia 100 Mg Tablet
# numProcessed:9
# numProcessed:9
# code:0006-0931-28
# processing term:Flexeril 10 Mg Po Tabs
# processing term:Flexeril 10 Mg Oral Tabs
# numProcessed:10
# code:0006-0952-31
# processing term:Cozaar 50 Mg Or Tabs
# processing term:Cozaar 50 Mg Tablet
# numProcessed:11
# code:0008-0606-01
# processing term:Pantoprazole 20 Mg Tablet,Delayed Release
# processing term:Pantoprazole 20 Mg Oral Tbec
# numProcessed:12
# code:0008-0607-01
# processing term:Pantoprazole Sodium 40 Mg Po Tbec
# processing term:Pantoprazole 40 Mg Tablet,Delayed Release
# processing term:Pantoprazole 40 Mg Oral Tbec
# numProcessed:13
# code:0008-0841-81
# processing term:Protonix 40 Mg Tablet,Delayed Release
# processing term:Protonix 40 Mg Po Dr Tablet
# numProcessed:14
# numProcessed:14
# numProcessed:14
# numProcessed:14
# code:0009-0050-02
# processing term:Provera 10 Mg Tablet
# processing term:Provera 10 Mg Po Tabs
# numProcessed:15
# numProcessed:15
# code:0009-0056-04
# processing term:Medrol (Pak) 4 Mg Or Tabs
# processing term:Medrol (Pak) 4 Mg Tablets In A Dose Pack
# numProcessed:16
# code:0009-0280-02
# processing term:Depo-Medrol 40 Mg/Ml Suspension For Injection
# processing term:Depo-Medrol 40 Mg/Ml Ij Susp
# numProcessed:17
# numProcessed:17
# numProcessed:17
# numProcessed:17
# numProcessed:17
# numProcessed:17
# numProcessed:17
# numProcessed:17
# numProcessed:17
# numProcessed:17
# numProcessed:17
# numProcessed:17
# numProcessed:17
# numProcessed:17
# numProcessed:17
# numProcessed:17
# numProcessed:17
# numProcessed:17
# numProcessed:17
# numProcessed:17
# numProcessed:17
# code:0023-9163-30
# processing term:Restasis 0.05 % Opht Dropperette
# processing term:Restasis 0.05 % Op Emul
# numProcessed:18
# code:0024-5401-31
# processing term:Ambien 5 Mg Tablet
# processing term:Ambien 5 Mg Po Tabs
# numProcessed:19
# numProcessed:19
# code:0025-1525-31
# processing term:Celebrex 200 Mg Capsule
# processing term:Celebrex 200 Mg Po Caps
# numProcessed:20
# code:0025-1821-31
# processing term:Flagyl 500 Mg Oral Tabs
# processing term:Flagyl 500 Mg Tablet
# processing term:Flagyl 500 Mg Po Tabs
# processing term:Flagyl 500 Mg Oral Tablet
# processing term:Flagyl 500 Mg Oral Tab
# numProcessed:21
# code:0029-1525-44
# processing term:Bactroban 2 % Topical Ointment
# processing term:Bactroban 2 % Ex Oint
# numProcessed:22
# numProcessed:22
# numProcessed:22
# numProcessed:22
# numProcessed:22
# numProcessed:22
# numProcessed:22
# numProcessed:22
# code:0045-0449-05
# processing term:Tylenol Extra Strength 500 Mg Po Tabs
# processing term:Tylenol Extra Strength 500 Mg Or Tabs
# numProcessed:23
# numProcessed:23
# numProcessed:23
# code:0049-2340-45
# processing term:Relpax 40 Mg Tablet
# processing term:Relpax 40 Mg Oral Tablet
# processing term:Relpax 40 Mg Po Tabs
# numProcessed:24
# code:0049-3500-79
# processing term:Diflucan 150 Mg Po Tabs
# processing term:Diflucan 150 Mg Tablet
# processing term:Diflucan 150 Mg Or Tabs
# numProcessed:25
# code:0049-4900-41
# processing term:Zoloft 50 Mg Po Tabs
# processing term:Zoloft 50 Mg Tablet
# numProcessed:26
# numProcessed:26
# code:0049-4910-41
# processing term:Zoloft 100 Mg Po Tabs
# processing term:Zoloft 100 Mg Tablet
# processing term:Zoloft 100 Mg Or Tabs
# numProcessed:27
# numProcessed:27
# code:0051-8462-33
# processing term:Androgel Pump 20.25 Mg/Act (1.62%) Td Gel
# processing term:Androgel 20.25 Mg/1.25 Gram (1.62 %) Td Glpm
# numProcessed:28
# code:0052-0105-30
# processing term:Remeron 15 Mg Oral Tab
# processing term:Remeron 15 Mg Tablet
# numProcessed:29
# code:0052-0273-01
# processing term:Nuvaring 0.12-0.015 Mg/24hr Vag Ring
# processing term:Nuvaring 0.12-0.015 Mg/24 Hr Vagl Ring
# processing term:Nuvaring 0.12-0.015 Mg/24hr Va Ring
# processing term:Nuvaring 0.12 Mg -0.015 Mg/24 Hr Vaginal
# numProcessed:30
# code:0052-0274-01
# processing term:Nexplanon 68 Mg Sc Impl
# processing term:Nexplanon 68 Mg Sdrm Implant
# numProcessed:31
# code:0052-0301-51
# processing term:Ganirelix Acetate 250 McG/0.5ml Sc Soln
# processing term:Ganirelix 250 McG/0.5 Ml Subq Syringe
# numProcessed:32
# numProcessed:32
# code:0054-0018-20
# processing term:Prednisone 20 Mg Po Tabs
# processing term:Prednisone 20 Mg Or Tabs
# numProcessed:33
# numProcessed:33
# code:0054-0037-21
# processing term:Clarithromycin 500 Mg Po Tabs
# processing term:Clarithromycin 500 Mg Or Tabs
# numProcessed:34
# code:0054-0046-41
# processing term:Ipratropium Bromide 0.06 % Nasal Spray
# processing term:Ipratropium Bromide 0.06 % Na Soln
# processing term:Ipratropium Bromide 0.06 % Na Spry
# numProcessed:35
# code:0054-0085-25
# processing term:Zaleplon 10 Mg Oral Cap
# processing term:Zaleplon 10 Mg Capsule
# numProcessed:36
# code:0054-0086-25
# processing term:Zolpidem Tartrate 5 Mg Po Tabs
# processing term:Ambien Or
# numProcessed:37
# code:0054-0086-29
# processing term:Zolpidem 5 Mg Oral Tab
# processing term:Zolpidem 5 Mg Po Tab
# numProcessed:38
# code:0054-0087-25
# processing term:Zolpidem Tartrate 10 Mg Po Tabs
# processing term:Zolpidem Tartrate 10 Mg Or Tabs
# processing term:Zolpidem 10 Mg Tablet
# processing term:Zolpidem 10 Mg Oral Tab
# numProcessed:39
# numProcessed:39
# numProcessed:39
# code:0054-0163-25
# processing term:Mycophenolate Mofetil 250 Mg Po Caps
# processing term:Mycophenolate Mofetil 250 Mg Capsule
# numProcessed:40
# code:0054-0166-25
# processing term:Mycophenolate Mofetil 500 Mg Or Tabs
# processing term:Mycophenolate Mofetil 500 Mg Tablet
# processing term:Mycophenolate Mofetil 500 Mg Po Tabs
# numProcessed:41
# numProcessed:41
# code:0054-0220-25
# processing term:Quetiapine Fumarate 25 Mg Po Tabs
# processing term:Seroquel Or
# processing term:Quetiapine Fumarate 25 Mg Or Tabs
# processing term:Seroquel Oral
# numProcessed:42
# code:0054-0222-25
# processing term:Quetiapine 200 Mg Tablet
# processing term:Quetiapine Fumarate 200 Mg Po Tabs
# numProcessed:43
# numProcessed:43
# numProcessed:43
# code:0054-0259-13
# processing term:Montelukast Sodium 10 Mg Po Tabs
# processing term:Singulair Po
# processing term:Montelukast Sodium 10 Mg Or Tabs
# processing term:Montelukast 10 Mg Tablet
# numProcessed:44
# code:0054-0269-13
# processing term:Letrozole 2.5 Mg Tablet
# processing term:Letrozole 2.5 Mg Po Tabs
# numProcessed:45
# code:0054-0279-03
# processing term:Naratriptan 2.5 Mg Oral Tab
# processing term:Naratriptan 2.5 Mg Tablet
# numProcessed:46
# code:0054-2527-25
# processing term:Lithium Carbonate 300 Mg Po Caps
# processing term:Lithium Carbonate 300 Mg Oral Capsule
# numProcessed:47
# code:0054-3270-99
# processing term:Fluticasone Propionate 50 McG/Act Nasal Susp
# processing term:Fluticasone 50 McG/Actuation Nasl Spsn
# processing term:Fluticasone Propionate 50 McG/Act Na Susp
# processing term:Fluticasone 50 McG/Actuation Nasal Spray,Suspension
# processing term:Fluticasone Propionate 50 McG/Act Nas Susp
# numProcessed:48
# code:0054-4084-25
# processing term:Azathioprine 50 Mg Tablet
# processing term:Azathioprine 50 Mg Po Tabs
# numProcessed:49
# numProcessed:49
# code:0054-4184-25
# processing term:Dexamethasone 4 Mg Po Tab
# processing term:Dexamethasone 4 Mg Tablet
# processing term:Dexamethasone 4 Mg Po Tabs
# processing term:Dexamethasone 4 Mg Oral Tab
# numProcessed:50
# code:0054-4297-25
# processing term:Furosemide 20 Mg Po Tabs
# processing term:Furosemide 20 Mg Tablet
# processing term:Furosemide 20 Mg Or Tabs
# processing term:Furosemide 20 Mg Oral Tab
# numProcessed:51
# code:0054-4299-25
# processing term:Furosemide 40mg Tab (Lasix Equiv)
# processing term:Furosemide 40 Mg Tablet
# processing term:Furosemide 40 Mg Po Tabs
# numProcessed:52
# code:0054-4527-25
# processing term:Lithium Carbonate 300 Mg Po Tabs
# processing term:Lithium Carbonate 300 Mg Oral Tab
# numProcessed:53
# code:0054-4570-25
# processing term:Methadone 5 Mg Oral Tab
# processing term:Methadone Hcl 5 Mg Po Tabs
# numProcessed:54
# code:0054-4581-11
# processing term:Mercaptopurine 50 Mg Oral Tab
# processing term:Mercaptopurine 50 Mg Tablet
# numProcessed:55
# code:0054-4728-25
# processing term:Prednisone 5 Mg Oral Tab
# processing term:Prednisone 5 Mg Tablet
# processing term:Prednisone 5 Mg Po Tabs
# numProcessed:56
# numProcessed:56
# numProcessed:56
# numProcessed:56
# numProcessed:56
# numProcessed:56
# numProcessed:56
# numProcessed:56
# code:0065-0272-25
# processing term:Pataday 0.2 % Eye Drops
# processing term:Pataday 0.2 % Opth Soln
# numProcessed:57
# numProcessed:57
# numProcessed:57
# numProcessed:57
# code:0069-3060-30
# processing term:Zithromax 250 Mg Tablet
# processing term:Zithromax 250 Mg Po Tabs
# numProcessed:58
# code:0069-3060-75
# processing term:Zithromax Z-Pak 250 Mg Tablet
# processing term:Zithromax Z-Pak 250 Mg Po Tabs
# processing term:Zithromax Z-Pak 250 Mg Oral Tabs
# numProcessed:59
# code:0069-5410-66
# processing term:Vistaril 25 Mg Oral Caps
# processing term:Vistaril 25 Mg Capsule
# processing term:Vistaril 25 Mg Po Caps
# processing term:Vistaril 25 Mg Or Caps
# numProcessed:60
# code:0071-0156-23
# processing term:Lipitor 20 Mg Tablet
# processing term:Lipitor 20 Mg Oral Tab
# processing term:Lipitor 20 Mg Po Tabs
# numProcessed:61
# numProcessed:61
# code:0071-0418-13
# processing term:Nitrostat 0.4 Mg Sl Subl Tab
# processing term:Nitrostat 0.4 Mg Sublingual Sl Tab
# processing term:Nitrostat 0.4 Mg Sublingual Tablet
# processing term:Nitrostat 0.4 Mg Sl Subl
# numProcessed:62
# numProcessed:62
# code:0071-1015-68
# processing term:Lyrica 100 Mg Capsule
# processing term:Lyrica 100 Mg Po Caps
# numProcessed:63
# numProcessed:63
# code:0074-3799-02
# processing term:Humira 40 Mg/0.8ml Subcut Pskt
# processing term:Humira 40 Mg/0.8 Ml Subcutaneous Syringe Kit
# numProcessed:64
# numProcessed:64
# code:0074-4552-11
# processing term:Synthroid 50 McG Or Tabs
# processing term:Synthroid 50 McG Po Tabs
# processing term:Synthroid 50 McG Tablet
# numProcessed:65
# numProcessed:65
# code:0074-6624-11
# processing term:Synthroid 100 McG Po Tabs
# processing term:Synthroid 100 McG Tablet
# numProcessed:66
# code:0074-7069-11
# processing term:Synthroid 150 McG Po Tabs
# processing term:Synthroid 150 McG Oral Tab
# numProcessed:67
# code:0074-7070-19
# processing term:Synthroid 175 McG Tablet
# processing term:Synthroid 175 McG Po Tabs
# numProcessed:68
# numProcessed:68
# numProcessed:68
# code:0078-0084-05
# processing term:Fioricet 50-325-40 Mg Po Tabs
# processing term:Fioricet 50-325-40 Mg Oral Tablet
# numProcessed:69
# numProcessed:69
# numProcessed:69
# code:0085-1132-01
# processing term:Proventil Hfa 108 (90 Base) McG/Act In Aers
# processing term:Proventil Hfa 90 McG/Actuation Aerosol Inhaler
# numProcessed:70
# numProcessed:70
# code:0085-4610-01
# processing term:Dulera 200-5 McG/Actuation Inhl Hfaa
# processing term:Dulera 200 McG-5 McG/Actuation Hfa Aerosol Inhaler
# numProcessed:71
# code:0085-7206-01
# processing term:Dulera 100-5 McG/Actuation Inhl Hfaa
# processing term:Dulera 100-5 McG/Act In Aero
# numProcessed:72
# code:0087-6063-13
# processing term:Glucophage Xr 500 Mg Po Tb24
# processing term:Glucophage Xr 500 Mg Tablet,Extended Release
# numProcessed:73
# code:0088-2219-05
# processing term:Lantus Solostar 100 Unit/Ml Sc Sopn
# processing term:Lantus Solostar 100 Unit/Ml (3 Ml) Subcutaneous Insulin Pen
# processing term:Lantus Solostar 100 Unit/Ml (3 Ml) Subq Inpn
# processing term:Lantus Solostar 100 Unit/Ml Subcut Sopn
# numProcessed:74
# code:0088-2220-33
# processing term:Lantus 100 Unit/Ml Subcutaneous Solution
# processing term:Lantus 100 Unit/Ml Subq Soln
# numProcessed:75
# code:0093-0011-98
# processing term:Pantoprazole 20 Mg Oral Tbec Dr Tab
# processing term:Pantoprazole 20 Mg Tablet,Delayed Release
# processing term:Pantoprazole Sodium 20 Mg Oral Tbec
# processing term:Pantoprazole 20 Mg Oral Tbec
# processing term:Pantoprazole Sodium 20 Mg Po Tbec
# numProcessed:76
# code:0093-0012-98
# processing term:Pantoprazole 40 Mg Oral Tbec Dr Tab
# processing term:Pantoprazole 40 Mg Tablet,Delayed Release
# processing term:Pantoprazole Sodium 40 Mg Po Tbec
# processing term:Pantoprazole Sodium 40 Mg Po Tab Dr
# processing term:Pantoprazole Sodium 40 Mg Po Dr Tablet
# numProcessed:77
# numProcessed:77
# numProcessed:77
# code:0093-0039-01
# processing term:Lamotrigine 25 Mg Po Tabs
# processing term:Lamotrigine 25 Mg Tab
# processing term:Lamotrigine 25 Mg Oral Tab
# processing term:Lamotrigine Po
# processing term:Lamotrigine 25 Mg Tablet
# numProcessed:78
# code:0093-0041-03
# processing term:Clomiphene Citrate 50 Mg Tablet
# processing term:Clomiphene Citrate 50 Mg Or Tabs
# processing term:Clomiphene Citrate 50 Mg Po Tabs
# numProcessed:79
# numProcessed:79
# code:0093-0053-01
# processing term:Buspirone 5 Mg Oral Tab
# processing term:Buspirone Hcl 5 Mg Po Tabs
# processing term:Buspirone 5 Mg Tablet
# numProcessed:80
# code:0093-0054-01
# processing term:Buspirone 10 Mg Tablet
# processing term:Buspirone Hcl 10 Mg Or Tabs
# processing term:Buspirone Hcl 10 Mg Po Tabs
# numProcessed:81
# code:0093-0058-01
# processing term:Tramadol 50 Mg Tablet
# processing term:Tramadol Hcl 50 Mg Po Tabs
# processing term:Tramadol 50 Mg Oral Tab
# processing term:Tramadol Hcl 50 Mg Or Tabs
# numProcessed:82
# numProcessed:82
# code:0093-0147-01
# processing term:Naproxen 250 Mg Oral Tabs
# processing term:Naproxen 250 Mg Or Tabs
# numProcessed:83
# numProcessed:83
# code:0093-0149-01
# processing term:Naproxen 500 Mg Or Tabs
# processing term:Naproxen 500 Mg Po Tabs
# processing term:Naproxen 500 Mg Tablet
# processing term:Naproxen 500 Mg Tab
# processing term:Naproxen 500 Mg Oral Tab
# processing term:Naproxen 500 Mg Oral Tabs
# numProcessed:84
# code:0093-0150-01
# processing term:Acetaminophen 300 Mg-Codeine 30 Mg Tablet
# processing term:Acetaminophen-Codeine #3 300-30 Mg Po Tabs
# processing term:Acetaminophen-Codeine #3 300-30 Mg Oral Tabs
# numProcessed:85
# code:0093-0155-06
# processing term:Topiramate 25 Mg Oral Tab
# processing term:Topiramate 25 Mg Po Tabs
# processing term:Topiramate 25 Mg Tablet
# numProcessed:86
# code:0093-0264-15
# processing term:Fluocinonide 0.05 % Top Oint
# processing term:Fluocinonide 0.05 % Ex Oint
# numProcessed:87
# code:0093-0293-01
# processing term:Carbidopa-Levodopa 25-100 Mg Or Tabs
# processing term:Carbidopa-Levodopa 25-100 Mg Po Tabs
# numProcessed:88
# code:0093-0311-01
# processing term:Loperamide Hcl 2 Mg Po Caps
# processing term:Loperamide 2 Mg Capsule
# numProcessed:89
# code:0093-0314-01
# processing term:Ketorolac 10 Mg Tablet
# processing term:Ketorolac 10 Mg Tab
# processing term:Ketorolac Tromethamine 10 Mg Po Tabs
# numProcessed:90
# numProcessed:90
# code:0093-0463-01
# processing term:Lamotrigine 100 Mg Oral Tab
# processing term:Lamotrigine 100 Mg Po Tabs
# processing term:Lamotrigine 100 Mg Tablet
# numProcessed:91
# code:0093-0537-01
# processing term:Naproxen Sodium 550 Mg Tablet
# processing term:Naproxen Sodium 550 Mg Po Tabs
# numProcessed:92
# code:0093-0576-06
# processing term:Lovastatin 20 Mg Oral Tab
# processing term:Lovastatin 20 Mg Po Tabs
# numProcessed:93
# code:0093-0657-01
# processing term:Calcitriol 0.25 McG Po Caps
# processing term:Calcitriol 0.25 McG Oral Cap
# numProcessed:94
# code:0093-0670-05
# processing term:Gemfibrozil 600 Mg Tablet
# processing term:Gemfibrozil 600 Mg Oral Tab
# numProcessed:95
# code:0093-0733-01
# processing term:Metoprolol Tartrate 50 Mg Po Tabs
# processing term:Metoprolol Tartrate 50 Mg Tablet
# numProcessed:96
# code:0093-0734-01
# processing term:Metoprolol Tartrate 100 Mg Po Tabs
# processing term:Metoprolol Tartrate 100 Mg Oral Tab
# numProcessed:97
# code:0093-0752-01
# processing term:Atenolol 50 Mg Oral Tab
# processing term:Atenolol 50 Mg Or Tabs
# processing term:Atenolol 50 Mg Tablet
# numProcessed:98
# code:0093-0753-01
# processing term:Atenolol 100mg Tab (Tenormin Equiv)
# processing term:Atenolol 100 Mg Oral Tab
# numProcessed:99
# code:0093-0771-98
# processing term:Pravastatin 10 Mg Tablet
# processing term:Pravastatin Sodium 10 Mg Or Tabs
# numProcessed:100
# code:0093-0810-01
# processing term:Nortriptyline Hcl 10 Mg Po Caps
# processing term:Nortriptyline 10 Mg Capsule
# numProcessed:101
# numProcessed:101
# code:0093-0811-01
# processing term:Nortriptyline Hcl 25 Mg Oral Caps
# processing term:Nortriptyline 25 Mg Capsule
# processing term:Nortriptyline 25 Mg Oral Cap
# numProcessed:102
# code:0093-0832-01
# processing term:Clonazepam 0.5 Mg Tablet
# processing term:Clonazepam 0.5 Mg Po Tabs
# processing term:Clonazepam 0.5 Mg Oral Tab
# processing term:Clonazepam 0.5 Mg Oral Tabs
# processing term:Clonazepam Po
# processing term:Clonazepam 0.5 Mg Oral Tablet
# numProcessed:103
# code:0093-0833-01
# processing term:Clonazepam 1 Mg Tablet
# processing term:Clonazepam 1 Mg Po Tabs
# numProcessed:104
# numProcessed:104
# code:0093-0840-15
# processing term:Ketoconazole 2 % Ex Crea
# processing term:Ketoconazole 2 % Top Crea
# processing term:Ketoconazole 2 % Topical Cream
# numProcessed:105
# code:0093-0900-01
# processing term:Ketoconazole 200 Mg Tablet
# processing term:Ketoconazole 200 Mg Po Tabs
# numProcessed:106
# code:0093-1003-01
# processing term:Buspirone Hcl 15 Mg Po Tabs
# processing term:Buspirone Hcl 15 Mg Oral Tabs
# numProcessed:107
# code:0093-1010-42
# processing term:Mupirocin 2 % Topical Ointment
# processing term:Mupirocin 2 % Top Oint
# processing term:Mupirocin 2 % Ex Oint
# numProcessed:108
# code:0093-1015-01
# processing term:Nabumetone 500 Mg Po Tabs
# processing term:Nabumetone 500 Mg Oral Tab
# numProcessed:109
# code:0093-1048-01
# processing term:Metformin Hcl 500 Mg Po Tabs
# processing term:Metformin 500 Mg Tablet
# processing term:Metformin Hcl 500 Mg Or Tabs
# processing term:Metformin 500 Mg Oral Tablet
# processing term:Metformin Hcl Or
# numProcessed:110
# code:0093-1049-01
# processing term:Metformin Hcl 850 Mg Po Tabs
# processing term:Metformin 850 Mg Tablet
# numProcessed:111
# code:0093-1174-01
# processing term:Penicillin V Potassium 500 Mg Tablet
# processing term:Penicillin V Potassium 500 Mg Po Tabs
# numProcessed:112
# code:0093-2060-98
# processing term:Fenofibrate 145 Mg Po Tabs
# processing term:Fenofibrate 145 Mg Or Tabs
# numProcessed:113
# code:0093-2085-17
# processing term:Triamcinolone Acetonide 55 McG Nasal Spray Aerosol
# processing term:Triamcinolone Acetonide 55 McG Na Spra
# processing term:Triamcinolone Acetonide 55 McG/Act Na Aero
# processing term:Triamcinolone Acetonide 55 McG Nasl Spra
# numProcessed:114
# code:0093-2203-01
# processing term:Metoclopramide 10 Mg Tablet
# processing term:Metoclopramide Hcl 10 Mg Oral Tab
# processing term:Metoclopramide Hcl 10 Mg Po Tabs
# numProcessed:115
# code:0093-2204-01
# processing term:Metoclopramide 5 Mg Tablet
# processing term:Metoclopramide Hcl 5 Mg Oral Tab
# processing term:Metoclopramide Hcl 5 Mg Po Tabs
# numProcessed:116
# code:0093-2210-01
# processing term:Sucralfate 1 Gram Tablet
# processing term:Sucralfate 1 G Po Tabs
# numProcessed:117
# code:0093-2263-01
# processing term:Amoxicillin 500 Mg Tablet
# processing term:Amoxicillin 500 Mg Po Tabs
# numProcessed:118
# code:0093-2264-01
# processing term:Amoxicillin 875 Mg Po Tabs
# processing term:Amoxicillin 875 Mg Oral Tab
# processing term:Amoxicillin 875 Mg Tablet
# numProcessed:119
# code:0093-2275-34
# processing term:Amoxicillin 875 Mg-Potassium Clavulanate 125 Mg Tablet
# processing term:Amoxicillin-Pot Clavulanate 875-125 Mg Po Tabs
# processing term:Amoxicillin-Pot Clavulanate 875-125 Mg Oral Tab
# processing term:Amoxicillin-Pot Clavulanate 875-125 Mg Or Tabs
# processing term:Amoxicillin-Pot Clavulanate 875-125 Mg Oral Tabs
# processing term:Amoxicillin-Pot Clavulanate 875-125 Mg Po Tab
# processing term:Amoxicillin 875 Mg-Clavulanate 125mg Tablet
# numProcessed:120
# code:0093-3109-05
# processing term:Amoxicillin 500 Mg Capsule
# processing term:Amoxicillin 500 Mg Po Caps
# processing term:Amoxicillin 500 Mg Oral Cap
# processing term:Amoxicillin 500 Mg Or Caps
# numProcessed:121
# numProcessed:121
# numProcessed:121
# code:0093-3147-01
# processing term:Cephalexin 500 Mg Capsule
# processing term:Cephalexin 500 Mg Po Caps
# processing term:Cephalexin 500 Mg Or Caps
# numProcessed:122
# code:0093-3160-06
# processing term:Cefdinir 300 Mg Capsule
# processing term:Cefdinir 300 Mg Po Caps
# numProcessed:123
# code:0093-3167-53
# processing term:Minocycline Hcl 100 Mg Po Caps
# processing term:Minocycline 100 Mg Capsule
# numProcessed:124
# code:0093-4177-73
# processing term:Cephalexin 250 Mg/5ml Po Susr
# processing term:Cephalexin 250 Mg/5 Ml Oral Susr
# numProcessed:125
# code:0093-5171-44
# processing term:Alendronate 70 Mg Tablet
# processing term:Alendronate 70 Mg Oral Tab
# processing term:Alendronate Sodium 70 Mg Po Tabs
# numProcessed:126
# numProcessed:126
# code:0093-5354-01
# processing term:Progesterone Micronized 200 Mg Oral Cap
# processing term:Progesterone Micronized 200 Mg Po Caps
# processing term:Progesterone Micronized 200 Mg Or Caps
# processing term:Progesterone Micronized 200 Mg Capsule
# numProcessed:127
# numProcessed:127
# code:0093-6450-56
# processing term:Esomeprazole Magnesium 20 Mg Po Cap Dr
# processing term:Esomeprazole Magnesium 20 Mg Oral Cpdr
# numProcessed:128
# code:0093-6451-56
# processing term:Esomeprazole Magnesium 40 Mg Po Cpdr
# processing term:Esomeprazole Magnesium 40 Mg Capsule,Delayed Release
# processing term:Esomeprazole Magnesium 40 Mg Po Cap Dr
# numProcessed:129
# code:0093-6815-73
# processing term:Budesonide 0.25 Mg/2 Ml Suspension For Nebulization
# processing term:Budesonide Inhl
# numProcessed:130
# code:0093-6816-73
# processing term:Budesonide 0.5 Mg/2 Ml Inhl Nbsp
# processing term:Budesonide 0.5 Mg/2 Ml Suspension For Nebulization
# numProcessed:131
# code:0093-7146-09
# processing term:Azithromycin 250 Mg Oral Tab
# processing term:Azithromycin 250 Mg Tablet
# processing term:Azithromycin 250 Mg Po Tabs
# processing term:Azithromycin 250 Mg Tab
# processing term:Azithromycin 250 Mg Oral Tabs
# numProcessed:132
# code:0093-7146-18
# processing term:Azithromycin 250mg Tab (Zithromax Equiv)
# processing term:Azithromycin 250 Mg Po Tabs
# numProcessed:133
# code:0093-7153-10
# processing term:Simvastatin 10 Mg Po Tabs *Sh*
# processing term:Simvastatin 10 Mg Po Tabs
# numProcessed:134
# code:0093-7154-10
# processing term:Simvastatin 20 Mg Po Tabs
# processing term:Simvastatin 20 Mg Oral Tab
# processing term:Simvastatin 20 Mg Tablet
# numProcessed:135
# code:0093-7155-10
# processing term:Simvastatin 40 Mg Tablet
# processing term:Simvastatin 40 Mg Or Tabs
# processing term:Simvastatin 40 Mg Po Tabs
# processing term:Simvastatin 40 Mg Oral Tab
# numProcessed:136
# numProcessed:136
# code:0093-7169-56
# processing term:Azithromycin 500 Mg Po Tabs
# processing term:Azithromycin 500 Mg Oral Tabs
# processing term:Azithromycin 500 Mg Tablet
# numProcessed:137
# numProcessed:137
# code:0093-7198-56
# processing term:Fluoxetine 40 Mg Oral Cap
# processing term:Fluoxetine 40 Mg Capsule
# processing term:Fluoxetine Hcl 40 Mg Po Caps
# numProcessed:138
# numProcessed:138
# code:0093-7202-10
# processing term:Pravastatin Sodium 40 Mg Po Tabs
# processing term:Pravastatin 40 Mg Tablet
# numProcessed:139
# code:0093-7206-56
# processing term:Mirtazapine 15 Mg Oral Tab
# processing term:Mirtazapine 15 Mg Tablet
# numProcessed:140
# code:0093-7212-01
# processing term:Metformin Hcl Er 750 Mg Po Tab Sr24
# processing term:Metformin Er 750 Mg Tablet,Extended Release 24 Hr
# processing term:Metformin Hcl Er 750 Mg Or Tb24
# numProcessed:141
# code:0093-7214-01
# processing term:Metformin 1000 Mg Oral Tab
# processing term:Metformin Hcl 1000 Mg Po Tabs
# processing term:Metformin 1,000 Mg Tablet
# numProcessed:142
# numProcessed:142
# code:0093-7234-01
# processing term:Meloxicam 7.5 Mg Po Tabs
# processing term:Meloxicam 7.5 Mg Or Tabs
# numProcessed:143
# code:0093-7247-06
# processing term:Lamotrigine 150 Mg Oral Tab
# processing term:Lamotrigine 150 Mg Tablet
# numProcessed:144
# code:0093-7248-06
# processing term:Lamotrigine 200 Mg Po Tabs
# processing term:Lamotrigine 200 Mg Or Tabs
# processing term:Lamotrigine 200 Mg Oral Tablet
# numProcessed:145
# numProcessed:145
# code:0093-7256-01
# processing term:Glimepiride 4 Mg Oral Tab
# processing term:Glimepiride 4 Mg Tablet
# processing term:Glimepiride 4 Mg Po Tabs
# numProcessed:146
# code:0093-7292-53
# processing term:Levofloxacin 500 Mg Tablet
# processing term:Levofloxacin 500 Mg Po Tabs
# numProcessed:147
# code:0093-7293-53
# processing term:Levofloxacin 750 Mg Or Tabs
# processing term:Levofloxacin 750 Mg Tablet
# numProcessed:148
# code:0093-7295-01
# processing term:Carvedilol 12.5 Mg Po Tabs
# processing term:Carvedilol 12.5 Mg Tablet
# numProcessed:149
# code:0093-7296-01
# processing term:Carvedilol 25 Mg Tablet
# processing term:Carvedilol 25 Mg Po Tabs
# numProcessed:150
# code:0093-7350-56
# processing term:Lansoprazole 15 Mg Capsule,Delayed Release
# processing term:Lansoprazole 15 Mg Po Cpdr
# processing term:Lansoprazole 15 Mg Oral Cpdr
# processing term:Lansoprazole Po
# numProcessed:151
# code:0093-7351-56
# processing term:Lansoprazole 30 Mg Capsule,Delayed Release
# processing term:Lansoprazole 30 Mg Po Cpdr
# processing term:Lansoprazole 30 Mg Oral Cpdr
# numProcessed:152
# code:0093-7355-56
# processing term:Finasteride 5 Mg Tablet
# processing term:Finasteride 5 Mg Oral Tab
# processing term:Finasteride 5 Mg Po Tabs
# numProcessed:153
# code:0093-7364-10
# processing term:Losartan Potassium 25 Mg Po Tabs
# processing term:Losartan 25 Mg Tablet
# processing term:Losartan Potassium 25 Mg Or Tabs
# processing term:Losartan Potassium Po
# numProcessed:154
# code:0093-7365-10
# processing term:Losartan 50 Mg Tablet
# processing term:Losartan Potassium 50 Mg Po Tabs
# processing term:Losartan 50 Mg Oral Tab
# processing term:Losartan Potassium 50 Mg Or Tabs
# numProcessed:155
# code:0093-7366-10
# processing term:Losartan Potassium 100 Mg Oral Tabs
# processing term:Losartan 100 Mg Tablet
# processing term:Losartan 100 Mg Oral Tab
# processing term:Losartan Potassium 100 Mg Po Tabs
# numProcessed:156
# code:0093-7367-10
# processing term:Losartan 50 Mg-Hydrochlorothiazide 12.5 Mg Tablet
# processing term:Losartan-Hydrochlorothiazide 50-12.5 Mg Oral Tab
# numProcessed:157
# numProcessed:157
# code:0093-7382-01
# processing term:Venlafaxine Hcl 75 Mg Po Tabs
# processing term:Venlafaxine 75 Mg Po Tab
# processing term:Venlafaxine 75 Mg Oral Tab
# numProcessed:158
# code:0093-7384-56
# processing term:Venlafaxine 37.5 Mg Oral 24hr Sr Cap
# processing term:Venlafaxine Er 37.5 Mg Capsule,Extended Release 24 Hr
# numProcessed:159
# code:0093-7385-56
# processing term:Venlafaxine Er 75 Mg Capsule,Extended Release 24 Hr
# processing term:Venlafaxine Hcl Er 75 Mg Po Cp24
# processing term:Venlafaxine 75 Mg Oral 24hr Sr Cap
# processing term:Venlafaxine 75 Mg Oral Cp24
# processing term:Venlafaxine Hcl Er 75 Mg Or Cp24
# numProcessed:160
# code:0093-7386-56
# processing term:Venlafaxine 150 Mg Oral 24hr Sr Cap
# processing term:Venlafaxine Hcl Er 150 Mg Po Cp24
# processing term:Venlafaxine Hcl Er 150 Mg Po Cap-Sr-24hr
# processing term:Venlafaxine Er 150 Mg Capsule,Extended Release 24 Hr
# processing term:Venlafaxine Hcl 150 Mg Po Cp24 *Sh*
# processing term:Venlafaxine Hcl 150 Mg Or Cp24
# processing term:Venlafaxine Hcl Er 150 Mg Oral Capsule 24 H
# numProcessed:161
# code:0093-7426-98
# processing term:Montelukast Sodium 10 Mg Po Tabs
# processing term:Montelukast 10 Mg Oral Tablet
# processing term:Montelukast 10 Mg Tab
# numProcessed:162
# code:0093-7465-05
# processing term:Irbesartan 150 Mg Tablet
# processing term:Irbesartan 150 Mg Po Tabs
# numProcessed:163
# code:0093-7474-89
# processing term:Capecitabine 500 Mg Po Tabs
# processing term:Capecitabine 500 Mg Oral Tab
# numProcessed:164
# code:0093-7540-06
# processing term:Topiramate 50 Mg Po Tabs
# processing term:Topiramate 50 Mg Oral Tab
# processing term:Topiramate 50 Mg Tablet
# numProcessed:165
# code:0093-7542-06
# processing term:Duloxetine Hcl 20 Mg Po Cpep
# processing term:Cymbalta Po
# numProcessed:166
# code:0093-7543-56
# processing term:Duloxetine Hcl 30 Mg Po Cpep
# processing term:Duloxetine Hcl 30 Mg Or Cpep
# numProcessed:167
# code:0093-7544-56
# processing term:Duloxetine Hcl 60 Mg Po Cpep
# processing term:Duloxetine Hcl 60 Mg Po Cap Dr
# numProcessed:168
# code:0093-7569-56
# processing term:Aripiprazole 5 Mg Po Tabs
# processing term:Aripiprazole 5 Mg Oral Tabs
# numProcessed:169
# numProcessed:169
# numProcessed:169
# numProcessed:169
# code:0093-8343-01
# processing term:Glyburide 2.5 Mg Or Tabs
# processing term:Glyburide 2.5 Mg Oral Tab
# processing term:Glyburide 2.5 Mg Po Tab
# processing term:Glyburide 2.5 Mg Po Tabs
# numProcessed:170
# code:0093-8344-01
# processing term:Glyburide 5 Mg Oral Tab
# processing term:Glyburide 5 Mg Po Tabs
# numProcessed:171
# code:0093-8940-01
# processing term:Acyclovir 200 Mg Oral Cap
# processing term:Acyclovir 200 Mg Capsule
# numProcessed:172
# code:0093-8943-01
# processing term:Acyclovir 400 Mg Po Tab
# processing term:Acyclovir 400 Mg Po Tabs
# processing term:Acyclovir 400 Mg Tablet
# processing term:Acyclovir 400 Mg Oral Tab
# numProcessed:173
# code:0093-8947-01
# processing term:Acyclovir 800 Mg Po Tabs
# processing term:Acyclovir 800 Mg Tablet
# processing term:Acyclovir 800 Mg Or Tabs
# numProcessed:174
# code:0093-9133-06
# processing term:Amiodarone 200 Mg Tablet
# processing term:Amiodarone Hcl 200 Mg Po Tabs
# numProcessed:175
# code:0093-9652-01
# processing term:Prochlorperazine Maleate 10 Mg Oral Tab
# processing term:Prochlorperazine Maleate 10 Mg Po Tabs
# processing term:Prochlorperazine Maleate 10 Mg Or Tabs
# processing term:Prochlorperazine Maleate 10 Mg Tablet
# numProcessed:176
# code:0096-0707-35
# processing term:Drysol Dab-O-Matic 20 % Top Soln
# processing term:Drysol 20 % Ex Soln
# numProcessed:177
# numProcessed:177
# code:0113-0274-68
# processing term:Aspirin 81 Mg Chewable Tablet
# processing term:Aspirin 81 Mg Oral Chew Tab
# processing term:Baby Aspirin Oral
# processing term:Aspirin 81 Mg Po Chew
# numProcessed:178
# numProcessed:178
# code:0113-0604-62
# processing term:Ibuprofen 200 Mg Po Tab
# processing term:Ibuprofen 200 Mg Po Tabs
# processing term:Ibuprofen 200 Mg Tablet
# processing term:Ibuprofen 200 Mg Or Tabs
# processing term:Ibuprofen 200 Mg Tab
# numProcessed:179
# numProcessed:179
# numProcessed:179
# code:0115-8211-01
# processing term:Tamsulosin Er 0.4 Mg Capsule,Extended Release 24 Hr
# processing term:Tamsulosin Hcl 0.4 Mg Po Caps
# processing term:Tamsulosin 0.4 Mg Oral 24hr Sr Cap
# processing term:Tamsulosin 0.4 Mg Po Cp24
# processing term:Tamsulosin Hcl 0.4 Mg Or Caps
# processing term:Tamsulosin 0.4 Mg Capsule
# numProcessed:180
# numProcessed:180
# code:01200010100110
# processing term:Amoxicillin 500 Mg Po Caps
# processing term:Amoxicillin 500 Mg Or Caps
# numProcessed:181
# numProcessed:181
# code:0121-0638-05
# processing term:Dextromethorphan-Guaifenesin 10-100 Mg/5 Ml Oral Syrp
# processing term:Dextromethorphan-Guaifenesin 10-100 Mg/5 Ml Oral Syrup
# processing term:Dextromethorphan-Guaifenesin 10 Mg-100 Mg/5 Ml Syrup
# numProcessed:182
# code:0121-0747-10
# processing term:Sucralfate 100 Mg/Ml Oral Suspension
# processing term:Sucralfate 1 Gm/10ml Suspension (Oral)
# numProcessed:183
# code:0121-1744-05
# processing term:Guaifenesin 100 Mg/5 Ml Oral Liquid
# processing term:Guaifenesin 100 Mg/5ml Po Soln
# numProcessed:184
# numProcessed:184
# numProcessed:184
# numProcessed:184
# code:0135-0070-03
# processing term:Tums 500 Mg Oral Chew
# processing term:Tums 500 Mg Po Chew
# numProcessed:185
# numProcessed:185
# code:0140-0005-01
# processing term:Valium 5 Mg Tablet
# processing term:Valium 5 Mg Po Tabs
# numProcessed:186
# code:0143-1263-01
# processing term:Lisinopril 20 Mg-Hydrochlorothiazide 12.5 Mg Tablet
# processing term:Lisinopril-Hydrochlorothiazide 20-12.5 Mg Oral Tab
# processing term:Lisinopril-Hydrochlorothiazide 20-12.5 Mg Or Tabs
# numProcessed:187
# code:0143-1264-01
# processing term:Lisinopril 20 Mg-Hydrochlorothiazide 25 Mg Tablet
# processing term:Lisinopril-Hydrochlorothiazide 20-25 Mg Or Tabs
# processing term:Lisinopril-Hydrochlorothiazide 20-25 Mg Oral Tab
# processing term:Lisinopril-Hydrochlorothiazide 20-25 Mg Po Tabs
# numProcessed:188
# code:0143-1265-01
# processing term:Lisinopril 2.5 Mg Tablet
# processing term:Lisinopril 2.5 Mg Oral Tab
# numProcessed:189
# code:0143-1267-01
# processing term:Lisinopril 10 Mg Tablet
# processing term:Lisinopril 10 Mg Po Tabs
# processing term:Lisinopril 10 Mg Or Tabs
# numProcessed:190
# code:0143-1270-01
# processing term:Lisinopril 40 Mg Tablet
# processing term:Lisinopril 40 Mg Po Tabs
# processing term:Lisinopril 40 Mg Oral Tab
# numProcessed:191
# code:0143-1290-01
# processing term:Methocarbamol 500 Mg Po Tab
# processing term:Methocarbamol 500 Mg Po Tabs
# processing term:Methocarbamol 500 Mg Oral Tabs
# processing term:Methocarbamol 500 Mg Tablet
# numProcessed:192
# code:0143-1292-01
# processing term:Methocarbamol 750 Mg Po Tabs
# processing term:Methocarbamol 750 Mg Or Tabs
# numProcessed:193
# code:0143-1473-01
# processing term:Prednisone 10 Mg Tablet
# processing term:Prednisone 10 Mg Or Tabs
# processing term:Prednisone 10 Mg Po Tabs
# processing term:Prednisone 10 Mg Oral Tab
# numProcessed:194
# code:0143-1787-01
# processing term:Butalbital-Acetaminophen-Caffeine 50 Mg-325 Mg-40 Mg Tablet
# processing term:Butalbital-Apap-Caffeine 50-325-40 Mg Or Tabs
# numProcessed:195
# code:0143-2112-05
# processing term:Doxycycline Hyclate 100 Mg Tablet
# processing term:Doxycycline Hyclate 100 Mg Po Tabs
# processing term:Doxycycline Hyclate 100 Mg Or Tabs
# numProcessed:196
# code:0143-3142-05
# processing term:Doxycycline Hyclate 100 Mg Po Caps
# processing term:Doxycycline Hyclate 100 Mg Capsule
# numProcessed:197
# numProcessed:197
# numProcessed:197
# code:0168-0003-15
# processing term:Triamcinolone Acetonide 0.025 % Topical Cream
# processing term:Triamcinolone Acetonide 0.025 % Ex Crea
# numProcessed:198
# code:0168-0004-15
# processing term:Triamcinolone Acetonide 0.1 % Ex Crea
# processing term:Triamcinolone Acetonide 0.1 % Topical Cream
# numProcessed:199
# code:0168-0006-15
# processing term:Triamcinolone Acetonide 0.1 % Topical Ointment
# processing term:Triamcinolone Acetonide 0.1 % Ex Oint
# numProcessed:200
# code:0168-0059-60
# processing term:Fluocinolone Acetonide 0.01 % Ex Soln
# processing term:Fluocinolone 0.01 % Top Soln
# numProcessed:201
# code:0168-0080-16
# processing term:Hydrocortisone 2.5 % External Crea
# processing term:Hydrocortisone 2.5 % Topical Cream
# processing term:Hydrocortisone 2.5 % Ex Crea
# numProcessed:202
# numProcessed:202
# code:0168-0134-60
# processing term:Fluocinonide 0.05 % Topical Solution
# processing term:Fluocinonide 0.05 % Ex Soln
# numProcessed:203
# numProcessed:203
# code:0168-0162-15
# processing term:Clobetasol Propionate 0.05 % Ex Oint
# processing term:Clobetasol 0.05 % Topical Ointment
# numProcessed:204
# numProcessed:204
# code:0168-0163-15
# processing term:Clobetasol Propionate 0.05 % Ex Crea
# processing term:Clobetasol Propionate 0.05 % External Crea
# processing term:Clobetasol 0.05 % Topical Cream
# processing term:Clobetasol Propionate 0.05 % Ext Crea
# numProcessed:205
# code:0168-0201-60
# processing term:Clindamycin Phosphate 1 % Top Soln
# processing term:Clindamycin 1 % Topical Solution
# processing term:Clindamycin Phosphate 1 % Ex Soln
# numProcessed:206
# code:0168-0202-30
# processing term:Clindamycin 1 % Topical Gel
# processing term:Clindamycin Phosphate 1 % Ex Gel
# numProcessed:207
# numProcessed:207
# code:0168-0203-60
# processing term:Clindamycin 1 % Lotion
# processing term:Clindamycin Phosphate 1 % Ex Lotn
# processing term:Clindamycin Phosphate 1 % Top Lotn
# processing term:Clindamycin Phosphate 1 % Topical Lotion
# numProcessed:208
# code:0168-0204-37
# processing term:Lidocaine 5 % Ex Oint
# processing term:Lidocaine 5 % External Oint
# numProcessed:209
# code:0168-0258-15
# processing term:Clotrimazole-Betamethasone 1-0.05 % Ex Crea
# processing term:Clotrimazole-Betamethasone 1 %-0.05 % Topical Cream
# numProcessed:210
# code:0168-0275-45
# processing term:Metronidazole 0.75 % Top Gel
# processing term:Metronidazole 0.75 % Topical Gel
# numProcessed:211
# numProcessed:211
# code:0168-0323-46
# processing term:Metronidazole 0.75 % Ex Crea
# processing term:Metronidazole 0.75 % Top Crea
# processing term:Metronidazole 0.75 % Topical Cream
# numProcessed:212
# numProcessed:212
# numProcessed:212
# code:0169-4060-13
# processing term:Victoza 3-Pak 0.6 Mg/0.1 Ml (18 Mg/3 Ml) Subcutaneous Pen Injector
# processing term:Victoza 3-Pak 0.6 Mg/0.1 Ml (18 Mg/3 Ml) Subq Pnij
# numProcessed:213
# code:0169-5176-03
# processing term:Vagifem 10 McG Vaginal Tablet
# processing term:Vagifem 10 McG Va Tabs
# numProcessed:214
# code:0169-6339-10
# processing term:Novolog Flexpen 100 Unit/Ml Sc Sopn
# processing term:Novolog Flexpen 100 Unit/Ml Subcutaneous
# processing term:Novolog Flexpen 100 Unit/Ml Sc Inpn
# processing term:Novolog Flexpen 100 Unit/Ml Subcut Sopn
# processing term:Novolog Flexpen 100 Unit/Ml Subq Inpn
# numProcessed:215
# code:0169-6438-10
# processing term:Levemir Flextouch 100 Unit/Ml Subcutaneous Sopn
# processing term:Levemir Flextouch 100 Unit/Ml (3 Ml) Subq Inpn
# numProcessed:216
# code:0169-7501-11
# processing term:Novolog 100 Unit/Ml Subcutaneous Solution
# processing term:Novolog 100 Unit/Ml Sc Soln
# processing term:Novolog 100 Unit/Ml Sq Soln
# numProcessed:217
# code:0172-2083-60
# processing term:Hydrochlorothiazide 25 Mg Po Tabs
# processing term:Hydrochlorothiazide 25 Mg Tablet
# processing term:Hydrochlorothiazide 25 Mg Or Tabs
# numProcessed:218
# numProcessed:218
# code:0172-3758-60
# processing term:Lisinopril 5 Mg Oral Tab
# processing term:Lisinopril 5 Mg Po Tabs
# processing term:Lisinopril 5 Mg Tablet
# numProcessed:219
# numProcessed:219
# numProcessed:219
# code:0172-3760-60
# processing term:Lisinopril 20 Mg Po Tabs *H*
# processing term:Lisinopril 20 Mg Tablet
# processing term:Lisinopril 20 Mg Po Tabs
# processing term:Lisinopril 20 Mg Tab
# numProcessed:220
# code:0172-3925-60
# processing term:Valium Oral
# processing term:Diazepam 2 Mg Oral Tablet
# numProcessed:221
# code:0172-3926-60
# processing term:Diazepam 5 Mg Po Tabs
# processing term:Diazepam 5 Mg Tablet
# numProcessed:222
# code:0172-3927-60
# processing term:Diazepam 10 Mg Tablet
# processing term:Diazepam 10 Mg Po Tabs
# numProcessed:223
# code:0172-4096-60
# processing term:Baclofen 10 Mg Po Tabs
# processing term:Baclofen 10 Mg Po Tab
# processing term:Baclofen 10 Mg Tablet
# numProcessed:224
# code:0172-4357-49
# processing term:Ranitidine 150 Mg Tablet
# processing term:Ranitidine Hcl 150 Mg Po Tabs
# processing term:Ranitidine Hcl 150 Mg Po Tab
# numProcessed:225
# numProcessed:225
# code:0172-4364-60
# processing term:Labetalol 100 Mg Tablet
# processing term:Labetalol 100 Mg Po Tab
# numProcessed:226
# code:0172-4365-60
# processing term:Labetalol 200 Mg Po Tab
# processing term:Labetalol 200 Mg Tablet
# processing term:Labetalol 200 Mg Tab
# processing term:Labetalol Hcl 200 Mg Po Tabs
# processing term:Labetalol Hcl 200 Mg Or Tabs
# numProcessed:227
# code:0172-4366-60
# processing term:Labetalol Hcl 300 Mg Po Tabs
# processing term:Labetalol 300 Mg Oral Tab
# numProcessed:228
# code:0172-5032-60
# processing term:Lisinopril-Hydrochlorothiazide 20-25 Mg Or Tabs
# processing term:Lisinopril-Hydrochlorothiazide 20-25 Mg Po Tabs
# numProcessed:229
# code:0172-5411-46
# processing term:Fluconazole 100 Mg Po Tab
# processing term:Fluconazole 100 Mg Tablet
# numProcessed:230
# code:0172-5412-11
# processing term:Fluconazole 150 Mg Po Tabs
# processing term:Fluconazole 150 Mg Tablet
# processing term:Fluconazole 150 Mg Or Tabs
# numProcessed:231
# code:0172-5413-46
# processing term:Fluconazole 200 Mg Tablet
# processing term:Fluconazole 200 Mg Oral Tabs
# numProcessed:232
# code:0172-5728-60
# processing term:Famotidine 20 Mg Po Tabs
# processing term:Famotidine 20 Mg Tablet
# processing term:Famotidine 20 Mg Or Tabs
# processing term:Famotidine 20 Mg Oral Tabs
# processing term:Famotidine 20 Mg Oral Tablet
# numProcessed:233
# numProcessed:233
# code:0173-0135-55
# processing term:Wellbutrin Sr 150 Mg Po Tb12
# processing term:Wellbutrin Sr 150 Mg Tablet,Sustained-Release
# numProcessed:234
# code:0173-0178-55
# processing term:Wellbutrin 100 Mg Oral Tab
# processing term:Wellbutrin 100 Mg Po Tabs
# numProcessed:235
# code:0173-0344-14
# processing term:Zantac 150 Mg Tablet
# processing term:Zantac 150 Mg Po Tabs
# numProcessed:236
# code:0173-0446-00
# processing term:Zofran 4 Mg Po Tabs
# processing term:Zofran 4 Mg Or Tabs
# processing term:Zofran 4 Mg Tablet
# processing term:Zofran (As Hydrochloride) 4 Mg Oral Tab
# numProcessed:237
# code:0173-0447-00
# processing term:Zofran 8 Mg Tablet
# processing term:Zofran (As Hydrochloride) 8 Mg Oral Tab
# numProcessed:238
# numProcessed:238
# code:0173-0569-00
# processing term:Zofran Odt 4 Mg Oral Tbdp
# processing term:Zofran Odt 4 Mg Disintegrating Tablet
# processing term:Zofran Odt 4 Mg Or Tbdp
# processing term:Zofran Odt 4 Mg Po Tbdp
# processing term:Zofran Odt 4 Mg Po Dispers Tab
# numProcessed:239
# code:0173-0570-00
# processing term:Zofran Odt 8 Mg Disintegrating Tablet
# processing term:Zofran Odt 8 Mg Oral Tbdl
# numProcessed:240
# numProcessed:240
# numProcessed:240
# code:0173-0682-20
# processing term:Ventolin Hfa 90 McG/Actuation Aerosol Inhaler
# processing term:Ventolin Hfa 108 (90 Base) McG/Act In Aers
# processing term:Ventolin Hfa 108 (90 Base) McG/Act Inh Aers
# processing term:Ventolin Hfa 90 McG/Actuation Inhl Hfaa
# processing term:Ventolin Hfa 108 (90 Base) McG/Act Inhalation Aers
# numProcessed:241
# numProcessed:241
# code:0173-0697-00
# processing term:Advair Diskus 500-50 McG/Dose Inhalation Aepb
# processing term:Advair Diskus 500-50 McG/Dose In Dsdv
# processing term:Advair Diskus 500 McG-50 McG/Dose Powder For Inhalation
# processing term:Advair Diskus 500-50 McG/Dose In Aepb
# numProcessed:242
# code:0173-0717-20
# processing term:Advair Hfa 230 McG-21 McG/Actuation Aerosol Inhaler
# processing term:Advair Hfa 230-21 McG/Act In Aero
# numProcessed:243
# numProcessed:243
# numProcessed:243
# code:0178-0891-30
# processing term:Citranatal Assure 35-1 & 300 Mg Po Misc
# processing term:Citranatal Assure 35-1 & 300 Mg Oral Misc
# numProcessed:244
# numProcessed:244
# numProcessed:244
# numProcessed:244
# numProcessed:244
# numProcessed:244
# numProcessed:244
# code:0185-0111-01
# processing term:Amphetamine-Dextroamphetamine 10 Mg Oral Tabs
# processing term:Amphetamine-Dextroamphetamine 10 Mg Po Tabs
# processing term:Amphetamine Salt Combo 10 Mg Oral Tab
# numProcessed:245
# numProcessed:245
# code:0185-0205-01
# processing term:Methimazole 5 Mg Oral Tab
# processing term:Methimazole 5 Mg Oral Tabs
# numProcessed:246
# code:0185-0210-01
# processing term:Methimazole 10 Mg Po Tabs
# processing term:Methimazole 10 Mg Tablet
# numProcessed:247
# code:0185-0281-01
# processing term:Metoprolol Succinate Er 25 Mg Tablet,Extended Release 24 Hr
# processing term:Metoprolol Succinate Sr 25 Mg 24 Hr Tab (Toprol Xl)
# processing term:Metoprolol Succinate 25 Mg Oral 24hr Sr Tab
# processing term:Metoprolol Succinate 25 Mg Oral Tb24
# numProcessed:248
# code:0185-0371-01
# processing term:Citalopram 10 Mg Tablet
# processing term:Citalopram Hydrobromide 10 Mg Po Tabs
# numProcessed:249
# code:0185-0372-01
# processing term:Citalopram Hydrobromide 20 Mg Po Tabs
# processing term:Citalopram 20 Mg Tablet
# processing term:Citalopram 20 Mg Oral Tab
# processing term:Citalopram 20mg Tab (Celexa Equiv)
# numProcessed:250
# code:0185-0373-01
# processing term:Citalopram Hydrobromide 40 Mg Po Tabs
# processing term:Citalopram 40mg Tab (Celexa Equiv)
# processing term:Citalopram 40 Mg Tablet
# processing term:Citalopram Hydrobromide 40 Mg Or Tabs
# processing term:Citalopram 40 Mg Oral Tab
# numProcessed:251
# code:0185-0401-01
# processing term:Amphetamine-Dextroamphetamine 20 Mg Po Tabs
# processing term:Amphetamine-Dextroamphetamine 20 Mg Or Tabs
# processing term:Amphetamine Salt Combo 20 Mg Tablet
# processing term:Amphetamine Salt Combo 20 Mg Oral Tab
# numProcessed:252
# code:0185-0404-01
# processing term:Amphetamine Salt Combo 30 Mg Tablet
# processing term:Amphetamine-Dextroamphetamine 30 Mg Or Tabs
# processing term:Amphetamine-Dextroamphetamine 30 Mg Po Tabs
# numProcessed:253
# numProcessed:253
# code:0185-0415-01
# processing term:Bupropion Hcl Er (Sr) 150 Mg Po Tb12
# processing term:Bupropion Sr 150 Mg Tablet
# processing term:Bupropion Hcl Sr 150 Mg Tablet,Sustained-Release
# numProcessed:254
# code:0185-0648-01
# processing term:Diphenhydramine 25 Mg Capsule
# processing term:Benadryl Allergy Po
# numProcessed:255
# numProcessed:255
# code:0185-0932-30
# processing term:Cyclosporine Modified 25 Mg Capsule
# processing term:Cyclosporine Modified 25 Mg Po Caps
# numProcessed:256
# code:0185-4400-10
# processing term:Tizanidine 4 Mg Tablet
# processing term:Tizanidine Hcl 4 Mg Or Tabs
# processing term:Tizanidine Hcl 4 Mg Po Tabs
# processing term:Tizanidine 4 Mg Oral Tab
# numProcessed:257
# numProcessed:257
# code:0186-0370-20
# processing term:Symbicort 160 McG-4.5 McG/Actuation Hfa Aerosol Inhaler
# processing term:Symbicort 160-4.5 McG/Act In Aero
# numProcessed:258
# numProcessed:258
# code:0186-0742-31
# processing term:Prilosec 20 Mg Oral Cpdr
# processing term:Prilosec 20 Mg Capsule,Delayed Release
# processing term:Prilosec 20 Mg Po Cpdr
# numProcessed:259
# code:0186-0916-12
# processing term:Pulmicort Flexhaler 180 McG/Actuation Inhl Aepb
# processing term:Pulmicort Flexhaler 180 McG/Actuation Breath Activated
# numProcessed:260
# code:0186-5020-31
# processing term:Nexium 20 Mg Capsule,Delayed Release
# processing term:Nexium 20 Mg Oral Cpdr
# numProcessed:261
# code:0186-5040-31
# processing term:Nexium 40 Mg Po Cpdr
# processing term:Nexium 40 Mg Capsule,Delayed Release
# numProcessed:262
# numProcessed:262
# numProcessed:262
# numProcessed:262
# code:01990002200340
# processing term:Amoxicillin-Pot Clavulanate 875-125 Mg Po Tabs
# processing term:Augmentin 875-125 Mg Po Tabs
# processing term:Amoxicillin-Pot Clavulanate 875-125 Mg Or Tabs
# processing term:Augmentin 875-125 Mg Or Tabs
# processing term:Amoxicillin-Pot Clavulanate 875-125 Mg Oral Tabs
# numProcessed:263
# code:02100020000110
# processing term:Cephalexin 500 Mg Po Caps
# processing term:Cephalexin 500 Mg Or Caps
# processing term:Keflex 500 Mg Po Caps
# numProcessed:264
# code:02200065050310
# processing term:Cefuroxime Axetil 250 Mg Po Tabs
# processing term:Ceftin 250 Mg Po Tabs
# numProcessed:265
# code:02200065050315
# processing term:Cefuroxime Axetil 500 Mg Or Tabs
# processing term:Ceftin 500 Mg Or Tabs
# numProcessed:266
# code:0228-2027-10
# processing term:Alprazolam 0.25 Mg Po Tabs
# processing term:Alprazolam 0.25 Mg Tablet
# processing term:Alprazolam 0.25 Mg Oral Tab
# processing term:Alprazolam 0.25mg Tab (Xanax Equiv)
# numProcessed:267
# code:0228-2029-10
# processing term:Alprazolam 0.5 Mg Tablet
# processing term:Alprazolam 0.5 Mg Po Tabs
# processing term:Alprazolam 0.5 Mg Tab
# numProcessed:268
# code:0228-2031-10
# processing term:Alprazolam 1 Mg Po Tabs
# processing term:Alprazolam 1 Mg Tablet
# processing term:Alprazolam 1 Mg Po Tab
# processing term:Alprazolam 1 Mg Tab
# numProcessed:269
# numProcessed:269
# code:0228-2057-10
# processing term:Lorazepam 0.5 Mg Tablet
# processing term:Lorazepam 0.5 Mg Oral Tab
# processing term:Lorazepam 0.5 Mg Po Tabs
# processing term:Lorazepam 0.5 Mg Po Tab
# numProcessed:270
# code:0228-2059-10
# processing term:Lorazepam 1 Mg Tablet
# processing term:Lorazepam 1 Mg Oral Tab
# numProcessed:271
# code:0228-2127-10
# processing term:Clonidine Hcl 0.1 Mg Po Tabs
# processing term:Clonidine Hcl 0.1 Mg Po Tab
# processing term:Clonidine Hcl 0.1 Mg Tablet
# numProcessed:272
# code:0228-2348-10
# processing term:Propylthiouracil 50 Mg Oral Tab
# processing term:Propylthiouracil 50 Mg Po Tabs
# numProcessed:273
# code:0228-2551-06
# processing term:Diclofenac Sodium 75 Mg Po Tbec
# processing term:Diclofenac Sodium 75 Mg Tablet,Delayed Release
# numProcessed:274
# code:0228-2636-11
# processing term:Gabapentin 600 Mg Tablet
# processing term:Gabapentin 600 Mg Po Tabs
# processing term:Gabapentin 600 Mg Po Tab
# processing term:Gabapentin 600 Mg Or Tabs
# numProcessed:275
# numProcessed:275
# numProcessed:275
# code:0228-2672-11
# processing term:Spironolactone 50 Mg Oral Tabs
# processing term:Spironolactone 50 Mg Po Tab
# processing term:Spironolactone 50 Mg Tablet
# numProcessed:276
# numProcessed:276
# code:0228-2820-11
# processing term:Hydrochlorothiazide 12.5 Mg Oral Tabs
# processing term:Hydrochlorothiazide 12.5 Mg Po Tabs
# numProcessed:277
# numProcessed:277
# numProcessed:277
# code:0228-3481-11
# processing term:Zolpidem Er 6.25 Mg Tablet,Extended Release,Multiphase
# processing term:Zolpidem 6.25 Mg Oral Tbmp
# numProcessed:278
# numProcessed:278
# code:0245-0108-01
# processing term:Ferrous Sulfate 325 Mg (65 Mg Iron) Oral Tbec Dr Tab
# ...
# numProcessed:945
# numProcessed:945
# code:187550
# processing term:Sertraline 100 Mg Oral Tab
# processing term:Sertraline 100 Mg Tablet
# processing term:Sertraline 100 Mg Po Tab
# numProcessed:946
# code:187749
# processing term:Prenatal Vitamin 27-0.8 Mg Or Tabs
# processing term:Prenatal Vitamin 27-0.8 Mg Po Tabs
# numProcessed:947
# numProcessed:947
# numProcessed:947
# numProcessed:947
# code:187978
# processing term:Prednisone 5 Mg Oral Tab
# processing term:Prednisone 5 Mg Tablet
# numProcessed:948
# numProcessed:948
# numProcessed:948
# code:188020
# processing term:Albuterol Sulfate 108 (90 Base) McG/Act Inhalation Aepb
# processing term:Albuterol Sulfate 108 (90 Base) McG/Act In Aepb
# numProcessed:949
# numProcessed:949
# code:188391
# processing term:Quetiapine 200 Mg Tablet
# processing term:Quetiapine 200 Mg Oral Tab
# numProcessed:950
# numProcessed:950
# numProcessed:950
# code:188671
# processing term:Ferrex 150 Mg Iron Capsule
# processing term:Ferrex 150 150 Mg Iron Oral Cap
# processing term:Ferrex 150 150 Mg Oral Cap
# numProcessed:951
# numProcessed:951
# numProcessed:951
# numProcessed:951
# numProcessed:951
# numProcessed:951
# numProcessed:951
# code:1895
# processing term:Calcium 600 Mg Capsule
# processing term:Calcium
# processing term:Calcium 500 Mg Po Tabs
# processing term:Calcium 500 Mg Tablet
# processing term:Calcium 500 Mg Oral Tab
# processing term:Calcium 1200-1000 Mg-Unit Po Chew
# numProcessed:952
# numProcessed:952
# numProcessed:952
# numProcessed:952
# code:18990003221815
# processing term:Tetanus-Diphtheria-Acellular Pertussis (Adacel) Im Inj (Pavilion)
# processing term:Tetanus-Diphth-Acell Pertussis 5-2-15.5 Lf-McG/0.5 Im Susp
# numProcessed:953
# code:18990003221820
# processing term:Tetanus-Diphth-Acell Pertussis 5-2.5-18.5 Lf-McG/0.5 Im Susp
# processing term:Boostrix 5-2.5-18.5 Im Susp
# numProcessed:954
# code:190014
# processing term:Clonazepam 1 Mg Tablet
# processing term:Clonazepam 1 Mg Oral Tab
# numProcessed:955
# numProcessed:955
# numProcessed:955
# numProcessed:955
# code:1910005000E550
# processing term:Rho (D) Immune Globulin (Rhophylac) Inj 300 McG/2 Ml (Pavilion)
# processing term:Rho D Immune Globulin 1500 Unit/2ml Ij Sosy
# processing term:Rhophylac 1500 Unit/2ml Ij Sosy
# numProcessed:956
# code:191094
# processing term:Calcium 500 Mg Po Tabs
# processing term:Calcium 500 Mg Tablet
# processing term:Calcium 500 Mg Oral Tab
# numProcessed:957
# code:191281
# processing term:Glipizide 5 Mg Oral Tr24
# processing term:Glipizide Er 5 Mg Tablet, Extended Release 24 Hr
# numProcessed:958
# code:191479
# processing term:Metformin 850 Mg Tablet
# processing term:Metformin 850 Mg Oral Tab
# numProcessed:959
# numProcessed:959
# code:192121
# processing term:Metolazone 5 Mg Tablet
# processing term:Metolazone 5 Mg Tab
# numProcessed:960
# numProcessed:960
# code:192245
# processing term:Moxifloxacin 400 Mg Tablet
# processing term:Moxifloxacin 400 Mg Oral Tab
# numProcessed:961
# code:192407
# processing term:Atenolol 25 Mg Oral Tab
# processing term:Atenolol 25 Mg Tablet
# numProcessed:962
# numProcessed:962
# code:192623
# processing term:Clobetasol 0.05 % Topical Cream
# processing term:Clobetasol 0.05 % Top Crea
# numProcessed:963
# code:192686
# processing term:Maxalt 10 Mg Oral Tab
# processing term:Maxalt 10 Mg Tablet
# numProcessed:964
# numProcessed:964
# numProcessed:964
# numProcessed:964
# code:193228
# processing term:Lantus 100 Unit/Ml Subcutaneous Solution
# processing term:Lantus 100 Unit/Ml Subq Soln
# numProcessed:965
# numProcessed:965
# code:193263
# processing term:Permethrin 5 % Top Crea
# processing term:Permethrin 5 % Topical Cream
# numProcessed:966
# numProcessed:966
# numProcessed:966
# numProcessed:966
# code:193691
# processing term:Venlafaxine 150 Mg Oral 24hr Sr Cap
# processing term:Venlafaxine Er 150 Mg Capsule,Extended Release 24 Hr
# processing term:Venlafaxine 150 Mg Po Cp24
# numProcessed:967
# numProcessed:967
# code:193747
# processing term:Sumatriptan 50 Mg Tablet
# processing term:Sumatriptan Succinate 50 Mg Po Tab
# processing term:Sumatriptan Succinate 50 Mg Oral Tab
# processing term:Sumatriptan 50 Mg Tab
# numProcessed:968
# numProcessed:968
# code:19502
# processing term:Simethicone 80 Mg Po Chew
# processing term:Simethicone 80 Mg Or Chew
# numProcessed:969
# numProcessed:969
# numProcessed:969
# code:196275
# processing term:Penicillin V Potassium 500 Mg Oral Tab
# processing term:Penicillin V Potassium 500 Mg Tablet
# numProcessed:970
# numProcessed:970
# numProcessed:970
# code:196892
# processing term:Clotrimazole 1 % Vagl Crea
# processing term:Clotrimazole 1 % Va Crea
# numProcessed:971
# numProcessed:971
# numProcessed:971
# code:197310
# processing term:Acyclovir 200 Mg Oral Cap
# processing term:Acyclovir 200 Mg Capsule
# numProcessed:972
# code:197311
# processing term:Acyclovir 400 Mg Oral Tab
# processing term:Acyclovir 400 Mg Po Tab
# processing term:Acyclovir 400 Mg Po Tabs
# processing term:ACYCLOVIR
# processing term:Acyclovir 400 Mg Tablet
# processing term:Acyclovir 400 Mg Tab
# numProcessed:973
# code:197313
# processing term:Acyclovir 800 Mg Po Tabs
# processing term:Acyclovir 800 Mg Tablet
# processing term:Acyclovir 800 Mg Oral Tab
# processing term:Acyclovir 800 Mg Or Tabs
# numProcessed:974
# code:197319
# processing term:Allopurinol 100 Mg Po Tabs
# processing term:Allopurinol 100 Mg Tablet
# processing term:Allopurinol 100 Mg Oral Tab
# numProcessed:975
# code:197320
# processing term:Allopurinol 300 Mg Oral Tab
# processing term:Allopurinol 300 Mg Tablet
# numProcessed:976
# code:197321
# processing term:Alprazolam 1 Mg Po Tabs
# processing term:Alprazolam 1 MG Oral Tablet
# processing term:Alprazolam 1 Mg Tablet
# processing term:Alprazolam 1 Mg Po Tab
# processing term:ALPRAZOLAM
# processing term:Alprazolam 1 Mg Tab
# numProcessed:977
# code:197322
# processing term:Alprazolam 2 Mg Tablet
# processing term:Alprazolam 2 Mg Oral Tab
# numProcessed:978
# code:197361
# processing term:Amlodipine 5 Mg Oral Tab
# processing term:Amlodipine 5 Mg Tablet
# processing term:Amlodipine Besylate 5 Mg Po Tabs
# numProcessed:979
# numProcessed:979
# code:197379
# processing term:Atenolol 100mg Tab (Tenormin Equiv)
# processing term:Atenolol 100 Mg Oral Tab
# numProcessed:980
# code:197380
# processing term:Atenolol 25 Mg Oral Tab
# processing term:Atenolol 25 Mg Po Tabs
# processing term:Atenolol 25 MG Oral Tablet
# processing term:Atenolol 25 Mg Tablet
# numProcessed:981
# code:197381
# processing term:Atenolol 50 Mg Oral Tab
# processing term:Atenolol 50 Mg Or Tabs
# processing term:Atenolol 50 Mg Tablet
# numProcessed:982
# code:197388
# processing term:Azathioprine 50 Mg Tablet
# processing term:Azathioprine 50 Mg Po Tabs
# numProcessed:983
# code:197391
# processing term:Baclofen 10 Mg Po Tabs
# processing term:Baclofen 10 Mg Oral Tab
# processing term:Baclofen 10 Mg Po Tab
# processing term:Baclofen 10 Mg Tablet
# processing term:Baclofen 10 Mg Tab
# numProcessed:984
# code:197397
# processing term:BENZONATATE
# processing term:Benzonatate 100 Mg Po Caps
# processing term:Benzonatate 100 Mg Capsule
# processing term:Benzonatate 100 Mg Or Caps
# processing term:Benzonatate 100 Mg Oral Cap
# processing term:Benzonatate 100 Mg Po Cap
# numProcessed:985
# code:197411
# processing term:Bromocriptine Mesylate 2.5 Mg Or Tabs
# processing term:Bromocriptine 2.5 Mg Tablet
# numProcessed:986
# code:197419
# processing term:Bumetanide 2 Mg Oral Tab
# processing term:Bumetanide 2 Mg Po Tabs
# numProcessed:987
# code:197444
# processing term:Carbidopa-Levodopa 25-100 Mg Or Tabs
# processing term:Carbidopa-Levodopa 25-100 Mg Po Tabs
# processing term:Carbidopa-Levodopa 25-100 Mg Oral Tab
# numProcessed:988
# code:197499
# processing term:Chlorthalidone 25 Mg Oral Tab
# processing term:Chlorthalidone 25 Mg Po Tabs
# numProcessed:989
# code:197511
# processing term:Ciprofloxacin 250 Mg Tablet
# processing term:Ciprofloxacin Hcl 250 Mg Oral Tab
# processing term:Ciprofloxacin 250 Mg Tab (Cipro Equiv)
# processing term:Ciprofloxacin Hcl 250 Mg Oral Tabs
# numProcessed:990
# code:197512
# processing term:Ciprofloxacin 750 Mg Tablet
# processing term:Ciprofloxacin Hcl 750 Mg Po Tabs
# numProcessed:991
# code:197517
# processing term:CLARITHROMYCIN
# processing term:Clarithromycin 500 Mg Po Tabs
# processing term:Clarithromycin 500 Mg Or Tabs
# numProcessed:992
# code:197518
# processing term:Clindamycin 150 MG Oral Capsule
# processing term:CLINDAMYCIN HCL
# processing term:Clindamycin Hcl 150 Mg Oral Cap
# numProcessed:993
# code:197519
# processing term:Clindamycin 10 MG/ML Topical Lotion
# processing term:Clindamycin 1 % Lotion
# processing term:Clindamycin Phosphate 1 % Ex Lotn
# processing term:Clindamycin Phosphate 1 % Top Lotn
# processing term:Clindamycin Phosphate 1 % Topical Lotion
# numProcessed:994
# code:197527
# processing term:Clonazepam 0.5 Mg Tablet
# processing term:Clonazepam 0.5 Mg Po Tabs
# processing term:Clonazepam 0.5 Mg Oral Tab
# processing term:Clonazepam 0.5 Mg Oral Tabs
# processing term:CLONAZEPAM
# processing term:Clonazepam 0.5 Mg Oral Tablet
# numProcessed:995
# code:197528
# processing term:Clonazepam 1 Mg Tablet
# processing term:Clonazepam 1 Mg Oral Tab
# processing term:Clonazepam 1 Mg Po Tabs
# numProcessed:996
# numProcessed:996
# numProcessed:996
# code:197564
# processing term:Topiramate 25 Mg Oral Tab
# processing term:Topiramate 25 Mg Tablet
# numProcessed:997
# code:197582
# processing term:Dexamethasone 4 Mg Po Tab
# processing term:Dexamethasone 4 Mg Tablet
# processing term:Dexamethasone 4 Mg Po Tabs
# processing term:Dexamethasone 4 Mg Oral Tab
# numProcessed:998
# code:197589
# processing term:Diazepam 10 Mg Tablet
# processing term:Diazepam 10 Mg Oral Tab
# processing term:Diazepam 10 Mg Po Tabs
# numProcessed:999
# numProcessed:999
# code:197591
# processing term:Diazepam 5 Mg Po Tabs
# processing term:DIAZEPAM
# processing term:Diazepam 5 Mg Oral Tab
# processing term:Diazepam 5 Mg Tablet
# numProcessed:1000
# code:197596
# processing term:Dicloxacillin 500 Mg Oral Cap
# processing term:Dicloxacillin Sodium 500 Mg Po Caps
# numProcessed:1001
# code:197604
# processing term:Digoxin 125 McG Tablet
# processing term:Digoxin 125 McG Po Tabs
# numProcessed:1002
# code:197635
# processing term:Dronabinol 2.5 Mg Capsule
# processing term:Dronabinol 2.5 Mg Oral Cap
# numProcessed:1003
# code:197658
# processing term:Estradiol 1 Mg Po Tabs
# processing term:Estradiol 1 Mg Oral Tab
# numProcessed:1004
# code:197659
# processing term:Estradiol 2 Mg Tablet
# processing term:Estradiol 2 Mg Po Tabs
# processing term:Estradiol 2 Mg Oral Tablet
# numProcessed:1005
# code:197662
# processing term:Estrogens Conjugated 1.25 Mg Po Tabs
# processing term:Conjugated Estrogens 1.25 Mg Tablet
# numProcessed:1006
# code:197686
# processing term:ETODOLAC
# processing term:Etodolac 400 Mg Oral Tab
# numProcessed:1007
# code:197696
# processing term:Fentanyl 75 McG/Hr Td Pt72
# processing term:Fentanyl 75 McG/Hr Transdermal Patch
# processing term:Fentanyl 75 McG/Hr 72 Hr Transderm Patch
# numProcessed:1008
# code:197698
# processing term:Fluconazole 100 Mg Po Tab
# processing term:Fluconazole 100 Mg Tablet
# numProcessed:1009
# code:197699
# processing term:Fluconazole 150 Mg Po Tabs
# processing term:Fluconazole 150 MG Oral Tablet
# processing term:Fluconazole 150 Mg Tablet
# processing term:Fluconazole 150 Mg Oral Tab
# processing term:FLUCONAZOLE
# processing term:Fluconazole 150 Mg Or Tabs
# numProcessed:1010
# code:197700
# processing term:Fluconazole 200 Mg Oral Tab
# processing term:Fluconazole 200 Mg Tablet
# processing term:Fluconazole 200 Mg Oral Tabs
# numProcessed:1011
# numProcessed:1011
# numProcessed:1011
# numProcessed:1011
# numProcessed:1011
# code:197805
# processing term:Ibuprofen 400 Mg Oral Tab
# processing term:Ibuprofen 400 Mg Po Tabs
# numProcessed:1012
# code:197806
# processing term:Ibuprofen 600 Mg Oral Tab
# processing term:Ibuprofen 600 Mg Oral Tabs
# processing term:Ibuprofen 600 Mg Po Tabs
# processing term:Ibuprofen 600 Mg Tablet
# processing term:Ibuprofen 600 Mg Tab
# processing term:IBUPROFEN
# processing term:Ibuprofen 600 Mg Or Tabs
# numProcessed:1013
# code:197807
# processing term:Ibuprofen 800 Mg Oral Tab
# processing term:Ibuprofen 800 MG Oral Tablet
# processing term:IBUPROFEN
# processing term:Ibuprofen 800 Mg Po Tabs
# processing term:Ibuprofen 800 Mg Tablet
# processing term:Ibuprofen 800 Mg Po Tab
# processing term:Ibuprofen 800 Mg Or Tabs
# processing term:Ibuprofen 800 Mg Tab
# numProcessed:1014
# code:197818
# processing term:Indomethacin 50 Mg Po Caps
# processing term:Indomethacin 50 Mg Capsule
# processing term:Indomethacin 50 Mg Oral Cap
# numProcessed:1015
# numProcessed:1015
# code:197853
# processing term:Ketoconazole 200 Mg Tablet
# processing term:Ketoconazole 200 Mg Po Tabs
# numProcessed:1016
# code:197877
# processing term:Lidocaine-Prilocaine 2.5-2.5 % Ex Crea
# processing term:Lidocaine-Prilocaine 2.5 %-2.5 % Topical Cream (Lidocaine/Prilocaine)
# numProcessed:1017
# code:197884
# processing term:Lisinopril 40 Mg Tablet
# processing term:Lisinopril 40 Mg Oral Tab
# processing term:Lisinopril 40 Mg Po Tabs
# processing term:Lisinopril 40 Mg Tab
# numProcessed:1018
# code:197885
# processing term:Lisinopril-Hydrochlorothiazide 10-12.5 Mg Po Tabs
# processing term:Lisinopril-Hydrochlorothiazide 10-12.5 Mg Oral Tab
# numProcessed:1019
# code:197886
# processing term:Lisinopril 20 Mg-Hydrochlorothiazide 12.5 Mg Tablet
# processing term:Lisinopril-Hydrochlorothiazide 20-12.5 Mg Oral Tab
# processing term:Lisinopril-Hydrochlorothiazide 20-12.5 Mg Or Tabs
# numProcessed:1020
# code:197887
# processing term:Lisinopril 20 Mg-Hydrochlorothiazide 25 Mg Tablet
# processing term:Lisinopril-Hydrochlorothiazide 20-25 Mg Or Tabs
# processing term:Lisinopril-Hydrochlorothiazide 20-25 Mg Oral Tab
# processing term:Lisinopril-Hydrochlorothiazide 20-25 Mg Po Tabs
# numProcessed:1021
# code:197889
# processing term:Lithium Carbonate 300 Mg Po Caps
# processing term:Lithium Carbonate 300 Mg Oral Capsule
# numProcessed:1022
# code:197890
# processing term:Lithium Carbonate 300 Mg Po Tabs
# processing term:Lithium Carbonate 300 Mg Oral Tab
# numProcessed:1023
# numProcessed:1023
# code:197900
# processing term:Lorazepam 0.5 Mg Or Tabs
# processing term:Lorazepam 0.5 Mg Oral Tab
# processing term:Lorazepam 0.5 Mg Tablet
# processing term:Lorazepam 0.5 Mg Po Tabs
# processing term:Lorazepam 0.5mg Tab (Ativan Equiv)
# processing term:Lorazepam 0.5 Mg Po Tab
# processing term:Lorazepam 0.5 Mg Oral Tabs
# processing term:Lorazepam 0.5 Mg Tab
# numProcessed:1024
# code:197901
# processing term:LORAZEPAM
# processing term:Lorazepam 1 Mg Oral Tab
# processing term:Lorazepam 1 Mg Tablet
# processing term:Lorazepam 1 Mg Po Tabs
# processing term:Lorazepam 1 Mg Oral Tabs
# processing term:Lorazepam 1 Mg Or Tabs
# numProcessed:1025
# code:197904
# processing term:Lovastatin 20 Mg Oral Tab
# processing term:Lovastatin 20 Mg Po Tabs
# numProcessed:1026
# code:197931
# processing term:Mercaptopurine 50 Mg Oral Tab
# processing term:Mercaptopurine 50 Mg Tablet
# numProcessed:1027
# code:197941
# processing term:Methimazole 10 Mg Po Tabs
# processing term:Methimazole 10 Mg Tablet
# numProcessed:1028
# code:197942
# processing term:Methimazole 5 Mg Oral Tab
# processing term:Methimazole 5 Mg Oral Tabs
# processing term:Methimazole 5 Mg Tablet
# numProcessed:1029
# code:197943
# processing term:Methocarbamol 500 Mg Oral Tab
# processing term:Methocarbamol 500 Mg Po Tab
# processing term:Methocarbamol 500 Mg Tablet
# processing term:METHOCARBAMOL
# processing term:Methocarbamol 500 Mg Po Tabs
# processing term:Methocarbamol 500 Mg Oral Tabs
# numProcessed:1030
# code:197944
# processing term:Methocarbamol 750 Mg Po Tabs
# processing term:Methocarbamol 750 Mg Oral Tab
# processing term:METHOCARBAMOL
# processing term:Methocarbamol 750 Mg Tablet
# processing term:Methocarbamol 750 Mg Or Tabs
# numProcessed:1031
# numProcessed:1031
# numProcessed:1031
# code:197979
# processing term:Metolazone 2.5 Mg Tablet
# processing term:Metolazone 2.5 Mg Oral Tab
# numProcessed:1032
# code:197984
# processing term:Minocycline 100 Mg Oral Cap
# processing term:Minocycline Hcl 100 Mg Po Caps
# processing term:Minocycline 100 Mg Cap
# processing term:Minocycline 100 Mg Capsule
# numProcessed:1033
# numProcessed:1033
# code:198013
# processing term:Naproxen 250 Mg Oral Tabs
# processing term:Naproxen 250 Mg Or Tabs
# processing term:Naproxen 250 Mg Oral Tab
# numProcessed:1034
# code:198014
# processing term:Naproxen 500 Mg Oral Tab
# processing term:Naproxen 500 Mg Or Tabs
# processing term:Naproxen 500 Mg Po Tabs
# processing term:NAPROXEN
# processing term:Naproxen 500 Mg Tablet
# processing term:Naproxen 500 Mg Tab
# processing term:Naproxen 500 Mg Oral Tabs
# numProcessed:1035
# numProcessed:1035
# code:198030
