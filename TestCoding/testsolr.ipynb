# %%
import sqlite3
import matplotlib as plt
import urllib2
import json
import requests
conn = sqlite3.connect("/Users/dc/TestCode/TestCoding/clinical.sqlite")
c=conn.cursor()

#test querying solr server



#test graph of 2-dim space for rxcui
#plot each userid and number of rxcui they use, number of entries per rxcui. If there are repeat entries, 
#plot the bar higher. Clip or take log to (normalize)
#2-d axis is sqrt(num of rxcui) on each. map the rxcui to a matrix, ->sqrt(#rxcui), sqrt(#rxcui)+1->2*sqrt(#rxcui), etc...
#generate a series of plots for each user; automate this webpage

#generate a 3d graph of all the users in rxcui space


#what is the difference between rxnorm space and rxcui/clinical.sqlite space? This shouldn't matter as long as 
#all the rxcui in clinical.sqlite is in rxnorm space

#rxnorm cuis in table lookup
q = "select distinct(rxcui) from lookup"
listRXCUI=c.execute(q)

# %%
q="select count(distinct(RXCUI)) from rxnconso"
res=c.execute(q)
print res.fetchone()[0]
import math
print math.sqrt(351648)
# Out:
# 351648
# 592.999156829

# %%
#recall/precision using clinical.sqlite
q="select distinct(medication_name) from medications"
med_names_list = c.execute(q).fetchall();
for med_name in med_names_list:
    print "processing med_name:%s" % med_name
    print "med_name[0]:%s" % med_name[0]
    q="select medication_name, code,type from medications where medication_name like '%"+med_name[0]+"%'"
    resList=(c.execute(q)).fetchall()
    cuiDict={}
    for res in resList:
        print "name:%s" % res[0], "rxcui:%s" % res[1], "type:%s" % res[2] 
        cuiDict[res[1]]=1
    print "for med_name:%s" % med_name[0] , "num rxcui:%d out of %d" % (len(cuiDict.keys()), len(resList))
    url="http://hadoop.is-very-good.org:8983/solr/testme/query"
    payload={"query" : med_name[0], "sort" : "score desc"}
    headers = {'content-type': 'application/json'}
    r = requests.post(url, data=json.dumps(payload), headers=headers)
    print "r:%s" % r.text
# Out:
# processing med_name:Multiple Vitamin (MULTIVITAMIN) tablet
# med_name[0]:Multiple Vitamin (MULTIVITAMIN) tablet
# name:Multiple Vitamin (MULTIVITAMIN) tablet rxcui:57896-504-10 type:extracted
# name:Multiple Vitamin (MULTIVITAMIN) tablet rxcui:78768 type:extracted
# name:Multiple Vitamin (MULTIVITAMIN) tablet rxcui:78200000000300 type:extracted
# name:Multiple Vitamin (MULTIVITAMIN) tablet rxcui:78768 type:extracted
# name:Multiple Vitamin (MULTIVITAMIN) tablet rxcui:89905 type:inferred
# for med_name:Multiple Vitamin (MULTIVITAMIN) tablet num rxcui:4 out of 5
# r:{
#   "responseHeader":{
#     "status":400,
#     "QTime":0,
#     "params":{
#       "json":"{\"sort\": \"score desc\", \"query\": \"Multiple Vitamin (MULTIVITAMIN) tablet\", \"fl\": \"*,score\"}"}},
#   "error":{
#     "metadata":[
#       "error-class","org.apache.solr.common.SolrException",
#       "root-error-class","org.apache.solr.common.SolrException"],
#     "msg":"Unknown top-level key in JSON request : fl",
#     "code":400}}
#
# processing med_name:Ascorbic Acid (VITAMIN C PO)
# med_name[0]:Ascorbic Acid (VITAMIN C PO)
# name:Ascorbic Acid (VITAMIN C PO) rxcui:31604-02509 type:extracted
# name:Ascorbic Acid (VITAMIN C PO) rxcui:null type:extracted
# name:Ascorbic Acid (VITAMIN C PO) rxcui:31604-02509 type:extracted
# for med_name:Ascorbic Acid (VITAMIN C PO) num rxcui:2 out of 3
# r:{
#   "responseHeader":{
#     "status":400,
#     "QTime":0,
#     "params":{
#       "json":"{\"sort\": \"score desc\", \"query\": \"Ascorbic Acid (VITAMIN C PO)\", \"fl\": \"*,score\"}"}},
#   "error":{
#     "metadata":[
#       "error-class","org.apache.solr.common.SolrException",
#       "root-error-class","org.apache.solr.common.SolrException"],
#     "msg":"Unknown top-level key in JSON request : fl",
#     "code":400}}
#
# processing med_name:Levothyroxine Sodium 150 McG Po Tabs
# med_name[0]:Levothyroxine Sodium 150 McG Po Tabs
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:966225 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:0378-1815-01 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:12003 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:28100010100330 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:12003 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:966225 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:0378-1815-01 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:12003 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:28100010100330 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:12003 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:966201 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:0074-7069-11 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:20820 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:28100010100330 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:20820 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:966225 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:0378-1815-01 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:12003 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:28100010100330 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:12003 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:966225 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:0378-1815-01 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:12003 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:28100010100330 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:12003 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:966201 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:0074-7069-11 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:20820 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:28100010100330 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:20820 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:966225 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:0378-1815-01 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:12003 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:28100010100330 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:12003 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:966225 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:0378-1815-01 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:12003 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:28100010100330 type:extracted
# name:Levothyroxine Sodium 150 McG Po Tabs rxcui:12003 type:extracted
# for med_name:Levothyroxine Sodium 150 McG Po Tabs num rxcui:7 out of 40
# r:{
#   "responseHeader":{
#     "status":400,
#     "QTime":0,
#     "params":{
#       "json":"{\"sort\": \"score desc\", \"query\": \"Levothyroxine Sodium 150 McG Po Tabs\", \"fl\": \"*,score\"}"}},
#   "error":{
#     "metadata":[
#       "error-class","org.apache.solr.common.SolrException",
#       "root-error-class","org.apache.solr.common.SolrException"],
#     "msg":"Unknown top-level key in JSON request : fl",
#     "code":400}}
#
# processing med_name:Sertraline 100 Mg Oral Tab
# med_name[0]:Sertraline 100 Mg Oral Tab
# name:Sertraline 100 Mg Oral Tab rxcui:312938 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:59762-4910-1 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:187550 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:312938 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:59762-4910-1 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:187550 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:312938 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:59762-4910-1 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:187550 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:312938 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:59762-4910-1 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:187550 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:312938 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:59762-4910-1 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:187550 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:312938 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:49999-861-30 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:187550 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:312938 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:59762-4910-1 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:187550 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:312938 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:59762-4910-1 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:187550 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:312938 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:59762-4910-1 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:187550 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:312938 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:59762-4910-1 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:187550 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:312938 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:59762-4910-1 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:187550 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:312938 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:59762-4910-1 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:187550 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:312938 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:54569-5819-0 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:187550 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:312938 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:59762-4910-1 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:187550 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:312938 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:59762-4910-1 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:187550 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:312938 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:59762-4910-1 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:187550 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:312938 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:59762-4910-1 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:187550 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:312938 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:59762-4910-1 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:187550 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:312938 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:59762-4910-1 type:extracted
# name:Sertraline 100 Mg Oral Tab rxcui:187550 type:extracted
# for med_name:Sertraline 100 Mg Oral Tab num rxcui:5 out of 57
# r:{
#   "responseHeader":{
#     "status":400,
#     "QTime":0,
#     "params":{
#       "json":"{\"sort\": \"score desc\", \"query\": \"Sertraline 100 Mg Oral Tab\", \"fl\": \"*,score\"}"}},
#   "error":{
#     "metadata":[
#       "error-class","org.apache.solr.common.SolrException",
#       "root-error-class","org.apache.solr.common.SolrException"],
#     "msg":"Unknown top-level key in JSON request : fl",
#     "code":400}}
#
# processing med_name:Cefuroxime Axetil 500 Mg Oral Tab
# med_name[0]:Cefuroxime Axetil 500 Mg Oral Tab
# name:Cefuroxime Axetil 500 Mg Oral Tab rxcui:309098 type:extracted
# name:Cefuroxime Axetil 500 Mg Oral Tab rxcui:54569-5418-0 type:extracted
# name:Cefuroxime Axetil 500 Mg Oral Tab rxcui:277182 type:extracted
# for med_name:Cefuroxime Axetil 500 Mg Oral Tab num rxcui:3 out of 3
# r:{
#   "responseHeader":{
#     "status":400,
#     "QTime":0,
#     "params":{
#       "json":"{\"sort\": \"score desc\", \"query\": \"Cefuroxime Axetil 500 Mg Oral Tab\", \"fl\": \"*,score\"}"}},
#   "error":{
#     "metadata":[
#       "error-class","org.apache.solr.common.SolrException",
#       "root-error-class","org.apache.solr.common.SolrException"],
#     "msg":"Unknown top-level key in JSON request : fl",
#     "code":400}}
#
# processing med_name:Blood Glucose Control, Normal (ONETOUCH VERIO MID CONTROL) Misc Soln
# med_name[0]:Blood Glucose Control, Normal (ONETOUCH VERIO MID CONTROL) Misc Soln
# name:Blood Glucose Control, Normal (ONETOUCH VERIO MID CONTROL) Misc Soln rxcui:53885-273-02 type:extracted
# name:Blood Glucose Control, Normal (ONETOUCH VERIO MID CONTROL) Misc Soln rxcui:569569 type:extracted
# name:Blood Glucose Control, Normal (ONETOUCH VERIO MID CONTROL) Misc Soln rxcui:4850 type:inferred
# for med_name:Blood Glucose Control, Normal (ONETOUCH VERIO MID CONTROL) Misc Soln num rxcui:3 out of 3
# r:{
#   "responseHeader":{
#     "status":400,
#     "QTime":0,
#     "params":{
#       "json":"{\"sort\": \"score desc\", \"query\": \"Blood Glucose Control, Normal (ONETOUCH VERIO MID CONTROL) Misc Soln\", \"fl\": \"*,score\"}"}},
#   "error":{
#     "metadata":[
#       "error-class","org.apache.solr.common.SolrException",
#       "root-error-class","org.apache.solr.common.SolrException"],
#     "msg":"Unknown top-level key in JSON request : fl",
#     "code":400}}
#
# processing med_name:Container (SHARPS CONTAINER) Misc Misc
# med_name[0]:Container (SHARPS CONTAINER) Misc Misc
# name:Container (SHARPS CONTAINER) Misc Misc rxcui:693114 type:extracted
# name:Container (SHARPS CONTAINER) Misc Misc rxcui:8290-323488 type:extracted
# name:Container (SHARPS CONTAINER) Misc Misc rxcui:446377 type:extracted
# name:Container (SHARPS CONTAINER) Misc Misc rxcui:null type:extracted
# name:Container (SHARPS CONTAINER) Misc Misc rxcui:693114 type:extracted
# name:Container (SHARPS CONTAINER) Misc Misc rxcui:8290-323488 type:extracted
# name:Container (SHARPS CONTAINER) Misc Misc rxcui:446377 type:extracted
# name:Container (SHARPS CONTAINER) Misc Misc rxcui:null type:extracted
# name:Container (SHARPS CONTAINER) Misc Misc rxcui:693114 type:extracted
# name:Container (SHARPS CONTAINER) Misc Misc rxcui:8290-323488 type:extracted
# name:Container (SHARPS CONTAINER) Misc Misc rxcui:446377 type:extracted
# name:Container (SHARPS CONTAINER) Misc Misc rxcui:null type:extracted
# name:Container (SHARPS CONTAINER) Misc Misc rxcui:693114 type:extracted
# name:Container (SHARPS CONTAINER) Misc Misc rxcui:8290-323488 type:extracted
# name:Container (SHARPS CONTAINER) Misc Misc rxcui:446377 type:extracted
# name:Container (SHARPS CONTAINER) Misc Misc rxcui:null type:extracted
# name:Container (SHARPS CONTAINER) Misc Misc rxcui:693114 type:extracted
# name:Container (SHARPS CONTAINER) Misc Misc rxcui:8290-323488 type:extracted
# name:Container (SHARPS CONTAINER) Misc Misc rxcui:446377 type:extracted
# name:Container (SHARPS CONTAINER) Misc Misc rxcui:null type:extracted
# name:Container (SHARPS CONTAINER) Misc Misc rxcui:693114 type:extracted
# name:Container (SHARPS CONTAINER) Misc Misc rxcui:8290-323488 type:extracted
# name:Container (SHARPS CONTAINER) Misc Misc rxcui:446377 type:extracted
# for med_name:Container (SHARPS CONTAINER) Misc Misc num rxcui:4 out of 23
# r:{
#   "responseHeader":{
#     "status":400,
#     "QTime":0,
#     "params":{
#       "json":"{\"sort\": \"score desc\", \"query\": \"Container (SHARPS CONTAINER) Misc Misc\", \"fl\": \"*,score\"}"}},
#   "error":{
#     "metadata":[
#       "error-class","org.apache.solr.common.SolrException",
#       "root-error-class","org.apache.solr.common.SolrException"],
#     "msg":"Unknown top-level key in JSON request : fl",
#     "code":400}}
#
# processing med_name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips
# med_name[0]:Blood Sugar Test (ONETOUCH VERIO) Misc Strips
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:53885-270-25 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:569346 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:53885-270-25 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:569346 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:null type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:53885-270-25 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:569346 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:null type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:53885-270-25 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:569346 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:null type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:53885-270-25 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:569346 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:null type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:53885-270-25 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:569346 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:null type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:53885-270-25 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:569346 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:null type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:53885-270-25 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:569346 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:null type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:53885-270-25 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:569346 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:null type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:53885-270-25 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:569346 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:53885-270-25 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:569346 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:53885-270-25 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:569346 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:null type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:53885-270-25 type:extracted
# name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips rxcui:569346 type:extracted
# for med_name:Blood Sugar Test (ONETOUCH VERIO) Misc Strips num rxcui:3 out of 35
# r:{
#   "responseHeader":{
#     "status":400,
#     "QTime":0,
#     "params":{
#       "json":"{\"sort\": \"score desc\", \"query\": \"Blood Sugar Test (ONETOUCH VERIO) Misc Strips\", \"fl\": \"*,score\"}"}},
#   "error":{
#     "metadata":[
#       "error-class","org.apache.solr.common.SolrException",
#       "root-error-class","org.apache.solr.common.SolrException"],
#     "msg":"Unknown top-level key in JSON request : fl",
#     "code":400}}
#
# processing med_name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc
# med_name[0]:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:53885-595-01 type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:575392 type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:53885-595-01 type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:575392 type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:53885-595-01 type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:575392 type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:null type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:53885-595-01 type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:575392 type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:null type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:53885-595-01 type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:575392 type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:null type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:53885-595-01 type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:575392 type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:null type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:53885-595-01 type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:575392 type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:null type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:53885-595-01 type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:575392 type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:null type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:53885-595-01 type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:575392 type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:53885-595-01 type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:575392 type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:null type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:53885-595-01 type:extracted
# name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc rxcui:575392 type:extracted
# for med_name:lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc num rxcui:3 out of 29
# r:{
#   "responseHeader":{
#     "status":400,
#     "QTime":0,
#     "params":{
#       "json":"{\"sort\": \"score desc\", \"query\": \"lancets (ONETOUCH DELICA LANCETS) 30 gauge Misc Misc\", \"fl\": \"*,score\"}"}},
#   "error":{
#     "metadata":[
#       "error-class","org.apache.solr.common.SolrException",
#       "root-error-class","org.apache.solr.common.SolrException"],
#     "msg":"Unknown top-level key in JSON request : fl",
#     "code":400}}
#
# processing med_name:Meloxicam 7.5 Mg Oral Tab
# med_name[0]:Meloxicam 7.5 Mg Oral Tab
# name:Meloxicam 7.5 Mg Oral Tab rxcui:311486 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:51079-457-01 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:216915 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:311486 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:51079-457-01 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:216915 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:311486 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:51079-457-01 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:216915 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:311486 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:51079-457-01 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:216915 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:311486 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:51079-457-01 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:216915 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:311486 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:51079-457-01 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:216915 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:311486 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:51079-457-01 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:216915 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:311486 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:51079-457-01 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:216915 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:311486 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:51079-457-01 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:216915 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:311486 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:51079-457-01 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:216915 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:311486 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:51079-457-01 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:216915 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:311486 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:51079-457-01 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:216915 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:311486 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:51079-457-01 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:216915 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:311486 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:51079-457-01 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:216915 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:311486 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:51079-457-01 type:extracted
# name:Meloxicam 7.5 Mg Oral Tab rxcui:216915 type:extracted
# for med_name:Meloxicam 7.5 Mg Oral Tab num rxcui:3 out of 45
# r:{
#   "responseHeader":{
#     "status":400,
#     "QTime":0,
#     "params":{
#       "json":"{\"sort\": \"score desc\", \"query\": \"Meloxicam 7.5 Mg Oral Tab\", \"fl\": \"*,score\"}"}},
#   "error":{
#     "metadata":[
#       "error-class","org.apache.solr.common.SolrException",
#       "root-error-class","org.apache.solr.common.SolrException"],
#     "msg":"Unknown top-level key in JSON request : fl",
#     "code":400}}
#
# processing med_name:Ibuprofen 600 Mg Oral Tab
# med_name[0]:Ibuprofen 600 Mg Oral Tab
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tabs rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tabs rxcui:0440-7627-30 type:extracted
# name:Ibuprofen 600 Mg Oral Tabs rxcui:10519 type:extracted
# name:Ibuprofen 600 Mg Oral Tabs rxcui:66100020000330 type:extracted
# name:Ibuprofen 600 Mg Oral Tabs rxcui:10519 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:49999-006-06 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:49999-006-06 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tabs rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tabs rxcui:0440-7627-30 type:extracted
# name:Ibuprofen 600 Mg Oral Tabs rxcui:10519 type:extracted
# name:Ibuprofen 600 Mg Oral Tabs rxcui:66100020000330 type:extracted
# name:Ibuprofen 600 Mg Oral Tabs rxcui:10519 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:197806 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:52959-076-00 type:extracted
# name:Ibuprofen 600 Mg Oral Tab rxcui:275877 type:extracted
# for med_name:Ibuprofen 600 Mg Oral Tab num rxcui:7 out of 199
# r:{
#   "responseHeader":{
#     "status":400,
#     "QTime":0,
#     "params":{
#       "json":"{\"sort\": \"score desc\", \"query\": \"Ibuprofen 600 Mg Oral Tab\", \"fl\": \"*,score\"}"}},
#   "error":{
#     "metadata":[
#       "error-class","org.apache.solr.common.SolrException",
#       "root-error-class","org.apache.solr.common.SolrException"],
#     "msg":"Unknown top-level key in JSON request : fl",
#     "code":400}}
#
# processing med_name:Docusate Sodium 100 Mg Oral Cap
# med_name[0]:Docusate Sodium 100 Mg Oral Cap
# name:Docusate Sodium 100 Mg Oral Cap rxcui:1115005 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:10135-111-60 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:258255 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:1115005 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:10135-111-60 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:258255 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:1115005 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:10135-111-60 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:258255 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:1115005 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:10135-111-60 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:258255 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:1115005 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:10135-111-60 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:258255 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:1115005 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:10135-111-60 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:258255 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:1115005 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:10135-111-60 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:258255 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:1115005 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:10135-111-60 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:258255 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:1115005 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:10135-111-60 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:258255 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:1115005 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:10135-111-60 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:258255 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:1115005 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:10135-111-01 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:258255 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:1247756 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:67618-101-10 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:159422 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:1115005 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:10135-111-60 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:258255 type:extracted
# name:Docusate Sodium 100 Mg Oral Caps rxcui:1115005 type:extracted
# name:Docusate Sodium 100 Mg Oral Caps rxcui:0615-0585-43 type:extracted
# name:Docusate Sodium 100 Mg Oral Caps rxcui:6927 type:extracted
# name:Docusate Sodium 100 Mg Oral Caps rxcui:46500010300110 type:extracted
# name:Docusate Sodium 100 Mg Oral Caps rxcui:6927 type:extracted
# name:Docusate Sodium 100 Mg Oral Caps rxcui:1115005 type:extracted
# name:Docusate Sodium 100 Mg Oral Caps rxcui:0615-0585-43 type:extracted
# name:Docusate Sodium 100 Mg Oral Caps rxcui:6927 type:extracted
# name:Docusate Sodium 100 Mg Oral Caps rxcui:46500010300110 type:extracted
# name:Docusate Sodium 100 Mg Oral Caps rxcui:6927 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:1115005 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:10135-111-01 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:258255 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:1115005 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:0536-3756-01 type:extracted
# name:Docusate Sodium 100 Mg Oral Cap rxcui:258255 type:extracted
# name:Docusate Sodium 100 Mg Oral Capsule rxcui:1115005 type:extracted
# name:Docusate Sodium 100 Mg Oral Capsule rxcui:10135-111-01 type:extracted
# name:Docusate Sodium 100 Mg Oral Capsule rxcui:258255 type:extracted
# name:Docusate Sodium 100 Mg Oral Capsule rxcui:1115005 type:extracted
# name:Docusate Sodium 100 Mg Oral Capsule rxcui:0440-7464-30 type:extracted
# name:Docusate Sodium 100 Mg Oral Capsule rxcui:6927 type:extracted
# name:Docusate Sodium 100 Mg Oral Capsule rxcui:46500010300110 type:extracted
# name:Docusate Sodium 100 Mg Oral Capsule rxcui:6927 type:extracted
# for med_name:Docusate Sodium 100 Mg Oral Cap num rxcui:12 out of 63
# r:{
#   "responseHeader":{
#     "status":400,
#     "QTime":0,
#     "params":{
#       "json":"{\"sort\": \"score desc\", \"query\": \"Docusate Sodium 100 Mg Oral Cap\", \"fl\": \"*,score\"}"}},
#   "error":{
#     "metadata":[
#       "error-class","org.apache.solr.common.SolrException",
#       "root-error-class","org.apache.solr.common.SolrException"],
#     "msg":"Unknown top-level key in JSON request : fl",
#     "code":400}}
#
# processing med_name:ALPHAGAN P
# med_name[0]:ALPHAGAN P
# name:ALPHAGAN P rxcui:00023932105 type:extracted
# name:ALPHAGAN P rxcui:861206 type:inferred
# name:ALPHAGAN P 0.1 % ophthalmic solution rxcui:null type:extracted
# name:ALPHAGAN P 0.1 % ophthalmic solution rxcui:861206 type:extracted
# name:ALPHAGAN P 0.1 % ophthalmic solution rxcui:0023-9321-05 type:extracted
# name:ALPHAGAN P 0.1 % ophthalmic solution rxcui:476455 type:extracted
# for med_name:ALPHAGAN P num rxcui:5 out of 6
# r:{
#   "responseHeader":{
#     "status":400,
#     "QTime":0,
#     "params":{
#       "json":"{\"sort\": \"score desc\", \"query\": \"ALPHAGAN P\", \"fl\": \"*,score\"}"}},
#   "error":{
#     "metadata":[
#       "error-class","org.apache.solr.common.SolrException",
#       "root-error-class","org.apache.solr.common.SolrException"],
#     "msg":"Unknown top-level key in JSON request : fl",
#     "code":400}}
#
# processing med_name:RESTASIS
# med_name[0]:RESTASIS
# name:RESTASIS rxcui:00023916360 type:extracted
# name:RESTASIS rxcui:402092 type:inferred
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:402092 type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:0023-9163-30 type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:448774 type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:null type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:402092 type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:0023-9163-30 type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:448774 type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:null type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:402092 type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:0023-9163-30 type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:448774 type:extracted
# name:RESTASIS 0.05 % ophthalmic emulsion rxcui:null type:extracted
# name:RESTASIS 0.05 % ophthalmic emulsion rxcui:402092 type:extracted
# name:RESTASIS 0.05 % ophthalmic emulsion rxcui:0023-9163-30 type:extracted
# name:RESTASIS 0.05 % ophthalmic emulsion rxcui:80852 type:extracted
# name:RESTASIS 0.05 % ophthalmic emulsion rxcui:86720020001620 type:extracted
# name:RESTASIS 0.05 % ophthalmic emulsion rxcui:80852 type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:null type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:402092 type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:0023-9163-30 type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:448774 type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:null type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:402092 type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:0023-9163-30 type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:448774 type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:null type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:402092 type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:0023-9163-30 type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:448774 type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:null type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:402092 type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:0023-9163-30 type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:448774 type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:null type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:402092 type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:0023-9163-30 type:extracted
# name:cycloSPORINE (RESTASIS) 0.05 % Opht Dropperette rxcui:448774 type:extracted
# for med_name:RESTASIS num rxcui:7 out of 39
# r:{
#   "responseHeader":{
#     "status":400,
#     "QTime":0,
#     "params":{
#       "json":"{\"sort\": \"score desc\", \"query\": \"RESTASIS\", \"fl\": \"*,score\"}"}},
#   "error":{
#     "metadata":[
#       "error-class","org.apache.solr.common.SolrException",
#       "root-error-class","org.apache.solr.common.SolrException"],
#     "msg":"Unknown top-level key in JSON request : fl",
#     "code":400}}
#
# processing med_name:TRIANEX
# med_name[0]:TRIANEX
# name:TRIANEX rxcui:00245013617 type:extracted
# name:TRIANEX rxcui:1110806 type:inferred
# for med_name:TRIANEX num rxcui:2 out of 2
# r:{
#   "responseHeader":{
#     "status":400,
#     "QTime":0,
#     "params":{
#       "json":"{\"sort\": \"score desc\", \"query\": \"TRIANEX\", \"fl\": \"*,score\"}"}},
#   "error":{
#     "metadata":[
#       "error-class","org.apache.solr.common.SolrException",
#       "root-error-class","org.apache.solr.common.SolrException"],
#     "msg":"Unknown top-level key in JSON request : fl",
#     "code":400}}
#
# processing med_name:NUVARING VAGINAL RING
# med_name[0]:NUVARING VAGINAL RING
# name:NUVARING VAGINAL RING rxcui:00052027303 type:extracted
# name:NUVARING VAGINAL RING rxcui:1367439 type:inferred
# for med_name:NUVARING VAGINAL RING num rxcui:2 out of 2
# r:{
#   "responseHeader":{
#     "status":400,
#     "QTime":0,
#     "params":{
#       "json":"{\"sort\": \"score desc\", \"query\": \"NUVARING VAGINAL RING\", \"fl\": \"*,score\"}"}},
#   "error":{
#     "metadata":[
#       "error-class","org.apache.solr.common.SolrException",
#       "root-error-class","org.apache.solr.common.SolrException"],
#     "msg":"Unknown top-level key in JSON request : fl",
#     "code":400}}
#
# processing med_name:RELPAX
# med_name[0]:RELPAX
# name:RELPAX rxcui:00049233045 type:extracted
# name:RELPAX rxcui:404443 type:inferred
# name:RELPAX 40 mg tablet rxcui:null type:extracted
# name:RELPAX 40 mg tablet rxcui:404444 type:extracted
# name:RELPAX 40 mg tablet rxcui:0049-2340-45 type:extracted
# name:RELPAX 40 mg tablet rxcui:448260 type:extracted
# name:RELPAX 40 MG PO tablet rxcui:null type:extracted
# name:RELPAX 40 MG PO tablet rxcui:404444 type:extracted
# name:RELPAX 40 MG PO tablet rxcui:0049-2340-05 type:extracted
# name:RELPAX 40 MG PO tablet rxcui:80051 type:extracted
# name:RELPAX 40 MG PO tablet rxcui:67406025100340 type:extracted
# name:RELPAX 40 MG PO tablet rxcui:80051 type:extracted
# name:RELPAX rxcui:00049234045 type:extracted
# name:RELPAX rxcui:404444 type:inferred
# name:Eletriptan Hydrobromide (RELPAX) 40 MG OR TABS rxcui:null type:extracted
# name:Eletriptan Hydrobromide (RELPAX) 40 MG OR TABS rxcui:404444 type:extracted
# name:Eletriptan Hydrobromide (RELPAX) 40 MG OR TABS rxcui:0049-2340-45 type:extracted
# name:Eletriptan Hydrobromide (RELPAX) 40 MG OR TABS rxcui:80051 type:extracted
# name:Eletriptan Hydrobromide (RELPAX) 40 MG OR TABS rxcui:67406025100340 type:extracted
# name:Eletriptan Hydrobromide (RELPAX) 40 MG OR TABS rxcui:80051 type:extracted
# for med_name:RELPAX num rxcui:10 out of 20
# r:{
#   "responseHeader":{
#     "status":400,
#     "QTime":0,
#     "params":{
# ...
#       "root-error-class","org.apache.solr.common.SolrException"],
#     "msg":"Unknown top-level key in JSON request : fl",
#     "code":400}}
#
# processing med_name:Simvastatin 40 Mg Oral Tab
# med_name[0]:Simvastatin 40 Mg Oral Tab
# name:Simvastatin 40 Mg Oral Tab rxcui:198211 type:extracted
# name:Simvastatin 40 Mg Oral Tab rxcui:51079-456-01 type:extracted
# name:Simvastatin 40 Mg Oral Tab rxcui:209275 type:extracted
# name:Simvastatin 40 Mg Oral Tab rxcui:198211 type:extracted
# name:Simvastatin 40 Mg Oral Tab rxcui:51079-456-01 type:extracted
# name:Simvastatin 40 Mg Oral Tab rxcui:209275 type:extracted
# name:Simvastatin 40 Mg Oral Tab rxcui:198211 type:extracted
# name:Simvastatin 40 Mg Oral Tab rxcui:51079-456-01 type:extracted
# name:Simvastatin 40 Mg Oral Tab rxcui:209275 type:extracted
# name:Simvastatin 40 Mg Oral Tab rxcui:198211 type:extracted
# name:Simvastatin 40 Mg Oral Tab rxcui:51079-456-01 type:extracted
# name:Simvastatin 40 Mg Oral Tab rxcui:209275 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:198211 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:d00746 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:15767 type:extracted
# name:Simvastatin 40 MG Oral Tablet rxcui:152923 type:extracted
# name:Simvastatin 40 Mg Oral Tab rxcui:198211 type:extracted
# name:Simvastatin 40 Mg Oral Tab rxcui:0093-7155-10 type:extracted
# name:Simvastatin 40 Mg Oral Tab rxcui:209275 type:extracted
# name:Simvastatin 40 Mg Oral Tab rxcui:198211 type:extracted
# name:Simvastatin 40 Mg Oral Tab rxcui:0093-7155-10 type:extracted
# name:Simvastatin 40 Mg Oral Tab rxcui:209275 type:extracted
# name:Simvastatin 40 Mg Oral Tab rxcui:198211 type:extracted
# name:Simvastatin 40 Mg Oral Tab rxcui:51079-456-01 type:extracted
# name:Simvastatin 40 Mg Oral Tab rxcui:209275 type:extracted
# name:Simvastatin 40 Mg Oral Tab rxcui:198211 type:extracted
# name:Simvastatin 40 Mg Oral Tab rxcui:51079-456-01 type:extracted
# name:Simvastatin 40 Mg Oral Tab rxcui:209275 type:extracted
# for med_name:Simvastatin 40 Mg Oral Tab num rxcui:7 out of 148
# r:{
#   "responseHeader":{
#     "status":400,
#     "QTime":0,
#     "params":{
#       "json":"{\"sort\": \"score desc\", \"query\": \"Simvastatin 40 Mg Oral Tab\", \"fl\": \"*,score\"}"}},
#   "error":{
#     "metadata":[
#       "error-class","org.apache.solr.common.SolrException",
#       "root-error-class","org.apache.solr.common.SolrException"],
#     "msg":"Unknown top-level key in JSON request : fl",
#     "code":400}}
#
# processing med_name:Allopurinol 300 Mg Oral Tab
# med_name[0]:Allopurinol 300 Mg Oral Tab
# name:Allopurinol 300 Mg Oral Tab rxcui:197320 type:extracted
# name:Allopurinol 300 Mg Oral Tab rxcui:54868-0076-3 type:extracted
# name:Allopurinol 300 Mg Oral Tab rxcui:266145 type:extracted
# name:Allopurinol 300 Mg Oral Tab rxcui:197320 type:extracted
# name:Allopurinol 300 Mg Oral Tab rxcui:54868-0076-3 type:extracted
# name:Allopurinol 300 Mg Oral Tab rxcui:266145 type:extracted
# for med_name:Allopurinol 300 Mg Oral Tab num rxcui:3 out of 6
# r:{
#   "responseHeader":{
#     "status":400,
#     "QTime":0,
#     "params":{
#       "json":"{\"sort\": \"score desc\", \"query\": \"Allopurinol 300 Mg Oral Tab\", \"fl\": \"*,score\"}"}},
#   "error":{
#     "metadata":[
#       "error-class","org.apache.solr.common.SolrException",
#       "root-error-class","org.apache.solr.common.SolrException"],
#     "msg":"Unknown top-level key in JSON request : fl",
#     "code":400}}
#
# processing med_name:Labetalol 100 Mg Oral Tab
# med_name[0]:Labetalol 100 Mg Oral Tab
# name:Labetalol 100 Mg Oral Tab rxcui:896758 type:extracted
# name:Labetalol 100 Mg Oral Tab rxcui:0185-0010-05 type:extracted
# name:Labetalol 100 Mg Oral Tab rxcui:279341 type:extracted
# name:Labetalol 100 Mg Oral Tab rxcui:896758 type:extracted
# name:Labetalol 100 Mg Oral Tab rxcui:0185-0010-05 type:extracted
# name:Labetalol 100 Mg Oral Tab rxcui:279341 type:extracted
# name:Labetalol 100 Mg Oral Tab rxcui:896758 type:extracted
# name:Labetalol 100 Mg Oral Tab rxcui:0185-0010-05 type:extracted
# name:Labetalol 100 Mg Oral Tab rxcui:279341 type:extracted
# name:Labetalol 100 Mg Oral Tab rxcui:896758 type:extracted
# name:Labetalol 100 Mg Oral Tab rxcui:0185-0010-05 type:extracted
# name:Labetalol 100 Mg Oral Tab rxcui:279341 type:extracted
# for med_name:Labetalol 100 Mg Oral Tab num rxcui:3 out of 12
# Traceback (most recent call last):
#   File "/Users/dc/anaconda/lib/python2.7/site-packages/IPython/core/ultratb.py", line 970, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/dc/anaconda/lib/python2.7/site-packages/IPython/core/ultratb.py", line 233, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/dc/anaconda/lib/python2.7/site-packages/IPython/core/ultratb.py", line 267, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/dc/anaconda/lib/python2.7/inspect.py", line 1049, in getinnerframes
#     framelist.append((tb.tb_frame,) + getframeinfo(tb, context))
#   File "/Users/dc/anaconda/lib/python2.7/inspect.py", line 1009, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/dc/anaconda/lib/python2.7/inspect.py", line 454, in getsourcefile
#     if hasattr(getmodule(object, filename), '__loader__'):
#   File "/Users/dc/anaconda/lib/python2.7/inspect.py", line 490, in getmodule
#     for modname, module in sys.modules.items():
# KeyboardInterrupt
# ERROR: Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
#
# Unfortunately, your original traceback can not be constructed.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/dc/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_code(self, code_obj, result)
#    3081             if result is not None:
#    3082                 result.error_in_exec = sys.exc_info()[1]
# -> 3083             self.showtraceback()
#    3084         else:
#    3085             outflag = 0
#
# /Users/dc/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in showtraceback(self, exc_tuple, filename, tb_offset, exception_only)
#    1878                     except Exception:
#    1879                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 1880                                             value, tb, tb_offset=tb_offset)
#    1881
#    1882                     self._showtraceback(etype, value, stb)
#
# /Users/dc/anaconda/lib/python2.7/site-packages/IPython/core/ultratb.pyc in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1240         self.tb = tb
#    1241         return FormattedTB.structured_traceback(
# -> 1242             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1243
#    1244
#
# /Users/dc/anaconda/lib/python2.7/site-packages/IPython/core/ultratb.pyc in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1148             # Verbose modes need a full traceback
#    1149             return VerboseTB.structured_traceback(
# -> 1150                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1151             )
#    1152         else:
#
# /Users/dc/anaconda/lib/python2.7/site-packages/IPython/core/ultratb.pyc in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1000
#    1001         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1002                                                                tb_offset)
#    1003
#    1004         colors = self.Colors  # just a shorthand + quicker name lookup
#
# /Users/dc/anaconda/lib/python2.7/site-packages/IPython/core/ultratb.pyc in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#     949         records = self.get_records(etb, number_of_lines_of_context, tb_offset)
#     950
# --> 951         frames = self.format_records(records)
#     952         if records is None:
#     953             return ""
#
# /Users/dc/anaconda/lib/python2.7/site-packages/IPython/core/ultratb.pyc in format_records(self, records)
#     722
#     723         abspath = os.path.abspath
# --> 724         for frame, file, lnum, func, lines, index in records:
#     725             #print '*** record:',file,lnum,func,lines,index  # dbg
#     726             if not file:
#
# TypeError: 'NoneType' object is not iterable
