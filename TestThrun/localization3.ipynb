# %%
# The function localize takes the following arguments:
#
# colors:
#        2D list, each entry either 'R' (for red cell) or 'G' (for green cell)
#
# measurements:
#        list of measurements taken by the robot, each entry either 'R' or 'G'
#
# motions:
#        list of actions taken by the robot, each entry of the form [dy,dx],
#        where dx refers to the change in the x-direction (positive meaning
#        movement to the right) and dy refers to the change in the y-direction
#        (positive meaning movement downward)
#        NOTE: the *first* coordinate is change in y; the *second* coordinate is
#              change in x
#
# sensor_right:
#        float between 0 and 1, giving the probability that any given
#        measurement is correct; the probability that the measurement is
#        incorrect is 1-sensor_right
#
# p_move:
#        float between 0 and 1, giving the probability that any given movement
#        command takes place; the probability that the movement command fails
#        (and the robot remains still) is 1-p_move; the robot will NOT overshoot
#        its destination in this exercise
#
# The function should RETURN (not just show or print) a 2D list (of the same
# dimensions as colors) that gives the probabilities that the robot occupies
# each cell in the world.
#
# Compute the probabilities by assuming the robot initially has a uniform
# probability of being in any cell.
#
# Also assume that at each step, the robot:
# 1) first makes a movement,
# 2) then takes a measurement.
#
# Motion:
#  [0,0] - stay
#  [0,1] - right
#  [0,-1] - left
#  [1,0] - down
#  [-1,0] - up    


def localize(colors,measurements,motions,sensor_right,p_move):
    # initializes p to a uniform distribution over a grid of the same dimensions as colors
    # why so complicated? 1/#cells in matrix = 1/20 = .05 in each cell. 
    pinit = 1.0 / float(len(colors)) / float(len(colors[0]))
    p = [[pinit for row in range(len(colors[0]))] for col in range(len(colors))]
    #make movement
    for x in range(len(motions)):
        move(p,motions[x],p_move)
        #measure
        print "before measure----------------------"
        show(p)
        print "------------------------------------"
        measure(p,measurements[x],sensor_right)
        print "after measure-----------------------"
        show(p)
        print "end---------------------------------"
    return p


def measure(p,measurement, sensor_right):
    """
    unclear how this works. 
    1) if measurement==color in color matrix, multiply p at that spot by .7
    else multiply by .3. kinda screwy if all the G are multiplied by sensor_right. things shouldnt work this
    way. only one value should be multiplied by sensor_right. that isnt the way we defined the problem tho. 
    2)normalize after each measurement. 
    """
    print "measurement", measurement
    for rows in range(len(colors)):
        for cols in range(len(colors[0])):
            print "(rows,cols):",(rows,cols), "procssing color:", colors[rows][cols]
    return p


def move(p, m,p_move):
    """
    multiply all cells by .3 if not moved cell, else .7
    """
    currentPos=(0,0)
    currentPos = currentPos[1] + m[0], currentPos[0]+m[1]
    print "processing motion:", m , "currentPos:", currentPos
    for row in range(len(p)):
        for col in range(len(p[0])):
            print " processing row,col:",row,col, "currentPos:", currentPos
            if currentPos[0]==row and currentPos[1] ==col:
                print "equal"
                p[row][col] = p[row][col]*p_move
            else:
                p[row][col] = p[row][col]*(1-p_move)
    #normalize
    sumElements = sumMatrix(p)
    for row in range(len(p[0])):
        for col in range(len(p)):
            p[row][col] = p[row][col]/sumElements
    return p

def sumMatrix(x):
    """
    assumes input 2d array
    """
    return sum(map(sum,x))

def show(p):
    rows = ['[' + ','.join(map(lambda x: '{0:.5f}'.format(x),r)) + ']' for r in p]
    print '[' + ',\n '.join(rows) + ']'
    
#############################################################
# For the following test case, your output should be 
# [[0.01105, 0.02464, 0.06799, 0.04472, 0.02465],
#  [0.00715, 0.01017, 0.08696, 0.07988, 0.00935],
#  [0.00739, 0.00894, 0.11272, 0.35350, 0.04065],
#  [0.00910, 0.00715, 0.01434, 0.04313, 0.03642]]
# (within a tolerance of +/- 0.001 for each entry)

colors = [['R','G','G','R','R'],
          ['R','R','G','R','R'],
          ['R','R','G','G','R'],
          ['R','R','R','R','R']]
measurements = ['G','G','G','G','G']
motions = [[0,0],[0,1],[1,0],[1,0],[0,1]]
p = localize(colors,measurements,motions,sensor_right = 0.7, p_move = 0.8)
show(p) # displays your answer
# Out:
# processing motion: [0, 0] currentPos: (0, 0)
#  processing row,col: 0 0 currentPos: (0, 0)
# equal
#  processing row,col: 0 1 currentPos: (0, 0)
#  processing row,col: 0 2 currentPos: (0, 0)
#  processing row,col: 0 3 currentPos: (0, 0)
#  processing row,col: 0 4 currentPos: (0, 0)
#  processing row,col: 1 0 currentPos: (0, 0)
#  processing row,col: 1 1 currentPos: (0, 0)
#  processing row,col: 1 2 currentPos: (0, 0)
#  processing row,col: 1 3 currentPos: (0, 0)
#  processing row,col: 1 4 currentPos: (0, 0)
#  processing row,col: 2 0 currentPos: (0, 0)
#  processing row,col: 2 1 currentPos: (0, 0)
#  processing row,col: 2 2 currentPos: (0, 0)
#  processing row,col: 2 3 currentPos: (0, 0)
#  processing row,col: 2 4 currentPos: (0, 0)
#  processing row,col: 3 0 currentPos: (0, 0)
#  processing row,col: 3 1 currentPos: (0, 0)
#  processing row,col: 3 2 currentPos: (0, 0)
#  processing row,col: 3 3 currentPos: (0, 0)
#  processing row,col: 3 4 currentPos: (0, 0)
# before measure----------------------
# [[0.04000,0.01000,0.01000,0.01000,0.01000],
#  [0.01000,0.01000,0.01000,0.01000,0.01000],
#  [0.01000,0.01000,0.01000,0.01000,0.01000],
#  [0.01000,0.01000,0.01000,0.01000,0.01000]]
# ------------------------------------
# measurement G
# (rows,cols): (0, 0) procssing color: R
# (rows,cols): (0, 1) procssing color: G
# (rows,cols): (0, 2) procssing color: G
# (rows,cols): (0, 3) procssing color: R
# (rows,cols): (0, 4) procssing color: R
# (rows,cols): (1, 0) procssing color: R
# (rows,cols): (1, 1) procssing color: R
# (rows,cols): (1, 2) procssing color: G
# (rows,cols): (1, 3) procssing color: R
# (rows,cols): (1, 4) procssing color: R
# (rows,cols): (2, 0) procssing color: R
# (rows,cols): (2, 1) procssing color: R
# (rows,cols): (2, 2) procssing color: G
# (rows,cols): (2, 3) procssing color: G
# (rows,cols): (2, 4) procssing color: R
# (rows,cols): (3, 0) procssing color: R
# (rows,cols): (3, 1) procssing color: R
# (rows,cols): (3, 2) procssing color: R
# (rows,cols): (3, 3) procssing color: R
# (rows,cols): (3, 4) procssing color: R
# after measure-----------------------
# [[0.04000,0.01000,0.01000,0.01000,0.01000],
#  [0.01000,0.01000,0.01000,0.01000,0.01000],
#  [0.01000,0.01000,0.01000,0.01000,0.01000],
#  [0.01000,0.01000,0.01000,0.01000,0.01000]]
# end---------------------------------
# processing motion: [0, 1] currentPos: (0, 1)
#  processing row,col: 0 0 currentPos: (0, 1)
#  processing row,col: 0 1 currentPos: (0, 1)
# equal
#  processing row,col: 0 2 currentPos: (0, 1)
#  processing row,col: 0 3 currentPos: (0, 1)
#  processing row,col: 0 4 currentPos: (0, 1)
#  processing row,col: 1 0 currentPos: (0, 1)
#  processing row,col: 1 1 currentPos: (0, 1)
#  processing row,col: 1 2 currentPos: (0, 1)
#  processing row,col: 1 3 currentPos: (0, 1)
#  processing row,col: 1 4 currentPos: (0, 1)
#  processing row,col: 2 0 currentPos: (0, 1)
#  processing row,col: 2 1 currentPos: (0, 1)
#  processing row,col: 2 2 currentPos: (0, 1)
#  processing row,col: 2 3 currentPos: (0, 1)
#  processing row,col: 2 4 currentPos: (0, 1)
#  processing row,col: 3 0 currentPos: (0, 1)
#  processing row,col: 3 1 currentPos: (0, 1)
#  processing row,col: 3 2 currentPos: (0, 1)
#  processing row,col: 3 3 currentPos: (0, 1)
#  processing row,col: 3 4 currentPos: (0, 1)
# before measure----------------------
# [[0.00800,0.00800,0.00200,0.00200,0.00200],
#  [0.00200,0.00200,0.00200,0.00200,0.00200],
#  [0.00200,0.00200,0.00200,0.00200,0.00200],
#  [0.00200,0.00200,0.00200,0.00200,0.00200]]
# ------------------------------------
# measurement G
# (rows,cols): (0, 0) procssing color: R
# (rows,cols): (0, 1) procssing color: G
# (rows,cols): (0, 2) procssing color: G
# (rows,cols): (0, 3) procssing color: R
# (rows,cols): (0, 4) procssing color: R
# (rows,cols): (1, 0) procssing color: R
# (rows,cols): (1, 1) procssing color: R
# (rows,cols): (1, 2) procssing color: G
# (rows,cols): (1, 3) procssing color: R
# (rows,cols): (1, 4) procssing color: R
# (rows,cols): (2, 0) procssing color: R
# (rows,cols): (2, 1) procssing color: R
# (rows,cols): (2, 2) procssing color: G
# (rows,cols): (2, 3) procssing color: G
# (rows,cols): (2, 4) procssing color: R
# (rows,cols): (3, 0) procssing color: R
# (rows,cols): (3, 1) procssing color: R
# (rows,cols): (3, 2) procssing color: R
# (rows,cols): (3, 3) procssing color: R
# (rows,cols): (3, 4) procssing color: R
# after measure-----------------------
# [[0.00800,0.00800,0.00200,0.00200,0.00200],
#  [0.00200,0.00200,0.00200,0.00200,0.00200],
#  [0.00200,0.00200,0.00200,0.00200,0.00200],
#  [0.00200,0.00200,0.00200,0.00200,0.00200]]
# end---------------------------------
# processing motion: [1, 0] currentPos: (1, 0)
#  processing row,col: 0 0 currentPos: (1, 0)
#  processing row,col: 0 1 currentPos: (1, 0)
#  processing row,col: 0 2 currentPos: (1, 0)
#  processing row,col: 0 3 currentPos: (1, 0)
#  processing row,col: 0 4 currentPos: (1, 0)
#  processing row,col: 1 0 currentPos: (1, 0)
# equal
#  processing row,col: 1 1 currentPos: (1, 0)
#  processing row,col: 1 2 currentPos: (1, 0)
#  processing row,col: 1 3 currentPos: (1, 0)
#  processing row,col: 1 4 currentPos: (1, 0)
#  processing row,col: 2 0 currentPos: (1, 0)
#  processing row,col: 2 1 currentPos: (1, 0)
#  processing row,col: 2 2 currentPos: (1, 0)
#  processing row,col: 2 3 currentPos: (1, 0)
#  processing row,col: 2 4 currentPos: (1, 0)
#  processing row,col: 3 0 currentPos: (1, 0)
#  processing row,col: 3 1 currentPos: (1, 0)
#  processing row,col: 3 2 currentPos: (1, 0)
#  processing row,col: 3 3 currentPos: (1, 0)
#  processing row,col: 3 4 currentPos: (1, 0)
# before measure----------------------
# [[0.00160,0.00160,0.00040,0.00040,0.00040],
#  [0.00160,0.00040,0.00040,0.00040,0.00040],
#  [0.00040,0.00040,0.00040,0.00040,0.00040],
#  [0.00040,0.00040,0.00040,0.00040,0.00040]]
# ------------------------------------
# measurement G
# (rows,cols): (0, 0) procssing color: R
# (rows,cols): (0, 1) procssing color: G
# (rows,cols): (0, 2) procssing color: G
# (rows,cols): (0, 3) procssing color: R
# (rows,cols): (0, 4) procssing color: R
# (rows,cols): (1, 0) procssing color: R
# (rows,cols): (1, 1) procssing color: R
# (rows,cols): (1, 2) procssing color: G
# (rows,cols): (1, 3) procssing color: R
# (rows,cols): (1, 4) procssing color: R
# (rows,cols): (2, 0) procssing color: R
# (rows,cols): (2, 1) procssing color: R
# (rows,cols): (2, 2) procssing color: G
# (rows,cols): (2, 3) procssing color: G
# (rows,cols): (2, 4) procssing color: R
# (rows,cols): (3, 0) procssing color: R
# (rows,cols): (3, 1) procssing color: R
# (rows,cols): (3, 2) procssing color: R
# (rows,cols): (3, 3) procssing color: R
# (rows,cols): (3, 4) procssing color: R
# after measure-----------------------
# [[0.00160,0.00160,0.00040,0.00040,0.00040],
#  [0.00160,0.00040,0.00040,0.00040,0.00040],
#  [0.00040,0.00040,0.00040,0.00040,0.00040],
#  [0.00040,0.00040,0.00040,0.00040,0.00040]]
# end---------------------------------
# processing motion: [1, 0] currentPos: (1, 0)
#  processing row,col: 0 0 currentPos: (1, 0)
#  processing row,col: 0 1 currentPos: (1, 0)
#  processing row,col: 0 2 currentPos: (1, 0)
#  processing row,col: 0 3 currentPos: (1, 0)
#  processing row,col: 0 4 currentPos: (1, 0)
#  processing row,col: 1 0 currentPos: (1, 0)
# equal
#  processing row,col: 1 1 currentPos: (1, 0)
#  processing row,col: 1 2 currentPos: (1, 0)
#  processing row,col: 1 3 currentPos: (1, 0)
#  processing row,col: 1 4 currentPos: (1, 0)
#  processing row,col: 2 0 currentPos: (1, 0)
#  processing row,col: 2 1 currentPos: (1, 0)
#  processing row,col: 2 2 currentPos: (1, 0)
#  processing row,col: 2 3 currentPos: (1, 0)
#  processing row,col: 2 4 currentPos: (1, 0)
#  processing row,col: 3 0 currentPos: (1, 0)
#  processing row,col: 3 1 currentPos: (1, 0)
#  processing row,col: 3 2 currentPos: (1, 0)
#  processing row,col: 3 3 currentPos: (1, 0)
#  processing row,col: 3 4 currentPos: (1, 0)
# before measure----------------------
# [[0.00032,0.00032,0.00008,0.00008,0.00008],
#  [0.00128,0.00008,0.00008,0.00008,0.00008],
#  [0.00008,0.00008,0.00008,0.00008,0.00008],
#  [0.00008,0.00008,0.00008,0.00008,0.00008]]
# ------------------------------------
# measurement G
# (rows,cols): (0, 0) procssing color: R
# (rows,cols): (0, 1) procssing color: G
# (rows,cols): (0, 2) procssing color: G
# (rows,cols): (0, 3) procssing color: R
# (rows,cols): (0, 4) procssing color: R
# (rows,cols): (1, 0) procssing color: R
# (rows,cols): (1, 1) procssing color: R
# (rows,cols): (1, 2) procssing color: G
# (rows,cols): (1, 3) procssing color: R
# (rows,cols): (1, 4) procssing color: R
# (rows,cols): (2, 0) procssing color: R
# (rows,cols): (2, 1) procssing color: R
# (rows,cols): (2, 2) procssing color: G
# (rows,cols): (2, 3) procssing color: G
# (rows,cols): (2, 4) procssing color: R
# (rows,cols): (3, 0) procssing color: R
# (rows,cols): (3, 1) procssing color: R
# (rows,cols): (3, 2) procssing color: R
# (rows,cols): (3, 3) procssing color: R
# (rows,cols): (3, 4) procssing color: R
# after measure-----------------------
# [[0.00032,0.00032,0.00008,0.00008,0.00008],
#  [0.00128,0.00008,0.00008,0.00008,0.00008],
#  [0.00008,0.00008,0.00008,0.00008,0.00008],
#  [0.00008,0.00008,0.00008,0.00008,0.00008]]
# end---------------------------------
# processing motion: [0, 1] currentPos: (0, 1)
#  processing row,col: 0 0 currentPos: (0, 1)
#  processing row,col: 0 1 currentPos: (0, 1)
# equal
#  processing row,col: 0 2 currentPos: (0, 1)
#  processing row,col: 0 3 currentPos: (0, 1)
#  processing row,col: 0 4 currentPos: (0, 1)
#  processing row,col: 1 0 currentPos: (0, 1)
#  processing row,col: 1 1 currentPos: (0, 1)
#  processing row,col: 1 2 currentPos: (0, 1)
#  processing row,col: 1 3 currentPos: (0, 1)
#  processing row,col: 1 4 currentPos: (0, 1)
#  processing row,col: 2 0 currentPos: (0, 1)
#  processing row,col: 2 1 currentPos: (0, 1)
#  processing row,col: 2 2 currentPos: (0, 1)
#  processing row,col: 2 3 currentPos: (0, 1)
#  processing row,col: 2 4 currentPos: (0, 1)
#  processing row,col: 3 0 currentPos: (0, 1)
#  processing row,col: 3 1 currentPos: (0, 1)
#  processing row,col: 3 2 currentPos: (0, 1)
#  processing row,col: 3 3 currentPos: (0, 1)
#  processing row,col: 3 4 currentPos: (0, 1)
# before measure----------------------
# [[0.00006,0.00026,0.00002,0.00002,0.00002],
#  [0.00026,0.00002,0.00002,0.00002,0.00002],
#  [0.00002,0.00002,0.00002,0.00002,0.00002],
#  [0.00002,0.00002,0.00002,0.00002,0.00002]]
# ------------------------------------
# measurement G
# (rows,cols): (0, 0) procssing color: R
# (rows,cols): (0, 1) procssing color: G
# (rows,cols): (0, 2) procssing color: G
# (rows,cols): (0, 3) procssing color: R
# (rows,cols): (0, 4) procssing color: R
# (rows,cols): (1, 0) procssing color: R
# (rows,cols): (1, 1) procssing color: R
# (rows,cols): (1, 2) procssing color: G
# (rows,cols): (1, 3) procssing color: R
# (rows,cols): (1, 4) procssing color: R
# (rows,cols): (2, 0) procssing color: R
# (rows,cols): (2, 1) procssing color: R
# (rows,cols): (2, 2) procssing color: G
# (rows,cols): (2, 3) procssing color: G
# (rows,cols): (2, 4) procssing color: R
# (rows,cols): (3, 0) procssing color: R
# (rows,cols): (3, 1) procssing color: R
# (rows,cols): (3, 2) procssing color: R
# (rows,cols): (3, 3) procssing color: R
# (rows,cols): (3, 4) procssing color: R
# after measure-----------------------
# [[0.00006,0.00026,0.00002,0.00002,0.00002],
#  [0.00026,0.00002,0.00002,0.00002,0.00002],
#  [0.00002,0.00002,0.00002,0.00002,0.00002],
#  [0.00002,0.00002,0.00002,0.00002,0.00002]]
# end---------------------------------
# [[0.00006,0.00026,0.00002,0.00002,0.00002],
#  [0.00026,0.00002,0.00002,0.00002,0.00002],
#  [0.00002,0.00002,0.00002,0.00002,0.00002],
#  [0.00002,0.00002,0.00002,0.00002,0.00002]]
